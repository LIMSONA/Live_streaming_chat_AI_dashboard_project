# %%
# conda install -c conda-forge jpype1==1.1
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - jpype1==1.1
#
# Current channels:
#
#   - https://conda.anaconda.org/conda-forge/linux-64
#   - https://conda.anaconda.org/conda-forge/noarch
#   - https://repo.anaconda.com/pkgs/main/linux-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/linux-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# conda install konlpy
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - konlpy
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/linux-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/linux-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
from konlpy.tag import Okt
from nltk.tokenize import word_tokenize
t = Okt()
Hann

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/adminuser/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# pip install konlpy 자바나 jpype 설치 필요없음
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 21.0 MB/s eta 0:00:01
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.3.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (449 kB)
#      |████████████████████████████████| 449 kB 75.0 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.6 in /anaconda/envs/new_azureml_py38/lib/python3.8/site-packages (from konlpy) (1.19.0)
# Collecting lxml>=4.1.0
#   Downloading lxml-4.8.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.9 MB)
#      |████████████████████████████████| 6.9 MB 74.5 MB/s eta 0:00:01
# Installing collected packages: JPype1, lxml, konlpy
# Successfully installed JPype1-1.3.0 konlpy-0.6.0 lxml-4.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
sentence_test = '''안녕하세요 저는 정다은 입니다. 
이건 코엔엘파이를 통해 형태소 분석과 품사 태깅을 하는 것입니다. 
잘 될런지 모르겠네요. 지금 너무 졸려서... 자고 싶은데... 내일 멘토링도 해야하고... ㅠㅠㅠㅠ'''

# %%
f = open('sample_file.txt', 'r')

# %%
sentence = f.read()

# %%
f.close()

# %%
print(sentence)
# Out:
# 우와!!
# 어머.. 진짜 뜯어서 보여주시니까 바로 믿을수 있을것 같아요!!!!
# 여름에 쓰기 좋겠어요!!
# 헐..ㅜㅜ 특가는 또 안하나요?ㅜㅜ
# 카시트에도 설치가능한거 볼 수 있나요?
# 저렇게테스트까지 아이가 여름에쉬원할것같네요
# 시원하겠다요!
# 통기성 좋네요
# 대박대박
# 구매했습니당
# 맘님들 혹시 신생아때도 써도 되나요?
# 여름아 기다려라 우린 준비됐다
# 저 선풍기 색깔 너무 예쁘다😍
# 오 쿨~~라이너 정말 시원할거같아요 대박 ㅎㅎㅎㅎ
# 어디든 호환가능한가요?
# 살랑살랑~~~
# 라이너 대박이네여
# 우리 아들이 열이 많아서 걱정이었는데 너무 좋아하겠네요
# 감사^^
# 여름에 땀띠 걱정 안해도 되겠네여
# 살균소독제 13900원 라이브가 맞는지확인해주세요 답변좀
# 기능성 제대로 보여주시네여^^
# 세재도 좋네요.
# 휴대용 유모차 쓸랴고 하는데 배게도 한번 붙야주세요융
# 여름에 통기 너무 중요해요~
# 하이체어에도 사용가능하네요.올~~
# 좋다좋다
# 활용도가 너무 좋네요
# 안그래도 쩍쩍 붙어서 신경쓰였는데
# 하이체어 특가 또 열어주세요ㅠㅠ
# 와우
# 1+1이네요ㅎㅎㅎ 역시 네러메 라방은 혜자네요~
# 배게까지 너무 귀여운 세트에요!
# 바닥에 깔린상품은 뭐에요??
# 벌써 더운거보니 이번여름 넘 덥겠어요ㅜㅜㅜㅜ
# 여름에아이가 아이스크림좋아하는데 원플원이라서좋네요
# 구매인증 어떻게 하나요?
# 선물용으로 구매해도 되겠네요
# 오~~~
# 낮잠 이불 구매할려고 들어왔어요 ^^
# 원플은 항상 좋아요ㅎ
# 낮잠이불
# ㅋㅋㅋ
# 귀쫑긋ㅎㅎㅎ
# ㅋㅋㅋ
# 히잉
# 낮잠이불도하나요
# 퀴즈 어려운거 싫어요ㅋㅋㅋ
# 퀴즈 어려운가봐요
# 바쁘다 바쁜 난주언니ㅋㅋ
# 낮잠이불 디자인 진짜 이쁘다
# 낮잠이불 가겯 할인듀ㅏㅆ나요????
# 2가지~~
# 낮잠이불 설명을 특히 열심히 들어야겠네요
# 어려우면ㅠ
# 일체형 분리형
# 퀴즈 쉬운걸로
# 분리형 일체형
# 부탁합니다
# ㅋㅋㅋ
# 수남할게 없는데 저거사면 공간 필요 없겠어요
# 바로 지르러 가봅니다ㅠㅠ
# 부엌도 진짜 은근 짐이 많아서 요래 딱 정리되니깐 너무 좋네요^^
# 진짜 완벽하네요
# 있어보여요 ㅎ
# 바다로 갑니다
# 고급졍
# 고급졍
# 왠지 이 구성 계속 있을 것 같지 않아소... 1달 고민했는데 질러봅니당....
# 얼굴보다 커요🤭 ㅋㅋ
# 산으로 들로 어디든 go go
# 너무 이쁘다 세트세트
# 어딜 그렇게 내려가세요
# ㅋㅋㅋ
# 같이가 ~~~~~!!!!!
# 같이가 ~~~~~!!!!!!
# 꾸안꾸느낌?
# 이왕이면 이쁜거♡
# ㅋㅋ 주방 용품 계 꾸안꾸
# 다 사고싶다 30만원두 안되네 대박
# 💥구매인증💥 2022042842480831
# 코도ㅋㅋㅋ
# 가 아니고 ~
# 오늘 작정하고 가져온 가격과 혜택이네요
# 우왕~~~~~~~~~
# 얼음 물 좋아요
# ㅋㅋㅋ 얼음
# 계곡물에 수박 넣는 느낌
# 맞아요 살려면 비싸요ㅋ
# 효율장인 보오글
# 목화솜으로 닦는 소중한 내얼굴 보오글이 챙겨준다네요
# ㅋㅋㅋㅋㅋㅋㅋㅋ
# 뜨거운 여름에 무쟈게 요긴할듯
# 진심 당장 떠나고 싶네요ㅋㅋ
# 충분하겄네요
# 💥구매인증💥 2022042842824531
# 삶의질이 수직상승 하겠어요
# 추카드려요♡
# 에잇 다음기회에
# 추카추카추카 치카포카
# 축하드려요
# 추카추카추카 치카포카🎉🎉🎉🎉🎉
# 축하드려요
# ㅋㅋㅋ 저도요
# 저도 지금 당장 떠나고 싶어요 ~
# 🛫
# 가정의 달이라
# 엄빠한테 선물해야게똬
# 플렉스 해보려!!
# 떠나자~~보오글과 함께ㅋㅋ
# 착 잘붙네여
# 수납미쳐따..
# 어~~반찬통
# 반찬통?!
# 맞아요 정리가ㅜ
# The Love..
# 와우
# 하지만 하나씩 쌓아야쥬
# 정리가잘되서좋네요
# 공간차지~~~~
# 수납 미쳤고 ㅠㅠ
# 정리 딱딱 지켜~~!
# 수납 미쳤고 지리고 레릿고 ㅠㅠ
# 오.. 근데 영상보니까
# 블랙도 너무 이쁘네요
# 공감공감🙋‍♀️
# 그냥 블랙으로 살까나..
# 깔끔~~굿
# 우와 교환이요?
# 등짝 조심
# 색상은 레드밖에 없나요?
# 5년??? ㅜ
# 색상은 블랙이랑 베이지랑 버건디 있어요~
# 건강을 위해선 그래야줘
# 안녕하세요~
# 난 얼마나썼드라….
# 마자욬ㅋㅋㅋ 코팅 벗겨져도 그냥 써 ㅠㅠ
# 크 넘 늦게 온건 아니져?!
# 네 넘 늦게 들어오셨어요
# 👍👍👍
# 10분 밖에 안남았어요!
# 그러니 빠르게 구매해야쥬
# 또 언제 실시간방송 하는지요
# ㅠㅠ반성중
# 제품 기대됩니다
# 잘볼께요
# 지구지키미 뽀오글!
# 구매고고
# 네넹~~~ 기대됩니다
# 앞치마 예쁘네요 ㅋㅋㅋ
# 😍😍😍😍😍
# 전이미 샀지용~~~~!!ㅋ
# 앞치마도 진짜 이뻐요♡
# 5월초 구입이가능해서요
# 가방있나요?
# 저번보다 더 할인 많이하네요ㅠㅠ
# 베이지도 이뻤는데 네이비도 고급져용
# 배아프다!!!!!!
# 캠핑가방!
# 맢치마도 버거요 ㅋ
# 우와 시간 후딱 가네요
# 뚜껑도 좋네요
# 비교해주시 이해가 가네요
# 앞치마 새로 나왔나여~~~?!!!
# ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 뚜껑 우와 진짜 예쁘네요
# 깨끗하당
# 얼굴이 잘보이네여
# 뚜껑 찐이에영
# 투명하다ㅋ
# 다음방송은 언제쯤일까요?
# 뚜껑 넘 좋아보이네요
# 중요하죠
# 코팅
# 징짜 편해요~~~~
# 우와
# 투명유리
# 사용기간은 어느정도 나요?
# 코팅 수명 끝나면 다 교환해쥼
# 잠만요 옵션 보고 온다 ㅋㅋㅋㅋ
# 전 투명이 젤 쏙 들어오네요ㅋㅋ
# 길이보려공
# 소재는 시원한가요?
# 데님 반바지랑 코디 가능한가요?
# 지연님 팔길어요?
# 두줄팔긴가오
# 왠지 난리난리인 느낌 ㅋㅋ
# 린넨 모자 빨리보고싶네용
# 제가 팔이 짧아오
# 오늘옷도 다이쁘네요 ㅎㅎ
# 사선 노랑vs보라 둘중 추천해주세요
# 사선민트 입어주세용~
# 아~~~ 고민!
# 지연님 팔길이유
# 아항
# 예쁘네요...어여 주문해야겠어요^^
# 주문했어요.ㅎ
# 지퍼 목까지 올리니 멋지네요
# 핑크랑 민트..
# 입으신 반바지는 오늘 라이브 방송상품인가요?
# 162이신가요??
# 신랑이랑 커플로 입으려고 주문했어요!!
# 저는 팔이 짧아우
# 없어지기전에 바로 구매했어요~^^
# 남자 177에 73키로 보통 100입는데 남자 맞을까요
# 반바지 오늘 방송할 거예요
# 사선 두개 추천해주세요~색~
# 사선 색상 추천해주세요
# 아들이랑 입으려고 민트랑 블랙샀어요~~
# 노랑 or 보라
# 아님 민트?ㅋ
# 남자 평균이 170이구나..ㅋㅋㅋㅋ장신이랑 살고있었네요 ㅋㅋ
# 두개사사 중딩아들이랑 나눠야겠네요
# 주머니도 생겼네요
# 다사고싶어요
# 신랑이랑 아침에 운동할때 입을려고 샀어요!
# 노랑이랑 두줄
# 두줄도입어봐주세요!!!!!
# 노랑이 절 나은듯요
# 배가 낄 듯하면 신랑은 지퍼를 입고 입으라고 해야겠어요 ㅋㅋㅋ
# 바람막이 바지 같이 구매했어요~초등 아이랑 같이 입으려고요~^^
# 더 이뻐지기 있음인가요~~
# 와 색 다 예쁘네요
# 이쁘다~~또 구매해야겠어요
# 초딩저학년아들은..ㅎㅎ 안될지...ㅎㅎ 노랑이랑 검정 두줄 주문했어요^^
# 초4학년 46키로 아이도 맞을까요
# 헐 이거 주머니도있네요? 지난번꺼 한개 불량이라 교환한다고 했는데 반품해도될까요? 이게 더 이쁘네요
# 또 뵈어요~~♡♡
# 아~~색깔 고민 머리 터져요 ㅜㅜ
# 오늘은 주영엠디님 오시니 방송이 들썩들썩~~^^
# 자꾸이뿐거올리지말아주세요ㅜㅜ ㅋ
# 다른 방송 소리가 들리는데요?
# 오 감사해요ㅋㅋ 이거 무슨색 사죠? 색 다이쁜데요?
# 남자는 두줄배색 추천인가요
# 즐거움 님 나갔다 다시 들어오시면 되요
# 저도 그럴때 있었어서요
# 이거 사이즈 지난번꺼보다 작은가요?
# 여러분 새고민되시면 대문대로 사시면 이뻐요
# 아직도 색상 고민중ㅜㅜㅡ
# 색
# 바람막이가 1+1 인거에요?
# 네 바막이요
# 2022042846750761 구매완료했어요
# 바지는 5부인가요?
# 노랑과 레터링블랙 샀네여~
# 색상선택 힘들었어요 ㅠ ㅠ
# 아들은 블랙 전 노랑노랑
# 색상추천해주세용~
# 롤업 데님은 몇번째로 보여주시나요?
# 색 다시보여주세요ㅜㅜ 마음이 급해요ㅋㅋ
# 데님 순서대로 입어봐주십니다
# 바지 배나온 초딩 입을수있겠죠?
# 노랑이랑 보라색 보여주세용 배색 되어있는거
# 사선은 노랑
# 구입완료했습니다~~~
# 뒷모습 보여주세요
# 두줄은 검정
# 비침 아이보리치고는 덜한듯요
# 저런 무늬있음 좀 덜하더라고요
# 허리 몇까지에요?
# 맞아요
# 연두
# 요핏 날씬하고 길어보여요
# 이바지 사이즈추천요
# 바지사이즈추천해주세오
# 보라스트라이프 니트로 샀어요ㅎ
# 66반까지일까
# 길이감이 차르르랑 같아요?
# 엄청낙낙하진않은거같은뎁
# 원뿔원이네요~
# 바지사이즈 추천
# 트리플진님 굿 보라니트 이뻐오
# 가격도 착한대 구성도 좋네요
# 바지 사이즈추천이오
# 똑똑똑
# ㅜㅜ😭
# 바지 허벅지 단면이 27.5네요
# 바지 사이즈요
# 근데바지는 입는거랑 달라오
# 전 가다릴수 있어요
# 넵
# 77까지 추천이오
# 눈이 침침해져 오지만
# 앗싸 77
# 바지허벅지 통도 낙낙한가오
# 차르르가 폭이 더 좁은거 같기도 하고 둘중 고민이네요
# 저 이거 기다렸어요 티셔츠
# 차르르랑은 상세페이지비교하셔야할거같아서 ㅜㅜ
# 바지 줄지가 더 날씬해보이더라구요
# 어제 상하도 찢으시더니
# 라임 😍
# 어제 참았는데 아른거리고
# 티셔츠 소재가 시원한가요?
# 소라요~~
# 차르르 바지랑 요 바지중 추천요 아이랑 블랙 살껄데요~~~
# 허벅지 있어서 덜 와이드 스러운거말고요
# 연두 차르르요
# 지연님 핑크 이쁘게 잘 받으시는것같아요
# 오호 넵~~^^
# 색상 추천좀해주세요^^
# 다리 군살이 티가 나더라구요 바지소재가 앏으면요
# 저도 허벅지 부자요
# 너무 얇은건 그래서 실패했나봐요
# 사이즈는 얼마까지 입을수 있나요?
# 77까지 가능합니다
# 숨쉬도 편할듯
# 여자쇼호스트님 컴포트 베이지 한번만 착용해봐주세요
# 20220428473843943
# 우와 좋네요
# 색상 베이지 구매했어요
# 사이즈 중형하면 되나요?
# 마스크 닥터스마일 쓰고 다른건 겁나서 못쓰겠어요. 피부자극 정말 없고 귀도 안아프고 좋아요.
# 우리 딸 kf80 블랙으로 주문 완료 2022042842664261
# 근데 베이지가 두개인데 차이가 있나요?다른제품인가요??
# 2022042842781692
# ㅋㅋㅋ
# 오천원 너무좋아요 ㅋㅋ
# 4개남았네요
# 소통 많이해야겠어요 ㅋㅋ
# 요새 무료배송 없단데
# 좋아요
# ㅎㅎㅎ
# 할인율 어마어마하다
# 할인율이 잘난아니다
# 할인할때 쟁여놔야죵~~~♡
# 마스크 색상 다 이쁨..
# 지금 프레시 착용하고 있습니다 컴포트랑 프레시 차이점이 뭔가요?
# 안녕하세요
# 마스크 추천좀 해주세요!!!
# 아이가 벗어서
# 힘들어요
# 불편하네요!!!
# 아이가 마스크 거부 하고있어요
# 자외선 차단되니여??
# 물청소는 물얼마에 한번 넣어줘야하나요?
# 걸레는 하나만 주시나요?
# 아아
# 아! 두장이군요
# 역시
# 물 채워야할때 알려주나요?
# 사은품 머 머 주시나여?
# 좋아요
# 방금 들어와서
# 5월1일에 ㅅㅏ야만이 먼지통 주는건가요?
# 공기청정기는 집에 있는데 ㅠ
# 좋아요
# 구매했는뎅
# 공기청정기는 끝났나염?ㅎ
# 좋아요
# 우와 좋아요
# 저도구매했는데 공기청정기?
# 오
# ㅎㅎㅎ
# 공기청정기 뭐주는건가여
# 아 저 방금 구매했늠데 라이브가 10만원 싸네요
# 오늘 12시에 구매했는데..
# 넵
# 이미 구매했는데...
# 1달지났어요,,,,ㅋㅋ
# 우아~~~~
# 어또케해!!
# ㅋㅋㅋㅋ
# 제가 엠지텍직원은 아니지만 동일가격대 성능은 트윈보스가 최고입니다 스펙비교해보고 저도 구매했네요.
# 안녕하세요
# 먼지통을 비워준다니 매력적인데요!
# 2022042842650091 구매인증합니다
# 말랑말랑 해보이네요
# 와 대박이네요
# 쇼호남님~~ 손가락 관리 해주고싶네요~~~
# ㅎㅎㅎㅎ
# 방수커버같은거있나요?
# 아기가오줌을....
# 편안해보이네요
# 좋은 핸드폰 ㅋㅋㅋㅋㅋ
# 응원 2022042842787171
# 선물하기로 구매해도 별도 신청 없이 핫앤쿨패드 증정 주나요?
# 좋네요
# 응원 2022042842607741 구입인증합니다기대중입니다
# 혜택좋군요
# 추첨은 언제하나요-?
# 굿
# 진행자분 고생 많으십니다~!
# 선물하기 구매완료
# 2022042842859751 구매인증요~
# 좋아요
# 대박대박!!!
# 대박!!!!
# 우와 하나도 안새네
# 패드 무게는 어떻게 되죠??? 그리고 제주 배송비는 얼마에요???
# 2022042842872001
# 라텍스랑 메모리폼차이는뭔가요?
# 방수되서너무좋네요~
# 방수기능 좋아요
# 지금쓰고있는것도 이건가??? 뭐죠?? 왜 더 좋아진 느낌이죠??? ㅋㅋㅋㅋㅋ
# 돌돌 말아서 보관 가능한가요?????
# 우왕
# 구매인증합니다. 2022042842920221
# 우리 둥이들 위해 구매했는데 정말 최고네요 뿌듯뿌듯
# 좋네요
# 오우~ 근육!!! 돋보였어요 ㅎㅎㅎㅎ
# 오호 ㅋㅋㅋㅋㅋ
# 유리컵 아래 뭐 붙어있는 거 아니죠??ㅋㅋㅋㅋ 좋네용♡♡♡♡
# 와
# 혜택 좋네여
# 선물하기로 구매는 어케하나요?? 라이브방송보면서 구매하니 선물하기는 안뜨던데..
# 2022042842951271 구매인증 완료
# 색선택하는거는커버색인가요?
# 반가워요
# 그럼 지금 구매한거 취소하고 선물하기로 구매 다시해도 될까요?
# 색선택하는거는어떤색을말하는거에요?
# 기대됩니다
# 잘볼께요
# 구매 고고
# 너무 좋네여
# 핫한 가격에 너무 잘 샀어요!
# 감사합니당
# 꿀잠 자야죠
# 럭스나인으로 꿀잠 보장해야죠
# 가격이 정말 좋네요~
# 2022042843127921 구매인증이요~!!
# 아기랑 바닥에서 잘껀데 추천해주세요 지금들어옴
# 엄마께 꿀잠 선물드려요~!!!
# 카푸치노 재료가 없군요 ㅎ
# 카푸취노 드시고 인자한 미소 :)
# 아이스아메리카노 촤고
# 그것이 힐링
# 이제 카페 갈 필요 없을 듯 ㅋㅋ
# 부머님 선물로 딱이네요
# 핫딜 또해용??
# 미리 어버이날 선물 고고~~
# 30분에 또한대요!!!! 기대기대
# 2만 핫딜 30분에 한데여 ㅋㅋㅋ 제꺼 하나 찜
# ㅋㅋㅋㅋㅋㅋㅋㅋ대박이네요 2만 넘어서 핫딜 한번 더 한대요! 11시 30분에!
# 핫딜 반복 구매 가능한건가요??
# 이번기회에 커피머신도 부모님 선물로 딱
# 손가락준비완료
# 안녕하세요
# 홈카페 인정~!!
# 아아아~~ 중복 이 안되는군요
# 아쉽당 ㅎㅎ
# 굿
# 한번만되나봐요ㅜ 아쉽
# 스터디카페에도 많이 보이는 기계입니다.
# Wow
# 1개만 구매가능한거죠?
# 샀어요~~~~~
# 드랍커피 사랑입니다
# 좋은 혜택 감사합니다(*☻-☻*)
# 이 커피원두 맛있더라구요
# 우유스팀까지 된다면 부드러운 실키폼 만들어서 카푸치노도 되겠네요
# ㅎㅎ
# 원두도 구매인증 가능한가요?
# 이게 실키폼인가요? 너무 부드러워 보입니다
# 조작법 너무 간단하네요!
# 드롱기 너무 좋네요
# 이지이지~
# ㅇ
# 용돈박스 대박 어버이날인뎅~~
# 좋아하시겟어여 ㅡㅋㅋㅋ
# 당첨발표는용?? 언제 해용??
# 컵 이뻐요 굿굿~~
# 좋아용
# 드롱기 커피머신 너무 고급스럽네요
# 진짜 완전 예쁜거 아니에요?!ㅎㅎㅎ
# 드롱기 가즈앗
# 아침마다 커피한잔 여유롭네요
# 세척 중요하죠..
# #🤎구매완료 2022042843050401
# #☕구매인증 2022042843050401
# 👍👍👍👍
# 고민하다 15b로 구매했어요~~
# 편리하겠어요
# 간단호네~~
# ㅋㅋㅋㅋ
# 드롱기 디자인이 질리지 않는 디자인
# 당황하셧움ㅋㅋㅋ
# 너무 깔끔해요 진짜 완전 맘에 들어요
# 만세~~~~~~~~~~``
# ㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 애기 키우는거같아
# 아니 언닠ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 범죄자삘인디
# ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 마네킹: 살려줘~~~~~~~~~
# ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 마네킹: 으아아아악~~~
# 지금입고계신 화이트 원피스 궁금해요
# 숙일 수 없는 마네킹이여 ~~~슬프다
# 팔빼여~~~ㅎ
# 홧팅
# 마네킹이랑 씨름해
# 언니 입어주심 앙대여? ㅜㅜ
# 온몸에 땀일듯 수고가 많아요
# 이뻐요~~
# 이뻐용
# 오프숄더
# 잘보여요
# 식사 했어요
# 벨로미 셔어링 원피스는 소매랑 몸판이 소재가 틀린가요
# 저는 오트밀빵이랑 번데기탕이요
# 핑크색 걸려있는거요
# 네
# 아 그렇군요^^
# 오픈숄더원피스 77가능한가요
# 이쁜데 아쉽네요
# 네~ 기다리고 있을게요^^
# 단추가 잘못 끼워졌어요.......
# 로브처럼 오픈해서 걸쳐도 멋스럽겠어요!
# 입으신거 연청이죠?
# 롱원피스 구매완료했어요~~기대됩니다
# 진청 한번 그냥 걸쳐봐주시겠어요?😊
# 좋아요
# 땡큐^^
# 진청으로 사놀까해서요ㅎ
# ㅎㅎㅎ 귀여운 요래언니 밴딩이니 미리 묶어놓고 어떻게 입으면 될듯요^^
# 66될것같아요~ 맨날이쁜거나와요
# 아까 민트바지 s입으셨던건가요?
# 네이비 티에 입으니 귀여워용
# s입으셨어요~~
# 답변감사합니다.
# 안녕하세요?^^트위드 구매하신분들어떤색으로 결정하셨나요? 색이 다 예뻐서 고민중입니다 ㅎㅎ
# 이 원피스 임산부 가능할까요?
# 아까 반팔트위드.사이즈몇까지입어요??
# 오픈하고 77까지라고하신것같아요~
# 오이쁘다 원피스!!
# 언니 다른색두 입어봐주심 안대여?!!
# 원피스이쁘당
# 넵
# 베이지!!
# 둘다요ㄲ
# 트위드 검은 원피스위에 입으려는데 색상추천해주심안될까요
# 오렌지같은 베이지 !
# 선택장애..ㅜ
# 이쁘네여
# 트위드 자켓 아이보리 흰빛에 가까울까요 노란느낌에 가까울까요~? 상세사진이랑 라방한거랑 느낌이달라서요ㅎㅎ
# 이건 휘뚜루 마뚜루 시원하면서 웬지 꾸안꾸 느낌이네용^^
# 구김 많이 갈까요??
# 푸리 플라워 원피스 지나갔나요?
# 힛 감사합니당 ❤️ 역시 무슨색이든 다이뻐요 그럴줄알앗어
# 베이지색 가까이서 보여주세용!
# 아침에등원시킬때 훌러덩입기좋겠어요
# 에횽 일하면서 보려니 쉽지않네영ㅜㅋ
# 아~~~~역시
# 이쁠줄알앗으
# 진청찜했어요 ㅋ
# 뒷모습도 보여주세요~
# 밴딩이 탄탄한가보네요
# 봄에 비슷한 느낌 점프슈트사서 사고 싶은 마음 꾹꾹 누르고 있어요ㅠㅠㅠ
# 연청도 입어봐주시나요~?
# 가슴때문에 66안될듯해요
# 진청으로 그냥 하나 지를까요?
# 진청은 다른 느낌
# 이건 55반까지이쁘겠어요..
# 맞아요 !!!훨씬 루즈했어용
# 174면 바지길이 짧지는 안을까요? 롤업해서 입고 싶은데ㅠㅠ
# 진청 눈에확들어와요~ 이쁘다
# 진청 그냥 사버렸어요🤣🤣🤣🤣🤣🤣
# ㅋㅋ언니 뒷모습자세히 보고파요..
# 멋있어요❤❤
# 찌기님 ㅋㅋㅋㅋ대박
# 언니 연청에 흰색 반팔티셔츠입어주시믄안되요?
# 👍👍👍
# 버클은 무슨용도예요? ㅋㅋ
# 허리가 요기다 알려주는?ㅎㅎ
# 유파이브님ㅋㅋㅋㅋㅋ
# 밑단 내려서 한번 보여주세욧;)
# 봄 점프슈트 기준으로 보면 버클은 그냥 멋있으라고 있는 용도
# 진청이거 사야겠네 ㅋ 이쁘다진짜
# 유파이브님 ㅋㅋㅋㅋㅋㅋㅋ 제가 그걸 몰랐네요ㅎㅎㅎㅎㅎㅎㅎ
# 아하 ㅋㅋ
# 초코칩님 고민고민하지 마시고 지르십시요!!!!!!!
# 이건 뽕뺄옷 ~~~
# 고민끝 퍼플구매했어요!
# 티입고입어도 귀엽다요 ㅋㅋ
# 키때문에 바지 길이 맨날 스트레스ㅜㅜㅜㅜㅜㅜㅜㅜ
# 이건사야함 ㅋㅋ아른거려서 ㅋ
# 👍이뻐요!! 전 연청사야겟어요ㅎ
# 진청이 역시 👍
# 저 가슴이 작고 키 작아서 자라키즈에서도 자주 사용ㅋㅋㅋㅋ
# 이쁘다요~~~ 사이즈 때문에 고민이네요 ㅡㅡ
# 안녕하세요
# 반가워요
# 안녕하세요^^
# 와 이거 써봤는데 좋아요!!
# ㅋㅋ대박이다
# ㅋㅋ우와.. 진짜 대박..
# 코스트코 가서 과일야채 빵 다 넣어서 소분해서 보관 짱
# 한눈에 보이니 좋네여
# 디자인이 일단 좋네요
# 다이어크 할때 과일 싸다니기도 좋음
# 깔끔하고 예뻐서 주방에 놓으면 너무 잘어울릴거같아요 ㅠㅠ
# 대형은 진짜 넉넉해보여요
# ""
# ""
# ""
# ""
# ""
# ""
# ""
# ""
# ""
# ""
# ""
# ""
# 와 너무 이뿌다
# 그렇지요~
# 수공 하나 하나 단가 플러스~
# 와............. 언니 진짜 코디 너무 이뻐요
# 언니 너무 멋있어요. 포즈도, 분위기도
# 와 88까지 되는거면 진짜 좋당
# ><
# 구찌주머니?
# 오호
# 폴리랑 린넨인데
# 완전 세트같아용
# 오 싱기하당
# 목소리도 독특하시네요 😀
# 진청 점푸수투 너무 이뿻어용
# ㅎㅎㅎㅎㅎㅎ
# 점푸수트 화장실 가기 불편해서 안 사는데 요곤 꼭 사야되는 점푸수트~~
# 근데 너무 이쁨
# 언니가 입으니 엄청 이쁜 정비사 가툼
# 나는 일부러 차 끌고 가서 정비 받는다
# 저 언니라면
# 카센터 앞에서 차 고장내야지
# 헤헷
# 리본 잘 묶는것도 신기
# 저도 리본 묶으면 맨날 한쪽 꼬리 위로 ㅋㅋㅋㅋㅋㅋㅋ
# 라방 100번 봐야지
# 오 배웁니다
# 와 되게 쉽게 하신당
# 오오 오오오
# 싱기
# 전문가 포스~^^
# 잉 이뿽
# 언니 핑크는 진짜이뿜
# 과하지도 않고 너무 연하지도 않은데
# 비비드함은 똭 살림
# 사장님 뜬금없는 질문이지만 하트 누름 사장님께 좋나요~?
# 오 그래여 ?
# 하트 좋아여?
# 오~~~
# 글쿠나
# 오 막 눌러~~~~
# 마구 눌러~~~~~~~~~~~~~~`
# 눌러눌러~~~~~~~~~~`
# 크으
# ㅎㅎㅎㅎㅎ 마자
# 소통하려고 ㅎ 라방이쥬
# 라방의 매력
# 엄훠나 언니 딸이 초5 ???
# 엄췅 크구낭
# 아니 밖에 가면 미혼으로 보겟다요
# 저도 언니 당근 미혼이신줄 아라짜나여여엉
# 초록단가라 완전 이뻐용
# 스마일 디테일도 짱짱
# 저는 기장이 엉덮인게 너무 좋은듯
# 진짜, 잘못입으면 되게 죄수복같은데
# 저건 진짜 라인도 잘빠졋네용
# 마자 스마일이 뽀인뚜에용
# 빠삐용 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 티랑 바지 기계세탁해도 보풀안생길까여?
# 기대해요
# 네
# 반가워요
# 안녕하세요
# 안녕하세요
# 반갑습니다
# ""
# 방가방가
# 오오
# 안녕하세요
# ㅎㅇ
# 모든차종 다 사용가능한가요??
# 안녕하세요
# ㅎㅎ
# ""
# 울릉도죠!!
# 이거 울릉도산인가요?!!?!?
# 안녕하세요 ~~~
# 울룽도오징어!!
# 우아
# 통통한 오징어다
# 버터구이라니..
# 냄새 장난아니겟다..
# 너무 먹고싶어여~~~
# 대박!!!
# 재료가 좋으니
# 뭐든 완벽!!
# 우와
# 냄새 4D로 전해지는듯..
# 잘구워졌네욬ㅎㅋㅎㅋㅎ
# 와우....
# ㅋ당장먹고싪어요ㅠㅠㅠ
# 와 마른오징어아니고 반건조인가요??
# 대박
# 건조된 오징어는
# 너무 딱딱하기만해요ㅠㅠ
# 안냐세요
# 와 진짜 너무 맛잇겠어요..
# 오징어 반건조 찾아서 왔어요
# 마요네즈 간장 청양고추 조합이면 끝이야
# 지금이 오징어 철인가요??
# 청양고추 진짜
# 마요간장이 없어요??
# 간장하러가셧넹
# 조금 덜익어보이는데~~
# 오징어튀김도 할수잇고
# 이건 구매
# 계란물 - 밀가루 - 튀김가루 -튀기면되요 ㅎㅎ
# 요알못 😂
# 안녕하세요
# 오징어 맛잇겟
# 긴장하셧누~~~~
# ㅋㅋㅋㅋ
# 뭔가 팍 하고 튀었는데 ㅎㅎ
# 몸에 튀엇나바요
# 헐...
# 다치셧나보다 ㅠㅠ 조심하세요
# 아직멀엇어요 ㅋㅋ
# 약불로 5분은 튀겨야 먹을수잇어여 최소 ㅋㅋ
# 너무빠른데 다익은거 맞아요??
# 오오
# 빛깔이 장난아니네용
# 아!!진짜 떡볶이랑..
# 바쁜 집사한테 아주딱이다.딱
# 고급스럽네용ㅎㅎ
# 우와 고양이 화장실
# 고양이 진짠줄 알았너요
# 애옹이들한테 좋은것만 쓰게해줘야죠
# 마음으로 낳아서 지갑으로 키우기
# 냥이는 이미 내 자식이라 자식한테 쓰는 건 안아까우ㅎ
# ""
# 소리가 나나용?
# 있는지도 모르겠다ㅋㅋㅋ
# 오호
# 소리가 작어서 좋네유
# 소리 안나는데우?
# 안들린단 소움이 없네
# 진짜 도용하다
# 어머 작동 안한줄알았는데
# 움직인지도 몰랐어요
# 어디든 잘어울리네용
# 디자인이 이쁘요
# 맞아ㅠ 다치면 어떡해
# 오홍
# 감자 안캐고 집사는 버리기만하면되넹
# 화장실잘가고 물많이 먹게해서 방광염 복막염 조심해야해요 증말
# 맞아요ㅠㅠㅠㅍ 진짜ㅠ 조심조심
# 웹툰 귀여웡ㅎㅎ
# 와..버튼 기능들 대박편하겠따
# 쇼호스트님이 말을 너무 잘하세요
# 설명 기대해요ㅎㅎ
# 귀에 쏙쏙들어와요
# 똑똑한 기계
# 고양이 키우는 친구에게 알려줬어요 ㅎㅎ 전 이런 기계 첨 보네요!
# 소리가 안들려요
# 이제 소리나오네영!
# 퇴근하고 집안일하기 힘들쥬ㅠ
# 전면버튼 아이디어 굿
# 안녕하세요
# ""
# 귀걸이가 원래 이렇게 고급스러운 아이템이었나요
# 안녕하세요
# 물방울 모양 너무 고급지네요
# 쇼호님 얼굴도 은은하니 예쁘네요
# ""
# 이제품 좌욕기능도 있어요?
# 구매인증요 2022042846418371
# 2022042846401341 구매했어요
# 스파 기능 - 좌욕기능
# 2022042846386341 구매인증요
# 주문완료여 2022042846405561
# ㅋㅋ친절답변 담사해요
# 구매인증요 2022042846439351
# 와우 좋아요
# 100번째 안넘은거죠??
# 주문완료! 2022042846545141
# 2022042850679971 인증번호 채팅창인가요?
# 구매 망설이시는 분들....가격이 블루밍 구형 제품보다 더 좋아요. 쿠팡로켓에서 사려다가 이벤트보고
# 오~!좋아요!
# 기다려서 샀어요. 지금 질러요!
# 그런데 이 제품은 건조기능이 없는데 보통 사람들 건조기능 잘 안쓰나요? 제가 비데는 처음 구매하는거라 궁금하네요.
# ㅎㅎ
# 인증번호 어디에 적나요?
# 건조 기능 냄새 올라옵니다...
# 구매완료했습니당
# 구입했는데 100명에 들어갈까요? 따로 인증 해야 하나요?
# 구매완료 2022042846591031
# 사무실 일하다 놓칠까봐 알람설정해놓고 구매했습니다.
# 역시 혜택이 너무 좋네요..
# 비데
# 좋다
# 가격이 너무 맘에 들어요
# 기대만큼 가격도 넘 좋네요
# 지금 주문했어요
# 방가방가
# 구성이 너무 좋아보여요... 굿
# 절전모드랑 반영구필터 좋네요
# 자가설치 하는거져?
# 재주문했어요~2022042846682191
# 네 감사합니다 ^^
# 라이브 기다리다 드디어 결제했어요!
# 2022042846556751
# 좋아보이네요
# 사은품이 뭔가요??
# 기대합니다
# 기대합니다
# 제가 좀 덩치가 있는 편인데 착석감도 블루밍이 최고였어요. 가끔 너무 작거나 엉덩이가 올라가는 불편한 느낌의 제품이 있는데... 블루밍은 한국 사람 체형에도 정말 좋아요.
# 좋아보이네요
# 오오
# 앉는곳 사이즈는 1사이즈인가요?
# 구매했어요 ^^
# 리모컨 설치는 테이프인가요?
# 아직 선착순 안끝났죠~?
# 주문 완료했어요 2022042851194971
# 안녕하세요!!!!
# 코랄핑크가 나왔군요..
# 코랄핑크 화사하고 너무 이뻐요~!
# 네쇼하
# 마스크 기대됩니다
# 잘볼께요
# 구매 고고
# 와아
# 반갑습니다
# 오오
# 안녕하세요
# 좋네요
# 안녕하세요
# 잘볼께요
# 핑크 마스크 벚꽃컬러네요~
# ""
# 좋네요
# 마스크 색상 이쁘네요~
# 핑크는 처음보는거같네요 이뻐요
# 아이 마스크 컬러는요?
# 핑크 없나요?
# ""
# 오모낫..
# 저 곱슬머리 귀엽군!!
# ""
# 우와 스티커네요~
# 바주카포 버블건 사줬더니 베란다에서 계속 쏘대는 통에 민원에 시달렸네요!! 곱게 놀 수 있는 스티커류가 나은듯요!!
# 어른이도 놀고싶은 그런 스티커에요
# 띠부띠부 스티커 좋아요~
# 아이들이 1시간만 가지고 놀아줘도 값어치있는 제품^^
# ""
# 대박
# 진짜 이렇게 활용하면 너무 좋을것 같아요!!
# 와아 허니팁🍯
# 다양하게활용~
# 사탕도 구입할껄ㅜㅜ
# 저렴한가격에 좋은선물이 될거같아요 ~
# #구매인증 2022042847685871 얼른 보내주세요! 빨리 먹어보고싶어요^^
# 사탕은 유통기한 얼마나되여?
# 가격이 정말 착하네요!!
# 허브향이 좋아하시는 울엄마께서 또 찾으실것같아요 ~
# 품절이다
# 품절됐어요
# 재희님 방송은 하트 만개
# 빨리구매하길 잘했네요~
# ㅋㅋㅋㅋㅋㅋ
# 뭐여요~
# 가격이 착해요~
# 샤프란차 선물할려고 몇개 더 구매했어요~
# 고급지네요~
# 우와~^^ 감사합니다^^
# 축하드려요 단순이님
# 아 방금샀는데...ㅠ
# 사프란제품 처음으로 먹어보느거라 기대중이에요!!
# 저 오늘 완전 좋은 상품에 구매인증 경품까지 완전 대박입니다~^^
# 캔디는 2년인데 샤프란차는 유통기한이 어떻게되나요?
# 재희님이 있는 민생상회 대박나라
# 네~
# 오늘 제품 소개해주시느라 고생하셨어요!!
# 오늘 대박
# 방송 잘 봤습니다~^^
# 고생하셨어요~
# 2022042848903021구매내역
# 고생하셨어요^^
# 재희님이 예뻐서 사버렸다
# 어머어머
# 외국인들 얼굴호리호리
# 반가와여
# 반갑습니다~~
# 반가워요
# 안녕하세여 반가워요
# ㅋㅋㅋ
# 반가워요
# 안녕하세요
# 제품 기대됩니다
# 반가워여
# 잘볼께요
# 구매 고고
# 와 오늘 많은분들 오셨네요
# 방송 기다렸어요
# 호스트님도 이쁘시네요 ㅋㅋ
# 반갑습니다
# 반가어영\
# 오 무료배송좋당
# 숨랩은 숨쉬기 더 편안한가요?
# 좋아요
# 네에에에
# 오늘 마지막 4월 라방이군영
# 숨랩 마스크 알쥬알쥬
# 오 51%
# 귀가 칼국수끈이네요 좋다요 ㅎㅎ
# 할인51퍼센트
# 대박이네요
# 오홍~~~ 할인율 좋아용~
# 어?? 이제 라방 안해요?ㅠㅠ
# 위에 써주세요.. 나가지마시오 ㅋㅋ
# 룰렛ㅋㅋ우와
# 오오
# 대박 ㅋㅋㅋ
# 고정 댓글 해주셔야할듯요 ㅋㅋㅋㅋ 구매인증 남기시고 가세요~~~~ 하고 ㅎㅎㅎ
# 오오
# 룰렛 넘좋아요~~ 지난번 추가발송해주신것도 잘쓰고있습니당
# 구매왕~~
# ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 우와
# 오홍
# 구매왕
# 와~~
# 구매왕
# 오늘 혜택 듬뿍이네요~~~~
# 넘좋네요
# 넉넉한 구성이내여
# 할인율에.. 이벤트에~~ ㅎㅎ
# 구매왕은 많이 사시는분인가요? 아님 랜덤인가요?
# 진짜 ㅋㅋㅋ 쟁기는날
# 구매왕은 제일 많이사시는 1등이신듯용
# 그츄
# 이제 날이더워져서 ㅠㅠ 더 숨쉬기편한 마스크 급급
# 이에여
# 오....
# 은지님 오늘 너무 아름다우시네영 ~
# 대박이네요 와아
# 어제 마스크끼고 밖에 걸었다가.. 더위 먹을뻔 했어요 ㅠㅠ
# 넘 더운 ㅠㅠ
# 안녕하세요
# 기본 색상~~~
# 화이트 블랙~~
# 실내은동화를 하나 살려고 하는데 쿠션감은 어느정도 될까요???
# ""
# 날좀 내버려둬 ㅠㅠ
# ㅋㅋㅋ
# 바캉스
# 바캉스
# 바캉스
# 바캉스
# 바캉스
# 바캉스
# 바캉스
# 바캉스
# 바캉스
# 바캉스
# 바캉스
# 바캉스
# 바캉스
# 바캉스
# 바캉스
# 바캉스
# 일욜 제주 갑니두
# 키.몸무게는 모르는데...18개월이면 S사이즈 하면 될까요??
# 바캉스
# 짜잔!
# 할인쿠폰은 없는거죠?
# 바캉스
# 바캉스??
# 바캉스
# 근데 10갤 아기랑 여행이 과연 바캉스가 될지 모르겟어요
# ㅋㅋㅋㅋ
# 바캉스
# 늦었네요 ㅋㅋ
# 모두 두손모아 기원해요 ㅋㅋ 오늘배송 된다고 문자왔어요 ㅎㅎ
# 또르륵 🥲
# 토욜입힐려고 26일 주문했는데ㅠㅠ 쫌더 걸릴거같다고 톡왔어용
# 저도 껴줘옄ㅋㅋ
# 사장님! 바캉스 상하 여유있게 나왔나요??
# 헤헿
# 넵 ㅎㅎ
# 넹
# 여기 있어요 ㅋ
# 저애기 S 사서 레깅스랑 입혀서 엄마랑 세트로 입을라구여 ㅋㅋㅋ 비슷한옷잇어서
# 와!
# 기다렸어요!
# 안녕하세요~
# ""
# 촬영중 잠깐 응원왔어요💕💕
# 안녕하세요~~^^
# 안뇽하세용 ㅎ
# 소리잘들려용
# 잘들려요ㅎㅎ
# ""
# 눈알 못참치
# 이뿌당
# 크 저는 하얀게 더 이뿌네용
# 밝아야 딱 눈에 띄는 느낌
# 머리가 검은색이자나여
# 와
# 고급져
# 언니 머리숱 대빵 많아보임
# ㄷㄷㄷㄷ
# 이뻐..
# 고급짐
# 제품이름이 뭐에요?
# 언니의 해시태그
# 견고함
# 어머 저거 이뿌당
# 압화
# 디저트같아요
# 그 보석 사탕?
# 코하쿠토!!
# 실시간 먹방 전환ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 우왕 네일 너무 이뿌당
# 귀걸이 너무 귀여운데여?
# 우와 대박이뻐
# 귀에 봄이 앉았어용
# 리본 달랑달랑 이뿌당
# 까만 리본도 매력있네용
# 이뿌당 ~
# 안녕하세요
# 와 민트 완전 이뿌다
# 대박
# 진짜 고급진 귀걸이라인인디
# 가격 실화?
# 언니 너무 이뿐 템들 잘 가져오셧어용
# 크~ 귀기울이게 된당
# 기여어
# 이거 국내산인가요?ㅎ
# 직접 만든건가봐요 ㅎ
# 와 견고해
# 좋아요
# 찾긴 뭘 찾아봐요 뚱뚱한 계란말이쥬ㅋㅋ
# 통에 꽉찼네욬
# 와우 ㅋㅋㅊㅋㅊㅋㅊㅋ
# 이제운빨이있네요ㅋㅋㅋ
# 가정의달 생각을 못하고 펑펑 돈썼쥬 😅
# 오늘따라 고생하시네요 도이님 ㅋㅋ
# 오늘시킴 이번주배송되요?
# 윽 토욜날먹구싶은더ㅈㅋㅈㅋㅋ 아쉽네요
# 진짜맛나게드시네유ㅋㅋㄱ
# 넉넉히 3일 배송기간 보면 될것같아요
# 헉 밥까지볶아두되요?ㅋㅋㅋ
# 대박 떡볶이네요
# 도이님 젖가락탐나네요ㅋㅋㅋ
# 무조건 쟁여두세요!!!
# 집게 저두사야겠네요ㅋㅋㅋㅋㅋㅋ
# 여기도파시는거예요?ㅋㅋ
# 집게 구매하시고 여러번 씻어주셔야되세요!!
# ㅇㅋㅇㅋ 쿠팡 접수요
# 식용유>베이킹소다>세제>키친타올로 연마제?가 나오는지 확인하시면되요
# 수저.젓가락 끓는물에 소독까지 완료~!!저도 쿠팡에서 샀지요
# 얼마나 살을 빼시려고 곤약밥을 드세요~?!
# 안녕하세요
# 누나 오늘 칼로리 폭탄이라 돼지되겠어 ㅠ
# 이거 몇칼로리예요???ㅎㅎㅎ
# ㅋㅋㅋㅋㅋㅋㅋㅋ
# 오
# 모르는 맛이라 덜 고통스럽네요 ㅋㅋ
# 이거 국내산인가요? 미국산인가욯 ㅎㅎ
# 맛있겠다......오늘저녁메뉴
# 참치는 다이어트 ㅎ
# 물엿 떡볶이?
# 학교앞 떡뽁이
# 그럼 가격은 1000원인가요? ㅎ 일인분에
# 맞아여
# 김말이도 주나요/ ㅋ
# 급하게주문하느라 ㅋㅋ추가구매는어케하나요?
# 그럼 배송비가 다시붙어서 ㅜㅜ
# 헤헷 왓어용
# 따악 졸릴시간
# ㅎㅎㅎㅎ
# 커피 한잔 타와서
# 언니랑 수다떠는 느낌으로
# ㅎㅎ
# 저는 회의인데 .. ㅎ 몰래 ㅎ
# 목이랑 소매, 밑단 주름이 은근 이쁘네용
# 프릴인듯 아닌듯
# 이지룩
# 살짝 비침있는 게 더 포인트
# 조아조아
# 블랙도 보여주세요~
# 우왕 주름 1도 없어
# 안녕하세요
# 살짜쿵 비침있겠죠?
# 이너 입으면 되겠네요
# ㅋㅋ 맙아요
# 맞아요
# 77이면 ...1번 입으면 약간 붙겠죠??
# 네 ㅋㅋ 블랙 주문해보려고요 ㅎㅎ
# 라이브 혜택이 따로 있나요~?
# 네~
# 88도 가능할거같아용
# 아~~ 크림이 더 잘 어울리시네요~
# 와 블랙도 이쁜데요?
# 블락 주문했어요 ㅎㅎㅎ
# 저는 블랙파라서 ㅋㅋ
# 크림 핑크는 다욧하고 ㅡ ㅎㅎ
# ㅋㅋ 그럼 저는 옷 입어보고 추후 또 올께요~~
# 안녕하세요 😄
# 여러분 리틀마켓 가지마세요 소통이 전혀 안되는 방송입니다. 피해보시지말라고 얘기드려요.
# 잌ㅋㅋㅋㅋㅋㅋㅋㅋ
# 언니는, 밝은 옷은 우아해보이고, 진한 옷은 시크하면서 단아해보여요
# 어머 어머
# 이지룩 가디건
# 색 화사하니 이뿌네용
# 혹시 아랫쪽에 트임이있나요~?
# 트임없는게조아요 종아리튼실해서
# 종아리보톡스도 맞아야하나..
# 일단 상의 3개로 민센스옷 시작해보아요ㅎㅎ
# 러블리~~하당
# 혹시 아까 나시 소재가 폴리인가요~?
# 아까보여주신거 그거맞아용
# 네맞아요
# 안에 나시하나 더 입구 위에 자켓입으려구요
# 침을...ㅋㅋㅋㅋㅋ
# 깔별로사야돼요
# 여러개 구매합니다 잘 보내주세용
# 좋아요
# 오모
# 이뿌요
# 가디건생각없었는데. .
# 저는 저 나시안에 레이스덧대서 입을꺼에용
# 좀파인것같아서 살짝 가리기용으로ㅎㅎ
# 아...?그렇군요
# 저는 55반정도에요
# 넹
# 그래도 낙낙하게입을래요
# 안에 살짝가려서...ㅎ
# 입어주세요!!
# 아직 안했어요 장바구니에 담겨있어요ㅎ
# 엄청크구나ㅋㅋㅋ
# 저그러면 가디건으로 바꾸는걸로...
# 린넨바지 사이즈77가능할까요?
# 팔뚝이 통통한데 가디건 팔쪽 낙낙한가영?
# 자.. 이것도 칼라고민합니다...ㅎ
# 다음에도 시청할께요ㅎ
# 진짜 좋다
# 짱이다!!!!
# 윸회랑 국거리 구매완료!!
# 요즘 너무 땡겼는데 ㅠㅜㅠㅜㅠㅠ
# 맛나겟당
# 좋아보이네요
# 빨리 배송 해주세요!!!!
# 맛있따는걸 온몸으로 춤춰서 보여주면 좋을거같습니다
# 좋아보이네요
# 그만큼 맛있어 보입니다...
# 사야겠군요
# 기대합니다
# 기대합니다
# 저기압일수록 고기?
# 국거리는 어느 부위에요?
# 구성 너무 좋아요 ㅠㅜ할인률 대박
# 유진님 멘트 센스😁👍
# 오늘 완전 육회 땡겼는데 ㅠㅜㅜ구성좋다
# 맛있어보이네요
# 우아 좋네요!!
# 국거리 ????
# 브랜드 소개해주세요!!!
# 기대됩니다
# 대박!!!
# 진짜 맛있어 보이네요 진짜 대박!!!
# 우와
# 진짜
# 백십일 맞나요>>?저번에 먹은거 같은데
# 대박!!ㅋㅋㅋㅋㅋㅋ
# 구성 너무 좋아요 !!
# 백십일 기다리고 있었는데 !!!
# 국거리 양은 얼마나 될까요??
# 우아!!
# 보관은 언제 까지 가능인가요?
# 좋은 방송이다 진짜
# 귀여워요!!!
# 뭐랑 먹어야 맛있어요? 밥???
# 기대해요
# 기대해요
# 굿~
# 진짜 좋다><
# 캠핑갈때 들고가도 될까요?
# 와!!!!!
# 유통기한 알려주세요!!
# 방송 너무 잘하세요!!!
# 마시꼐따
# 당일생산 맞나요???
# 대박!
# 내가 먹어본 육회중에 여기 짱 좋아요!!
# 백십일 추천이요!!
# ㅋㅋㅋㅋ우앙
# 흥해라!!!!!!
# 넘 좋다 !!ㅎㅁㅎ
# 한우 맛있죠
# 국거리와 육회
# 하...짱이다!!!!
# 왜이렇게 좋나요!
# 한우~~~
# 요즘 캠핑가고 싶었는데 딱이다 ㅜㅠㅠ
# 구매 !!!완료!!!
# 방송 고맙습니다
# 기대되네요
# 진짜
# 살까말까
# 이벤트 해주세요!!!
# 소스랑 먹어주세요!!!
# 깔별로 소장각 ㅎㅎ
# 좋아요
# 가운데 선 있으면 진짜 간지러운데.. 없어서 너무 좋네요!
# 쨍한색이라 이뻐요ㅋ누가 팬티로 보겠어요 그냥 반바지 같아요
# 지금 방송 들어온게 완전 럭키네용
# 진짜 깔별소장각이네요ㅋㅋㅋ
# 지금선착몇분남았나요????
# 사이즈가 너무 고민되네요ㅠ
# 빠른 배송 되나요 빨리 입고싶어요 ㅎㅎ
# 저두 사이즈고민되요...ㅜ
# 2022042848526661구매인증합니다~^^
# 삼각팬티 입고 그위에 입는거에요?트렁크 입어보고 싶은데 낯설어용..ㅎㅎ
# 2022042848539741구매요
# 한번입어보고 일주일치 사고싶네요ㅜ 사이즈 고민이...
# 저도 입어보고 괜찮으면 더사고싶은데
# 또 라방 계획있나요?
# 가격이 싸서 깔별구매 딱인데ㅜ
# 진짜 구매하신당 ㅎㅎ믿고 사는
# 밴딩은 편할까요??
# 구매선착은 톡톡따로안남겨도 되나요?~^^
# 믿고 깔별 구매했습니당
# 2022042848633391
# 66이면 M인거죠?
# 쇼호스트님이 방송중에 주문하실 정도면 믿고사는템이에요 ㅎㅎ
# 3장이한세트에요?? 한장인거아니죠?
# 선착순안에 들어간건지 궁금합니다~!^^
# 언니~~ 혹시 다음방송은 언제인지 알수있을까요?
# ㅋㅋㅋㅋㅋㅋ😂
# 헉 대박 이렇게보니까 비교가 확실히되네요!!
# 요새 여성 트렁크 사려고 열심히 보러 다녔는데.. 올데 제품 진짜 예쁘고 좋아보이는데 싸기까지 하네요!!ㅠ 입어보고 2차 때 더 구매할게용
# 꺅 감사합니다💜
# 맞아요~~~ 저도 집에 가면 속옷부터 벗는데~~
# 앗 감사합니당!💗
# 혹시 이거 국내산인강교?
# 아래까지 해방시킬 수 있다니❤️
# 이거 국내산인가요?
# 아 뭐지 남자용이 아니구나
# 죄송해요 ㅠ
# 스태프 목소리 들리네요 ㅎ
# 💜💜💜
# 축하드려요~~~
# 잘봤어요 감사합니다~~

# %%
print('형태소:', t.morphs(sentence))
print('명사:', t.nouns(sentence))
print('품사 태깅 결과:', t.pos(sentence))
# Out:
# 형태소: ['우와', '!!', '\n', '어머', '..', '진짜', '뜯어서', '보여주시니까', '바로', '믿을수', '있을것', '같아요', '!!!!', '\n', '여름', '에', '쓰기', '좋겠어요', '!!', '\n', '헐', '..', 'ㅜㅜ', '특가', '는', '또', '안하나요', '?', 'ㅜㅜ', '\n', '카시트', '에도', '설치', '가능한거', '볼', '수', '있나요', '?', '\n', '저렇게', '테스트', '까지', '아이', '가', '여름', '에', '쉬', '원할것', '같네요', '\n', '시원하겠다요', '!', '\n', '통', '기성', '좋네요', '\n', '대박', '대박', '\n', '구매', '했', '습', '니당', '\n', '맘', '님', '들', '혹시', '신생아', '때', '도', '써도', '되나요', '?', '\n', '여름', '아', '기다려라', '우린', '준비', '됐다', '\n', '저', '선풍기', '색깔', '너무', '예쁘다', '😍', '\n', '오', '쿨', '~~', '라이너', '정말', '시원할거', '같아요', '대박', 'ㅎㅎㅎㅎ', '\n', '어디', '든', '호환', '가능한가요', '?', '\n', '살랑살랑', '~~~', '\n', '라이너', '대박', '이네', '여', '\n', '우리', '아들', '이', '열', '이', '많아서', '걱정', '이었는데', '너무', '좋아하겠네요', '\n', '감사', '^^', '\n', '여름', '에', '땀띠', '걱정', '안해', '도', '되', '겠네여', '\n', '살균', '소독제', '13900원', '라이브', '가', '맞는지', '확인', '해주세요', '답변', '좀', '\n', '기능', '성', '제대로', '보여주시', '네', '여', '^^', '\n', '세재도', '좋네요', '.', '\n', '휴대', '용', '유모차', '쓸랴', '고', '하는데', '배게도', '한번', '붙야주세요', '융', '\n', '여름', '에', '통기', '너무', '중요해요', '~', '\n', '하이', '체어', '에도', '사용', '가능하네요', '.', '올', '~~', '\n', '좋다', '좋다', '\n', '활', '용도', '가', '너무', '좋네요', '\n', '안', '그래도', '쩍쩍', '붙어서', '신경', '쓰였는데', '\n', '하이', '체어', '특', '가', '또', '열어주세요', 'ㅠㅠ', '\n', '와우', '\n', '1', '+', '1', '이네요', 'ㅎㅎㅎ', '역시', '네러메', '라', '방', '은', '혜자', '네', '요', '~', '\n', '배게까지', '너무', '귀여운', '세트', '에요', '!', '\n', '바닥', '에', '깔린', '상품', '은', '뭐', '에요', '??', '\n', '벌써', '더운거', '보니', '이번', '여름', '넘', '덥겠어요', 'ㅜㅜㅜㅜ', '\n', '여름', '에', '아이', '가', '아이스크림', '좋아하는데', '원', '플', '원', '이라서', '좋네요', '\n', '구매', '인증', '어떻게', '하나요', '?', '\n', '선물', '용', '으로', '구매', '해도', '되겠네요', '\n', '오', '~~~', '\n', '낮잠', '이불', '구매', '할려고', '들어왔어요', '^^', '\n', '원플', '은', '항상', '좋아요', 'ㅎ', '\n', '낮잠', '이불', '\n', 'ㅋㅋㅋ', '\n', '귀', '쫑긋', 'ㅎㅎㅎ', '\n', 'ㅋㅋㅋ', '\n', '히잉', '\n', '낮잠', '이불', '도', '하나요', '\n', '퀴즈', '어려운거', '싫어요', 'ㅋㅋㅋ', '\n', '퀴즈', '어려운', '가봐요', '\n', '바쁘다', '바쁜', '난주', '언니', 'ㅋㅋ', '\n', '낮잠', '이불', '디자인', '진짜', '이쁘다', '\n', '낮잠', '이불', '가겯', '할인', '듀', 'ㅏㅆ', '나요', '????', '\n', '2', '가지', '~~', '\n', '낮잠', '이불', '설명', '을', '특히', '열심히', '들어야겠네요', '\n', '어려우면', 'ㅠ', '\n', '일체', '형', '분리', '형', '\n', '퀴즈', '쉬운', '걸', '로', '\n', '분리', '형', '일체', '형', '\n', '부탁', '합니다', '\n', 'ㅋㅋㅋ', '\n', '수', '남', '할게', '없는데', '저', '거사', '면', '공간', '필요', '없겠어요', '\n', '바로', '지르러', '가봅니다', 'ㅠㅠ', '\n', '부엌', '도', '진짜', '은근', '짐', '이', '많아서', '요', '래', '딱', '정리', '되니깐', '너무', '좋네요', '^^', '\n', '진짜', '완벽하네요', '\n', '있어', '보여요', 'ㅎ', '\n', '바다로', '갑니다', '\n', '고급', '졍', '\n', '고급', '졍', '\n', '왠지', '이', '구성', '계속', '있을', '것', '같지', '않아소', '...', '1', '달', '고민', '했는데', '질러', '봅니당', '....', '\n', '얼굴', '보다', '커요', '🤭', 'ㅋㅋ', '\n', '산', '으로', '들로', '어디', '든', 'go', 'go', '\n', '너무', '이쁘다', '세트', '세트', '\n', '어딜', '그렇게', '내려가세요', '\n', 'ㅋㅋㅋ', '\n', '같이가', '~~~~~!!!!!', '\n', '같이가', '~~~~~!!!!!!', '\n', '꾸안', '꾸', '느낌', '?', '\n', '이왕이면', '이쁜거', '♡', '\n', 'ㅋㅋ', '주방', '용품', '계', '꾸안', '꾸', '\n', '다', '사고싶다', '30만원', '두', '안되네', '대박', '\n', '💥', '구매', '인증', '💥', '2022042842480831', '\n', '코', '도', 'ㅋㅋㅋ', '\n', '가', '아니고', '~', '\n', '오늘', '작정', '하고', '가져온', '가격', '과', '혜택', '이네', '요', '\n', '우왕', '~~~~~~~~~', '\n', '얼음', '물', '좋아요', '\n', 'ㅋㅋㅋ', '얼음', '\n', '계곡', '물', '에', '수박', '넣는', '느낌', '\n', '맞아요', '살려면', '비싸요', 'ㅋ', '\n', '효율', '장인', '보오', '글', '\n', '목화', '솜', '으로', '닦는', '소중한', '내', '얼굴', '보오', '글', '이', '챙겨', '준다네요', '\n', 'ㅋㅋㅋㅋㅋㅋㅋㅋ', '\n', '뜨거운', '여름', '에', '무쟈', '게', '요긴', '할듯', '\n', '진심', '당장', '떠나고', '싶네요', 'ㅋㅋ', '\n', '충분하', '겄', '네', '요', '\n', '💥', '구매', '인증', '💥', '2022042842824531', '\n', '삶의질', '이', '수직', '상승', '하겠어요', '\n', '추카', '드려요', '♡', '\n', '에잇', '다음', '기회', '에', '\n', '추카', '추카', '추카', '치카', '포카', '\n', '축하', '드려요', '\n', '추카', '추카', '추카', '치카', '포카', '🎉🎉🎉🎉🎉', '\n', '축하', '드려요', '\n', 'ㅋㅋㅋ', '저', '도', '요', '\n', '저', '도', '지금', '당장', '떠나고', '싶어요', '~', '\n', '🛫', '\n', '가정', '의', '달이', '라', '\n', '엄빠', '한테', '선물', '해야게', '똬', '\n', '플렉 ...

# %%
tokens_const = t.morphs(sentence)
print('토큰의 수:', len(tokens_const))
print(tokens_const[:100])
# Out:
# 토큰의 수: 7351
# ['우와', '!!', '\n', '어머', '..', '진짜', '뜯어서', '보여주시니까', '바로', '믿을수', '있을것', '같아요', '!!!!', '\n', '여름', '에', '쓰기', '좋겠어요', '!!', '\n', '헐', '..', 'ㅜㅜ', '특가', '는', '또', '안하나요', '?', 'ㅜㅜ', '\n', '카시트', '에도', '설치', '가능한거', '볼', '수', '있나요', '?', '\n', '저렇게', '테스트', '까지', '아이', '가', '여름', '에', '쉬', '원할것', '같네요', '\n', '시원하겠다요', '!', '\n', '통', '기성', '좋네요', '\n', '대박', '대박', '\n', '구매', '했', '습', '니당', '\n', '맘', '님', '들', '혹시', '신생아', '때', '도', '써도', '되나요', '?', '\n', '여름', '아', '기다려라', '우린', '준비', '됐다', '\n', '저', '선풍기', '색깔', '너무', '예쁘다', '😍', '\n', '오', '쿨', '~~', '라이너', '정말', '시원할거', '같아요', '대박', 'ㅎㅎㅎㅎ', '\n']
