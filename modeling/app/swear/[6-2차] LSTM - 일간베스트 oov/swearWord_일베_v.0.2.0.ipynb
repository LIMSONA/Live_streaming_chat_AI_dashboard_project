# %% [markdown]
# ### 모듈 import 하기

# %%
import pandas as pd
import numpy as np
# import matplotlib.pyplot as plt
import re
import urllib.request


import nltk
from konlpy.tag import Okt
from nltk.tokenize import word_tokenize
okt = Okt()

from tqdm import tqdm
from tensorflow.python.keras.preprocessing.text import Tokenizer
from tensorflow.python.keras.preprocessing.sequence import pad_sequences

# %%
badcomm = pd.read_csv('./dataset/비속어데이터셋_전처리o.csv')
badcomm
# Out:
#                                              댓글  비속어여부
# 0                                        좌배 까는건      1
# 1                      집에 롱 패딩만 세 개다 10년 더 입어야지      0
# 2     개소리야 니가 빨갱이를 옹호하고 드루킹을 짓이라고 말못해서 삐진거야 빨갱아      1
# 3                                   세탁이라고 봐도 된다      0
# 4                                  애새끼가 초딩도 아니고      1
# ...                                         ...    ...
# 6764                                       후장꽂아      1
# 6765                                       후장뚫어      1
# 6766                                         흐접      1
# 6767                                         흐젚      1
# 6768                                         흐졉      1
#
# [6769 rows x 2 columns]

# %% [markdown]
# ### 토큰화 - 불용어 제거

# %%
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# %%
# 데이터셋 분리

text = badcomm['댓글'] # 시리즈 객체로 저장
score = badcomm['비속어여부']

# %% [markdown]
# ### train, test 데이터 분리

# %%
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(text, score , test_size=0.2, random_state=0)
print(len(train_x), len(train_y), len(test_x), len(test_y))
# Out:
# 5415 5415 1354 1354

# %%
train_x
# Out:
# 1833                         딱봐도 남이 인증한거 파온거고 본인거라고도 안했는데
# 6204                                                  젖꼮찌
# 4727    리얼로 성정체성에 혼란느껴서 남자인데 남자좋아하는 게이는 전체 1쯤 될듯 근데 인간...
# 4456                                    개일베잡짓거리하다 니인생종친거다
# 2876                                    편돌이주제에   누굴 평가해 거
#                               ...
# 4931                                                  부랄탁
# 3264                                               섹스자지보지
# 1653                                                   팝핀
# 2607                            민주당 드루킹댓글조작알바 새끼들 정신 못차렸네
# 2732                디지털이 발전하면서 예견됐던 일이지 근데 여자가 먼저 찍자고 하던데
# Name: 댓글, Length: 5415, dtype: object

# %%
# 형태소 분석기를 사용하여 토큰화를 하면서 불용어를 제거하여 X_train에 저장

X_train = []
for sentence in tqdm(train_x):
    tokenized_sentence = okt.morphs(sentence, stem=True) # 토큰화, 동사 기본형으로 변경
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    X_train.append(stopwords_removed_sentence)
# Out:
# 100%|██████████| 5415/5415 [00:12<00:00, 439.47it/s]

# %%
print(X_train[:3])
# Out:
# [['딱', '보다', '남', '인증', '거', '파', '오다', '보다', '안'], ['젖꼮찌'], ['리얼', '로', '성정체성', '혼란', '느끼다', '남자', '인데', '남자', '좋아하다', '게이', '전체', '1', '쯤', '되다', '근데', '인간', '양성애자', '라', '고함']]

# %%
# 형태소 분석기를 사용하여 토큰화를 하면서 불용어를 제거하여 X_test에 저장

X_test = []
for sentence in tqdm(test_x):
    tokenized_sentence = okt.morphs(sentence, stem=True) # 토큰화, 동사 기본형으로 변경
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    X_test.append(stopwords_removed_sentence)
# Out:
# 100%|██████████| 1354/1354 [00:02<00:00, 649.66it/s]

# %%
print(X_test[:3])
# Out:
# [['즐', '라도', '사기꾼', '출신', '이라', '던데'], ['리더', '말', '그렇다', '박쥐', '없다', '코로나', '그거', '잡기', '힘들다', '꽈', '래야', '되다', '보지'], ['븅신', '보', '빨다', '나', '치다', '먹다', '이기']]

# %% [markdown]
# ### 정수 인코딩

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

# %%
# 단어사전 저장!!
import json
with open("일베집합_test4.json","w",encoding="utf-8") as f:
    json.dump(tokenizer.word_index ,f,ensure_ascii=False, indent=4)

# %%
# 빈도수가 낮은 단어들은 자연어 처리에서 배제
# 등장 빈도수가 3회 미만인 단어들이 이 데이터에서 얼만큼의 비중을 차지하는지 확인

threshold = 3
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)

# 생각보다 희귀단어 등장빈도 비율이 높다.
# Out:
# 단어 집합(vocabulary)의 크기 : 10097
# 등장 빈도가 2번 이하인 희귀 단어의 수: 7190
# 단어 집합에서 희귀 단어의 비율: 71.20927008022184
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 17.47407273675553

# %%
# 등장 빈도수가 2이하인 단어들의 수를 제외한 단어의 개수를 단어 집합의 최대 크기로 제한

# 전체 단어 개수 중 빈도수 2이하인 단어는 제거.
# 0번 패딩 토큰을 고려하여 + 1
vocab_size = total_cnt - rare_cnt + 1
print('단어 집합의 크기 :',vocab_size)
# Out:
# 단어 집합의 크기 : 2908

# %%
# 케라스 토크나이저의 인자로 넘겨주고 텍스트 시퀀스를 정수 시퀀스로 변환

tokenizer = Tokenizer(vocab_size) 
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

# %%
# 정수 인코딩이 잘 되었나?
print(X_train[:3])
# Out:
# [[105, 3, 173, 524, 22, 2184, 58, 3, 11], [], [1430, 10, 430, 119, 62, 119, 190, 120, 857, 92, 767, 5, 68, 158, 50, 698]]

# %%
print(train_y)
# Out:
# 1833    0
# 6204    1
# 4727    0
# 4456    1
# 2876    1
#        ..
# 4931    1
# 3264    1
# 1653    0
# 2607    1
# 2732    0
# Name: 비속어여부, Length: 5415, dtype: int64

# %%
print(test_y)
# Out:
# 1914    0
# 3433    0
# 1632    1
# 4906    0
# 2323    0
#        ..
# 5872    1
# 5548    0
# 1624    1
# 30      0
# 6201    1
# Name: 비속어여부, Length: 1354, dtype: int64

# %%
# y를 array 형식으로 저장해주기

train_y = np.array(train_y)
test_y = np.array(test_y)

# %%
print(train_y)
print(test_y )
# Out:
# [0 1 0 ... 0 1 0]
# [0 0 1 ... 1 0 1]

# %% [markdown]
# ### 패딩으로 댓글 길이 맞추기

# %%
print('리뷰의 최대 길이 :',max(len(review) for review in train_x))
print('리뷰의 평균 길이 :',sum(map(len, train_x))/len(train_x))

# 최대길이가 요상한 댓글이 있음
# Out:
# 리뷰의 최대 길이 : 911
# 리뷰의 평균 길이 : 26.21865189289012

# %%
def below_threshold_len(max_len, nested_list):
  count = 0
  for sentence in nested_list:
    if(len(sentence) <= max_len):
        count = count + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (count / len(nested_list))*100))

# %%
max_len = 30
below_threshold_len(max_len, X_train)

# 96 % 가 30 이하이기 때문에 최대글자수는 30으로 패딩해주는것이 좋을것같다.
# Out:
# 전체 샘플 중 길이가 30 이하인 샘플의 비율: 96.76823638042474

# %%
# 모든 샘플의 길이를 30으로 맞춘다 - 이때 정수인코딩한 데이터 사용!
X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)

# %% [markdown]
# ### LSTM으로 분류하기
# #### 하이퍼파라미터
# - 임베딩 벡터 차원 = 100
# - 은닉 상태 크기 = 128
# - 배치 크기 = 64
# - 에포크 = 15

# %%
# 두 개의 선택지 중 하나를 예측하는 이진 분류 문제를 수행하는 모델    

from tensorflow.python.keras.layers import Embedding, Dense, LSTM
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.models import load_model
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint # 조기종료

embedding_dim = 100
hidden_units = 32

model = Sequential()
model.add(Embedding(vocab_size, embedding_dim))
model.add(LSTM(hidden_units))
model.add(Dense(1, activation='sigmoid'))# 로지스틱 회귀를 사용해야 하기 때문에 sigmoid

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('test-model1.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, train_y, epochs=15, callbacks=[es, mc], batch_size=16, validation_split=0.2)
# Out:
# Epoch 1/15
# 269/271 [============================>.] - ETA: 0s - loss: 0.6048 - acc: 0.6731
# Epoch 00001: val_acc improved from -inf to 0.76731, saving model to test-model1.h5
# 271/271 [==============================] - 3s 13ms/step - loss: 0.6031 - acc: 0.6745 - val_loss: 0.5095 - val_acc: 0.7673
# Epoch 2/15
# 268/271 [============================>.] - ETA: 0s - loss: 0.4016 - acc: 0.8223
# Epoch 00002: val_acc improved from 0.76731 to 0.76824, saving model to test-model1.h5
# 271/271 [==============================] - 3s 13ms/step - loss: 0.4020 - acc: 0.8216 - val_loss: 0.4864 - val_acc: 0.7682
# Epoch 3/15
# 271/271 [==============================] - ETA: 0s - loss: 0.3397 - acc: 0.8592
# Epoch 00003: val_acc improved from 0.76824 to 0.80609, saving model to test-model1.h5
# 271/271 [==============================] - 3s 10ms/step - loss: 0.3397 - acc: 0.8592 - val_loss: 0.4517 - val_acc: 0.8061
# Epoch 4/15
# 267/271 [============================>.] - ETA: 0s - loss: 0.3030 - acc: 0.8755
# Epoch 00004: val_acc did not improve from 0.80609
# 271/271 [==============================] - 3s 10ms/step - loss: 0.3024 - acc: 0.8751 - val_loss: 0.4557 - val_acc: 0.8061
# Epoch 5/15
# 267/271 [============================>.] - ETA: 0s - loss: 0.2775 - acc: 0.8858
# Epoch 00005: val_acc improved from 0.80609 to 0.81071, saving model to test-model1.h5
# 271/271 [==============================] - 3s 11ms/step - loss: 0.2768 - acc: 0.8864 - val_loss: 0.4802 - val_acc: 0.8107
# Epoch 6/15
# 271/271 [==============================] - ETA: 0s - loss: 0.2575 - acc: 0.8966
# Epoch 00006: val_acc did not improve from 0.81071
# 271/271 [==============================] - 3s 10ms/step - loss: 0.2575 - acc: 0.8966 - val_loss: 0.4979 - val_acc: 0.8024
# Epoch 7/15
# 268/271 [============================>.] - ETA: 0s - loss: 0.2350 - acc: 0.9056
# Epoch 00007: val_acc did not improve from 0.81071
# 271/271 [==============================] - 3s 10ms/step - loss: 0.2375 - acc: 0.9044 - val_loss: 0.5561 - val_acc: 0.7793
# Epoch 00007: early stopping

# %%
# 모델 정확도 테스트
loaded_model = load_model('./test-model1.h5')
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X_test, test_y)[1]))
# Out:
# 43/43 [==============================] - 0s 3ms/step - loss: 0.5046 - acc: 0.8035
#
#  테스트 정확도: 0.8035

# %% [markdown]
# ### 모델 사용해서 댓글 비속어 포함여부 예측해보기

# %%
def sentiment_predict(new_sentence):
    new_sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','', new_sentence)
    new_sentence = okt.morphs(new_sentence, stem=True) # 토큰화
    new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
    encoded = tokenizer.texts_to_sequences([new_sentence]) # 정수 인코딩
    pad_new = pad_sequences(encoded, maxlen = max_len) # 패딩
    score = float(loaded_model.predict(pad_new)) # 예측
    if(score > 0.8):
        print("{:.2f}% 확률로 비속어가 포함된 댓글입니다.\n".format(score * 100))
    else:
        print("{:.2f}% 확률로 일반 댓글입니다.\n".format((1 - score) * 100))

# %%
slang_predict('미친 존나 싸다!')
# Out:
# '비속어 댓글 99.85% 확률'

# %%
slang_predict('졸라 이쁘다 ㅋㅋㅋㅋ')
# Out:
# '비속어 댓글 87.05% 확률'

# %%
slang_predict('애새끼가 초딩도 아니고')
# Out:
# '비속어 댓글 97.52% 확률'

# %%
slang_predict('시바')
# Out:
# '일반 댓글 40.09% 확률'

# %%
test = pd.read_csv('./dataset/153cm_키작녀_시니럽의_봄_여름_코디🎨.csv')
test = test.drop(columns=['id','program','time','love','play'])
test
# Out:
#                          comment
# 0                         좋을호 맞넹
# 1                             ^^
# 2                             ㅎㅎ
# 3                            👏 👏
# 4                이옷이 좀 더 날씬해 보여요
# 5                      언니한테 어울려요
# 6                         티 이쁘네영
# 7                   가단이 어떻게 되나영?
# 8                   언니 진짜 다잘어울린다
# 9                   바지 허리밴딩 있나요?
# 10                   민트 모자 써 주세영
# 11                           야자수
# 12                            ㅠㅜ
# 13                 다른티셔츠도 입어바주세요
# 14                     놀러가구싶당 ㅜㅜ
# 15                     언니 옷입고 ㅠㅠ
# 16                아직 쪼꼼 위험?해서 ㅜㅜ
# 17                 뒤에 완전 바캉스룩 찰떡
# 18                 언니 사이즈가 55시죠?
# 19                  44 엄청 날씬하시네요
# 20                      엄청 깜짝하네열
# 21                             헐
# 22                         대박 시크
# 23           아니 저런 룩에 저 러블리한 모자가
# 24                      완전 뽀인뚜네용
# 25                      나왓다 언니최애
# 26                            굿굿
# 27                             👋
# 28                  뚜호님 안녕하세요 ^^
# 29                         찰떡 착장
# 30                         손뜨개같앙
# 31                     짜임이 견고해 ㅎ
# 32         진짜 저런 손재주 없으니 나는 산다 .
# 33                  ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 34                      저걸 어케 떠.
# 35               저는 이게 젤 이뿐거같아ㅛㅇ
# 36                        하얀 모자에
# 37                       하늘색 파란색
# 38                         스타일리시
# 39                            대박
# 40            위아래 흰색 입어도 아래가 포인트
# 41                          아래란다
# 42                       모자가 포인트
# 43                        ㅋㅋㅋㅋㅋㅋ
# 44                     와 가격도 좋네용
# 45                        이뿌당 진짜
# 46             케이프 스타일 두건도 넘 이뿨용
# 47                          러블리해
# 48                      알프스 소녀느낌
# 49                           ㅎㅎㅎ
# 50              기여워 살짝 앞옆머리 냄겨놔야
# 51                         더 이뿐듯
# 52                머리숱 진짜 볼떄마다 부럽
# 53                           ㄹㄹㄹ
# 54                   와 레알 머리숱 부럽
# 55                          산뜻해요
# 56  키작녀에요 여기를 이제야 알다니 앞으로 자주 올게요

# %%
def slang_predict(new_sentence):
    new_sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','', str(new_sentence))
    new_sentence = okt.morphs(new_sentence, stem=True) # 토큰화
    new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
    encoded = tokenizer.texts_to_sequences([new_sentence]) # 정수 인코딩
    pad_new = pad_sequences(encoded, maxlen = max_len) # 패딩
    score = float(loaded_model.predict(pad_new)) # 예측
    if(score > 0.8):
        return "비속어 댓글 {:.2f}% 확률".format(score * 100)
    else:
        return "일반 댓글 {:.2f}% 확률".format((1 - score) * 100)

# %%
test['result'] = test['comment'].map(lambda x: slang_predict(x))

# %%
test
# Out:
#                          comment            result
# 0                         좋을호 맞넹   일반 댓글 55.48% 확률
# 1                             ^^   일반 댓글 26.69% 확률
# 2                             ㅎㅎ   일반 댓글 26.69% 확률
# 3                            👏 👏   일반 댓글 26.69% 확률
# 4                이옷이 좀 더 날씬해 보여요   일반 댓글 90.35% 확률
# 5                      언니한테 어울려요   일반 댓글 63.55% 확률
# 6                         티 이쁘네영   일반 댓글 96.25% 확률
# 7                   가단이 어떻게 되나영?   일반 댓글 98.93% 확률
# 8                   언니 진짜 다잘어울린다   일반 댓글 85.06% 확률
# 9                   바지 허리밴딩 있나요?   일반 댓글 88.22% 확률
# 10                   민트 모자 써 주세영   일반 댓글 77.46% 확률
# 11                           야자수   일반 댓글 26.69% 확률
# 12                            ㅠㅜ   일반 댓글 26.69% 확률
# 13                 다른티셔츠도 입어바주세요   일반 댓글 98.15% 확률
# 14                     놀러가구싶당 ㅜㅜ   일반 댓글 96.52% 확률
# 15                     언니 옷입고 ㅠㅠ   일반 댓글 94.97% 확률
# 16                아직 쪼꼼 위험?해서 ㅜㅜ   일반 댓글 97.98% 확률
# 17                 뒤에 완전 바캉스룩 찰떡   일반 댓글 80.74% 확률
# 18                 언니 사이즈가 55시죠?   일반 댓글 48.50% 확률
# 19                  44 엄청 날씬하시네요   일반 댓글 69.94% 확률
# 20                      엄청 깜짝하네열   일반 댓글 97.37% 확률
# 21                             헐   일반 댓글 35.30% 확률
# 22                         대박 시크   일반 댓글 26.69% 확률
# 23           아니 저런 룩에 저 러블리한 모자가   일반 댓글 91.88% 확률
# 24                      완전 뽀인뚜네용   일반 댓글 88.87% 확률
# 25                      나왓다 언니최애   일반 댓글 26.69% 확률
# 26                            굿굿   일반 댓글 26.69% 확률
# 27                             👋   일반 댓글 26.69% 확률
# 28                  뚜호님 안녕하세요 ^^   일반 댓글 93.32% 확률
# 29                         찰떡 착장   일반 댓글 75.22% 확률
# 30                         손뜨개같앙  비속어 댓글 97.38% 확률
# 31                     짜임이 견고해 ㅎ   일반 댓글 26.69% 확률
# 32         진짜 저런 손재주 없으니 나는 산다 .   일반 댓글 94.54% 확률
# 33                  ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ   일반 댓글 26.69% 확률
# 34                      저걸 어케 떠.  비속어 댓글 98.29% 확률
# 35               저는 이게 젤 이뿐거같아ㅛㅇ   일반 댓글 72.86% 확률
# 36                        하얀 모자에   일반 댓글 53.44% 확률
# 37                       하늘색 파란색   일반 댓글 26.69% 확률
# 38                         스타일리시   일반 댓글 26.69% 확률
# 39                            대박   일반 댓글 26.69% 확률
# 40            위아래 흰색 입어도 아래가 포인트   일반 댓글 98.11% 확률
# 41                          아래란다   일반 댓글 87.03% 확률
# 42                       모자가 포인트   일반 댓글 86.13% 확률
# 43                        ㅋㅋㅋㅋㅋㅋ   일반 댓글 26.69% 확률
# 44                     와 가격도 좋네용   일반 댓글 87.75% 확률
# 45                        이뿌당 진짜   일반 댓글 85.23% 확률
# 46             케이프 스타일 두건도 넘 이뿨용   일반 댓글 91.22% 확률
# 47                          러블리해   일반 댓글 26.69% 확률
# 48                      알프스 소녀느낌   일반 댓글 50.56% 확률
# 49                           ㅎㅎㅎ   일반 댓글 26.69% 확률
# 50              기여워 살짝 앞옆머리 냄겨놔야  비속어 댓글 89.21% 확률
# 51                         더 이뿐듯   일반 댓글 67.05% 확률
# 52                머리숱 진짜 볼떄마다 부럽   일반 댓글 97.24% 확률
# 53                           ㄹㄹㄹ   일반 댓글 26.69% 확률
# 54                   와 레알 머리숱 부럽   일반 댓글 97.12% 확률
# 55                          산뜻해요   일반 댓글 26.69% 확률
# 56  키작녀에요 여기를 이제야 알다니 앞으로 자주 올게요   일반 댓글 77.77% 확률

# %%
youtube = pd.read_csv('./dataset/2022-05-11.csv')
youtube= youtube.head(500)

# %%
youtube['result'] = youtube['comment'].map(lambda x: slang_predict(x))

# %%
youtube.sample(15)
# Out:
#                                                comment            result
# 413                                       원래 똥은 거름 농사시  비속어 댓글 84.83% 확률
# 116                                            영국도 핵있다   일반 댓글 75.98% 확률
# 377                                           한동훈이가 키다   일반 댓글 26.69% 확률
# 289                                         토리가 제일 상식적   일반 댓글 91.32% 확률
# 295  검수완박 통과못시키면 청외대 20명 감옥간다며 죄지었으면 감옥가야지 왜 양향자의원을...   일반 댓글 39.16% 확률
# 308                                     깁시다ㅡ일본은 매일 깁니다   일반 댓글 99.18% 확률
# 232  동후니가 그러케 무서? 왜 그렇게 무서워? 장관올라가기도 전에 오바야? 만주당 그냥...   일반 댓글 97.75% 확률
# 415                                           공산당이 시러요   일반 댓글 26.69% 확률
# 281  드루킹이 그러더라 문재인에게 조국은 로마다 :shelterin::shelterin:...   일반 댓글 37.14% 확률
# 304                                                 에잇   일반 댓글 26.69% 확률
# 153                                마녀할머니 혈압에 심정지 조심하세요   일반 댓글 78.46% 확률
# 237                                     나도 안봤지 ㅋㅋㅋㅋㅋㅋㅋ   일반 댓글 99.02% 확률
# 372                              북한 야간 행사 탁현민 작품이라며 ㅋㅋ  비속어 댓글 95.56% 확률
# 338                                        아니구나 그건 그래    일반 댓글 94.92% 확률
# 371                                러시아 맨날 북한편들아 시러 ㅠㅠㅠ  비속어 댓글 93.66% 확률

# %%
youtube2 = pd.read_csv('./dataset/womad_swear.csv', index_col=0)
youtube2
# Out:
#                            msg  label
# 0                    지금 어디 계세요      0
# 1                한국 시간에 시계 맞췄어      0
# 2              햄버거 두 개랑 콜라 주세요      0
# 3              우리는 밤새 춤추고 노래했다      0
# 4     무엇보다도 스트레스를 줄이는 것이 중요합니다      0
# ...                        ...    ...
# 1995         개독냄새 나노 ㅋㅋㅋ조팔 개오글      1
# 1996   사실상 페미니즘 영업사원 아니노 ㅋㅋㅋㅋ       1
# 1997                   ㅋㅋㅋㅋㅋㅋㅋ      1
# 1998        아버지는 아침 일찍 서울로 가셨다      0
# 1999         과천에 있는 국립박물관 가 봤어      0
#
# [2000 rows x 2 columns]

# %%
youtube2['result'] = youtube2['msg'].map(lambda x: slang_predict(x))

# %%
youtube2.sample(20)
# Out:
#                                                     msg  label  \
# 518                           도와드릴까요  어른 두 명하고 아이 한 명이요      0
# 1238                                     이거 전에 올라왓던 글이노      1
# 799   그걸 이제 알다니 등신력 ㄱㅆㅅㅌㅊ노 근데 저런 개돼지들 군무군무 많아서 정신 못차...      1
# 1829                                       나 새벽에 일어나야 해      0
# 1452                                     나를 잊지 않겠다고 약속해      0
# 620                                                 네네네      1
# 820                                         칠판에 써 볼 사람       0
# 1465                                 유료회원만 볼 수 있는 댓글입니다      1
# 1894                                     저 식당은 냉면으로 유명해      0
# 1013                  후팔ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ나도 돌아왔놐ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ느      1
# 1573                                    우리 형은 아버지처럼 행동해      0
# 1730  프랑스에서 살다왔는데 서민들 이 글에 설명된 그대로노 좆국도 자수성가 계층이동 앵나...      1
# 1836                                   한 시간 뒤에 꽃에 물을 줘라      0
# 1637                                        아래에 서명해 주세요      0
# 341                                            정보꿘은 워추노      1
# 1655                                저는 백 퍼센트 이길 자신이 있어요      0
# 1188                                        ㄴ 웃챙ㅋㅋㅋㅋㅋㅋㅋ      1
# 1630                           나 이 스웨터 다시는 안 입을 거야 늘어났어      0
# 1579                  자댕이 체취 개심하노 특히 흡연자지는 살남충동 누르기힘드노       1
# 1937                               홍본좌 무죄 건강챙겨가며 공부해라이니      1
#
#                 result
# 518    일반 댓글 99.31% 확률
# 1238   일반 댓글 79.31% 확률
# 799   비속어 댓글 99.63% 확률
# 1829   일반 댓글 93.95% 확률
# 1452   일반 댓글 98.40% 확률
# 620    일반 댓글 39.79% 확률
# 820    일반 댓글 97.27% 확률
# 1465   일반 댓글 99.31% 확률
# 1894   일반 댓글 68.09% 확률
# 1013   일반 댓글 96.10% 확률
# 1573   일반 댓글 98.77% 확률
# 1730   일반 댓글 30.46% 확률
# 1836   일반 댓글 97.10% 확률
# 1637   일반 댓글 71.33% 확률
# 341    일반 댓글 50.48% 확률
# 1655   일반 댓글 96.13% 확률
# 1188   일반 댓글 26.69% 확률
# 1630   일반 댓글 87.96% 확률
# 1579   일반 댓글 88.26% 확률
# 1937  비속어 댓글 88.14% 확률

# %%
test2 = pd.read_csv('./dataset/ilbe_swear.csv', index_col=0)
test2['result'] = test2['msg'].map(lambda x: slang_predict(x))

# %%
test2.sample(15)
# Out:
#                                                     msg  label  \
# 3874                       ㅈ같은 아메리카요가 본점이든 지점이든 ㅈ되길 바란다      1
# 4776                                            네다음용접충       1
# 3449                                   꼭 좋은날 올거예요힘내세요ㅜㅜ      0
# 5576  착오로 송부 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ갈데까지 갔구나...      1
# 3319                                      노무노무 쪽팔리겠다ㅋㅋㅋ      1
# 1641  팩트체크 어딘가 모자라고 어딘가 열등감이 있고 결함 있는 사람들만 하위 직종을 무시...      0
# 494                                               기레기들아      1
# 4637                                           뭐 좋지 우리야      0
# 5054                        최근에 본 실사화 중에 젤 잘 만든 거 같네 ㄷㄷ      0
# 3917                      네겐 다른 선생이 필요없으니 성령님께서 네 선생님이다      0
# 3793    ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 난 24살 군인이데 개백수련 한심하네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ      1
# 1182                                  공시생 샘통이내 절대합의하지마라      0
# 4447                                    다수의 피정복민은 백인이엇음      0
# 4156                                            쇼타꼬추조아ㄷ      1
# 249                                             해체가 답이지      0
#
#                 result
# 3874   일반 댓글 92.76% 확률
# 4776   일반 댓글 91.46% 확률
# 3449   일반 댓글 99.66% 확률
# 5576  비속어 댓글 97.68% 확률
# 3319  비속어 댓글 99.63% 확률
# 1641   일반 댓글 98.04% 확률
# 494   비속어 댓글 84.67% 확률
# 4637   일반 댓글 96.75% 확률
# 5054   일반 댓글 98.40% 확률
# 3917   일반 댓글 99.31% 확률
# 3793   일반 댓글 57.01% 확률
# 1182   일반 댓글 95.88% 확률
# 4447   일반 댓글 42.47% 확률
# 4156   일반 댓글 21.70% 확률
# 249    일반 댓글 97.79% 확률

# %%
slang_predict('너 미친놈이지')
# Out:
# '비속어 댓글 97.60% 확률'
