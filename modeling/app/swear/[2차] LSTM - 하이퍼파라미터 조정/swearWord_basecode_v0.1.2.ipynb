# %% [markdown]
# ### 모듈 import 하기

# %%
import pandas as pd
import numpy as np
# import matplotlib.pyplot as plt
import re
import urllib.request


import nltk
from konlpy.tag import Okt
from nltk.tokenize import word_tokenize
okt = Okt()

from tqdm import tqdm
from tensorflow.python.keras.preprocessing.text import Tokenizer
from tensorflow.python.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# ### 데이터 전처리
# - 데이터셋 불러오기
# - 원하는 데이터프레임으로 만들어주기

# %%
badcomm = pd.read_csv('./비속어데이터셋_전처리o.csv')
badcomm.sample(10)
# Out:
#                                                      댓글  비속어여부
# 1548                                   건설교통부는 뭐냐 국토교통부지      0
# 719                                         누나 내 쥬예즤 주겅      1
# 579                                    디지기전 이름은 카라스마 렌야      0
# 705   야동도 야동이지만 게임이나 애니 같은 것도 빠질 수 없음진짜 일본 문화 한국인들 싹...      1
# 3993                                          어제꺼를 쳐올리네      1
# 684                                      그이상 받는건 불공평한거다      0
# 511   다들 속으로 똑같이 생각하면서 아닌척 정의감에 불타느척 해야 사회적 으로 형성된 공...      1
# 4833                                    상습 주작글 올리는 개새끼야      1
# 1941                                     홍어 쉑 만날 만 처올리노      1
# 3317  옆에서 쓴소리하는 사람이 없으니깐 저러지 박근혜도 옆에서 쓴소리하면 보지식 기분나빵...      1

# %% [markdown]
# ### 토큰화 - 불용어 제거

# %%
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','을','으로','자','에','와','한','하다','부터']

# %%
# 데이터셋 분리

text = badcomm['댓글'] # 시리즈 객체로 저장
score = badcomm['비속어여부']

# %% [markdown]
# ### train, test 데이터 분리

# %%
from sklearn.model_selection import train_test_split

train_x, test_x, train_y, test_y = train_test_split(text, score , test_size=0.2, random_state=0)
print(len(train_x), len(train_y), len(test_x), len(test_y))
# Out:
# 5415 5415 1354 1354

# %%
train_x
# Out:
# 1833                         딱봐도 남이 인증한거 파온거고 본인거라고도 안했는데
# 6204                                                  젖꼮찌
# 4727    리얼로 성정체성에 혼란느껴서 남자인데 남자좋아하는 게이는 전체 1쯤 될듯 근데 인간...
# 4456                                    개일베잡짓거리하다 니인생종친거다
# 2876                                    편돌이주제에   누굴 평가해 거
#                               ...
# 4931                                                  부랄탁
# 3264                                               섹스자지보지
# 1653                                                   팝핀
# 2607                            민주당 드루킹댓글조작알바 새끼들 정신 못차렸네
# 2732                디지털이 발전하면서 예견됐던 일이지 근데 여자가 먼저 찍자고 하던데
# Name: 댓글, Length: 5415, dtype: object

# %%
# 형태소 분석기를 사용하여 토큰화를 하면서 불용어를 제거하여 X_train에 저장

X_train = []
for sentence in tqdm(train_x):
    tokenized_sentence = okt.morphs(sentence, stem=True) # 토큰화, 동사 기본형으로 변경
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    X_train.append(stopwords_removed_sentence)
# Out:
# 100%|██████████| 5415/5415 [00:15<00:00, 340.01it/s]

# %%
print(X_train[:3])
# Out:
# [['딱', '보다', '남', '인증', '거', '파', '오다', '보다', '안'], ['젖꼮찌'], ['리얼', '로', '성정체성', '혼란', '느끼다', '남자', '인데', '남자', '좋아하다', '게이', '전체', '1', '쯤', '되다', '근데', '인간', '양성애자', '라', '고함']]

# %%
# test 데이터도 형태소 분석기를 사용하여 토큰화를 하면서 불용어를 제거하여 X_test에 저장

X_test = []
for sentence in tqdm(test_x):
    tokenized_sentence = okt.morphs(sentence, stem=True) # 토큰화, 동사 기본형으로 변경
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    X_test.append(stopwords_removed_sentence)
# Out:
# 100%|██████████| 1354/1354 [00:02<00:00, 475.83it/s]

# %%
print(X_test[:5])
# Out:
# [['즐', '라도', '사기꾼', '출신', '이라', '던데'], ['리더', '말', '그렇다', '박쥐', '없다', '코로나', '그거', '잡기', '힘들다', '꽈', '래야', '되다', '보지'], ['븅신', '보', '빨다', '나', '치다', '먹다', '이기'], ['똑같이', '해주다', '쫌'], ['저', '거', '황해', '하정우', '룩', '아니다']]

# %% [markdown]
# ### 정수 인코딩

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train) #fit으로 tokenization 적용해주기
print(tokenizer.word_index)
# Out:
# {'있다': 1, '보다': 2, '아니다': 3, '되다': 4, '없다': 5, '새끼': 6, '다': 7, '같다': 8, '로': 9, '안': 10, '에서': 11, '아': 12, '고': 13, '못': 14, '만': 15, '나': 16, '그렇다': 17, '저': 18, '말': 19, '이다': 20, '거': 21, '그': 22, '임': 23, '먹다': 24, '존나': 25, '사람': 26, '개': 27, '게': 28, '니': 29, '야': 30, '들다': 31, '하고': 32, '돈': 33, '가다': 34, '지': 35, '때': 36, '진짜': 37, '좋다': 38, '맞다': 39, '그냥': 40, '내': 41, '적': 42, '네': 43, '더': 44, '뭐': 45, '병신': 46, '면': 47, '생각': 48, '라': 49, '인': 50, '년': 51, '일': 52, '애': 53, '받다': 54, '치다': 55, '왜': 56, '오다': 57, '알다': 58, '것': 59, '용접': 60, '인데': 61, '한테': 62, '나오다': 63, '놈': 64, '않다': 65, '기': 66, '근데': 67, '많다': 68, '글': 69, '좆': 70, '함': 71, '지다': 72, '이나': 73, '씹다': 74, '너': 75, '서': 76, '냐': 77, '씨발': 78, '정도': 79, '주다': 80, '사': 81, '이냐': 82, '여자': 83, '쓰다': 84, '랑': 85, '나다': 86, '한국': 87, '하': 88, '살다': 89, '모르다': 90, '1': 91, '일본': 92, '공부': 93, '소리': 94, '지랄': 95, '일베': 96, '나라': 97, '지금': 98, '수': 99, '많이': 100, '까지': 101, '시발': 102, '보고': 103, '딱': 104, '안되다': 105, '자다': 106, '이지': 107, '따다': 108, '난': 109, '라고': 110, '시키다': 111, '공': 112, '이라고': 113, '이렇다': 114, '중': 115, '2': 116, '남자': 117, '게이': 118, '집': 119, '하나': 120, '버리다': 121, '어떻다': 122, '걸': 123, '이고': 124, '만들다': 125, '또': 126, '미치다': 127, '해주다': 128, '링크': 129, '몇': 130, '저런': 131, '시': 132, '대': 133, '들이다': 134, '해보다': 135, '살': 136, '알': 137, '뭔': 138, '크다': 139, '라는': 140, '너무': 141, '미국': 142, '급': 143, '때문': 144, '이랑': 145, '요': 146, '중국': 147, '이네': 148, '대다': 149, '내다': 150, '당하다': 151, '전': 152, '돼다': 153, '우리': 154, '결혼': 155, '인간': 156, '늘다': 157, '뒤지다': 158, '넘다': 159, '싶다': 160, '다른': 161, '그리고': 162, '끄다': 163, '욕': 164, '그래서': 165, '문제': 166, '해': 167, '들어가다': 168, '쓰레기': 169, '밉다': 170, '남': 171, '한번': 172, '새': 173, '나가다': 174, '처럼': 175, '이제': 176, '데': 177, '문': 178, '다니다': 179, '건': 180, '올리다': 181, '조': 182, '써다': 183, '자기': 184, '빨다': 185, '머리': 186, '이야': 187, '좋아하다': 188, '수준': 189, '무슨': 190, '당': 191, '곳': 192, '이해': 193, '죽다': 194, '그렇게': 195, '이기': 196, '갈다': 197, '3': 198, '그게': 199, '주': 200, '보지': 201, '사실': 202, '기술': 203, '배우다': 204, '위': 205, '차다': 206, '다음': 207, '이런': 208, '이라': 209, '이상': 210, '직업': 211, '거리': 212, '처': 213, '저러다': 214, '보이다': 215, '명': 216, '니까': 217, '틀': 218, '댓글': 219, '다르다': 220, '찍다': 221, '벌다': 222, '싸다': 223, '친구': 224, '번': 225, '대가리': 226, '자체': 227, '그거': 228, '줄': 229, '키': 230, '그래도': 231, '요즘': 232, '노': 233, '짤': 234, '두': 235, '짱깨': 236, '어디': 237, '가능하다': 238, '야하다': 239, '누가': 240, '조선': 241, '제': 242, '노가다': 243, '팩트': 244, '사다': 245, '같이': 246, '세상': 247, '생기다': 248, '되어다': 249, '쓸다': 250, '감': 251, '7등': 252, '깔다': 253, '해도': 254, '후': 255, '식': 256, '홍어': 257, '본인': 258, '힘들다': 259, '에게': 260, '바로': 261, '현실': 262, '질': 263, '거지': 264, '형': 265, '인생': 266, '앞': 267, '놓다': 268, '물': 269, '인지': 270, '두다': 271, '찌다': 272, '세': 273, '다시': 274, '전라도': 275, '밖에': 276, '잡다': 277, '저렇게': 278, '비': 279, '짜다': 280, '솔직하다': 281, '뭘': 282, '날': 283, '장': 284, '넣다': 285, '구': 286, '상황': 287, '빨': 288, '시간': 289, '차': 290, '짓': 291, '보내다': 292, '그런': 293, '강사': 294, '분': 295, '끼': 296, '눈': 297, '인가': 298, '보수': 299, '머': 300, '이미': 301, '이면': 302, '이건': 303, '입': 304, '10': 305, '이쁘다': 306, '정신': 307, '기사': 308, '어': 309, '이노': 310, '제발': 311, '공무원': 312, '신': 313, '상': 314, '에는': 315, '사진': 316, '어리다': 317, '만나다': 318, '제대로': 319, '높다': 320, '사회': 321, '말다': 322, '대한민국': 323, '엔': 324, '얼굴': 325, '비다': 326, '경우': 327, '권': 328, '충': 329, '씨': 330, '국룰': 331, '학계': 332, '정설': 333, '여': 334, '망하다': 335, '일이': 336, '시작': 337, '쟤': 338, '경찰': 339, '입다': 340, '이라도': 341, '개새끼': 342, '거기': 343, '그걸': 344, '일게이': 345, '남다': 346, '정말': 347, '이유': 348, '믿다': 349, '정부': 350, '답': 351, '응': 352, '얘기': 353, '버': 354, '치고': 355, '당연하다': 356, '죽이다': 357, '4': 358, '동네': 359, '모': 360, '비슷하다': 361, '에선': 362, '밥': 363, '물론': 364, '타다': 365, '그건': 366, '양': 367, '끼리': 368, '수학': 369, '예전': 370, '자지': 371, '좌파': 372, '대구': 373, '여기': 374, '문재인': 375, '등': 376, '어차피': 377, '뿐': 378, '이기다': 379 ...

# %%
# 빈도수가 낮은 단어들은 자연어 처리에서 배제
# 등장 빈도수가 1회인 단어들이 이 데이터에서 얼만큼의 비중을 차지하는지 확인

threshold = 2
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0  # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0  # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0  # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value 

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1 # 빈도수가 2보다 작은 단어 개수 + 1
        rare_freq = rare_freq + value # 빈도수가 2보다 작은 단어들의 빈도수 총합

        
print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 10095
# 등장 빈도가 1번 이하인 희귀 단어의 수: 5669
# 단어 집합에서 희귀 단어의 비율: 56.15651312530956
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 11.49595441364346

# %%
# 등장 빈도수가 2이하인 단어들의 수를 제외한 단어의 개수를 단어 집합의 최대 크기로 제한

# 전체 단어 개수 중 빈도수 2이하인 단어는 제거.
# 0번 패딩 토큰을 고려하여 + 1

# 등장 빈도가 1회 이하인 단어들은 자연어 처리에서 별로 중요하지 않을 듯하여 정수인코딩 할때 없애줄것

vocab_size = total_cnt - rare_cnt + 1
print('단어 집합의 크기 :',vocab_size)
# Out:
# 단어 집합의 크기 : 4427

# %%
# 케라스 토크나이저의 인자로 넘겨주고 텍스트 시퀀스를 정수 시퀀스로 변환
# 높은 정수가 부여된 단어들은 등장 빈도수가 매우 낮다
# 빈도수가 낮은 단어들은 자연어 처리에서 배제

tokenizer = Tokenizer(vocab_size) 
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

# %%
# 정수 인코딩이 잘 되었나?
print(X_train[:5])
# Out:
# [[104, 2, 171, 522, 21, 2182, 57, 2, 10], [], [1428, 9, 2906, 428, 117, 61, 117, 188, 118, 855, 91, 765, 4, 67, 156, 49, 696], [27, 96, 455, 949, 88, 7, 29, 266, 552, 55], [553, 1429, 599, 2907, 1430, 21]]

# %%
print(train_y)
# Out:
# 1833    0
# 6204    1
# 4727    0
# 4456    1
# 2876    1
#        ..
# 4931    1
# 3264    1
# 1653    0
# 2607    1
# 2732    0
# Name: 비속어여부, Length: 5415, dtype: int64

# %%
print(test_y)
# Out:
# 1914    0
# 3433    0
# 1632    1
# 4906    0
# 2323    0
#        ..
# 5872    1
# 5548    0
# 1624    1
# 30      0
# 6201    1
# Name: 비속어여부, Length: 1354, dtype: int64

# %%
# y를 array 형식으로 저장해주기

y_train = np.array(train_y)
y_test = np.array(test_y)

# %%
print(y_train)
print(y_test)
# Out:
# [0 1 0 ... 0 1 0]
# [0 0 1 ... 1 0 1]

# %% [markdown]
# ### 패딩으로 댓글 길이 맞추기

# %%
print('리뷰의 최대 길이 :',max(len(review) for review in train_x))
print('리뷰의 평균 길이 :',sum(map(len, train_x))/len(train_x))

# 최대길이가 요상한 댓글이 있음
# Out:
# 리뷰의 최대 길이 : 911
# 리뷰의 평균 길이 : 26.21865189289012

# %%
def below_threshold_len(max_len, nested_list):
  count = 0
  for sentence in nested_list:
    if(len(sentence) <= max_len):
        count = count + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (count / len(nested_list))*100))

# %%
max_len = 30
below_threshold_len(max_len, X_train)

# 96 % 가 30 이하이기 때문에 최대글자수는 30으로 패딩해주는것이 좋을것같다.
# Out:
# 전체 샘플 중 길이가 30 이하인 샘플의 비율: 96.30655586334257

# %%
# 모든 샘플의 길이를 30으로 맞춘다 - 이때 정수인코딩한 데이터 사용!
X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)

# %%
print(X_train)
# Out:
# [[   0    0    0 ...   57    2   10]
#  [   0    0    0 ...    0    0    0]
#  [   0    0    0 ...  156   49  696]
#  ...
#  [   0    0    0 ...    0    0    0]
#  [   0    0    0 ...  307   14  898]
#  [   0    0    0 ...   83 1030  221]]

# %% [markdown]
# ### LSTM으로 분류하기
# #### 하이퍼파라미터
# - 임베딩 벡터 차원 = 100
# - 은닉 상태 크기 = 128
# - 배치 크기 = 64
# - 에포크 = 15

# %%
# !nvidia-smi
# Out:
# Wed May  4 06:30:01 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.103.01   Driver Version: 470.103.01   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  On   | 00000001:00:00.0 Off |                    0 |
# | N/A   28C    P0    31W / 250W |    497MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A     32592      C   python                            495MiB |
# +-----------------------------------------------------------------------------+

# %%
# 두 개의 선택지 중 하나를 예측하는 이진 분류 문제를 수행하는 모델    

from tensorflow.python.keras.layers import Embedding, Dense, LSTM
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.models import load_model
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint # 조기종료

# embedding_dim = 100
# hidden_units = 128

embedding_dim = 100
hidden_units = 128

model = Sequential()
model.add(Embedding(vocab_size, embedding_dim))
model.add(LSTM(hidden_units))
model.add(Dense(1, activation='sigmoid')) # 로지스틱 회귀를 사용해야 하기 때문에 sigmoid

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=3)
mc = ModelCheckpoint('best_model_v0.0.16.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
# mc = ModelCheckpoint('best_model_v0.0.12.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc']) # 훈련을 모니터링 하기 위한 지표 metrics=acc

# %%
history = model.fit(X_train, y_train, epochs=15, callbacks=[es, mc], batch_size=4, validation_split=0.2)
# Out:
# Epoch 1/15
# 1083/1083 [==============================] - 48s 43ms/step - loss: 0.6019 - acc: 0.6969 - val_loss: 0.4967 - val_acc: 0.7784
#
# Epoch 00001: val_acc improved from -inf to 0.77839, saving model to best_model_v0.0.16.h5
# Epoch 2/15
# 1083/1083 [==============================] - 46s 42ms/step - loss: 0.4487 - acc: 0.8105 - val_loss: 0.4696 - val_acc: 0.8061
#
# Epoch 00002: val_acc improved from 0.77839 to 0.80609, saving model to best_model_v0.0.16.h5
# Epoch 3/15
# 1083/1083 [==============================] - 46s 42ms/step - loss: 0.3674 - acc: 0.8497 - val_loss: 0.4889 - val_acc: 0.7959
#
# Epoch 00003: val_acc did not improve from 0.80609
# Epoch 4/15
# 1083/1083 [==============================] - 45s 42ms/step - loss: 0.3295 - acc: 0.8696 - val_loss: 0.4604 - val_acc: 0.8061
#
# Epoch 00004: val_acc did not improve from 0.80609
# Epoch 5/15
# 1083/1083 [==============================] - 43s 39ms/step - loss: 0.2965 - acc: 0.8862 - val_loss: 0.5210 - val_acc: 0.7913
#
# Epoch 00005: val_acc did not improve from 0.80609
# Epoch 6/15
# 1083/1083 [==============================] - 42s 38ms/step - loss: 0.2631 - acc: 0.8984 - val_loss: 0.5554 - val_acc: 0.7812
#
# Epoch 00006: val_acc did not improve from 0.80609
# Epoch 7/15
# 1083/1083 [==============================] - 42s 38ms/step - loss: 0.2345 - acc: 0.9118 - val_loss: 0.5989 - val_acc: 0.7959
#
# Epoch 00007: val_acc did not improve from 0.80609
# Epoch 00007: early stopping

# %%
# 모델 정확도 테스트
loaded_model = load_model('best_model_v0.0.16.h5')
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X_test, y_test)[1]))
# Out:
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 43/43 [==============================] - 1s 10ms/step - loss: 0.4682 - acc: 0.8013
#
#  테스트 정확도: 0.8013

# %%
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_13 (Embedding)     (None, None, 100)         442700
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 64)                42240
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 485,005
# Trainable params: 485,005
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 모델 사용해서 댓글 비속어 포함여부 예측해보기

# %%
def sentiment_predict(new_sentence):
    new_sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣 ]', '', str(new_sentence))
    new_sentence = okt.morphs(new_sentence, stem=True) # 토큰화
    new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
    encoded = tokenizer.texts_to_sequences([new_sentence]) # 정수 인코딩
    pad_new = pad_sequences(encoded, maxlen = max_len) # 패딩
    score = float(loaded_model.predict(pad_new)) # 예측
    if(score > 0.5):
        print("{:.2f}% 확률로 비속어가 포함된 댓글입니다.\n".format(score * 100))
    else:
        print("{:.2f}% 확률로 일반 댓글입니다.\n".format((1 - score) * 100))

# %%
sentiment_predict('쓰레기들은 휴지통으로')
# Out:
# '96.91% 확률로 비속어가 포함된 댓글입니다.'

# %%
sentiment_predict('미쳤나 진짜 시발')
# Out:
# '99.48% 확률로 비속어가 포함된 댓글입니다.'

# %%
sentiment_predict('진주네요...여기 동네에 잠시 살았는데...여기 주차 장난아닙니다.....그냥 욕만 나오죠...')
# Out:
# '67.83% 확률로 일반 댓글입니다.'

# %%
sentiment_predict('애새끼가 초딩도 아니고')
# Out:
# '98.97% 확률로 비속어가 포함된 댓글입니다.'

# %%
sentiment_predict('성형후 사진 원래 포샵 존나 하는거 아님? 실제로 보면 오른쪽같이 안생겼을듯')
# Out:
# '97.14% 확률로 비속어가 포함된 댓글입니다.'

# %%
sentiment_predict('내말이 ㅋㅋ 아직 세상물정을 잘 모르는것 같더라...사회생활이 적었나..')
# Out:
# '91.17% 확률로 일반 댓글입니다.'

# %%
sentiment_predict('집가서 마라탕 먹자')
# Out:
# '46.38% 확률로 비속어가 포함된 댓글입니다.'

# %%
loaded_model = load_model('./best_model.h5')
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %% [markdown]
# ## 크롤링 데이터

# %%
# forders = os.listdir('/home/adminuser/notebooks/modeling/raw_data/crawling/')

# df_all = pd.DataFrame()

# for i in range(0,len(forders)):
#     if forders[i].split('.')[1] == 'csv':
#         file = '/home/adminuser/notebooks/modeling/raw_data/crawling/'+forders[i]
#         df= pd.read_csv(file,encoding='utf-8') 
#         df_all = pd.concat([df_all, df])

# df_all = df_all.dropna()

# %%
# 크롤링 데이터셋 합치기

import os
file_list= os.listdir("../raw_data/crawling")
base= "../raw_data/crawling/"
prev=pd.DataFrame()
for i in file_list[2:4]: #마지막 5개 데이터만 합치기
    print(base+i)
    df= pd.read_csv(base+i)
    prev= pd.concat([prev,df], axis=0)
# Out:
# ../raw_data/crawling/네이쳐러브메레❄️Cool~❄️리츄얼낮잠이불54%OFF.csv
# ../raw_data/crawling/가정의_달_맞이❤보오글_시그니처_에디션_오픈🎁.csv

# %%
# def sentiment_predict(new_sentence):
#     new_sentence = re.compile('[^ A-Za-z0-9ㄱ-ㅣ가-힣]+').sub('', str(new_sentence))
#     new_sentence = okt.morphs(new_sentence, stem=True) # 토큰화        
#     new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
#     encoded = tokenizer.texts_to_sequences([new_sentence]) # 정수 인코딩
#     pad_new = pad_sequences(encoded, maxlen = max_len) # 패딩
#     score = float(load_model).predict(pad_new) # 예측
#     if(score > 0.3): # 1에 가까워질수록 욕의 범위가 넓어짐, 0일때 필터링 강도가 최대
#         return "{:.2f}% 확률로 비속어가 포함된 댓글입니다.".format(score * 100)
#     else:
#         return "{:.2f}% 확률로 일반 댓글입니다.".format((1 - score) * 100)

# %%
def sentiment_predict(new_sentence):
    new_sentence = re.compile('[^ A-Za-z0-9ㄱ-ㅣ가-힣]+').sub('', str(new_sentence))
    new_sentence = okt.morphs(new_sentence, stem=True) # 토큰화        
    new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
    encoded = tokenizer.texts_to_sequences([new_sentence]) # 정수 인코딩
    pad_new = pad_sequences(encoded, maxlen = max_len) # 패딩
    score = float(loaded_model.predict(pad_new)) # 예측
    if(score > 0.4): # 1에 가까워질수록 필터링강도가 약해지고, 0에 가까울때 필터링 강도가 최대
        return "{:.2f}% 확률로 비속어가 포함된 댓글입니다.".format(score * 100)
    else:
        return "{:.2f}% 확률로 일반 댓글입니다.".format((1 - score) * 100)

# %%
sentiment_predict('배고파') #0.8 을 기준으로 비속어와 안 비속어 갈라짐
# Out:
# '57.75% 확률로 비속어가 포함된 댓글입니다.'

# %%
sentiment_predict('하지말라고 좀') #0.6 일반 0.4 비속어
# Out:
# '57.75% 확률로 비속어가 포함된 댓글입니다.'

# %%
sentiment_predict('가나가나')
# Out:
# '57.75% 확률로 비속어가 포함된 댓글입니다.'

# %%
sentiment_predict('밥 먹어야지')
# Out:
# '68.58% 확률로 일반 댓글입니다.'

# %%
sentiment_predict('ㄱㄱ')
# Out:
# '57.75% 확률로 비속어가 포함된 댓글입니다.'

# %%
prev['result'] = prev[["comment"]].comment.map(lambda x: sentiment_predict(x))

# %%
if '*비속어' in prev['result']:
    print(prev['comment'])
else:
    pass

# %%
def check_a(x):
    if "비속어" in x:
        return 
prev[['comment', 'result']]
# Out:
#                                    comment                      result
# 0                                     우와!!  57.75% 확률로 비속어가 포함된 댓글입니다.
# 1    어머.. 진짜 뜯어서 보여주시니까 바로 믿을수 있을것 같아요!!!!        90.57% 확률로 일반 댓글입니다.
# 2                            여름에 쓰기 좋겠어요!!        71.29% 확률로 일반 댓글입니다.
# 3                      헐..ㅜㅜ 특가는 또 안하나요?ㅜㅜ        61.05% 확률로 일반 댓글입니다.
# 4                    카시트에도 설치가능한거 볼 수 있나요?        97.12% 확률로 일반 댓글입니다.
# ..                                     ...                         ...
# 116                                   투명유리  57.75% 확률로 비속어가 포함된 댓글입니다.
# 117                         사용기간은 어느정도 나요?        93.53% 확률로 일반 댓글입니다.
# 118                       코팅 수명 끝나면 다 교환해쥼        71.50% 확률로 일반 댓글입니다.
# 119                      잠만요 옵션 보고 온다 ㅋㅋㅋㅋ        94.75% 확률로 일반 댓글입니다.
# 120                      전 투명이 젤 쏙 들어오네요ㅋㅋ        63.74% 확률로 일반 댓글입니다.
#
# [181 rows x 2 columns]

# %%
def check_a(x):
    if "비속어" in x:
        return

# %%
prev[['comment','result']].sample(10)
# Out:
#             comment                      result
# 18   ㅋㅋ 주방 용품 계 꾸안꾸        61.33% 확률로 일반 댓글입니다.
# 101         뚜껑도 좋네요        72.01% 확률로 일반 댓글입니다.
# 111     뚜껑 넘 좋아보이네요        85.95% 확률로 일반 댓글입니다.
# 49    바쁘다 바쁜 난주언니ㅋㅋ        79.42% 확률로 일반 댓글입니다.
# 42              ㅋㅋㅋ  57.75% 확률로 비속어가 포함된 댓글입니다.
# 4           있어보여요 ㅎ        94.33% 확률로 일반 댓글입니다.
# 99       맢치마도 버거요 ㅋ        90.30% 확률로 일반 댓글입니다.
# 5           바다로 갑니다        88.33% 확률로 일반 댓글입니다.
# 22          가 아니고 ~        98.18% 확률로 일반 댓글입니다.
# 37           추카드려요♡        76.13% 확률로 일반 댓글입니다.

# %%
def slang_predict(new_sentence):
    new_sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣 ]', '', new_sentence)
    if new_sentence == "" or new_sentence.isspace():
        return "일반 댓글"
    else : 
        new_sentence = okt.morphs(new_sentence, stem=True)
        new_sentence = [word for word in new_sentence if not word in stopwords]
        if not new_sentence:
            return "일반 댓글"
        else:
            encoded = tokenizer.texts_to_sequences([new_sentence])
            pad_new = pad_sequences(encoded, maxlen = max_len)
            score = loaded_model.predict(pad_new)
            if(score > 0.4): # 1에 가까워질수록 필터링강도가 약해지고, 0에 가까울때 필터링 강도가 최대
                return "비속어 포함"
            else:
                return "일반 댓글"
            
        
#         return round(float(score), 2)
        
#     if(score > 0.4): # 1에 가까워질수록 필터링강도가 약해지고, 0에 가까울때 필터링 강도가 최대
#         return "{:.2f}% 확률로 비속어가 포함된 댓글입니다.".format(score * 100)
#     else:
#         return "{:.2f}% 확률로 일반 댓글입니다.".format((1 - score) * 100)

# %%
prev['result2'] = prev[["comment"]].comment.map(lambda x: slang_predict(x))

# %%
prev[['comment','result']].sample(10)
# Out:
#                            comment                      result
# 50                 낮잠이불 디자인 진짜 이쁘다        90.39% 확률로 일반 댓글입니다.
# 64                     블랙도 너무 이쁘네요        88.93% 확률로 일반 댓글입니다.
# 33                 바닥에 깔린상품은 뭐에요??        85.76% 확률로 일반 댓글입니다.
# 57                         분리형 일체형        66.31% 확률로 일반 댓글입니다.
# 31                        ㅋㅋㅋㅋㅋㅋㅋㅋ  57.75% 확률로 비속어가 포함된 댓글입니다.
# 27                   계곡물에 수박 넣는 느낌  44.00% 확률로 비속어가 포함된 댓글입니다.
# 31      1+1이네요ㅎㅎㅎ 역시 네러메 라방은 혜자네요~        82.01% 확률로 일반 댓글입니다.
# 84                        제품 기대됩니다        92.63% 확률로 일반 댓글입니다.
# 23   휴대용 유모차 쓸랴고 하는데 배게도 한번 붙야주세요융        86.72% 확률로 일반 댓글입니다.
# 116                           투명유리  57.75% 확률로 비속어가 포함된 댓글입니다.

# %%
def swear_predict(new_sentence):
    new_sentence = re.compile('[^ 0-9ㄱ-ㅎㅏ-ㅣ가-힣]+').sub('', str(new_sentence))
    if new_sentence == "" or new_sentence.isspace():
        return "일반 댓글"
    else:
        new_sentence = okt.morphs(new_sentence, stem=True) # 토큰화
        new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
        if not new_sentence:
            return "일반 댓글"
        else:    
            encoded = tokenizer.texts_to_sequences([new_sentence]) # 정수 인코딩
            pad_new = pad_sequences(encoded, maxlen = max_len) # 패딩
            score = float(loaded_model.predict(pad_new)) # 예측
            if(score > 0.4):
                print(new_sentence)
                print("{:.2f}% 확률로 비속어가 포함된 댓글입니다.\n".format(score * 100))
                #  return round(float(score), 3)
            else:
                print(new_sentence)
                print("{:.2f}% 확률로 일반 댓글입니다.\n".format((1 - score) * 100))

# %%
prev['result4'] = prev[["comment"]].comment.map(lambda x: swear_predict(x))
# Out:
# ['우와']
# 57.75% 확률로 비속어가 포함된 댓글입니다.
#
# ['어머', '진짜', '뜯다', '보여주다', '바로', '믿다', '있다', '같다']
# 90.57% 확률로 일반 댓글입니다.
#
# ['여름', '쓰기', '좋다']
# 71.29% 확률로 일반 댓글입니다.
#
# ['헐다', 'ㅜㅜ', '특가', '또', '알다', 'ㅜㅜ']
# 61.05% 확률로 일반 댓글입니다.
#
# ['카시트', '에도', '설치', '가능하다', '볼', '수', '있다']
# 97.12% 확률로 일반 댓글입니다.
#
# ['저렇게', '테스트', '까지', '아이', '여름', '쉬', '원하다', '같다']
# 81.93% 확률로 일반 댓글입니다.
#
# ['시원하다']
# 45.56% 확률로 비속어가 포함된 댓글입니다.
#
# ['통', '기성', '좋다']
# 66.62% 확률로 일반 댓글입니다.
#
# ['대박', '대박']
# 57.75% 확률로 비속어가 포함된 댓글입니다.
#
# ['구매', '습', '니당다']
# 44.29% 확률로 비속어가 포함된 댓글입니다.
#
# ['맘', '님', '들다', '혹시', '신생아', '때', '써다', '되다']
# 95.33% 확률로 일반 댓글입니다.
#
# ['여름', '아', '기다리다', '우린', '준비', '돼다']
# 82.03% 확률로 일반 댓글입니다.
#
# ['저', '선풍기', '색깔', '너무', '예쁘다']
# 91.16% 확률로 일반 댓글입니다.
#
# ['오', '쿨', '라이너', '정말', '시원하다', '같다', '대박', 'ㅎㅎㅎㅎ']
# 88.41% 확률로 일반 댓글입니다.
#
# ['어디', '든', '호환', '가능하다']
# 77.53% 확률로 일반 댓글입니다.
#
# ['살랑살랑']
# 57.75% 확률로 비속어가 포함된 댓글입니다.
#
# ['라이너', '대박', '이네', '여']
# 64.86% 확률로 일반 댓글입니다.
#
# ['우리', '아들', '열', '많다', '걱정', '이다', '너무', '좋아하다']
# 97.89% 확률로 일반 댓글입니다.
#
# ['감사']
# 57.75% 확률로 비속어가 포함된 댓글입니다.
#
# ['여름', '땀띠', '걱정', '안해', '되다', '겠다']
# 87.95% 확률로 일반 댓글입니다.
#
# ['살균', '소독제', '13900원', '라이브', '맞다', '확인', '해주다', '답변']
# 92.23% 확률로 일반 댓글입니다.
#
# ['기능', '성', '제대로', '보여주다', '네', '여']
# 86.26% 확률로 일반 댓글입니다.
#
# ['세다', '좋다']
# 72.11% 확률로 일반 댓글입니다.
#
# ['휴대', '용', '유모차', '쓸다', '고', '배다', '한번', '붙다', '융']
# 86.72% 확률로 일반 댓글입니다.
#
# ['여름', '통기다', '너무', '중요하다']
# 84.01% 확률로 일반 댓글입니다.
#
# ['하이', '체어', '에도', '사용', '가능하다', '오다']
# 92.52% 확률로 일반 댓글입니다.
#
# ['좋다', '좋다']
# 73.30% 확률로 일반 댓글입니다.
#
# ['활', '용도', '너무', '좋다']
# 85.94% 확률로 일반 댓글입니다.
#
# ['안', '그렇다', '쩍쩍', '붙다', '신경', '쓰이다']
# 73.31% 확률로 일반 댓글입니다.
#
# ['하이', '체어', '특', '또', '열다', 'ㅠㅠ']
# 53.39% 확률로 비속어가 포함된 댓글입니다.
#
# ['와우']
# 62.55% 확률로 일반 댓글입니다.
#
# ['11', '이다', 'ㅎㅎㅎ', '역시', '네러메', '라', '방', '혜자', '네', '요']
# 82.01% 확률로 일반 댓글입니다.
#
# ['배다', '너무', '귀엽다', '세트', '에요']
# 66.36% 확률로 일반 댓글입니다.
#
# ['바닥', '깔리다', '상품', '뭐', '에요']
# 85.76% 확률로 일반 댓글입니다.
#
# ['벌써', '덥다', '보다', '이번', '여름', '넘다', '덥다', 'ㅜㅜㅜㅜ']
# 73.74% 확률로 일반 댓글입니다.
#
# ['여름', '아이', '아이스크림', '좋아하다', '원', '플', '원', '이라서', '좋다']
# 81.29% 확률로 일반 댓글입니다.
#
# ['구매', '인증', '어떻다', '하나요']
# 88.49% 확률로 일반 댓글입니다.
#
# ['선물', '용', '구매', '되다']
# 92.71% 확률로 일반 댓글입니다.
#
# ['오']
# 87.39% 확률로 일반 댓글입니다.
#
# ['낮잠', '이불', '구매', '들어오다']
# 69.46% 확률로 일반 댓글입니다.
#
# ['원플', '항상', '좋다', 'ㅎ']
# 68.93% 확률로 일반 댓글입니다.
#
# ['낮잠', '이불']
# 45.91% 확률로 비속어가 포함된 댓글입니다.
#
# ['ㅋㅋㅋ']
# 57.75% 확률로 비속어가 포함된 댓글입니다.
#
# ['귀', '쫑긋', 'ㅎㅎㅎ']
# 41.06% 확률로 비속어가 포함된 댓글입니다.
#
# ['ㅋㅋㅋ']
# 57.75% 확률로 비속어가 포함된 댓글입니다.
#
# ['히잉']
# 57.75% 확률로 비속어가 포함된 댓글입니다.
#
# ['낮잠', '이불', '하나요']
# 45.91% 확률로 비속어가 포함된 댓글입니다.
#
# ['퀴즈', '어렵다', '싫다', 'ㅋㅋㅋ']
# 69.09% 확률로 일반 댓글입니다.
#
# ['퀴즈', '어렵다', '가보다']
# 66.00% 확률로 일반 댓글입니다.
#
# ['바쁘다', '바쁘다', '난주', '언니', 'ㅋㅋ']
# 79.42% 확률로 일반 댓글입니다.
#
# ['낮잠', '이불', '디자인', '진짜', '이쁘다']
# 90.39% 확률로 일반 댓글입니다.
#
# ['낮잠', '이불', '가겯', '할인', '듀', 'ㅏㅆ', '나요']
# 62.76% 확률로 일반 댓글입니다.
#
# ['2', '가지']
# 73.31% 확률로 일반 댓글입니다.
#
# ['낮잠', '이불', '설명', '특히', '열심히', '들다']
# 45.69% 확률로 비속어가 포함된 댓글입니다.
#
# ['어리다', 'ㅠ']
# 44.64% 확률로 비속어가 포함된 댓글입니다.
#
# ['일체', '형', '분리', '형']
# 66.55% 확률로 일반 댓글입니다.
#
# ['퀴즈', '쉽다', '걸', '로']
# 95.22% 확률로 일반 댓글입니다.
#
# ['분리', '형', '일체', '형']
# 66.31% 확률로 일반 댓글입니다.
#
# ['부탁']
# 60.06% 확률로 일반 댓글입니다.
#
# ['ㅋㅋㅋ']
# 57.75% 확률로 비속어가 포함된 댓글입니다.
#
# ['수', '남', '없다', '저', '거사', '면', '공간', '필요', '없다']
# 91.58% 확률로 일반 댓글입니다.
#
# ['바로', '지르다', '가보다', 'ㅠㅠ']
# 81.92% 확률로 일반 댓글입니다.
#
# ['부엌', '진짜', '은근', '짐', '많다', '요', '래', '딱', '정리', '되다', '너무', '좋다']
# 61.82% 확률로 일반 댓글입니다.
#
# ['진짜', '완벽하다']
# 84.68% 확률로 일반 댓글입니다.
#
# ['있다', '보이다', 'ㅎ']
# 94.33% 확률로 일반 댓글입니다.
#
# ['바다로', '가다']
# 88.33% 확률로 일반 댓글입니다.
#
# ['고급', '졍']
# 63.98% 확률로 일반 댓글입니다.
#
# ['고급', '졍']
# 63.98% 확률로 일반 댓글입니다.
#
# ['왠지', '구성', '계속', '있다', '것', '같다', '않다', '1', '달', '고민', '지르다', '보다']
# 97.94% 확률로 일반 댓글입니다.
#
# ['얼굴', '보다', '크다', 'ㅋㅋ']
# 96.13% 확률로 일반 댓글입니다.
#
# ['산', '들다', '어디', '든']
# 63.63% 확률로 일반 댓글입니다.
#
# ['너무', '이쁘다', '세트', '세트']
# 88.93% 확률로 일반 댓글입니다.
#
# ['어딜', '그렇게', '내려가다']
# 82.78% 확률로 일반 댓글입니다.
#
# ['ㅋㅋㅋ']
# 57.75% 확률로 비속어가 포함된 댓글입니다.
#
# ['같다']
# 63.46% 확률로 일반 댓글입니다.
#
# ['같다']
# 63.46% 확률로 일반 댓글입니다.
#
# ['꾸다', '꾸다', '느낌']
# 53.94% 확률로 비속어가 포함된 댓글입니다.
#
# ['이왕이면', '이쁘다']
# 68.00% 확률로 일반 댓글입니다.
#
# ['ㅋㅋ', '주방', '용품', '계', '꾸다', '꾸다']
# 61.33% 확률로 일반 댓글입니다.
#
# ['다', '사다', '30만원', '두', '안되다', '대박']
# 74.74% 확률로 일반 댓글입니다.
#
# ['구매', '인증', '2022042842480831']
# 70.01% 확률로 일반 댓글입니다.
#
# ['코', 'ㅋㅋㅋ']
# 69.53% 확률로 일반 댓글입니다.
#
# ['가다', '아니다']
# 98.18% 확률로 일반 댓글입니다.
#
# ['오늘', '작정', '하고', '가져오다', '가격', '혜택', '이네', '요']
# 89.33% 확률로 일반 댓글입니다.
#
# ['우왕']
# 57.75% 확률로 비속어가 포함된 댓글입니다.
#
# ['얼음', '물', '좋다']
# 60.10% 확률로 일반 댓글입니다.
#
# ['ㅋㅋㅋ', '얼음']
# 57.75% 확률로 비속어가 포함된 댓글입니다.
#
# ['계곡', '물', '수박', '넣다', '느낌']
# 44.00% 확률로 비속어가 포함된 댓글입니다.
#
# ['맞다', '살리다', '비싸다', 'ㅋ']
# 91.42% 확률로 일반 댓글입니다.
#
# ['효율', '장인', '보오', '글']
# 57.80% 확률로 비속어가 포함된 댓글입니다.
#
# ['목화', '솜', '닦다', '소중하다', '내', '얼굴', '보오', '글', '챙기다', '주다']
# 87.11% 확률로 일반 댓글입니다.
#
# ['ㅋㅋㅋㅋㅋㅋㅋㅋ']
# 57.75% 확률로 비속어가 포함된 댓글입니다.
#
# ['뜨겁다', '여름', '무쟈', '게', '요긴']
# 71.18% 확률로 일반 댓글입니다.
#
# ['진심', '당장', '떠나다', '싶다', 'ㅋㅋ']
# 50.56% 확률로 비속어가 포함된 댓글입니다.
#
# ['충분하다', '겄', '네', '요']
# 95.93% 확률로 일반 댓글입니다.
#
# ['구매', '인증', '2022042842824531']
# 70.01% 확률로 일반 댓글입니다.
#
# ['삶의질', '수직', '상승']
# 43.74% 확률로 비속어가 포함된 댓글입니다.
#
# ['추카', '드리다']
# 76.13% 확률로 일반 댓글입니다.
#
# ['에잇', '다음', '기회']
# 71.12% 확률로 일반 댓글입니다.
#
# ['추카', '추카', '추카', '치카', '포카']
# 57.75% 확률로 비속어가 포함된 댓글입니다.
#
# ['축하', '드리다']
# 79.08% 확률로 일반 댓글입니다.
#
# ['추카', '추카', '추카', '치카', '포카']
# 57.75% 확률로 비속어가 포함된 댓글입니다.
#
# ['축하', '드리다']
# 79.08% 확률로 일반 댓글입니다.
#
# ['ㅋㅋㅋ', '저', '요']
# 95.59% 확률로 일반 댓글입니다.
#
# ['저', '지금', '당장', '떠나다', '싶다']
# 70.47% 확률로 일반 댓글입니다.
#
# ['가정', '달이', '라']
# 40.48% 확률로 비속어가 포함된 댓글입니다.
#
# ['엄빠', '한테', '선물', '똬']
# 64.17% 확률로 비속어가 포함된 댓글입니다.
#
# ['플렉스', '해보다']
# 62.37% 확률로 일반 댓글입니다.
#
# ['떠나다', '보오', '글', '함께', 'ㅋㅋ']
# 46.15% 확률로 비속어가 포함된 댓글입니다.
#
# ['착', '붙다']
# 65.73% 확률로 일반 댓글입니다.
#
# ['수납', '미치다', '따다']
# 99.32% 확률로 비속어가 포함된 댓글입니다.
#
# ['어', '반찬', '통']
# 63.33% 확률로 일반 댓글입니다.
#
# ['반찬', '통']
# 44.81% 확률로 비속어가 포함된 댓글입니다.
#
# ['맞다', '정리', 'ㅜ']
# 89.04% 확률로 일반 댓글입니다.
#
# ['와우']
# 62.55% 확률로 일반 댓글입니다.
#
# ['하지만', '하나', '씩', '쌓다', '쥬']
# 82.85% 확률로 일반 댓글입니다.
#
# ['정리', '되다', '좋다']
# 91.22% 확률로 일반 댓글입니다.
#
# ['공간', '차지']
# 67.06% 확률로 일반 댓글입니다.
#
# ['수납', '미치다', 'ㅠㅠ']
# 98.74% 확률로 비속어가 포함된 댓글입니다.
#
# ['정리', '딱', '딱', '지키다']
# 93.12% 확률로 비속어가 포함된 댓글입니다.
#
# ['수납', '미치다', '지리', '고', '레릿', '고', 'ㅠㅠ']
# 80.22% 확률로 비속어가 포함된 댓글입니다.
#
# ['오', '근데', '영', '상보', '니까']
# 93.29% 확률로 일반 댓글입니다.
#
# ['블랙', '너무', '이쁘다']
# 88.93% 확률로 일반 댓글입니다.
#
# ['공감', '공감']
# 64.58% 확률로 일반 댓글입니다.
#
# ['그냥', '블랙', '살다', '나']
# 95.72% 확률로 일반 댓글입니다.
#
# ['깔다', '끄다', '굿']
# 81.02% 확률로 비속어가 포함된 댓글입니다.
#
# ['우와', '교환', '요']
# 92.49% 확률로 일반 댓글입니다.
#
# ['등짝', '조심']
# 57.75% 확률로 비속어가 포함된 댓글입니다.
#
# ['색상', '레드', '밖에', '없다']
# 94.39% 확률로 일반 댓글입니다.
#
# ['5년', 'ㅜ']
# 55.12% 확률로 비속어가 포함된 댓글입니다.
#
# ['색상', '블랙', '이랑', '베이지', '랑', '버건디', '있다']
# 90.78% 확률로 일반 댓글입니다.
#
# ['건강', '위해', '선', '그렇다']
# 85.68% 확률로 일반 댓글입니다.
#
# ['안녕하다']
# 57.75% 확률로 비속어가 포함된 댓글입니다.
#
# ['난', '얼마나', '써다', '드', '라']
# 69.58% 확률로 일반 댓글입니다.
#
# ['마자', '욬', 'ㅋㅋㅋ', '코팅', '벗겨지다', '그냥', '써다', 'ㅠㅠ']
# 84.90% 확률로 일반 댓글입니다.
#
# ['크다', '넘다', '늦다', '온건', '아니다']
# 96.29% 확률로 일반 댓글입니다.
#
# ['네', '넘다', '늦다', '들어오다']
# 76.09% 확률로 일반 댓글입니다.
#
# ['10분', '밖에', '안남다']
# 81.54% 확률로 일반 댓글입니다.
#
# ['그렇다', '빠르다', '구매', '쥬']
# 73.37% 확률로 일반 댓글입니다.
#
# ['또', '언제', '실시간', '방송']
# 81.13% 확률로 일반 댓글입니다.
#
# ['ㅠㅠ', '반성', '중']
# 85.60% 확률로 일반 댓글입니다.
#
# ['제품', '기대', '되다']
# 92.63% 확률로 일반 댓글입니다.
#
# ['보다']
# 91.97% 확률로 일반 댓글입니다.
#
# ['지구', '지키다', '밉다', '뽀오글']
# 86.59% 확률로 비속어가 포함된 댓글입니다.
#
# ['구매', '고고']
# 44.29% 확률로 비속어가 포함된 댓글입니다.
#
# ['네넹', '기대', '되다']
# 93.60% 확률로 일반 댓글입니다.
#
# ['앞치마', '예쁘다', 'ㅋㅋㅋ']
# 43.22% 확률로 비속어가 포함된 댓글입니다.
#
# ['전이', '밉다', '사다', 'ㅋ']
# 87.34% 확률로 비속어가 포함된 댓글입니다.
#
# ['앞치마', '진짜', '이쁘다']
# 90.33% 확률로 일반 댓글입니다.
#
# ['5월', '초', '구입', '가능하다']
# 65.64% 확률로 일반 댓글입니다.
#
# ['가방', '있다']
# 91.70% 확률로 일반 댓글입니다.
#
# ['저번', '보다', '더', '할인', '많다', 'ㅠㅠ']
# 94.28% 확률로 일반 댓글입니다.
#
# ['베이지', '이쁘다', '네이비', '고급', '지다']
# 48.25% 확률로 비속어가 포함된 댓글입니다.
#
# ['배', '아프다']
# 65.27% 확률로 일반 댓글입니다.
#
# ['캠핑', '가방']
# 44.33% 확률로 비속어가 포함된 댓글입니다.
#
# ['맢치마', '버거', '요', 'ㅋ']
# 90.30% 확률로 일반 댓글입니다.
#
# ['우와', '시간', '후딱', '가다']
# 87.84% 확률로 일반 댓글입니다.
#
# ['뚜껑', '좋다']
# 72.01% 확률로 일반 댓글입니다.
#
# ['비교', '해주다', '이해', '가다']
# 88.99% 확률로 일반 댓글입니다.
#
# ['앞치마', '새롭다', '나오다']
# 84.86% 확률로 일반 댓글입니다.
#
# ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ']
# 57.75% 확률로 비속어가 포함된 댓글입니다.
#
# ['뚜껑', '우와', '진짜', '예쁘다']
# 89.35% 확률로 일반 댓글입니다.
#
# ['깨끗하다']
# 43.19% 확률로 비속어가 포함된 댓글입니다.
#
# ['얼굴', '자다', '보이', '네', '여']
# 79.03% 확률로 일반 댓글입니다.
#
# ['뚜껑', '찌다', '영']
# 74.14% 확률로 비속어가 포함된 댓글입니다.
#
# ['투명하다', 'ㅋ']
# 57.75% 확률로 비속어가 포함된 댓글입니다.
#
# ['다음', '방송', '언제', '쯤', '이다', '요']
# 97.06% 확률로 일반 댓글입니다.
#
# ['뚜껑', '넘다', '좋다', '보이다']
# 85.95% 확률로 일반 댓글입니다.
#
# ['중요하다']
# 50.37% 확률로 비속어가 포함된 댓글입니다.
#
# ['코팅']
# 57.75% 확률로 비속어가 포함된 댓글입니다.
#
# ['징', '짜다', '편하다']
# 60.49% 확률로 비속어가 포함된 댓글입니다.
#
# ['우와']
# 57.75% 확률로 비속어가 포함된 댓글입니다.
#
# ['투명', '유리']
# 57.75% 확률로 비속어가 포함된 댓글입니다.
#
# ['사', '용기', '간', '어느', '정도', '나요']
# 93.53% 확률로 일반 댓글입니다.
#
# ['코팅', '수명', '끝나다', '다', '교환', '쥼']
# 71.50% 확률로 일반 댓글입니다.
#
# ['잠', '만', '요', '옵션', '보고', '오다', 'ㅋㅋㅋㅋ']
# 94.75% 확률로 일반 댓글입니다.
#
# ['전', '투명', '젤', '쏙', '들어오다', 'ㅋㅋ']
# 63.74% 확률로 일반 댓글입니다.

# %%
prev[['comment','result','result2', 'result3', 'result4']].sample(10)
# Out:
#            comment                      result result2 result3 result4
# 56         퀴즈 쉬운걸로        95.22% 확률로 일반 댓글입니다.   일반 댓글   일반 댓글    None
# 109          투명하다ㅋ  57.75% 확률로 비속어가 포함된 댓글입니다.  비속어 포함     비속어    None
# 58           부탁합니다        60.06% 확률로 일반 댓글입니다.   일반 댓글   일반 댓글    None
# 8             대박대박  57.75% 확률로 비속어가 포함된 댓글입니다.  비속어 포함     비속어    None
# 40           축하드려요        79.08% 확률로 일반 댓글입니다.   일반 댓글   일반 댓글    None
# 55      The Love..  57.75% 확률로 비속어가 포함된 댓글입니다.   일반 댓글       0   일반 댓글
# 2    여름에 쓰기 좋겠어요!!        71.29% 확률로 일반 댓글입니다.   일반 댓글   일반 댓글    None
# 102  비교해주시 이해가 가네요        88.99% 확률로 일반 댓글입니다.   일반 댓글   일반 댓글    None
# 92    앞치마도 진짜 이뻐요♡        90.33% 확률로 일반 댓글입니다.   일반 댓글   일반 댓글    None
# 6              고급졍        63.98% 확률로 일반 댓글입니다.   일반 댓글   일반 댓글    None
