# %%
import pandas as pd
import numpy as np
# import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./hate_speech_binary_dataset.csv')
df.head(10)
# Out:
#                                                   문장  혐오 여부
# 0                              정말 재밌다 연기도 좋고 디카프리오 짱      1
# 1                    심쿵심쿵 미치네요이수혁땜에 잠 못자겠어요ㅠ자꾸 아른거림ㅠ      1
# 2                          하지만 이니후빨러들은 이런거 관심 하나도 없음      0
# 3                                  @착한아이임당 A4 용지 덮고?      0
# 4  진짜 평점 믿으면 안된 다는 걸 현실로 보여주는 영화입니다. 네티즌,전문가 하나같이...      1
# 5           조원진이 비례대표나 경북에서 공천 못받고도 입다물면 친중질히던거 이해할게      0
# 6                                후!!!!!!!!!!! 쩔었다...      1
# 7  오랜만에 휴가내서 조카들 데리고 보고나왔어요 !! 조카들이 너무 좋아해서 평점 10...      1
# 8        제목만 보고도 더러운 머리스탈 떠올랐다 이름보다 아 그더런새끼겠지? 이랬다니까      0
# 9                                      중국 공산당 보는것 같다      0

# %%
# 특수문자, 이모티콘 제거 하는 방법 예시

import re

sentence = "@KyunRyong ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 멜론 참고 https://t.co/ode2U1aw"
    
sentence_split = sentence.split()
sentence_split_result = []

for word in sentence_split:
    if word[0] != "@" and word[:4] !="http":
        sentence_split_result.append(word)

sentence_result =" ".join(sentence_split_result)

text_result = "".join(re.compile('[가-힣|0-9|a-z| ]+').\
findall(sentence_result)).strip()

text_result
# Out:
# '멜론 참고'

# %%
# 문장을 나누기 위해서 str 처리 해주기

df['문장'] = df['문장'].astype('string')

# %%
df = df.dropna(axis=0)
df.isnull().sum()
# Out:
# 문장       0
# 혐오 여부    0
# dtype: int64

# %%
# 전체 데이터에 적용시키기 위한 과정

def preprocessing(sentence):
    sentence_split = sentence.split()
    sentence_split_result = []
    for word in sentence_split:
        if word[0] != '@' and word[:4] !='http':
            sentence_split_result.append(word)
    sentence_result = ' '.join(sentence_split_result)
    text_result = ''.join(re.compile('[가-힣|0-9|a-z| ]+').\
    findall(sentence_result)).strip()
    return text_result

df["문장"] = df["문장"].apply(preprocessing)

# %%
df.head(10)
# Out:
#                                                   문장  혐오 여부
# 0                              정말 재밌다 연기도 좋고 디카프리오 짱      1
# 1                      심쿵심쿵 미치네요이수혁땜에 잠 못자겠어요자꾸 아른거림      1
# 2                          하지만 이니후빨러들은 이런거 관심 하나도 없음      0
# 3                                            4 용지 덮고      0
# 4  진짜 평점 믿으면 안된 다는 걸 현실로 보여주는 영화입니다 네티즌전문가 하나같이 영...      1
# 5           조원진이 비례대표나 경북에서 공천 못받고도 입다물면 친중질히던거 이해할게      0
# 6                                              후 쩔었다      1
# 7  오랜만에 휴가내서 조카들 데리고 보고나왔어요  조카들이 너무 좋아해서 평점 10점 남겨용      1
# 8         제목만 보고도 더러운 머리스탈 떠올랐다 이름보다 아 그더런새끼겠지 이랬다니까      0
# 9                                      중국 공산당 보는것 같다      0

# %%
# 것, 너, 후 ... 처럼 1글자로 이루어진 단어 제거하는 방법 예시

sentence = "으흑흑 나 나비님 보러가게해줘"
sentence_list = []

for index in range(len(sentence.split())):
    if len(sentence.split()[index]) > 1: #문자 1글자 초과일 때
        sentence_list.append(sentence.split()[index]) #문자 1글자로 이루어진 단어만 빼고 sentence_list에 추가
        
sentence = " ".join(sentence_list) #리스트의 내용을 하나의 문자열로 join
sentence
# Out:
# '으흑흑 나비님 보러가게해줘'

# %%
# 한글자 삭제 전체데이터에 적용

def onewordremove(sentence):
    sentence_list = []
    for index in range(len(sentence.split())):
        if len(sentence.split()[index]) > 1: #문자 1글자 초과일 때
            sentence_list.append(sentence.split()[index]) #문자 1글자로 이루어진 단어만 빼고 sentence_list에 추가
    sentence = " ".join(sentence_list) #리스트의 내용을 하나의 문자열로 join
    return sentence

df['문장'] = df['문장'].apply(onewordremove)

# %%
df.head(10)
# Out:
#                                                   문장  혐오 여부
# 0                                정말 재밌다 연기도 좋고 디카프리오      1
# 1                        심쿵심쿵 미치네요이수혁땜에 못자겠어요자꾸 아른거림      1
# 2                          하지만 이니후빨러들은 이런거 관심 하나도 없음      0
# 3                                              용지 덮고      0
# 4  진짜 평점 믿으면 안된 다는 현실로 보여주는 영화입니다 네티즌전문가 하나같이 영화에...      1
# 5           조원진이 비례대표나 경북에서 공천 못받고도 입다물면 친중질히던거 이해할게      0
# 6                                                쩔었다      1
# 7   오랜만에 휴가내서 조카들 데리고 보고나왔어요 조카들이 너무 좋아해서 평점 10점 남겨용      1
# 8           제목만 보고도 더러운 머리스탈 떠올랐다 이름보다 그더런새끼겠지 이랬다니까      0
# 9                                      중국 공산당 보는것 같다      0

# %%
# 한 문장 내에 5단어 이하 문장 제거하고 글자수 컬럼 생성

def word_split(x):
    return len(x.split()) #단어의 개수 return
df['글자수'] = df['문장'].apply(word_split)
df = df[df.글자수>=5] #5개 이상만 남긴다

# %%
df.head()
# Out:
#                                                   문장  혐오 여부  글자수
# 0                                정말 재밌다 연기도 좋고 디카프리오      1    5
# 2                          하지만 이니후빨러들은 이런거 관심 하나도 없음      0    6
# 4  진짜 평점 믿으면 안된 다는 현실로 보여주는 영화입니다 네티즌전문가 하나같이 영화에...      1   19
# 5           조원진이 비례대표나 경북에서 공천 못받고도 입다물면 친중질히던거 이해할게      0    8
# 7   오랜만에 휴가내서 조카들 데리고 보고나왔어요 조카들이 너무 좋아해서 평점 10점 남겨용      1   11

# %%
# 한 문장 내에 25단어 이상인 문장 제거

df = df[df.글자수<=25]
df
# Out:
#                                                        문장  혐오 여부  글자수
# 0                                     정말 재밌다 연기도 좋고 디카프리오      1    5
# 2                               하지만 이니후빨러들은 이런거 관심 하나도 없음      0    6
# 4       진짜 평점 믿으면 안된 다는 현실로 보여주는 영화입니다 네티즌전문가 하나같이 영화에...      1   19
# 5                조원진이 비례대표나 경북에서 공천 못받고도 입다물면 친중질히던거 이해할게      0    8
# 7        오랜만에 휴가내서 조카들 데리고 보고나왔어요 조카들이 너무 좋아해서 평점 10점 남겨용      1   11
# ...                                                   ...    ...  ...
# 189993                지들 물건이라고 부셔먹었네 전세집에 공사 허가하면 안된다 이래서      0    8
# 189994                              드라마도 완전 재밌고 배우들도 멋있어서      1    5
# 189995  원작을 읽을 이런 절대 영상화하기 힘들다고 생각했는데 벤휘쇼의 연기와 더불어 나름 ...      1   22
# 189997        day and night round the clock without break      0    8
# 189998           로버트다우니주니어를 좋아해서 봤는데너무재밌게 봤던영화생각없이 볼때 딱좋음      1    6
#
# [95991 rows x 3 columns]

# %% [markdown]
# # 자모 분류, fast text 는 git 참고
# https://github.com/smothly/bad-word-detection/blob/master/FastTextVocab.ipynb

# %%
df.dtypes
# Out:
# 문장       object
# 혐오 여부     int64
# 글자수       int64
# dtype: object

# %%
# 특수문자나 한자 등이 안날라 갔을 경우를 처리
import re
pattern = re.compile("[^ㄱ-ㅎㅏ-ㅣ가-힣0-9a-zA-Z ]") # 한글 숫자 영어 공백 말고 제거

# 각 단어에 해당 해당 정규표현식 적용
def clear_word(word):
    word = re.sub(pattern, "", word)
    return word

df['문장'] = df['문장'].astype('str')
df['문장'] = df['문장'].apply(lambda x: clear_word(x))

# %%
# index 뒤죽박죽 된 것 재정비
df.reset_index(inplace=True)
df.drop('index', axis=1, inplace=True)
df = df[1:]

# %%
CHOSUNGS = [u'ㄱ',u'ㄲ',u'ㄴ',u'ㄷ',u'ㄸ',u'ㄹ',u'ㅁ',u'ㅂ',u'ㅃ',u'ㅅ',u'ㅆ',u'ㅇ',u'ㅈ',u'ㅉ',u'ㅊ',u'ㅋ',u'ㅌ',u'ㅍ',u'ㅎ']
JOONGSUNGS = [u'ㅏ',u'ㅐ',u'ㅑ',u'ㅒ',u'ㅓ',u'ㅔ',u'ㅕ',u'ㅖ',u'ㅗ',u'ㅘ',u'ㅙ',u'ㅚ',u'ㅛ',u'ㅜ',u'ㅝ',u'ㅞ',u'ㅟ',u'ㅠ',u'ㅡ',u'ㅢ',u'ㅣ']
JONGSUNGS = [u'_',u'ㄱ',u'ㄲ',u'ㄳ',u'ㄴ',u'ㄵ',u'ㄶ',u'ㄷ',u'ㄹ',u'ㄺ',u'ㄻ',u'ㄼ',u'ㄽ',u'ㄾ',u'ㄿ',u'ㅀ',u'ㅁ',u'ㅂ',u'ㅄ',u'ㅅ',u'ㅆ',u'ㅇ',u'ㅈ',u'ㅊ',u'ㅋ',u'ㅌ',u'ㅍ',u'ㅎ']
TOTAL = CHOSUNGS + JOONGSUNGS + JONGSUNGS

# 자모분리
def jamo_split(word, end_char="_"):
    
    result = []
    
    for char in word:
        
        character_code = ord(char)
        
        if 0xD7A3 < character_code or character_code < 0xAC00:
            result.append(char)
            continue

        chosung_index = int((((character_code - 0xAC00) / 28) / 21) % 19)
        joongsung_index = int(((character_code - 0xAC00) / 28) % 21)
        jongsung_index = int((character_code - 0xAC00) % 28)
        
        chosung = CHOSUNGS[chosung_index]
        joongsung = JOONGSUNGS[joongsung_index]
        jongsung = JONGSUNGS[jongsung_index]
        
        # 종성 범위 밖에 있는 것들은 end_char로 메꿔준다.
        if jongsung_index == 0:
            jongsung = end_char
        
        result.append(chosung)
        result.append(joongsung)
        result.append(jongsung)

    return "".join(result)

# %%
# 각 문장을 jamo_split하여 저장
#from JamoSplit import jamo_split, jamo_combine
df.loc[:,'문장'] = df.loc[:,'문장'].apply(lambda x: jamo_split(x))
df.loc[:,'문장'] = df.loc[:,'문장'].apply(lambda x: x.split(" "))
# Out:
# /tmp/ipykernel_6230/3057658231.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'문장'] = df.loc[:,'문장'].apply(lambda x: jamo_split(x))
# /tmp/ipykernel_6230/3057658231.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'문장'] = df.loc[:,'문장'].apply(lambda x: x.split(" "))

# %%
df.sample(15)
# Out:
#                                                       문장  혐오 여부  글자수
# 43274  [ㅇㅓ_ㄹㅡㄴㅇㅣ_, ㅇㅓ_ㄹㅡㄴㄷㅏㅂㅈㅣ_, ㅁㅗㅅㅎㅏ_ㄱㅗ_, ㅇㅐ_ㄱㅏ_, ㅅ...      0    5
# 73214  [ㅁㅕㅇㅍㅜㅁㄷㅡ_ㄹㅏ_ㅁㅏ_ㄹㅏ_ㄴㅡㄴ, ㅁㅏㄹㅇㅣ_, ㅇㅏ_ㄲㅏㅂㅈㅣ_, ㅇㅏㄶ...      1    7
# 38571  [ㅋㅔ_ㅇㅣ_ㅂㅡㄹ, ㅊㅐ_ㄴㅓㄹㅇㅔ_ㅅㅓ_, ㅁㅐ_ㅂㅓㄴ, ㅌㅡㄹㅇㅓ_, ㅈㅜ_ㄴ...      1   20
# 42964  [ㅇㅣㄴㄱㅕㄱㅊㅔ_, ㄱㅏㄴㅇㅢ_, ㅅㅜㄴㅅㅜ_ㅎㅏㄴ, ㅅㅏ_ㄹㅏㅇㅇㅡㄹ, ㄷㅗㅇㅁ...      1   18
# 37467  [ㅎㅏㄴㅈㅜㄹㅂㅜㄴㅅㅓㄱㅇㅣ_, ㅇㅕㅇㅎㅘ_ㄹㅡㄹ, ㄱㅏ_ㅈㅏㅇ, ㅈㅗㅎㅇㅏ_ㅎㅏ_...      1    5
# 19396  [ㅅㅓㄴㄱㅘ_ㅇㅏㄱㅇㅡㄴ, ㅈㅓㅇㅁㅏㄹ, ㅅㅐㅇㄱㅏㄱㅎㅏ_ㅁㅕㄴ, ㅈㅗㅇㅇㅣ_, ㅊ...      1   10
# 56378  [ㅇㅣ_ㄱㅓ_, ㅍㅕㅇㅈㅓㅁㅇㅣ_, ㅇㅙㄹㅋㅔ_, ㄴㅏㅈㅈㅣ_, ㅈㅗㅎㅇㅡㄴ, ㅇㅕ...      1    6
# 44166  [ㅅㅣ_ㅂㅏㄹ, ㅁㅜㄷㅈㅣ_ㅁㅏ_, ㅍㅏ_ㅌㅣ_, ㄴㅏ_ㅇㅘㅆㄷㅓㄴ, ㄴㅏ_ㅇㅕㅇㅇ...      0    6
# 40949  [ㅁㅏ_ㅇㅡㅁㅇㅡㄹ, ㅇㅜㄹㄹㅕㅆㅈㅣ_ㅁㅏㄴ, ㅎㅕㅇㅅㅏㅇㅎㅘ_, ㅇㅓㅄㅅㅡㅂㄴㅣ_...      1    7
# 95296  [ㅈㅜㅇㄱㅜㄱㅇㅣ_, ㅁㅣ_ㄱㅜㄱㅇㅡㄹ, ㅂㅜㅇㄱㅚ_ㅅㅣ_ㅋㅣ_ㄴㅡㄴ, ㅅㅐ_ㄹㅗ_...      0    6
# 52204  [ㅇㅣ_ㄴㅔ_ㄴㅏ_ㄱㅏㅌㅇㅡ_ㅁㅕㄴ, ㅅㅏ_ㅋㅓ_ㅋㅣㄱ, 120ㄷㅗ_ㄹㅗ_, ㄱㅓㄷ...      0    6
# 15635  [ㅁㅐ_ㅊㅜㄹㅇㅐㄱ, ㄱㅣ_ㅈㅜㄴ, ㅇㅜ_ㄹㅣ_ㄴㅏ_ㄹㅏ_, ㅂㅓㅂㄹㅠㄹㅅㅣ_ㅈㅏㅇ...      0   10
# 26360  [ㅆㅣ_ㅂㅏㄹ, ㅇㅣ_ㅅㅡㅇㅇㅜ_ㅎㅏㄴㅌㅔ_, ㅇㅛㄱㅇㅡㄹㅎㅏ_ㄷㅡㄴㄱㅏ_, ㅈㅓ_...      0    5
# 9146   [ㄱㅡ_ㄹㅣ_ㄱㅗ_, ㅈㅣㄴㅂㅗ_ㄹㅏ_ㅁㅕㄴ, ㅇㅕㄴㅈㅘ_ㅈㅔ_ㄹㅡㄹ, ㄱㅏ_ㅈㅏㅇ...      0   15
# 21429  [ㅊㅜ_ㅊㅡㄱㅎㅐ_ㅅㅓ_, ㅇㅣ_ㅈㅐ_ㅇㅛㅇ, ㅇㅠ_ㅈㅚ_, ㄸㅐ_ㄹㅣㄴㄱㅓ_, ㅇ...      0    7

# %%
# dataframe -> list로 변환
sentence_list = list(df['문장'])
len(sentence_list)
# Out:
# 95990

# %%
# fasttext 인풋 완성!
sentence_list[:10]
# Out:
# [['ㅎㅏ_ㅈㅣ_ㅁㅏㄴ',
#   'ㅇㅣ_ㄴㅣ_ㅎㅜ_ㅃㅏㄹㄹㅓ_ㄷㅡㄹㅇㅡㄴ',
#   'ㅇㅣ_ㄹㅓㄴㄱㅓ_',
#   'ㄱㅘㄴㅅㅣㅁ',
#   'ㅎㅏ_ㄴㅏ_ㄷㅗ_',
#   'ㅇㅓㅄㅇㅡㅁ'],
#  ['ㅈㅣㄴㅉㅏ_',
#   'ㅍㅕㅇㅈㅓㅁ',
#   'ㅁㅣㄷㅇㅡ_ㅁㅕㄴ',
#   'ㅇㅏㄴㄷㅚㄴ',
#   'ㄷㅏ_ㄴㅡㄴ',
#   'ㅎㅕㄴㅅㅣㄹㄹㅗ_',
#   'ㅂㅗ_ㅇㅕ_ㅈㅜ_ㄴㅡㄴ',
#   'ㅇㅕㅇㅎㅘ_ㅇㅣㅂㄴㅣ_ㄷㅏ_',
#   'ㄴㅔ_ㅌㅣ_ㅈㅡㄴㅈㅓㄴㅁㅜㄴㄱㅏ_',
#   'ㅎㅏ_ㄴㅏ_ㄱㅏㅌㅇㅣ_',
#   'ㅇㅕㅇㅎㅘ_ㅇㅔ_ㅅㅓ_',
#   'ㅇㅖ_ㅅㅜㄹㅅㅓㅇㄱㅘ_',
#   'ㅊㅓㄹㅎㅏㄱㅁㅏㄴ',
#   'ㅊㅏㅈㄱㅗ_ㅇㅣㅆㅇㅡ_ㄴㅣ_',
#   'ㅇㅕㅇㅎㅘ_',
#   'ㅂㅗㄹㄸㅐ_',
#   'ㅍㅕㅇㅈㅓㅁ',
#   'ㅇㅏㄴㅂㅗ_ㄱㅗ_',
#   'ㅂㅗㅂㄴㅣ_ㄷㅏ_'],
#  ['ㅈㅗ_ㅇㅝㄴㅈㅣㄴㅇㅣ_',
#   'ㅂㅣ_ㄹㅖ_ㄷㅐ_ㅍㅛ_ㄴㅏ_',
#   'ㄱㅕㅇㅂㅜㄱㅇㅔ_ㅅㅓ_',
#   'ㄱㅗㅇㅊㅓㄴ',
#   'ㅁㅗㅅㅂㅏㄷㄱㅗ_ㄷㅗ_',
#   'ㅇㅣㅂㄷㅏ_ㅁㅜㄹㅁㅕㄴ',
#   'ㅊㅣㄴㅈㅜㅇㅈㅣㄹㅎㅣ_ㄷㅓㄴㄱㅓ_',
#   'ㅇㅣ_ㅎㅐ_ㅎㅏㄹㄱㅔ_'],
#  ['ㅇㅗ_ㄹㅐㄴㅁㅏㄴㅇㅔ_',
#   'ㅎㅠ_ㄱㅏ_ㄴㅐ_ㅅㅓ_',
#   'ㅈㅗ_ㅋㅏ_ㄷㅡㄹ',
#   'ㄷㅔ_ㄹㅣ_ㄱㅗ_',
#   'ㅂㅗ_ㄱㅗ_ㄴㅏ_ㅇㅘㅆㅇㅓ_ㅇㅛ_',
#   'ㅈㅗ_ㅋㅏ_ㄷㅡㄹㅇㅣ_',
#   'ㄴㅓ_ㅁㅜ_',
#   'ㅈㅗㅎㅇㅏ_ㅎㅐ_ㅅㅓ_',
#   'ㅍㅕㅇㅈㅓㅁ',
#   '10ㅈㅓㅁ',
#   'ㄴㅏㅁㄱㅕ_ㅇㅛㅇ'],
#  ['ㅈㅔ_ㅁㅗㄱㅁㅏㄴ',
#   'ㅂㅗ_ㄱㅗ_ㄷㅗ_',
#   'ㄷㅓ_ㄹㅓ_ㅇㅜㄴ',
#   'ㅁㅓ_ㄹㅣ_ㅅㅡ_ㅌㅏㄹ',
#   'ㄸㅓ_ㅇㅗㄹㄹㅏㅆㄷㅏ_',
#   'ㅇㅣ_ㄹㅡㅁㅂㅗ_ㄷㅏ_',
#   'ㄱㅡ_ㄷㅓ_ㄹㅓㄴㅅㅐ_ㄲㅣ_ㄱㅔㅆㅈㅣ_',
#   'ㅇㅣ_ㄹㅐㅆㄷㅏ_ㄴㅣ_ㄲㅏ_'],
#  ['ㅈㅗ_ㅅㅔㄴㅈㅣㅇㄷㅡㄹㅇㅢ_',
#   'ㅎㅏㄴㄱㅖ_ㅈㅣ_',
#   'ㅁㅣㄴㅈㅗㄱㅅㅓㅇ',
#   'ㅈㅏ_ㅊㅔ_ㄱㅏ_',
#   'ㄷㅗㅇㄴㅏㅁㅇㅏ_ㄴㅏ_',
#   'ㅇㅏ_ㅍㅡ_ㄹㅣ_ㅋㅏ_',
#   'ㅌㅗ_ㅇㅣㄴㅇㅣ_ㄹㅏㅇ',
#   'ㄷㅏ_ㄹㅡ_ㄱㅔ_ㅇㅓㅄㅇㅡㅁ'],
#  ['ㅇㅏ_ㄴㅣ_',
#   'ㅂㅜㄱㅎㅏㄴㅇㅣ_',
#   'ㄱㅡ_ㄹㅓㅎㄱㅔ_',
#   'ㅈㅗㅎㅇㅡ_ㅁㅕㄴ',
#   'ㅂㅗ_ㄸㅏ_ㄹㅣ_',
#   'ㅆㅏ_ㄱㅏ_ㅅㅓ_',
#   'ㅅㅏㄹㅈㅣ_',
#   'ㅈㅣㄴㅉㅏ_'],
#  ['ㅈㅓ_ㅅㅐ_ㄲㅣ_ㄴㅡㄴ',
#   'ㅇㅏ_ㅁㅜ_',
#   'ㄱㅓㅅㄷㅗ_',
#   'ㅎㅏㄴㄱㅔ_',
#   'ㅇㅓㅄㄴㅡㄴㄷㅔ_',
#   'ㅁㅗㄱㅅㅗ_ㄹㅣ_ㅁㅏㄴ',
#   'ㄲㅏㄹㅇㅏ_ㅅㅓ_',
#   'ㅈㅣ_ㅈㅣ_ㅇㅠㄹ',
#   'ㄴㅗㅍㅇㅡㄴ',
#   'ㅁㅣ_ㅅㅡ_ㅌㅔ_ㄹㅣ_ㅎㅏㄴ',
#   'ㅇㅣㄴㄱㅏㄴㅇㅣㅁ'],
#  ['ㅇㅐㄱㅅㅕㄴㅇㅡㄹ',
#   'ㅈㅓㅇㅁㅏㄹ',
#   'ㅇㅣ_ㄹㅓㅎㄱㅔ_',
#   'ㅁㅏㅅㄲㅏㄹㄴㅏ_ㄱㅔ_',
#   'ㅍㅛ_ㅎㅕㄴㅎㅏㄹㅅㅜ_ㄱㅏ_',
#   'ㅅㅣㄴㅅㅓㄴㅎㅏ_ㄱㅗ_',
#   'ㅁㅓㅅㅈㅣ_ㄷㅏ_'],
#  ['ㅇㅓㅁㅁㅏ_ㅇㅢ_',
#   'ㅇㅏ_ㅍㅡㅁㅇㅣ_',
#   'ㄱㅗ_ㅅㅡ_ㄹㅏㄴㅎㅣ_',
#   'ㅈㅓㄴㅎㅐ_ㅈㅣ_ㄴㅡㄴㄱㅓㅅ',
#   'ㄱㅏㅌㅇㅏ_',
#   'ㅅㅡㄹㅍㅓㅆㅇㅓ_ㅇㅛ_']]

# %%
sentence_list[:]
# Out:
# [['ㅎㅏ_ㅈㅣ_ㅁㅏㄴ',
#   'ㅇㅣ_ㄴㅣ_ㅎㅜ_ㅃㅏㄹㄹㅓ_ㄷㅡㄹㅇㅡㄴ',
#   'ㅇㅣ_ㄹㅓㄴㄱㅓ_',
#   'ㄱㅘㄴㅅㅣㅁ',
#   'ㅎㅏ_ㄴㅏ_ㄷㅗ_',
#   'ㅇㅓㅄㅇㅡㅁ'],
#  ['ㅈㅣㄴㅉㅏ_',
#   'ㅍㅕㅇㅈㅓㅁ',
#   'ㅁㅣㄷㅇㅡ_ㅁㅕㄴ',
#   'ㅇㅏㄴㄷㅚㄴ',
#   'ㄷㅏ_ㄴㅡㄴ',
#   'ㅎㅕㄴㅅㅣㄹㄹㅗ_',
#   'ㅂㅗ_ㅇㅕ_ㅈㅜ_ㄴㅡㄴ',
#   'ㅇㅕㅇㅎㅘ_ㅇㅣㅂㄴㅣ_ㄷㅏ_',
#   'ㄴㅔ_ㅌㅣ_ㅈㅡㄴㅈㅓㄴㅁㅜㄴㄱㅏ_',
#   'ㅎㅏ_ㄴㅏ_ㄱㅏㅌㅇㅣ_',
#   'ㅇㅕㅇㅎㅘ_ㅇㅔ_ㅅㅓ_',
#   'ㅇㅖ_ㅅㅜㄹㅅㅓㅇㄱㅘ_',
#   'ㅊㅓㄹㅎㅏㄱㅁㅏㄴ',
#   'ㅊㅏㅈㄱㅗ_ㅇㅣㅆㅇㅡ_ㄴㅣ_',
#   'ㅇㅕㅇㅎㅘ_',
#   'ㅂㅗㄹㄸㅐ_',
#   'ㅍㅕㅇㅈㅓㅁ',
#   'ㅇㅏㄴㅂㅗ_ㄱㅗ_',
#   'ㅂㅗㅂㄴㅣ_ㄷㅏ_'],
#  ['ㅈㅗ_ㅇㅝㄴㅈㅣㄴㅇㅣ_',
#   'ㅂㅣ_ㄹㅖ_ㄷㅐ_ㅍㅛ_ㄴㅏ_',
#   'ㄱㅕㅇㅂㅜㄱㅇㅔ_ㅅㅓ_',
#   'ㄱㅗㅇㅊㅓㄴ',
#   'ㅁㅗㅅㅂㅏㄷㄱㅗ_ㄷㅗ_',
#   'ㅇㅣㅂㄷㅏ_ㅁㅜㄹㅁㅕㄴ',
#   'ㅊㅣㄴㅈㅜㅇㅈㅣㄹㅎㅣ_ㄷㅓㄴㄱㅓ_',
#   'ㅇㅣ_ㅎㅐ_ㅎㅏㄹㄱㅔ_'],
#  ['ㅇㅗ_ㄹㅐㄴㅁㅏㄴㅇㅔ_',
#   'ㅎㅠ_ㄱㅏ_ㄴㅐ_ㅅㅓ_',
#   'ㅈㅗ_ㅋㅏ_ㄷㅡㄹ',
#   'ㄷㅔ_ㄹㅣ_ㄱㅗ_',
#   'ㅂㅗ_ㄱㅗ_ㄴㅏ_ㅇㅘㅆㅇㅓ_ㅇㅛ_',
#   'ㅈㅗ_ㅋㅏ_ㄷㅡㄹㅇㅣ_',
#   'ㄴㅓ_ㅁㅜ_',
#   'ㅈㅗㅎㅇㅏ_ㅎㅐ_ㅅㅓ_',
#   'ㅍㅕㅇㅈㅓㅁ',
#   '10ㅈㅓㅁ',
#   'ㄴㅏㅁㄱㅕ_ㅇㅛㅇ'],
#  ['ㅈㅔ_ㅁㅗㄱㅁㅏㄴ',
#   'ㅂㅗ_ㄱㅗ_ㄷㅗ_',
#   'ㄷㅓ_ㄹㅓ_ㅇㅜㄴ',
#   'ㅁㅓ_ㄹㅣ_ㅅㅡ_ㅌㅏㄹ',
#   'ㄸㅓ_ㅇㅗㄹㄹㅏㅆㄷㅏ_',
#   'ㅇㅣ_ㄹㅡㅁㅂㅗ_ㄷㅏ_',
#   'ㄱㅡ_ㄷㅓ_ㄹㅓㄴㅅㅐ_ㄲㅣ_ㄱㅔㅆㅈㅣ_',
#   'ㅇㅣ_ㄹㅐㅆㄷㅏ_ㄴㅣ_ㄲㅏ_'],
#  ['ㅈㅗ_ㅅㅔㄴㅈㅣㅇㄷㅡㄹㅇㅢ_',
#   'ㅎㅏㄴㄱㅖ_ㅈㅣ_',
#   'ㅁㅣㄴㅈㅗㄱㅅㅓㅇ',
#   'ㅈㅏ_ㅊㅔ_ㄱㅏ_',
#   'ㄷㅗㅇㄴㅏㅁㅇㅏ_ㄴㅏ_',
#   'ㅇㅏ_ㅍㅡ_ㄹㅣ_ㅋㅏ_',
#   'ㅌㅗ_ㅇㅣㄴㅇㅣ_ㄹㅏㅇ',
#   'ㄷㅏ_ㄹㅡ_ㄱㅔ_ㅇㅓㅄㅇㅡㅁ'],
#  ['ㅇㅏ_ㄴㅣ_',
#   'ㅂㅜㄱㅎㅏㄴㅇㅣ_',
#   'ㄱㅡ_ㄹㅓㅎㄱㅔ_',
#   'ㅈㅗㅎㅇㅡ_ㅁㅕㄴ',
#   'ㅂㅗ_ㄸㅏ_ㄹㅣ_',
#   'ㅆㅏ_ㄱㅏ_ㅅㅓ_',
#   'ㅅㅏㄹㅈㅣ_',
#   'ㅈㅣㄴㅉㅏ_'],
#  ['ㅈㅓ_ㅅㅐ_ㄲㅣ_ㄴㅡㄴ',
#   'ㅇㅏ_ㅁㅜ_',
#   'ㄱㅓㅅㄷㅗ_',
#   'ㅎㅏㄴㄱㅔ_',
#   'ㅇㅓㅄㄴㅡㄴㄷㅔ_',
#   'ㅁㅗㄱㅅㅗ_ㄹㅣ_ㅁㅏㄴ',
#   'ㄲㅏㄹㅇㅏ_ㅅㅓ_',
#   'ㅈㅣ_ㅈㅣ_ㅇㅠㄹ',
#   'ㄴㅗㅍㅇㅡㄴ',
#   'ㅁㅣ_ㅅㅡ_ㅌㅔ_ㄹㅣ_ㅎㅏㄴ',
#   'ㅇㅣㄴㄱㅏㄴㅇㅣㅁ'],
#  ['ㅇㅐㄱㅅㅕㄴㅇㅡㄹ',
#   'ㅈㅓㅇㅁㅏㄹ',
#   'ㅇㅣ_ㄹㅓㅎㄱㅔ_',
#   'ㅁㅏㅅㄲㅏㄹㄴㅏ_ㄱㅔ_',
#   'ㅍㅛ_ㅎㅕㄴㅎㅏㄹㅅㅜ_ㄱㅏ_',
#   'ㅅㅣㄴㅅㅓㄴㅎㅏ_ㄱㅗ_',
#   'ㅁㅓㅅㅈㅣ_ㄷㅏ_'],
#  ['ㅇㅓㅁㅁㅏ_ㅇㅢ_',
#   'ㅇㅏ_ㅍㅡㅁㅇㅣ_',
#   'ㄱㅗ_ㅅㅡ_ㄹㅏㄴㅎㅣ_',
#   'ㅈㅓㄴㅎㅐ_ㅈㅣ_ㄴㅡㄴㄱㅓㅅ',
#   'ㄱㅏㅌㅇㅏ_',
#   'ㅅㅡㄹㅍㅓㅆㅇㅓ_ㅇㅛ_'],
#  ['ㄷㅐ_ㄷㅏㄴㅎㅏㄴ',
#   'ㅇㅕㅇㅎㅘ_ㅇㅣ_ㄱㅣㄴ',
#   'ㅎㅏㄴㄷㅔ_',
#   'ㄷㅗ_ㄷㅐ_ㅊㅔ_',
#   'ㄴㅏㅁㅈㅏ_',
#   'ㅆㅏㅇㄷㅜㅇㅇㅣ_',
#   'ㅇㅖ_ㅈㅣ_ㅈㅏ_ㄴㅡㄴ',
#   'ㅍㅣㄹㅇㅛ_ㅎㅏㄴㄱㅓ_ㅈㅣ_',
#   'ㅇㅓ_ㅊㅏ_ㅍㅣ_',
#   'ㅇㅏ_ㄱㅏ_ㅅㅏ_ㄱㅏ_',
#   'ㅈㅔ_ㅇㅣㄹ',
#   'ㅈㅏㄹㅎㅏ_ㄱㅗ_',
#   'ㄷㅜㄹㅇㅣ_',
#   'ㄴㅗㅎㅊㅣ_ㄴㅡㄴ',
#   'ㄱㅓㅅㄷㅗ_',
#   'ㅇㅏ_ㄱㅏ_ㅅㅏ_',
#   'ㅎㅗㄴㅈㅏ_ㅅㅓ_',
#   'ㅈㅏㅂㅇㅏ_ㄴㅐㄹ',
#   'ㅈㅓㅇㄷㅗ_ㅇㅣㄴㄷㅔ_',
#   'ㅎㅏㄴㅁㅕㅇㅇㅣ_ㅁㅕㄴ',
#   'ㄴㅓ_ㅁㅜ_',
#   'ㅆㅡㄹㅆㅡㄹㅎㅏㄹㄱㅓ_ㄱㅏㅌㅇㅏㅆㄴㅏ_'],
#  ['ㄱㅐ_ㄷㅙ_ㅈㅣ_ㄷㅡㄹㅇㅡㄴ',
#   'ㄷㅏㅇㅎㅐ_ㅂㅘ_ㅇㅑ_',
#   'ㅇㅏ_ㄴㅡㄴㄱㅓㄹㄲㅏ_',
#   'ㄱㅡ_ㄹㅐ_ㅅㅓ_',
#   'ㄱㅐ_ㄷㅙ_ㅈㅣㄴㄱㅏ_'],
#  ['ㅁㅜ_ㅇㅓㅅㅂㅗ_ㄷㅏ_',
#   'ㅂㅔㄴㅇㅢ_',
#   'ㅅㅡ_ㄹㅔ_ㅇㅣ_ㅋㅔ_ㅇㅗ_ㄹㅡㄹ',
#   'ㅎㅑㅇㅎㅏㄴ',
#   'ㅎㅢ_ㅅㅐㅇㅈㅓㄱ',
#   'ㅅㅏ_ㄹㅏㅇㅇㅣ_',
#   'ㅁㅏㅁㅇㅏ_ㅍㅡ_ㅁㅕㄴㅅㅓ_ㄷㅗ_',
#   'ㄸㅏ_ㄸㅡㅅㅎㅏ_ㄱㅔ_',
#   'ㄴㅡ_ㄲㅕ_ㅈㅕㅆㄷㅏ_'],
#  ['ㅎㅗㅇㅌㅗㅇㄱㅓ_ㄹㅡ_ㄱㅗ_',
#   'ㅈㅓ_ㅌㅗ_ㄹㅗㄴㅇㅡㄴ',
#   'ㅋㅐ_ㄹㅣ_ㅎㅏㄴㄱㅓㄴㅁㅏㅈㅈㅣ_ㅇㅏㄶㄴㅑ_',
#   'ㄴㅏ_ㄷㅗ_ㅂㅘㅆㄴㅡㄴㄷㅔ_',
#   'ㅇㅕㄱㅅㅣ_',
#   'ㄴㅠ_ㅅㅡ_',
#   'ㄱㅏㄴㅍㅏㄴㅎㅏ_ㄷㅓㄴㅅㅏ_ㄹㅏㅁㅇㅡㄴ',
#   'ㅇㅣㅂㅌㅓ_ㄴㅡㄴㄱㅓ_ㅂㅜ_ㅌㅓ_',
#   'ㄱㅡㅂㅇㅣ_ㄷㅏ_ㄹㅡ_ㄱㅜ_ㄴㅏ_',
#   'ㅅㅣㅍㄷㅓㄴㄷㅔ_'],
#  ['15ㄴㅕㄴㅈㅓㄴ', 'ㅇㅕㅇㅎㅘ_ㄹㅏ_ㄱㅗ_ㄴㅡㄴ', 'ㅁㅣㄷㄱㅣ_ㅈㅣ_', 'ㅇㅏㄶㅇㅡㄹ', 'ㅈㅓㅇㄷㅗ_'],
#  ['ㄷㅡ_ㄹㅏ_ㅁㅏ_ㄴㅣ_',
#   'ㅁㅝ_ㄴㅣ_',
#   'ㅇㅏ_ㅇㅣ_ㄷㅗㄹㅇㅣ_ㄴㅣ_',
#   'ㅁㅝ_ㄴㅣ_',
#   'ㅎㅏ_ㄴㅡㄴ',
#   'ㅅㅓㄴㅇㅣㅂㄱㅕㄴㅇㅡㄹ',
#   'ㅈㅔ_ㅇㅚ_ㅎㅏ_ㄱㅗ_',
#   'ㅂㅗ_ㅁㅕㄴ',
#   'ㄴㅏㅁㅈㅏㅇㅇㅕ_ㅈㅏ_ㄹㅏ_ㄴㅡㄴ',
#   'ㅇㅕㄱㅎㅏㄹㅇㅡㄹ',
#   'ㅇㅝㄴㅈㅏㄱㅁㅏㄴㅋㅡㅁㅇㅣ_ㄴㅏ_',
#   'ㄲㅏㄹㄲㅡㅁㅎㅏ_ㄱㅔ_',
#   'ㅅㅗ_ㅎㅘ_ㅎㅏㄴ',
#   'ㄷㅡ_ㄹㅏ_ㅁㅏ_ㅇㅏ_ㅅㅟ_ㅇㅝㅆㄷㅏ_ㅁㅕㄴ',
#   'ㅂㅕㄹㅈㅓㅁㅇㅡㄹ',
#   'ㅈㅓㄱㄱㅔ_',
#   'ㅈㅜ_ㄴㅡㄴ',
#   'ㅁㅏㄶㅇㅡㄴ',
#   'ㅅㅏ_ㄹㅏㅁㄷㅡㄹㅇㅢ_',
#   'ㄱㅗㅇㅌㅗㅇㅈㅓㅁㅇㅣㄴ',
#   'ㄷㅡ_ㄹㅏ_ㅁㅏ_ㄹㅏ_ㄴㅡㄴ'],
#  ['ㅈㅓㅇㅌㅗㅇ',
#   'ㄹㅗ_ㅁㅐㄴㅌㅣㄱㅋㅗ_ㅁㅣ_ㄷㅣ_ㅊㅓㅅㅅㅏ_ㄹㅏㅇㅇㅡㄹ',
#   'ㅇㅘㄴㅂㅕㄱㅎㅏ_ㄱㅔ_',
#   'ㅅㅡㅇㅎㅘ_ㅅㅣ_ㅋㅣㄴ',
#   'ㅇㅕㅇㅎㅘ_ㄴㅔ_ㅇㅛ_ㅇㅣ_ㄹㅓㅎㄱㅔ_',
#   'ㅈㅏㄴㅈㅏㄴㅎㅏㄴ',
#   'ㄹㅗ_ㅁㅐㄴㅌㅣㄱ',
#   'ㅋㅗ_ㅁㅔ_ㄷㅣ_',
#   'ㅈㅗㅎㅇㅏ_'],
#  ['ㅈㅏㄴㅈㅏㄴㅎㅏ_ㄷㅏ_',
#   '10ㅈㅓㅁ',
#   'ㄱㅐ_ㅇㅣㄴㅈㅓㄱㅇㅡ_ㄹㅗ_',
#   'ㅇㅣ_ㄹㅓㄴㅇㅕㅇㅎㅘ_ㄹㅡㄹ',
#   'ㅈㅗㅎㅇㅏ_ㅎㅐ_ㅅㅓ_'],
#  ['ㅈㅣㄴㅉㅏ_',
#   'ㅈㅐ_ㅁㅣㅆㄱㅔ_',
#   'ㅂㅗ_ㄱㅗ_ㅇㅣㅆㅇㅓ_ㅇㅛ_',
#   'ㅈㅜ_ㅁㅏㄹㅁㅏㄴ',
#   'ㄱㅣ_ㄷㅏ_ㄹㅕ_ㅈㅣ_ㄴㅔ_ㅇㅛ_',
#   'ㄱㅡ_ㄹㅣ_ㄱㅗ_',
#   'ㅅㅐㅇㄱㅏㄱㅇㅔ_ㄴㅡㄴ',
#   'ㅇㅢ_ㅅㅏ_ㅂㅜㄴㅇㅣ_',
#   'ㅇㅏ_ㄷㅡㄹㄱㅏㅌㅇㅏ_ㅇㅛ_'],
#  ['ㅂㅗㄴㄴㅡㅇㅇㅡㄹ',
#   'ㅇㅣ_ㄱㅣ_ㅈㅣ_',
#   'ㅁㅗㅅㅎㅏㄴ',
#   'ㄱㅖ_ㅁㅗㅇㄱㅏ_ㅇㅘ_',
#   'ㅇㅓ_ㄹㅣ_ㅅㅓㄱㅇㅡㄴ',
#   'ㅅㅣ_ㅁㅣㄴㄷㅡㄹㅇㅣ_',
#   'ㅂㅣㅈㅇㅓ_ㄴㅐㄴ',
#   'ㅂㅣ_ㄱㅡㄱ',
#   'ㄱㅡ_ㄷㅡㄹㅇㅢ_',
#   'ㄱㅏㅁㅈㅓㅇㅇㅡㄹ',
#   'ㅁㅐ_ㅇㅜ_',
#   'ㅍㅛ_ㅎㅕㄴㅎㅐ_ㄴㅐㅆㄷㅏ_'],
#  ['ㄱㅓ_ㅈㅣㅅㅁㅏㄹ', 'ㅌㅏㅁㅈㅣ_ㄱㅣ_ㄹㅗ_', 'ㅎㅏㄴㅂㅓㄴ', 'ㄱㅓㅁㅈㅡㅇㅇㅡㄹ', 'ㅂㅏㄷㅇㅏ_ㅂㅘ_ㅇㅑ_'],
#  ['ㅂㅗ_ㅌㅗㅇㅇㅡㄴ',
#   'ㅇㅗ_ㄹㅏㅇㅋㅐ_ㄹㅏ_ㄴㅡㄴ',
#   'ㅍㅛ_ㅎㅕㄴㅇㅣ_',
#   'ㅇㅚ_ㄱㅜㄱㅇㅔ_ㅅㅓ_ㄴㅡㄴ',
#   'ㅁㅗ_ㅇㅛㄱㅇㅡ_ㄹㅗ_',
#   'ㅂㅏㄷㅇㅏ_ㄷㅡㄹㅇㅕ_ㅈㅣㄹㅅㅜ_',
#   'ㅇㅣㅆㄷㅏ_',
#   'ㄹㅏ_ㄴㅡㄴ',
#   'ㄴㅗㄴㄹㅣ_ㄹㅗ_',
#   'ㅇㅣㅆㄴㅡㄴㄷㅔ_',
#   'ㅁㅜㄴㅈㅐ_ㅇㅏㅇ',
#   'ㅂㅕㅇㅅㅣㄴㅅㅐ_ㄲㅣ_ㄱㅏ_',
#   'ㅈㅜㅇㄱㅜㄱㅁㅗㅇㄱㅏㅌㅇㅡㄴ',
#   'ㅅㅗ_ㄹㅣ_ㅎㅐ_ㅅㅓ_',
#   'ㅅㅏ_ㄷㅏㄴㄴㅏㄴㄱㅓ_ㅈㅣ_',
#   'ㅈㅣㄴㅉㅏ_',
#   'ㄷㅓ_ㅂㅜㄹㄷㅏㅇ',
#   'ㅅㅐ_ㄲㅣ_ㄷㅡㄹ',
#   'ㅈㅜㅇㄱㅜㄱㅎㅏㄴㅌㅔ_',
#   'ㅈㅓㅇㅊㅣ_ㅈㅏ_ㄱㅡㅁ',
#   'ㅂㅏㄷㅇㅏ_ㅁㅓㄱㅇㅡㄴㄱㅔ_',
#   'ㅂㅜㄴㅁㅕㅇㅎㅏㅁ'],
#  ['ㅇㅏ_ㄴㅣ_',
#   'ㄱㅗ_ㅈㅏㄱ',
#   'ㄸㅏㄴㄸㅏ_ㄹㅏ_ㅅㅐ_ㄲㅣ_ㄷㅡㄹ',
#   'ㅇㅣㅂㄱㅜㄱ',
#   'ㅎㅏ_ㄱㅔ_',
#   'ㅎㅐㅆㄷㅏ_ㄱㅗ_',
#   'ㅌㅡ_ㄹㅓㅁㅍㅡ_ㄴㅣ_',
#   'ㅁㅝ_ㄴㅣ_',
#   'ㅈㅓㄴㅈㅐㅇㄲㅏ_ㅈㅣ_',
#   'ㄷㅡㄹㅁㅓㄱㅇㅣ_ㄴㅔ_',
#   'ㅂㅕㅇㅅㅣㄴㄷㅡㄹ'],
#  ['ㅇㅜ_ㄹㅣ_ㄴㅏ_ㄹㅏ_',
#   'ㅈㅓㄴㅊㅔ_',
#   'ㅅㅜ_ㅊㅜㄹㅈㅜㅇㅇㅔ_',
#   'ㅈㅜㅇㄱㅜㄱㅇㅔ_',
#   'ㅅㅜ_ㅊㅜㄹㅎㅏ_ㄴㅡㄴㄱㅔ_',
#   'ㄱㅏ_ㅈㅏㅇ',
#   'ㅁㅏㄶㅇㅡㄴㄷㅔ_',
#   'ㄱㅡ_ㄹㅓㅁ',
#   'ㅊㅣㄴㅈㅜㅇㄷㅗ_',
#   'ㅇㅐ_ㄱㅜㄱㅇㅣ_ㄱㅔㅆㄴㅔ_',
#   'ㅇㅣ_ㄹㅓㄴ',
#   'ㅂㅕㅇㅅㅣㄴㄱㅏㅌㅇㅡㄴ',
#   'ㅅㅐ_ㄲㅣ_ㄱㅏ_',
#   'ㅇㅣㅆㅈㅣ_'],
#  ['ㅅㅗㄹㅈㅣㄱㅎㅣ_',
#   'ㅊㅓ_ㅇㅡㅁ',
#   'ㄸㅐ_ㄴㅡㄴ',
#   'ㅇㅣ_ㄱㅔ_ㅁㅝ_ㅇㅑ_',
#   'ㅇㅣ_ㄹㅐㅆㄴㅡㄴㄷㅔ_',
#   'ㄴㅕㄴㅉㅐ_',
#   'ㄱㅖ_ㅅㅗㄱ',
#   'ㅂㅗ_ㄴㅡㄴㅈㅜㅇ',
#   'ㅇㅣㅈㅇㅡ_ㄹㅕ_ㅎㅏ_ㅁㅕㄴ',
#   'ㄷㅏ_ㅅㅣ_',
#   'ㅅㅐㅇㄱㅏㄱㄴㅏ_ㅅㅓ_',
#   'ㅇㅖ_ㅃㅡㄴ',
#   'ㅇㅕㅇㅅㅏㅇ',
#   'ㄷㅏ_ㅅㅣ_',
#   'ㄷㅗㄹㄹㅕ_ㅂㅗ_ㄱㅗ_',
#   'ㅎㅏ_ㄱㅗ_ㅇㅣㅆㄷㅏ_'],
#  ['ㅎㅏ_ㄱㅣㄴ',
#   'ㅇㅐ_ㅁㅣ_ㄱㅏ_',
#   'ㅁㅝㄴㅈㅣ_ㄷㅗ_',
#   'ㅁㅗ_ㄹㅡ_ㄴㅡㄴㅅㅐ_ㄲㅣ_ㅎㅏㄴㅌㅔ_',
#   'ㅁㅜ_ㅅㅡㄴㅁㅏㄹㅇㅡㄹ',
#   'ㅎㅏ_ㄴㅗ_',
#   'ㅇㅔㄴㄷㅜ_ㅈㅏㅇㄱㅜㄴㅇㅣ_',
#   'ㄱㅘㅇㅈㅜ_ㅍㅗㄱㄷㅗㅇㄸㅐ_',
#   'ㅆㅏㄱㅁㅣㄹㅇㅓㅆㅇㅡ_ㅁㅕㄴ',
#   'ㅈㅣ_ㄱㅡㅁㄱㅏㅌㅇㅡㄴ',
#   'ㄲㅗ_ㄹㅏ_ㅈㅣ_ㄴㅡㄴ',
#   'ㅇㅓㅄㅇㅓㅅㅇㅡㄹㅌㅔㄴㄷㅔ_',
#   'ㄱㅡ_ㅊㅣ_'],
#  ['ㅂㅗ_ㅁㅕㄴㅅㅓ_',
#   'ㅅㅐㅇㄱㅏㄱㅎㅏ_ㄱㅔ_ㅁㅏㄴㄷㅡㄹㄱㅗ_',
#   'ㅂㅐ_ㅇㅜ_ㄷㅡㄹㅇㅢ_',
#   'ㅈㅣㅌㅇㅡㄴ',
#   'ㅇㅕㄴㄱㅣ_ㅇㅔ_',
#   'ㅈㅣㅂㅈㅜㅇㅎㅏ_ㅁㅕㄴㅅㅓ_',
#   'ㅂㅘㅆㄴㅔ_ㅇㅛ_ㅎㅡㅇㅎㅐ_ㄹㅏ_'],
#  ['uccㅇㅔ_ㅅㅓ_',
#   'ㅇㅕㅇㅎㅘ_ㄹㅗ_',
#   'ㅂㅏㅇㅎㅏ_ㄴㅏ_ㅇㅔ_ㅅㅓ_',
#   'ㄷㅗ_ㅅㅣ_ㄹㅗ_',
#   'ㄷㅐ_ㄷㅏㄴㅎㅏ_ㄷㅏ_',
#   'ㅅㅏㅇㅅㅏㅇㄹㅕㄱㅇㅔ_',
#   'ㅂㅏㄱㅅㅜ_ㄹㅡㄹ'],
#  ['ㅇㅏ_ㅁㅜㄴㅂㅓㅂ', '5ㅈㅗ_ㄹㅗ_', 'ㅇㅣㄹㄷㅡㅇ', 'ㅂㅕㄱㅅㅏㅇㄱㅗㅇㅅㅣㄴㅇㅡ_ㄹㅗ_', 'ㅅㅡㅇㄱㅕㄱㄷㅚ_ㄴㅗ_'],
#  ['ㄷㅐ_ㄱㅏ_ㄹㅣ_ㅂㅏㄱㄱㅣ_ㅇㅔ_ㄴㅡㄴ',
#   'ㄴㅓ_ㅁㅜ_',
#   'ㅁㅏㄶㅇㅡㄴ',
#   'ㅅㅣ_ㄱㅏㄴㅇㅣ_',
#   'ㅎㅡㄹㄹㅓㅆㄴㅡㄴㄷㅔ_',
#   'ㅈㅣ_ㄱㅡㅁ',
#   'ㅇㅏㄹㅇㅏㅆㄴㅗ_'],
#  ['ㅈㅐ_ㅁㅣㅆㅅㅡㅂㄴㅣ_ㄷㅏ_',
#   'ㅇㅣ_ㅈㅓㅇㅎㅕㄴ',
#   'ㅂㅐ_ㅇㅜ_ㅇㅢ_',
#   'ㅇㅏㅍㅇㅡ_ㄹㅗ_ㅇㅢ_',
#   'ㅎㅐㅇㅂㅗ_ㄱㅏ_',
#   'ㄱㅣ_ㄷㅐ_ㄷㅚㅂㄴㅣ_ㄷㅏ_'],
#  ['ㅆㅣㄱㅆㅣㄱㅎㅏ_ㄱㅔ_', 'ㅇㅏ_ㅇㅗ_ㅈㅣ_ㄹㅗ_', 'ㄱㅏ_ㅈㅡ_ㅇㅏ_', 'ㄱㅐ_ㄷㅙ_ㅈㅣ_', 'ㄱㅜㄱㅁㅣㄴㅇㅣㄹㄷㅗㅇ'],
#  ['ㅇㅣ_ㄹㅓㄴ', 'ㅇㅕㅇㅎㅘ_', 'ㅁㅏㄶㅇㅣ_', 'ㄴㅏ_ㅇㅘㅆㅇㅡㅁ', 'ㅈㅗㅎㄱㅔㅆㅇㅓ_ㅇㅛ_'],
#  ['ㅂㅐㄱㅅㅓㅇㄷㅡㄹ',
#   'ㄱㅗ_ㅎㅕㄹㅇㅡㄹ',
#   'ㅉㅏ_ㄴㅐ_ㅅㅓ_',
#   'ㅈㅜㅇㄱㅜㄱㅅㅏ_ㅅㅣㄴ',
#   'ㄷㅐ_ㅈㅓㅂㅎㅏ_ㄷㅓㄴ',
#   'ㅈㅗ_ㅅㅓㄴㅅㅣ_ㄷㅐ_ㄹㅗ_',
#   'ㄷㅗㄹㅇㅏ_ㄱㅏㅆㄴㅗ_'],
#  ['ㅉㅏㅇㄲㅐ_ㄱㅏ_',
#   'ㅊㅓㅇㅇㅘ_ㄷㅐ_',
#   'ㅊㅓㅇㅇㅝㄴㅎㅏㄴㄷㅏ_ㄴㅡㄴㄱㅓ_',
#   'ㅈㅏ_ㅊㅔ_ㄱㅏ_',
#   'ㅈㅗㄴㄴㅏ_',
#   'ㅆㅣ_ㅂㅏㄹㅇㅣ_ㄴㅔ_'],
#  ['ㅂㅜㄱㅎㅏㄴ', 'ㄱㅗㅇㅅㅣㄱ', 'ㅇㅣㄴㅈㅡㅇ', 'ㅅㅏㄻㅇㅡㄴ', 'ㅅㅗ_ㄷㅐ_ㄱㅏ_ㄹㅣ_', 'ㅇㅏ_ㄴㅣ_ㄹㅏㄹㄲㅏ_ㅂㅘ_'],
#  ['ㄷㅏ_ㄹㅡㄴㅁㅠ_ㅈㅣ_ㅋㅓㄹㅇㅕㅇㅎㅘ_ㅇㅔ_ㅅㅓㄴ',
#   'ㅅㅡ_ㅌㅗ_ㄹㅣ_ㄱㅏ_',
#   'ㅇㅏ_ㅅㅟ_ㅇㅝㅆㄴㅡㄴㄷㅔ_',
#   'ㅇㅣ_ㅇㅕㅇㅎㅘㄴ',
#   'ㄴㅗ_ㄹㅐ_ㅊㅜㅁㅇㅔ_',
#   'ㅅㅡ_ㅌㅗ_ㄹㅣ_ㄷㅗ_',
#   'ㄴㅏ_ㅃㅡ_ㅈㅣ_ㅇㅏㄶㅇㅏㅆㄷㅏ_'],
#  ['ㅅㅏ_ㅇㅠ_ㅎㅏ_ㄴㅡㄴ', 'ㅇㅕㅇㅎㅘ_', 'ㅁㅏㄴㄷㅡㄹㄱㅣ_ㅇㅢ_', 'ㅇㅓ_ㄸㅓㄴ', 'ㄱㅡㄱㅈㅓㅁ'],
#  ['ㅇㅣ_ㅇㅕㅇㅎㅘ_ㅇㅔ_ㄴㅡㄴ',
#   'ㄷㅡㅇㄱㅡㅂㅇㅣ_ㅇㅓㅄㄷㅏ_',
#   'ㄹㅏ_ㄴㅡㄴ',
#   'ㅇㅕㅇㅎㅘ_ㅂㅗ_ㄱㅗ_',
#   'ㅂㅗ_ㄱㅔ_ㄷㅚㄴ',
#   'ㅇㅕㅇㅎㅘ_',
#   'ㅎㅣㄹㄹㅓ_ㄹㅣ_ㅅㅡ_ㅇㅞㅇㅋㅡ_',
#   'ㄷㅏ_ㅅㅣ_ㅂㅗ_ㄱㅔ_ㄷㅚㅁ'],
#  ['ㅅㅡㄹㅍㅡ_ㄱㅗ_',
#   'ㅂㅜㄹㅆㅏㅇㅎㅏ_ㄴㅔ_ㅇㅛ_',
#   'ㅇㅏ_ㅃㅏ_ㄹㅏ_ㄴㅡㄴ',
#   'ㅁㅏㄹㅇㅣ_',
#   'ㅇㅓㄹㅁㅏ_ㄴㅏ_ㅎㅏ_ㄱㅗ_',
#   'ㅅㅣㅍㅇㅓㅆㅇㅡㄹㄲㅏ_'],
#  ['ㅇㅣ_ㄱㅓ_',
#   'ㅍㅕㅇㅈㅓㅁ',
#   'ㅇㅙ_ㅋㅔ_ㄴㅏㅈㅇㅓ_',
#   'ㅇㅏ_ㅈㅣㄱㄷㅗ_',
#   'ㄱㅏ_ㄲㅡㅁ',
#   'ㅂㅗ_ㄴㅡㄴㄷㅔ_',
#   'ㅈㅐ_ㅁㅣㅆㅇㅓ_'],
#  ['ㄲㅜㅁㅇㅣ_ㅇㅓㅄㅇㅣ_',
#   'ㅅㅜ_ㄷㅗ_',
#   'ㅇㅣㅆㅇㅓ_',
#   'ㄲㅜㅁㅁㅏㄴ',
#   'ㄲㅜ_ㅁㅕ_',
#   'ㅅㅜ_ㄷㅗ_',
#   'ㅇㅣㅆㅇㅓ_',
#   'ㅅㅗ_ㄴㅕㄴㄷㅡㄹㅇㅡㄹ',
#   'ㅇㅟ_ㄹㅗ_ㅎㅐ_ㅈㅝ_'],
#  ['ㅈㅓ_ㄱㅔ_',
#   'ㅅㅏ_ㅅㅣㄹㅇㅣ_ㅁㅕㄴ',
#   'ㅈㅣㄴㅉㅏ_',
#   'ㅅㅜ_ㅅㅣㅂㄴㅕㄴㄷㅗㅇㅇㅏㄴ',
#   'ㄱㅡ_ㅈㅣㅅㅇㅡㄹ',
#   'ㅎㅐ_ㅇㅘㅆㄷㅏ_ㄴㅡㄴㄱㅓ_',
#   'ㅇㅏ_ㄴㅣ_ㄴㅑ_'],
#  ['ㄴㅓ_ㅁㅜ_', 'ㅈㅐ_ㅁㅣ_ㅇㅣㅆㄱㅔ_', 'ㅂㅘㅆㄷㅏ_', 'ㄴㅓ_ㅁㅜ_ㄴㅓ_ㅁㅜ_', 'ㅁㅓㅅㅇㅣㅆㄴㅡㄴ'],
#  ['ㅇㅣ_ㄹㅓㄴ', 'ㄱㅏㅁㄷㅗㅇㅈㅓㄱㅇㅣ_ㅁㅕㄴㅅㅓ_ㄷㅗ_', 'ㅉㅓ_ㄴㅡㄴ', 'ㅁㅕㅇㅍㅜㅁㅇㅐ_ㄴㅣ_ㄱㅏ_', '8ㅈㅓㅁㄷㅐ_'],
#  ['ㅎㅏ_ㄴㅏ_',
#   'ㅂㅜ_ㅈㅗㄱㅎㅏㄴㄱㅓㄴ',
#   'ㅇㅓㅄㄷㅏ_',
#   'ㄱㅏ_ㄲㅡㅁ',
#   'tvㅇㅔ_ㅅㅓ_',
#   'ㅂㅗ_ㅁㅕㄴ',
#   'ㅈㅐ_ㅁㅣㅆㅇㅡㅁ'],
#  ['ㄷㅐ_ㅎㅏㄴㅁㅣㄴㄱㅜㄱㅇㅣ_',
#   'ㅉㅏㅇㄱㅐ_ㄱㅜㄱㄱㅏ_ㄱㅏ_',
#   'ㅁㅣ_ㅊㅕㅆㄴㅔ_',
#   'ㅇㅣ_ㄱㅓ_',
#   'ㅌㅏㄴㅎㅐㄱ',
#   'ㅇㅏㄴㅎㅏ_ㄴㅡㄴ',
#   'ㄱㅓ_ㄴㅗ_',
#   'ㅇㅣ_ㄱㅣ_'],
#  ['ㅇㅣ_ㅈㅔ_',
#   '19ㄹㅔㅂ',
#   'ㅁㅜㄴㅅㅡㄹㄹㅏㅁ',
#   'ㅇㅣㄹㅃㅗㅇxxㄷㅏㄴㅈㅏㅇㅇㅣ_',
#   'ㅇㅘ_ㅅㅓ_',
#   'ㅂㅜ_ㄷㅡㄹㄱㅓ_ㄹㅣㄹ',
#   'ㄱㅔ_ㅅㅣ_ㅁㅜㄹㅇㅣㅂㄴㅣ_ㄷㅏ_'],
#  ['ㅇㅓㅁㅊㅓㅇ',
#   'ㅈㅐ_ㅁㅣㅆㄴㅔ_ㅇㅛ_',
#   'ㅇㅡㅁㅇㅏㄱㄷㅗ_',
#   'ㅈㅗㅎㄱㅗ_',
#   'ㅇㅕㄴㅇㅣㄴㄲㅣ_ㄹㅣ_ㄱㅏ_ㅁㅕㄴ',
#   'ㅇㅏ_ㅈㅜ_',
#   'ㅈㅗㅎㅇㅡㄹㄱㅓㅅ',
#   'ㄱㅏㅌㄱㅗ_',
#   'ㅅㅗㄹㄹㅗ_ㄷㅡㄹㄷㅗ_',
#   'ㅎㅗㄴㅈㅏ_ㄱㅏ_ㅅㅓ_',
#   'ㅂㅗ_ㅅㅔ_ㅇㅛ_',
#   'ㅇㅕㄴㅇㅐ_ㅇㅛㄱㄱㅜ_ㄱㅏ_',
#   'ㅁㅣ_ㅊㅣㄴㄷㅡㅅㅇㅣ_',
#   'ㅇㅣㄹㅇㅓ_ㄴㅏ_ㄴㅔ_ㅇㅛ_'],
#  ['ㅂㅏㄱㅈㅜㅇㅎㅜㄴㅊㅏ_ㅌㅐ_ㅎㅕㄴ',
#   'ㅋㅗㅁㅂㅣ_',
#   'ㄱㅗㄹㄸㅐ_ㄹㅣㄴㄷㅏ_ㅇㅓㄴㅈㅔ_ㅂㅘ_ㄷㅗ_',
#   'ㅈㅐ_ㅁㅣㅆㄱㅗ_',
#   'ㅇㅠ_ㅋㅙ_ㅎㅏㄴㅇㅕㅇㅎㅘ_'],
#  ['ㅅㅜ_ㅅㅜ_ㅎㅏ_ㄱㅗ_',
#   'ㅍㅕㅇㅇㅏㄴㅎㅏㅁㅇㅡㄹ',
#   'ㅁㅏ_ㅇㅡㅁㅇㅔ_',
#   'ㄱㅏㅈㄷㅏ_ㅈㅜ_ㄴㅡㄴㄷㅡㅅ',
#   'ㅈㅐ_ㅁㅣㅅㄱㅔ_',
#   'ㅂㅘㅅㅇㅓ_ㅇㅛ_'],
#  ['ㄴㅐ_ㄹㅗ_',
#   'ㄴㅏㅁㅂㅜㄹ',
#   'ㅇㅗ_ㅈㅣ_ㄴㅔ_',
#   'ㅊㅚ_ㅅㅜㄴㅅㅣㄹ',
#   'ㅁㅜ_ㄷㅏㅇㅅㅓㄹ',
#   'ㅍㅓ_ㄸㅡ_ㄹㅣ_ㄷㅓㄴ',
#   'ㄴㅗㅁㄷㅡㄹㅇㅣ_'],
#  ['ㄷㅜ_ㅂㅜㄴㅇㅢ_',
#   'ㅁㅏ_ㅇㅡㅁㅇㅔ_',
#   'ㄷㅗㅇㅎㅘ_ㄷㅚ_ㅇㅓ_',
#   'ㅇㅜㄹㄱㅗ_ㅇㅜㅅㄱㅗ_ㅎㅏ_ㄴㅔ_ㅇㅛ_16ㅂㅜ_ㅈㅏㄱㅇㅣ_ㄹㅏㄴㄱㅔ_',
#   'ㅂㅓㄹㅆㅓ_',
#   'ㅇㅏ_ㅅㅟ_ㅇㅟ_ㅇㅛ_'],
#  ['ㅋㅜ_ㅇㅔㄴㅌㅣㄴ',
#   'ㅈㅓ_ㄹㅣ_ㄱㅏ_ㄹㅏ_',
#   'ㅍㅗ_ㅅㅡ_',
#   'ㅇㅗ_ㄹㅐㄴㅁㅏㄴㅇㅔ_',
#   'ㅊㅏㅈㅇㅡㄴ',
#   'ㅂㅗ_ㅅㅓㄱ',
#   'ㅊㅚ_ㄱㅗ_'],
#  ['ㄱㅏㅁㄷㅗㄱㅇㅢ_',
#   'ㅇㅕㄴㅊㅜㄹ',
#   'ㅂㅐ_ㅇㅜ_ㄷㅡㄹㅇㅢ_',
#   'ㅇㅕㄴㄱㅣ_',
#   'ㅇㅡㅁㅇㅏㄱㄲㅏ_ㅈㅣ_',
#   'ㅁㅗ_ㄷㅡㄴ',
#   'ㅇㅛ_ㅅㅗ_ㅇㅢ_',
#   'ㅎㅘㄴㅅㅏㅇㅈㅓㄱㅇㅣㄴ',
#   'ㅈㅗ_ㅎㅏㅂ',
#   'ㅎㅑㅇㅅㅜ_ㅇㅢ_',
#   'ㅈㅏㄴㅎㅑㅇㅊㅓ_ㄹㅓㅁ',
#   'ㄱㅖ_ㅅㅗㄱ',
#   'ㅅㅐㅇㄱㅏㄱㄴㅏ_ㄱㅗ_',
#   'ㅂㅗ_ㄱㅗ_',
#   'ㅅㅣㅍㄷㅏ_'],
#  ['ㅇㅣ_ㄱㅠ_ㅎㅕㅇ',
#   'ㄱㅏㅁㄷㅗㄱㄴㅣㅁ',
#   'ㅅㅣㄹㅎㅘ_',
#   'ㅁㅏㅈㅇㅡ_ㅅㅔ_ㅇㅛ_',
#   'ㄱㅣㅁㅈㅓㅇㅎㅜㄴㅇㅣ_',
#   'ㅇㅣ_ㄱㅠ_ㅎㅕㅇ',
#   'ㄱㅏㅁㄷㅗㄱㄴㅣㅁㅇㅣ_ㅅㅣ_ㄱㅜ_ㅇㅛ_',
#   'ㄷㅐ_ㄷㅏㄴㅎㅏ_ㅅㅣㅂㄴㅣ_ㄷㅏ_',
#   'ㄱㅡㄴㄷㅔ_',
#   'ㄷㅓ_ㄷㅐ_ㄷㅏㄴㅎㅏㄴㄱㅓㄴ',
#   'ㄹㅣ_ㅅㅜ_ㅇㅕㄴ',
#   'ㄱㅡㅁㅁㅔ_ㄷㅏㄹ',
#   'ㅅㅣㄹㅎㅘ_ㅇㅣㄴㄱㅏ_ㅇㅛ_',
#   'ㅇㅏ_ㅁㅜ_ㅌㅡㄴ',
#   'ㅇㅕㅇㅎㅘ_ㅈㅐ_ㅁㅣㅆㅅㅡㅂㄴㅣ_ㄷㅏ_',
#   'ㅇㅔㄴㄷㅣㅇㄱㅗㄱㅇㅡㄴ',
#   'ㄴㅓ_ㅁㅜ_',
#   'ㅍㅕㅇㅎㅘ_ㄹㅗㅂㄱㅗ_',
#   'ㅈㅗㅎㄴㅔ_ㅇㅛ_'],
#  ['ㅈㅗㅎㄷㅏ_', 'ㄴㅏ_ㄷㅗ_', 'ㄴㅏ_ㅇㅢ_', 'ㅂㅏ_ㄷㅏ_ㄹㅡㄹ', 'ㅊㅏㅈㅇㅏ_', 'ㄴㅏ_ㅇㅏ_ㄱㅏ_ㅇㅑ_ㅈㅣ_'],
#  ['ㅎㅗ_ㅇㅗㅇㅇㅣ_ㅅㅣㄴㄱㅣ_ㅎㅏ_ㄴㅔ_',
#   'ㅈㅏ_ㄱㅣ_',
#   'ㄱㅗㅇㅂㅜ_',
#   'ㅈㅏㄹㅎㅏㄴㄷㅏ_ㄷㅓ_ㄴㅣ_',
#   'ㅈㅣㄴㅉㅏㄴㄱㅏ_ㅂㅗ_ㄴㅔ_',
#   'ㅅㅣㄴㄱㅣ_ㅎㅏ_ㄷㅏ_'],
#  ['ㅈㅏㄴㅈㅏㄴㅎㅏ_ㄱㅔ_',
#   'ㄱㅡ_ㄹㅣ_ㄱㅗ_',
#   'ㅁㅏ_ㅇㅡㅁㅇㅔ_',
#   'ㅁㅝㄴㄱㅏ_',
#   'ㅇㅘ_ㄷㅏㅎㄱㅔ_',
#   'ㅂㅘㅆㄷㅓㄴ',
#   'ㅇㅕㅇㅎㅘ_ㅇㅣㅂㄴㅣ_ㄷㅏ_',
#   'ㅇㅡㅁㅅㅣㄱㄱㅘ_',
#   'ㅇㅡㅁㅇㅏㄱㄱㅘ_',
#   'ㅇㅕㅇㅅㅏㅇㄱㅘ_',
#   'ㄱㅡ_ㄹㅣ_ㄱㅗ_',
#   'ㅅㅏ_ㄹㅏㅁㄷㅡㄹ'],
#  ['ㅈㅓㄴㅈㅏㄱㅂㅗ_ㄷㅏ_',
#   '100',
#   'ㅈㅐ_ㅁㅣㅆㄷㅏ_',
#   'ㅂㅐ_ㅇㅜ_',
#   'ㄴㅐ_ㅇㅛㅇ',
#   'ㅁㅗ_ㄷㅜ_',
#   'ㅅㅔ_ㄹㅕㄴㄷㅚㅁ'],
#  ['ㅇㅖ_ㅈㅓㄴㅇㅔ_',
#   'ㅇㅕㅇㅎㅘ_ㄱㅘㄴㅇㅔ_ㅅㅓ_',
#   'ㅇㅓㅁㅊㅓㅇ',
#   'ㅈㅐ_ㅁㅣㅆㄱㅔ_',
#   'ㅂㅗ_ㄱㅗ_',
#   'ㅁㅏㄶㅇㅣ_',
#   'ㄱㅗㅇㄱㅏㅁㅎㅐㅆㄴㅡㄴㄷㅔ_',
#   'ㅈㅣㄴㅉㅏ_',
#   'ㅇㅛ_ㅈㅡㅁ',
#   'ㄷㅓ_ㅇㅜㄱㄷㅓ_',
#   'ㅅㅐㅇㄱㅏㄱㄴㅏ_ㄴㅡㄴ',
#   'ㅇㅕㅇㅎㅘ_'],
#  ['ㄴㅏ_ㅇㅑ_', 'ㅈㅓ_ㄱㅔ_', 'ㅅㅏㄹㅁㅏㄴㅎㅏ_ㄱㅗ_', 'ㅂㅐ_ㄱㅏ_', 'ㅂㅜㄹㄹㅓ_ㅅㅓ_', 'ㄱㅡ_ㄹㅓㄴㄱㅓ_ㅇㅣㅁ'],
#  ['ㄷㅟㅅㅌㅗㅇㅅㅜ_',
#   'ㅇㅓㄹㅇㅓㄹㅎㅏ_ㄱㅔ_',
#   'ㅁㅏㅈㅇㅡ_ㄴㅣ_ㄲㅏ_',
#   'ㅈㅓ_ㄹㅓㄴ',
#   'ㅁㅏㄹㅇㅡㄹ',
#   'ㅎㅏ_ㅈㅣ_',
#   'ㅇㅕㄱㅇㅡ_ㄹㅗ_',
#   'ㅅㅏ_ㄹㅏㅁㅇㅣ_',
#   'ㅊㅐㅇㄱㅕ_ㅈㅝㅆㄷㅏ_ㅁㅕㄴ',
#   'ㅈㅣ_ㄱㅡㅁㄷㅗ_',
#   'ㄱㅡ_ㅉㅗㄱㅇㅔ_ㅅㅓ_',
#   'ㅇㅕㄹㅅㅣㅁㅎㅣ_',
#   'ㄱㅗㅇㅈㅏㄱㅎㅏ_ㄱㅗ_',
#   'ㅇㅣㅆㅇㅓㅆㄱㅔㅆㅈㅣ_'],
#  ['ㅊㅓ_ㅇㅡㅁㅇㅔ_',
#   'ㅇㅔㄴㄷㅣㅇㅁㅏㄴ',
#   'ㅂㅘㅆㅇㅡㄹ',
#   'ㅎㅏㄴㅂㅓㄴ',
#   'ㅇㅜㄹㄱㅗ_',
#   'ㄴㅏ_ㅈㅜㅇㅇㅔ_',
#   'ㅂㅘㅆㅇㅡㄹㄸㅐ_',
#   'ㅇㅜㄹㅇㅓㅆㄷㅏ_',
#   'ㄴㅓ_ㅁㅜ_',
#   'ㅅㅡㄹㅍㅡ_ㄷㅏ_'],
#  ['ㅂㅏㄱㅇㅛㅇㅁㅏㄴ',
#   'ㅇㅣㄴㄱㅏㄴ',
#   'ㅂㅜㄱㅎㅏㄴㅇㅔ_',
#   'ㄷㅐ_ㅎㅐ_',
#   'ㅎㅗ_ㅇㅢ_ㅈㅓㄱㅇㅣㄴ',
#   'ㅂㅏㄹㅇㅓㄴㅎㅏㄴㄱㅓ_ㅂㅗ_ㄱㅗ_',
#   'ㅂㅕㄹㄹㅗ_',
#   'ㅇㅏㄴㅈㅗㅎㅇㅏㅆㅇㅓㅆㄴㅡㄴㄷㅔ_',
#   'ㄷㅏㄹㄹㅏ_ㅂㅗ_ㅇㅣ_ㄴㅔ_'],
#  ['ㅇㅡㄴㄱㅡㄴㅎㅣ_',
#   'ㅈㅜㅇㄷㅗㄱㄷㅚ_ㄴㅡㄴㄱㅓ_',
#   'ㄱㅏㅌㅇㅏ_ㅇㅛ_',
#   'ㅎㅏㄴㅂㅓㄴㅂㅗ_ㅁㅕㄴ',
#   'ㅁㅓㅁㅊㅜㄹ',
#   'ㅇㅓㅄㅇㅓㅆㅇㅓ_ㅇㅛ_',
#   'ㅈㅐㅁㅇㅣㅆㅇㅓㅆㅇㅓ_ㅇㅛ_'],
#  ['ㅎㅏㄹㄷㅏㅇㄹㅑㅇ',
#   'ㅁㅗㅅㅊㅐ_ㅇㅜ_ㄱㅗ_',
#   'ㄷㅣ_ㅈㅣ_ㄴㅗㅁ',
#   'ㄴㅗㅁㄷㅡㄹㅇㅡㄴ',
#   'ㄴㅏ_ㄱㅏ_',
#   'ㅈㅜㄱㅇㅕ_ㅂㅓ_ㄹㅣㄹㄲㅕ_'],
#  ['ㅆㅣ_ㅂㅏㄹ',
#   'ㅇㅣㄹㅂㅔ_ㅅㅐ_ㄲㅣ_ㄷㅡㄹㄷㅗ_',
#   'ㅇㅏ_ㄴㅡㄴㄱㅓㄹ',
#   'ㄱㅟ_ㅁㅏㄱㄱㅗ_',
#   'ㅇㅏㄴㄷㅡㄷㄴㅗ_',
#   'ㅇㅛ_ㅈㅡㅁ',
#   'ㅈㅘ_ㅍㅏ_ㅅㅐ_ㄲㅣ_ㄷㅡㄹ',
#   'ㅈㅗㄴㄴㅏ_',
#   'ㅎㅐㅇㅂㅗㄱㅎㅏㄴ',
#   'ㅂㅏ_ㅂㅗ_ㅂㅕㅇㅅㅣㄴㄷㅡㄹㄱㅏㅌㅇㅡㅁ'],
#  ['ㅅㅠ_ㅍㅓ_ㅊㅏ_ㅇㅣ_ㄴㅏ_ㄹㅏ_ㄴㅡㄴ',
#   'ㄷㅏ_ㅋㅠ_',
#   'ㅁㅏㄴㄷㅡㄹㅇㅓㅆㄴㅡㄴㄷㅔ_',
#   'ㅈㅜㅇㄱㅜㄱㅁㅗㅇ',
#   'ㅅㅣㄴㄴㅏ_ㄱㅔ_',
#   'ㅃㅏ_ㄴㅡㄴ',
#   'ㄴㅐ_ㅇㅛㅇㅇㅣㅁ',
#   'ㄱㅡ_ㄹㅐ_ㅅㅓ_',
#   'ㅉㅏㅇㄲㅐ_ㄱㅜㄱ',
#   'ㄱㅏ_ㅅㅓ_',
#   'ㅅㅏㅇㄲㅏ_ㅈㅣ_',
#   'ㅂㅏㄷㄱㅗ_'],
#  ['ㅇㅔ_ㄷㅡ_ㅇㅞ_ㅅㅡ_ㅌㅡ_ㅇㅝㄱㅇㅣ_',
#   'ㅊㅜㄹㅇㅕㄴㅎㅏ_ㄴㅡㄴㄱㅓ_ㄹㅏ_ㅁㅕㄴ',
#   'ㄷㅏㅇㄱㅡㄴ',
#   'ㅎㅜ_ㅎㅚ_ㅎㅏ_ㅈㅣ_ㅇㅏㄶㄴㅡㄴ',
#   'ㅇㅕㅇㅎㅘ_ㅇㅣㅁ',
#   'ㅇㅕㄱㅅㅣ_',
#   'ㄹㅗ_ㅁㅐㄴㅌㅣㄱㅋㅗ_ㅁㅔ_ㄷㅣ_',
#   'ㅈㅗㅇㄱㅕㄹㅈㅏ_',
#   'ㅅㅑㄹㄹㅔ_ㅇㅣ_ㄱㅓㄹ',
#   'ㅎㅡㅇㅎㅐㅇ'],
#  ['ㅇㅣ_ㄴㅏ_ㄹㅏ_ㄴㅡㄴ', 'ㄴㅏㅁㅈㅏ_ㄹㅗ_', 'ㅌㅐ_ㅇㅓ_ㄴㅏㄴㄱㅔ_', 'ㅈㅚ_ㄹㅡㄹ', 'ㅈㅣ_ㅇㅡㄴㄱㅓ_ㄷㅏ_'],
#  ['ㅈㅐ_ㅁㅣㅆㄱㅔ_', 'ㅂㅘㅆㄴㅡㄴㄷㅔ_', 'ㅍㅕㅇㅈㅓㅁㅇㅣ_', 'ㅇㅣ_ㄹㅓㄴㅈㅣ_', 'ㅁㅗ_ㄹㅡ_ㄱㅔㅅㄷㅏ_'],
#  ['ㅇㅗ_ㄴㅡㄹ',
#   'ㄱㅣ_ㅅㅏ_ㄴㅡㄴ',
#   '2ㄷㅡㅇㅇㅣ_ㄷㅏ_',
#   'ㅍㅛ_ㅂㅗㄴㅁㅏ_ㄷㅏ_',
#   'ㄱㅡ_ㅁㅏㄴㅋㅡㅁ',
#   'ㅊㅏ_ㅇㅣ_ㄱㅏ_',
#   'ㅋㅡ_ㄷㅏ_ㄴㅡㄴㄱㅓ_ㄷㅏ_',
#   'ㄱㅡ_ㄹㅓㅎㄱㅔ_',
#   'ㅈㅐ_ㄱㅏ_ㅇㅣㅂㄲㅏ_ㅈㅣ_',
#   'ㅎㅏ_ㅁㅕ_',
#   'ㅇㅣㄹㅂㅔ_ㅇㅔ_ㅅㅓ_',
#   'ㅇㅣ_ㄹㅓ_ㄱㅗ_',
#   'ㅅㅣㅍㄴㅑ_',
#   'ㅈㅣㄴㅉㅏ_',
#   'ㅎㅘㅇㄱㅛ_ㅇㅏㄴㅇㅣ_',
#   'ㅈㅓㄴㄹㅏ_ㄷㅗ_',
#   'ㄱㅘㄴㄹㅕㄴㅇㅡㄴ',
#   'ㅁㅜ_ㅅㅣ_ㅎㅏ_ㄴㅡㄴㅈㅣ_',
#   'ㅇㅏㄹㄱㅔㅆㄷㅏ_'],
#  ['ㄱㅡ_ㄹㅐ_ㄷㅗ_', 'ㅅㅓㄹㄹㅏ_ㄷㅗ_', 'ㄱㅐ_ㄷㅙ_ㅈㅣ_ㄷㅡㄹㅇㅡㄴ', 'ㅈㅏㄹㅎㅏㄴㄷㅏ_', 'ㅂㅏㄱㅅㅜ_ㅊㅣㅁ'],
#  ['ㅁㅜㄴㅈㅐ_ㅇㅣㄴ',
#   'ㅂㅏㄴㄷㅐ_',
#   'ㅅㅣ_ㅇㅟ_ㅎㅏ_ㅁㅕㄴ',
#   'ㅁㅝ_ㄹㅏ_ㄱㅗ_',
#   'ㄱㅣ_ㅅㅏ_ㅆㅡㄹㅈㅣ_',
#   'ㄱㅜㅇㄱㅡㅁㅎㅏ_ㄴㅔ_'],
#  ['80ㅇㅔ_',
#   'ㅍㅔ_ㅌㅣ_ㅅㅟ_',
#   'ㅇㅣㅆㄴㅑ_',
#   'ㅈㅗㅈㅂㅕㅇㅅㅣㄴㅆㅣ_ㅂㅏㄹㅅㅐ_ㄲㅣ_ㅇㅑ_',
#   'ㄱㅜㄱㅁㅣㄴㅇㅢ_',
#   '80ㄱㅏ_',
#   'ㅁㅜㄴㅆㅣ_ㅂㅏㄹㅇㅔ_',
#   'ㅇㅢ_ㅎㅐ_',
#   'ㅅㅐㅇㅎㅘㄹㅇㅣ_',
#   'ㅇㅓ_ㄹㅕ_ㅇㅝ_ㅈㅕㅅㄷㅏ_ㄱㅗ_',
#   'ㅎㅐ_ㄹㅏ_'],
#  ['ㅍㅕㅇㅅㅐㅇ',
#   'ㅊㅚ_ㄱㅗ_ㅇㅢ_',
#   'ㅇㅕㅇㅎㅘ_',
#   'ㅈㅓㄹㅈㅓㄹㅎㅏ_ㄱㅔ_',
#   'ㄱㅏ_ㅅㅡㅁㅇㅡㄹ',
#   'ㅇㅜㄹㄹㅣ_ㄴㅡㄴ',
#   'ㄱㅜ_ㅇㅐ_',
#   'ㅍㅕㅇㅅㅐㅇ',
#   'ㅇㅣㅈㅈㅣ_',
#   'ㅁㅗㅅㅎㅏㄹ',
#   'ㅇㅕ_ㅇㅜㄴ'],
#  ['ㅈㅏㄹㅁㅏㄴㄷㅡㄴ',
#   'ㅇㅕㅇㅎㅘ_ㅇㅣ_ㄹㅓㄴ',
#   'ㅇㅕㅇㅎㅘ_ㄱㅏ_',
#   'ㅁㅏㄶㅇㅏ_ㅈㅣ_ㄱㅣㄹ',
#   'ㅂㅏ_ㄹㅏ_ㅁㅕ_',
#   '10ㅈㅓㅁ'],
#  ['ㄱㅡ_ㄷㅡㄹㅇㅢ_',
#   'ㅇㅛㄱㅁㅏㅇㅇㅡㄴ',
#   'ㄷㅓ_ㄹㅓ_ㅇㅜㄴㄱㅏ_',
#   'ㅊㅜㄹㅈㅜㅇㅎㅏㄴ',
#   'ㅇㅚ_ㅁㅗ_ㅇㅢ_',
#   'ㅂㅜ_ㅇㅠ_ㅎㅏㄴ',
#   'ㅈㅓㅇㅅㅏㅇㅇㅣㄴㄷㅡㄹㅇㅢ_',
#   'ㅇㅛㄱㅁㅏㅇㅇㅡㄴ',
#   'ㄲㅐ_ㄲㅡㅅㅎㅏㄴㄱㅏ_',
#   'ㄱㅡ_ㄷㅡㄹㅇㅡㄹ',
#   'ㅂㅗ_ㄷㅡㅁㅇㅓ_',
#   'ㅇㅣㅆㄴㅡㄴ',
#   'ㅇㅠ_ㅇㅣㄹㅎㅏㄴ',
#   'ㅂㅏㅇㅂㅓㅂㅇㅣ_',
#   'ㅎㅘㄴㅅㅏㅇ',
#   'ㄸㅗ_ㄴㅡㄴ',
#   'ㅈㅜㄱㅇㅡㅁㅃㅜㄴㅇㅣ_ㄹㅏ_ㄴㅡㄴ',
#   'ㅅㅏ_ㅅㅣㄹㅇㅣ_',
#   'ㅅㅡㄹㅍㅡ_ㄷㅏ_',
#   'ㅇㅗ_ㄹㅐㄴㅁㅏㄴㅇㅔ_',
#   'ㄴㅜㄴㅁㅜㄹㄴㅏ_ㄴㅡㄴ',
#   'ㅇㅕㅇㅎㅘ_ㅇㅡㄹ',
#   'ㅂㅘㅆㄷㅏ_'],
#  ['ㅇㅕㅇㅎㅘ_ㄴㅡㄴ',
#   'ㅇㅏ_ㅅㅟㅂㅈㅣ_ㅁㅏㄴ',
#   'ㅎㅏㄴㄱㅣㄹㅅㅜ_ㄹㅏㄴ',
#   'ㅇㅣㄴㅁㅜㄹㅇㅣ_',
#   'ㅈㅗㄴㄱㅕㅇㅅㅡ_ㄹㅓㅂㄱㅜㄴㅇㅛ_'],
#  ['ㅊㅚ_ㄱㅗ_ㄹㅗ_', 'ㅁㅓㅅㅇㅣㅆㄷㅏ_', 'ㅇㅣ_ㅇㅕㅇㅎㅘ_', 'ㅈㅓㅇㅁㅏㄹ', 'ㅊㅚ_ㄱㅗ_ㄷㅏ_'],
#  ['ㄴㅜ_ㄱㅜ_ㄴㅏ_', 'ㅇㅛ_ㄹㅣ_ㅎㅏㄹ', 'ㅇㅣㅆㄷㅏ_', 'ㅈㅣㄴㅈㅓㅇㅎㅏㄴ', 'ㄷㅡ_ㄹㅏ_ㅁㅏ_ㅇㅕㅆㄷㅏ_'],
#  ['ㅅㅗㄹㅈㅣㄱㅎㅣ_',
#   'ㅍㅕㄴㄹㅣ_ㅅㅡ_ㅁㅓ_ㅍㅡ_',
#   'ㅎㅓ_ㅇㅕㅇㅇㅣ_ㅅㅡ_ㅁㅓ_ㅍㅡ_',
#   'ㄱㅡ_ㄹㅣ_ㄱㅗ_',
#   'ㅅㅏ_ㅅㅔ_ㅌㅡ_',
#   'ㄷㅡㅇㅇㅡㄹ',
#   'ㅂㅗ_ㄱㅗ_',
#   'ㅅㅣㅍㅇㅓㅆㅇㅓ_ㅇㅛ_',
#   'ㄱㅡ_ㄱㅔ_',
#   'ㅇㅏ_ㅅㅟㅂㄱㅣㄴ',
#   'ㅎㅐㅆㅇㅡ_ㄴㅏ_',
#   'ㄱㅡ_ㄹㅐ_ㄷㅗ_',
#   'ㅈㅗㅎㅇㅡㄴㅇㅕㅇㅎㅘ_',
#   '9ㅈㅓㅁ',
#   'ㄷㅡ_ㄹㅣㄹㄱㅔ_ㅇㅛ_'],
#  ['ㄴㅏㅁㄴㅕ_ㅈㅜ_ㅇㅣㄴㄱㅗㅇ',
#   'ㅇㅕㄴㄱㅣ_ㅈㅗㅎㅇㅏ_ㅇㅛ_',
#   'ㄷㅏㄴㅅㅜㄴ',
#   'ㅇㅔ_ㄹㅗ_ㄹㅗ_',
#   'ㅂㅗ_ㄱㅣ_ㅇㅔㄴ',
#   'ㅈㅣㄴㅉㅏ_',
#   'ㅇㅏ_ㄲㅏ_ㅇㅜㅁ',
#   'ㅌㅣ_ㅂㅣ_ㄴㅏ_',
#   'ㅇㅕㅇㅎㅘ_ㅇㅔ_ㅅㅓ_',
#   'ㅈㅏ_ㅈㅜ_ㅂㅘㅆㅇㅡㅁ',
#   'ㅈㅗㅎㄱㅔㅆㄷㅏ_'],
#  ['ㄱㅡ_ㄹㅓㅁ',
#   'ㅆㅣㅅㅇㅡㄹ',
#   'ㅂㅣ_ㄴㅜ_ㅊㅣㄹㅎㅐ_ㅅㅓ_',
#   'ㅆㅣㅅㅇㅓ_ㄷㅗ_',
#   'ㄷㅚ_ㄴㅗ_',
#   'ㄱㅡㄴㄷㅔ_',
#   'ㅂㅏㅇㅅㅜ_ㄱㅣ_ㄴㅡㅇ',
#   'ㅇㅣㅆㅇㅡ_ㄴㅣ_',
#   'ㄲㅐ_ㄲㅡㅅㅎㅏ_ㄱㅔ_',
#   'ㅆㅣㅅㅇㅡㄹ',
#   'ㅇㅣㅆㄱㅔㅆㄴㅗ_'],
#  ['ㄴㅔ_ㅇㅣ_ㅂㅓ_',
#   'ㅇㅕㅇㅎㅘ_ㅍㅕㅇㅈㅓㅁ',
#   'ㅊㅓ_ㅇㅡㅁ',
#   'ㅇㅗㄹㄹㅕ_ㅂㅗㅂㄴㅣ_ㄷㅏ_',
#   'ㅇㅕㅇㅎㅘ_ㄱㅏ_',
#   'ㅇㅜ_ㄹㅣ_',
#   'ㅅㅏㄻㅇㅔ_ㅅㅓ_',
#   'ㅎㅐ_ㅈㅜㄹ',
#   'ㅇㅣㅆㄴㅡㄴ',
#   'ㄱㅏ_ㅈㅏㅇ',
#   'ㅇㅘㄴㅂㅕㄱㅎㅏㄴ',
#   'ㅇㅕㄱㅎㅏㄹㅇㅡㄹ',
#   'ㅇㅕㅇㅎㅘ_ㄴㅡㄴ',
#   'ㅎㅐ_ㄴㅐㅆㄷㅏ_ㄱㅗ_',
#   'ㅂㅘ_ㅇㅛ_'],
#  ['ㅁㅜㄴㅈㅐ_ㅇㅏㅇ',
#   'ㅌㅡㄹㄸㅏㄱ',
#   'ㄷㅐ_ㅅㅣㄴ',
#   'ㄸㅗㅇㅅㅟㄴㄴㅐ_',
#   'ㅍㅜㅇㄱㅣ_ㄴㅡㄴ',
#   'ㅈㅘ_ㅈㅗㅁ',
#   'ㅌㅡㄹㄸㅏㄱㄷㅡㄹㄲㅔ_ㅅㅓ_',
#   'ㄷㅐ_ㅅㅣㄴ',
#   'ㅍㅗㄱㄱㅕㄱㅎㅏㄹ',
#   'ㄱㅔ_ㅅㅣ_ㄱㅡㄹㄹㅗ_',
#   'ㅍㅏㄴㅁㅕㅇㄷㅚ_ㅇㅓㅆㅅㅡㅂㄴㅣ_ㄷㅏ_'],
#  ['ㅈㅓㅇㅁㅏㄹㄹㅗ_',
#   'ㄴㅜㄴㅁㅜㄹ',
#   'ㅎㅡㄹㄹㅣ_ㄱㅗ_',
#   'ㄸㅗ_ㅇㅜㄹㄱㅗ_ㅇㅣㅆㄷㅏ_',
#   'ㅊㅓㄴㅇㅏㄴㅎㅏㅁ',
#   'ㅎㅢ_ㅅㅐㅇㅈㅏ_',
#   'ㅇㅓ_ㅁㅓ_ㄴㅣ_ㅇㅢ_',
#   'ㅍㅛ_ㅈㅓㅇ'],
#  ['ㄷㅏㄹㅊㅏㅇㅂㅕㅇㅅㅣㄴㄷㅡㄹ',
#   'ㅁㅜ_ㅈㅓㄱㄱㅝㄴ',
#   'ㅈㅏ_ㅎㅏㄴㄷㅏㅇ',
#   'ㄲㅡ_ㄴㅏ_ㅍㅜㄹㅇㅣ_',
#   'ㅍㅗㄱㅎㅐㅇㅎㅐㅆㄷㅏ_ㄱㅗ_',
#   'ㅈㅗㄴㄴㅏ_ㅎㅏ_ㄷㅓ_ㅁㅏㄴ'],
#  ['ㄷㅏㅂㄷㅏㅂㅎㅏㄹㄸㅐ_',
#   'ㅃㅓㅇㄸㅜㅀㅇㅓ_ㅈㅜ_ㄴㅡㄴ',
#   'ㅇㅕㅇㅎㅘ_',
#   'ㅊㅚ_ㄱㅗㅂㄴㅣ_ㄷㅏ_',
#   'ㅎㅏㄴㄱㅜㄱㅇㅐㄱㅅㅕㄴㅇㅢ_',
#   'ㅂㅏㄹㅈㅓㄴㅎㅑㅇㅅㅏㅇㅇㅡㄹ',
#   'ㅂㅗ_ㅇㅕ_ㅈㅜ_ㄴㅔ_ㅇㅛ_'],
#  ['ㄱㅗㄹㄸㅐ_ㄹㅣ_ㄱㅔ_',
#   'ㅇㅜㅅㄱㅕㅆㄷㅏ_',
#   'ㅋㅗ_ㅁㅣ_ㄷㅣ_',
#   'ㅇㅕㅇㅎㅘ_ㄱㅏ_',
#   'ㅇㅜㅅㄱㅣ_ㅁㅕㄴ',
#   'ㅈㅏㅇㄸㅐㅇㅇㅣ_ㅈㅣ_'],
#  ['ㅅㅣㄴㅇㅣㄴㄱㅏㅁㄷㅗㄱㄴㅣㅁ',
#   'ㄱㅏㅌㅇㅡㄴㄷㅔ_',
#   'ㅇㅕㅇㅎㅘ_',
#   'ㄴㅓ_ㅁㅜ_',
#   'ㅈㅏㄹㅁㅏㄴㄷㅡ_ㅅㅕㅆㅇㅓ_ㅇㅛ_ㅈㅐ_ㅁㅣㅆㅇㅓ_ㅇㅛ_',
#   'ㅈㅏㄹㅂㅘㅆㅅㅡㅂㄴㅣ_ㄷㅏ_ㄷㅏ_ㅇㅡㅁㅇㅕㅇㅎㅘ_ㄷㅗ_',
#   'ㄱㅣ_ㄷㅐ_ㄷㅙ_ㅇㅛ_'],
#  ['ㅂㅗ_ㅈㅣ_ㄴㅕㄴ',
#   'ㄴㅗㄴㄹㅣ_',
#   'ㅁㅣ_ㅊㅣㄴㄴㅕㄴㅇㅏ_',
#   'ㅍㅐㄱㅌㅡ_ㄹㅡㄹ',
#   'ㅈㅔ_ㅅㅣ_ㅎㅏㄹ',
#   'ㄱㅡㄴㄱㅓ_',
#   'ㄱㅏ_ㅈㅕ_ㅇㅘ_',
#   'ㅁㅣ_ㅊㅣㄴㄴㅕㄴㅇㅣ_',
#   'ㅂㅗ_ㅈㅣ_ㄱㅏ_',
#   'ㄴㅏ_ㄷㅐ_ㄴㅣ_',
#   'ㅂㅗ_ㅈㅣ_ㄴㅡㄴ',
#   'ㄱㅡ_ㄴㅑㅇ',
#   'ㅂㅗ_ㅈㅣ_',
#   'ㅂㅗ_ㅇㅕ_ㅈㅜ_ㄱㅗ_',
#   'ㅂㅏㄱㅎㅣ_ㅁㅕㄴ',
#   'ㄷㅚ_ㄴㅡㄴㄷㅔ_'],
#  ['ㅇㅓ_ㄹㅣㄹㄸㅐ_',
#   'ㄱㅏㅁㄷㅗㅇㅇㅡ_ㄹㅗ_ㅂㅗ_ㄱㅗ_',
#   'ㅅㅓㅇㅇㅣㄴㅇㅣ_ㄷㅚ_ㅇㅓ_',
#   'ㅅㅐㅇㄱㅏㄱㄴㅏ_ㅅㅓ_',
#   'ㅊㅏㅈㅇㅏ_ㅂㅗ_ㄱㅗ_',
#   'ostㄴㅡㄴ',
#   'ㅍㅗㄴㄱㅗㄱㄹㅣ_ㅅㅡ_ㅌㅡ_ㄹㅡㄹ',
#   'ㅊㅏ_ㅈㅣ_ㅎㅐㅆㅅㅡㅂㄴㅣ_ㄷㅏ_',
#   'ㅇㅝㄹㅌㅡ_ㄷㅣ_ㅈㅡ_ㄴㅣ_ㅁㅕㅇㅈㅏㄱ'],
#  ['ㅇㅣ_ㅎㅐ_ㅁㅗㅅㅎㅏ_ㄱㅗ_',
#   '1ㅈㅓㅁ',
#   'ㅉㅣ_ㅈㅣㄹㅇㅣ_ㄴㅗㅁㄷㅡㄹ',
#   'ㄸㅐ_ㅁㅜㄴㅇㅔ_',
#   'ㅍㅕㅇㅈㅓㅁㅇㅣ_',
#   'ㄲㅏㄲㅇㅕㅆㄴㅔ_'],
#  ['ㄷㅏㅇㅅㅣ_ㅇㅔ_',
#   'ㅇㅣ_ㄹㅓㄴ',
#   'ㅇㅕㅇㅎㅘ_ㄹㅡㄹ',
#   'ㅁㅏㄴㄷㅡㄹㅅㅜ_',
#   'ㅇㅣㅆㄷㅏ_ㄴㅡㄴㄱㅓㅅㅇㅣ_',
#   'ㄴㅗㄹㄹㅏ_ㅇㅜㄹㅃㅜㄴ',
#   'ㅁㅕㅇㅈㅏㄱㅇㅣㅂㄴㅣ_ㄷㅏ_'],
#  ['ㅇㅏㄴㅊㅓㄹㅅㅜ_',
#   'ㅈㅣ_ㄱㅡㅁㄲㅏ_ㅈㅣ_',
#   'ㅎㅏㄴㅈㅣㅅㄱㅓ_ㄹㅣ_',
#   'ㅂㅗ_ㄱㅗ_ㄷㅗ_',
#   'ㅂㅗㅇㅅㅏ_',
#   'ㅎㅏ_ㄴㅏ_',
#   'ㅎㅏㄴㄱㅓㄹㄹㅗ_',
#   'ㅃㅗㅂㄱㅔㅆㄷㅏ_ㄱㅗ_'],
#  ['ㅈㅜ_ㅂㅕㄴㅇㅣ_', 'ㅈㅗㅇㅂㅜㄱㅇㅣ_', 'ㅇㅏ_ㄴㅣ_ㄹㅏ_', 'ㅈㅓ_ㅅㅐ_ㄲㅣ_ㄱㅏ_', 'ㅈㅗㅇㅂㅜㄱㅇㅣ_ㅇㅑ_'],
#  ['ㄷㅡ_ㄹㅏ_ㅁㅏ_ㄱㅏ_',
#   'ㅅㅏㄹㅇㅏ_ㅇㅣㅆㄴㅡㄴ',
#   'ㄱㅏ_ㅅㅡㅁ',
#   'ㅁㅓㄱㅁㅓㄱㅎㅐ_ㅈㅣ_ㄴㅡㄴ',
#   'ㅇㅕㅇㅎㅘ_ㅇㅕㅆㄷㅏ_',
#   'ㅈㅣㄴㅉㅏ_',
#   'ㅊㅚ_ㄱㅗ_ㄷㅏ_',
#   'ㅁㅏㄴㅎㅘ_ㄹㅏㅇㅇㅡㄴ',
#   'ㅈㅗ_ㄱㅡㅁ',
#   'ㄷㅏ_ㄹㅡ_ㄴㅣ_ㄲㅏ_',
#   'ㄴㅓ_ㅁㅜ_',
#   'ㅁㅏㄴㅎㅘ_',
#   'ㅅㅐㅇㄱㅏㄱㅎㅏ_ㅁㅕㄴ',
#   'ㅇㅏㄴㄷㅚㄴㄷㅏ_',
#   'ㅇㅝㄴㅈㅏㄱㅇㅡㄹ',
#   'ㄸㅟ_ㅇㅓ_ㄴㅓㅁㅇㅡㄴ',
#   'ㅇㅕㅇㅎㅘ_ㅇㅕㅆㄷㅏ_'],
#  ['ㄱㅚ_ㅉㅏ_ㅅㅡ_ㄹㅓㅂㄱㅗ_',
#   'ㅂㅏㄹㅊㅣㄱㅎㅏㄴ',
#   'ㅈㅐ_ㅁㅣ_ㄱㅏ_',
#   'ㅇㅣㅆㄴㅡㄴ',
#   'ㅇㅕㅇㅎㅘ_',
#   'ㅇㅗ_ㄹㅡ_ㅍㅔ_ㅇㅗ_',
#   'ㄱㅏㅌㅇㅡㄴ',
#   'ㅊㅣㄴㄱㅜ_ㄱㅏ_',
#   'ㅇㅣㅆㅇㅡㅁ',
#   'ㅈㅗㅎㄱㅔㅆㅇㅓ_'],
#  ['ㄴㅐ_ㄱㅏ_',
#   'ㄹㅗ_ㅁㅐㄴㅅㅡ_ㄹㅡㄹ',
#   'ㅂㅕㄹㄹㅗ_ㅇㅏㄴㅈㅗㅎㅇㅏ_ㅎㅏ_ㄴㅡㄴㄷㅔ_',
#   'ㅇㅣㅁㅊㅏㅇㅈㅓㅇㄸㅐ_ㅁㅜㄴㅇㅔ_ㅂㅘㅆㄷㅏ_',
#   'ㅇㅣㅁㅊㅓㅇㅈㅓㅇ',
#   'ㅅㅜㄴㅅㅜ_ㅎㅐ_ㅂㅗ_ㅇㅣ_ㄱㅗ_',
#   'ㅍㅜㅅㅍㅜㅅㅎㅏ_ㄷㅓㄴ',
#   'ㄱㅡ_ㅅㅣ_ㅈㅓㄹ',
#   'ㅈㅣ_ㄱㅡㅁ',
#   'ㄷㅏ_ㅅㅣ_ㅂㅘ_ㄷㅗ_',
#   'ㅁㅕㅇㅈㅏㄱㅇㅣ_ㄷㅏ_'],
#  ['ㅇㅣ_ㄱㅓ_',
#   'ㅈㅣㄴㅉㅏ_',
#   'ㅁㅏㄱㅇㅏ_ㅇㅑ_',
#   'ㅎㅏ_ㄴㅡㄴㄱㅓ_ㄷㅏ_',
#   'ㅇㅣ_ㄱㅓㄴ',
#   'ㅈㅏ_ㅇㅠ_ㅇㅘ_',
#   'ㅂㅓㅂㅊㅣ_ㅇㅘ_',
#   'ㅅㅐㅇㅈㅗㄴㅇㅢ_',
#   'ㅁㅜㄴㅈㅔ_ㄷㅏ_'],
#  ['ㅁㅣ_ㅈㅣ_ㅁㅏㄱ',
#   'ㅇㅛ_ㄱㅏㅇ',
#   '1ㅁㅏㄴㅇㅝㄴ',
#   'ㄸㅓㅆㅇㅡ_ㅁㅕㄴ',
#   'ㄸㅓㄱㅂㅗㄲㅇㅣ_',
#   'ㅇㅏ_ㅈㅣ_ㅁㅐ_ㅊㅓ_ㄹㅓㅁ',
#   'ㅈㅜ_ㅈㅓ_ㅇㅏㄵㅇㅡㄴ',
#   'ㅁㅕㅇㅉㅏㄹ',
#   'ㄴㅏ_ㅇㅘㅆㅇㅡㄹㄱㅓㄴㄷㅔ_',
#   'ㄱㅐ_ㅍㅐ_ㄷㅏ_ㄱㅏ_',
#   'ㅈㅜㄱㄱㅣ_',
#   'ㅈㅣㄱㅈㅓㄴㅇㅔ_',
#   'ㅎㅣㄹㅈㅜ_ㄴㅗ_'],
#  ['ㅅㅏ_ㅎㅚ_ㅈㅓㄱ',
#   'ㅂㅜㄴㅇㅟ_ㄱㅣ_',
#   'ㄸㅐ_ㅁㅜㄴㅇㅔ_',
#   'ㅁㅏ_ㄱㅜ_ㅈㅏㅂㅇㅣ_ㄹㅗ_',
#   'ㅂㅜ_ㅅㅓ_ㅈㅣ_ㄴㅡㄴ',
#   'ㅍㅏ_ㄱㅚ_ㅆㅣㄴㅇㅡㄴ',
#   'ㅇㅓㅄㅇㅓㅆㅈㅣ_ㅁㅏㄴ',
#   'ㄱㅡ_ㄹㅓㅁㅇㅔ_ㄷㅗ_',
#   'ㅈㅓㄴㅌㅜ_ㅆㅣㄴㅇㅡㄴ',
#   'ㅈㅓㅇㅁㅏㄹ',
#   'ㅊㅚ_ㄱㅏㅇㅇㅣ_ㅇㅕㅆㅅㅡㅂㄴㅣ_ㄷㅏ_',
#   'ㄱㅐ_ㄱㅡ_ㄷㅗ_',
#   'ㄲㅐ_ㅇㅏㄹㄱㅏㅌㄱㅗ_',
#   'ㅇㅜㅅㅇㅡ_ㅁㅕㄴㅅㅓ_',
#   'ㅂㅘㅆㄴㅔ_ㅇㅛ_'],
#  ['ㅁㅣㄴㅈㅗㄱㅇㅢ_', 'ㅅㅏㄴㅂㅜㄹ', 'ㅇㅜㄴㅈㅣ_ㅊㅗ_', 'ㅎㅐㅇㄷㅗㅇㅎㅏ_ㄴㅡㄴ', 'ㄱㅓ_ㅈㅣㅅ', 'oyota', 'oo'],
#  ['ㅈㅔ_ㅁㅗㄱㅇㅢ_', 'ㅍㅕㄴㄱㅕㄴㅇㅣ_', 'ㅇㅏ_ㅅㅟ_ㅇㅜㄴ', 'ㅊㅚ_ㄱㅗ_ㅇㅢ_', 'ㅇㅕㅇㅎㅘ_'],
#  ['ㅇㅣ_ㅈㅐ_ㅇㅛㅇ',
#   'ㅍㅛ_ㅈㅓㅇㅂㅗ_ㄴㅣ_',
#   'ㅈㅗ_ㅁㅏㄴㄱㅏㄴ',
#   'ㅈㅗ_ㅅㅓㄴㅇㅔ_',
#   'ㅈㅣ_ㅇㅗㄱㅇㅣ_',
#   'ㄷㅏㄱㅊㅣ_ㄱㅓㅆㄴㅗ_'],
#  ['ㅇㅣㄹㅂㅗㄴ', 'ㅈㅜ_ㅅㅣㄱ', 'ㅈㅓㄴㅁㅜㄴㄱㅏ_ㄴㅑ_', 'ㅇㅣㄹㅂㅗㄴㅇㅔ_', 'ㅇㅠ_ㅁㅏㅇㄱㅣ_ㅇㅓㅂ', 'ㅇㅣㅆㄴㅑ_'],
#  ['ㅊㅗ_6ㅂㅜ_ㅌㅓ_',
#   '7ㅅㅔ_ㄲㅏ_ㅈㅣ_',
#   'ㅇㅜ_ㄹㅣ_ㅇㅏ_ㅇㅣ_ㄷㅡㄹㅇㅣ_',
#   'ㅊㅚ_ㄱㅗ_ㅇㅢ_',
#   'ㅇㅕㅇㅎㅘ_ㄹㅗ_',
#   'ㄲㅗㅂㅇㅡㄴ',
#   'ㅇㅏ_ㄹㅡㅁㄷㅏ_ㅇㅜㄴ',
#   'ㅇㅕㅇㅎㅘ_ㅇㅣ_ㄷㅏ_',
#   'ㄷㅓ_ㅂㅣㅇㅎㅏ_ㅈㅣ_',
#   'ㅇㅏㄶㅇㅡㄴㄱㅓㅅㅇㅡ_ㄹㅗ_',
#   '7ㅅㅔ_ㅇㅏ_ㅇㅣ_ㄷㅗ_',
#   'ㅊㅜㅇㅂㅜㄴㅎㅣ_',
#   'ㅇㅣ_ㅎㅐ_ㅎㅏ_ㅇㅕㅆㅇㅡㅁㅇㅡㄹ',
#   'ㅊㅏㅁㄱㅗ_ㅎㅏ_ㅅㅕ_ㄷㅗ_',
#   'ㄷㅚㄹㄷㅡㅅㅎㅏㅁ'],
#  ['ㅌㅏㄹㄹㅏ_ㄷㅗ_',
#   'ㅈㅣㄴㅉㅏ_',
#   'ㅇㅏㄴㅂㅗ_ㄱㅘㄴ',
#   'ㅂㅏㄴㄷㅗ_',
#   '1ㄷㅡㅇ',
#   'ㄱㅐ_ㅆㅣㅂ',
#   'ㅈㅗㅈㄱㅕㅇㄷㅜ_ㄹㅏㅇㅇㅡㄴ',
#   'ㅊㅏ_ㅇㅝㄴㅇㅣ_',
#   'ㄷㅏ_ㄹㅡㅁ'],
#  ['ㅅㅏ_ㄱㅗ_ㅁㅜㅇㅊㅣ_ㅇㅣ_ㅈㅣ_ㅁㅏㄴ',
#   'ㅇㅓ_ㅁㅓ_ㄴㅣ_ㅇㅔ_',
#   'ㄷㅐ_ㅎㅏㄴ',
#   'ㄸㅡ_ㄱㅓㄴㅇㅜㄴ',
#   'ㅅㅏ_ㄹㅏㅇㅇㅣ_',
#   'ㄴㅜㄹㅁㅜㄹㄱㅕ_ㅇㅝ_',
#   'ㄱㅏㅁㄷㅗㅇㅈㅓㄱㅇㅣ_ㅇㅓㅆㄷㅏ_'],
#  ['ㅍㅐㄱㅌㅡ_',
#   'ㅁㅜㄴㅈㅐ_ㅇㅏㅇㄸㅐ_ㅁㅜㄴㅇㅔ_',
#   'ㅇㅓㅄㅇㅓ_ㅅㅓ_',
#   'ㅊㅏ_ㄴㅡㄴ',
#   'ㅁㅜ_ㅅㅡㄴ',
#   'ㅅㅜ_ㄹㅣ_ㅂㅣ_ㄷㅗ_',
#   'ㅃㅏ_ㅅㅡㅅㅎㅏㄴ',
#   'ㅅㅏㅇㅎㅘㅇㅇㅣㅁ'],
#  ['ㄴㅜ_ㄱㅏ_',
#   'ㅅㅡ_ㅌㅣ_ㅋㅓ_',
#   'ㅁㅗㄹㄹㅐ_',
#   'ㅇㅓㄵㅇㅓ_ㄴㅗㅎㅇㅡㄴ',
#   'ㅇㅏ_ㄴㅑ_',
#   'ㅊㅏㅇㅁㅜㄴㅇㅔ_',
#   'ㅂㅣ_ㅊㅕ_',
#   'ㅂㅗ_ㅇㅣㄹㄹㅐ_ㄴㅏ_'],
#  ['ㅅㅓㄴㅈㅔ_ㄷㅗㅇㅈㅏ_ㄱㅏ_',
#   'ㅂㅜ_ㅊㅓ_ㄱㅏ_',
#   'ㄷㅙ_ㄱㅣ_ㅇㅟ_ㅎㅐ_ㅅㅓ_',
#   'ㅅㅜ_ㅎㅐㅇㅇㅡㄹ',
#   'ㅎㅏ_ㄴㅡㄴㄱㅓㅅㅇㅣ_ㄹㅏ_ㄱㅗ_',
#   'ㅇㅓ_ㅂㅓ_ㅈㅣ_ㄲㅔ_ㅅㅓ_',
#   'ㄱㅡ_ㄹㅓ_ㅅㅣ_ㄷㅓ_ㄱㅜㄴㅇㅛ_',
#   'ㅂㅐ_ㄱㅕㅇㅇㅣ_',
#   'ㅎㅕㄴㄷㅐ_ㄹㅏ_ㅅㅓ_',
#   'ㅁㅗㄹㅇㅣㅂㅇㅣ_',
#   'ㅈㅗ_ㄱㅡㅁ',
#   'ㄷㅓㄹㄷㅚㄴㄱㅓㅅ',
#   'ㄱㅏㅌㄴㅔ_ㅇㅛ_'],
#  ['10ㄴㅕㄴㅈㅓㄴㅇㅔ_',
#   'ㄴㅓ_ㄹㅡㄹ',
#   'ㅅㅐㅇㄱㅏㄱㅎㅐ_ㅂㅘ_ㄹㅏ_',
#   'ㅈㅣ_ㄱㅡㅁ',
#   'ㅈㅜ_ㅂㅕㄴㅇㅢ_',
#   'ㅅㅏ_ㄹㅏㅁㄷㅡㄹㅇㅣ_',
#   'ㄱㅡ_ㄸㅐ_ㅇㅢ_',
#   'ㄴㅓ_ㄹㅡㄹ',
#   'ㅈㅣ_ㄱㅡㅁ',
#   'ㄴㅓ_ㄹㅏ_ㄱㅗ_',
#   'ㅅㅐㅇㄱㅏㄱㅎㅏ_ㄱㅣㄹㅂㅏ_ㄹㅏ_ㄴㅗ_'],
#  ['ㅇㅛㄱㅇㅣ_ㄴㅏ_',
#   'ㄷㅏㅁㅂㅐ_ㅍㅣ_ㄴㅡㄴㄱㅓㅅㅇㅣ_',
#   'ㄴㅏ_ㅇㅗ_ㄱㅣㄴ',
#   'ㅎㅏ_ㅈㅣ_ㅁㅏㄴ',
#   'ㅇㅕㄴㄱㅣ_ㄹㅕㄱ',
#   'ㄴㅓ_ㅁㅜ_',
#   'ㅈㅗㅎㄱㅗ_',
#   'ㅈㅐ_ㅁㅣ_ㅇㅣㅆㅇㅓㅆㅅㅡㅂㄴㅣ_ㄷㅏ_'],
#  ['ㅇㅣ_ㄸㅐ_ㄲㅏ_ㅈㅣ_',
#   'ㅂㅗㄴㅇㅕㅇㅎㅘ_ㅈㅜㅇㅇㅔ_',
#   'ㅅㅗㄴㄲㅗㅂㅎㅣ_ㄴㅡㄴ',
#   'ㅇㅕㅇㅎㅘ_ㄱㅏㅌㅇㅏ_ㅇㅛ_',
#   'ㅇㅙ_ㅇㅣ_ㅈㅔ_ㅅㅓ_ㅇㅑ_ㅂㅘㅆㅇㅡㄹㄲㅏ_ㅇㅕㅇㅎㅘ_ㄱㅘㄴㅇㅔ_ㅅㅓ_ㅂㅗㄹㄱㅓㄹ',
#   'ㅈㅣㄴㅉㅏ_ㅈㅐ_ㅁㅣㅆㄷㅏ_'],
#  ['ㅁㅣ_ㅊㅣㄴㄴㅗㅁㅇㅣ_ㄴㅗ_',
#   'ㅍㅣㄴㄹㅏㄴㄷㅡ_',
#   'ㅅㅏ_ㄹㅏㅁㅇㅣ_',
#   'ㅇㅣㄹㅂㅔ_ㄹㅡㄹ',
#   'ㅎㅏ_ㄱㅗ_',
#   'ㅇㅖ_ㅈㅓㄴㅇㅔ_',
#   'ㄹㅓ_ㅅㅣ_ㅇㅏ_',
#   'ㄱㅔ_ㅇㅣ_',
#   'ㅅㅐㅇㄱㅏㄱㄴㅏ_ㄴㅔ_'],
#  ['ㅂㅐㄱㅁㅜㄴㅇㅣ_',
#   'ㅂㅜㄹㅇㅕ_ㅇㅣㄹㄱㅕㄴㅇㅣㄴ',
#   'ㄷㅡ_ㄴㅣ_ㄹㅗ_',
#   'ㅅㅡ_ㅋㅗㄹㅅㅔ_ㅈㅣ_',
#   'ㅋㅗㅁㅂㅣ_ㅇㅢ_',
#   'ㄱㅓㄹㅈㅏㄱ',
#   'ㅈㅗ_ㅍㅔ_ㅅㅣ_'],
#  ['ㄱㅡ_ㄹㅐ_ㄷㅗ_',
#   'ㅈㅗㅎㄷㅏ_ㄱㅗ_',
#   'ㄷㅏ_ㅇㅡㅁ',
#   'ㅊㅗㅇㅅㅓㄴ',
#   'ㄷㅐ_ㅅㅓㄴ',
#   'ㅁㅣㄴㅈㅜ_ㄷㅏㅇ',
#   'ㅃㅗㅂㄱㅗ_',
#   'ㄱㅗㅇㅅㅏㄴ',
#   'ㄷㅗㄱㅈㅐ_ㅅㅏ_ㅎㅚ_ㄹㅗ_',
#   'ㅇㅘㄴㅈㅓㄴㅎㅣ_',
#   'ㄱㅓ_ㅈㅣ_',
#   'ㅂㅓ_ㄹㅣㄹ'],
#  ['ㄷㅐ_ㅂㅏㄱ',
#   'ㅈㅣㄴㅉㅏ_',
#   'ㅇㅕㅇㅎㅘ_',
#   'ㅎㅏㄴㅍㅕㄴ',
#   'ㄴㅡ_ㄲㅣㅁ',
#   'ㅇㅕㄴㄱㅣ_ㅈㅏ_ㄷㅡㄹㄷㅗ_',
#   'ㅎㅏㄴㅁㅕㅇㅎㅏㄴㅁㅕㅇ',
#   'ㄴㅓ_ㅁㅜ_',
#   'ㅅㅗ_ㅎㅘ_ㅎㅏㅁ'],
#  ['ㄱㅟ_ㅇㅕ_ㅇㅜㄴ',
#   'ㅋㅐ_ㄹㅣㄱㅌㅓ_ㄷㅡㄹㄷㅗ_',
#   'ㅁㅏㄶㅇㅣ_',
#   'ㄴㅏ_ㅇㅘ_ㅅㅓ_',
#   'ㅂㅗ_ㄹㅓ_',
#   'ㄱㅏ_ㅇㅑ_',
#   'ㄱㅔㅆㅇㅓ_ㅇㅛ_'],
#  ['ㅇㅓ_ㅉㅓㄴㅈㅣ_',
#   'ㅇㅐ_ㅅㅐ_ㄲㅣ_ㄷㅡㄹㅇㅣ_',
#   'ㄱㅏㄴㅍㅏㄴㅇㅡㄴ',
#   'ㄱㅙㄴㅊㅏㄶㅇㅡㄴㄱㅓ_',
#   'ㄱㅏㅌㅇㅡㄴㄷㅔ_',
#   'ㄷㅐ_ㄱㅏ_ㄹㅣ_ㄱㅏ_',
#   'ㅆㅣㅂㅊㅏㅇㅇㅣ_ㄷㅓ_ㄹㅏ_ㄴㅣ_'],
#  ['ㅎㅏㄴㄱㅜㄱㅋㅗㄹㅁㅏ_', 'ㅈㅔ_ㅍㅜㅁ', 'ㅅㅏ_ㅅㅓ_', 'ㅇㅣㄴㅈㅡㅇㅎㅏ_ㅁㅕㄴ', 'ㄱㅏㄹㄷㅡㅅ'],
#  ['ㄱㅜㄴㅅㅏ_ㅋㅜ_ㄷㅔ_ㅌㅏ_ㅇㅘ_',
#   'ㅎㅏㅁㄲㅔ_',
#   'ㄷㅜ_ㅌㅔ_ㄹㅡ_ㅌㅡ_',
#   'ㅁㅏㅈㄴㅑ_',
#   'ㅍㅣㄹㄹㅣ_ㅍㅣㄴ',
#   'ㄷㅐ_ㅌㅗㅇㄹㅕㅇ',
#   'ㄱㅡ_ㄹㅓㄴ',
#   'ㅅㅏ_ㄹㅏㅁ',
#   'ㄴㅏ_ㅇㅘ_ㅅㅓ_',
#   'ㅈㅘ_ㅃㅏㄹㅇㅕㄱㅈㅓㄱㅅㅐ_ㄲㅣ_ㄷㅡㄹ',
#   'ㅊㅓ_ㅎㅕㅇㅅㅣ_ㅋㅕ_ㅇㅑ_',
#   'ㄴㅏ_ㄹㅏ_ㄱㅏ_',
#   'ㅅㅏㄴㄷㅏ_'],
#  ['ㅂㅜ_ㅈㅓㅇㅎㅏ_ㄱㅗ_', 'ㅅㅣㅍㅈㅣ_ㅁㅏㄴ', 'ㅂㅏㄷㅇㅏ_ㄷㅡㄹㅇㅓ_ㅇㅑ_', 'ㅎㅏ_ㄴㅡㄴ', 'ㅇㅕㅇㅎㅘ_'],
#  ['ㅌㅗㅇㅇㅣㄹㅇㅢ_',
#   'ㅇㅣㅁㅅㅜ_ㄱㅕㅇ',
#   'ㅁㅏㄴㄷㅡㄹㄱㅗ_',
#   'ㅈㅓㄴㅎㅑㅇ',
#   'ㅎㅐㅆㄷㅏㄴ',
#   'ㅇㅓㅄㅈㅣ_',
#   'ㅇㅗ_ㄴㅡㄹ',
#   'ㅁㅏㅈㄱㅗ_ㅅㅗ_',
#   'ㄷㅡㄹㅇㅓ_ㄱㅏㅁ'],
#  ['2ㄷㅗ_', 'ㅈㅐ_ㅁㅣㅆㄱㅗ_', 'ㅁㅜ_ㅇㅓㅅㅂㅗ_ㄷㅏ_', 'ㄱㅕㄹㅁㅏㄹㅇㅣ_', 'ㅁㅏ_ㅇㅡㅁㅇㅔ_', 'ㄷㅡ_ㄴㅔ_ㅇㅛ_'],
#  ['ㄱㅣ_ㄷㅐ_ㅇㅣ_ㅅㅏㅇㅇㅡ_ㄹㅗ_',
#   'ㅎㅝㄹㅆㅣㄴ',
#   'ㅈㅐ_ㅁㅣㅆㄴㅡㄴ',
#   'ㅇㅘㄴㄱㅕㄹㅍㅕㄴ',
#   'ㅇㅕㄱㅅㅣ_',
#   'ㅎㅔ_ㄷㅓ_ㄱㅏ_',
#   'ㄴㅏ_ㅇㅘ_ㅇㅑ_',
#   'ㅈㅐㅁㄴㅏ_'],
#  ['ㄴㅣ_ㄱㅏ_', 'ㄴㅏ_ㅃㅡㄴ', 'ㅅㅐ_ㄲㅣ_ㅇㅑ_', 'ㅅㅡ_ㅌㅏ_ㅌㅡ_', 'ㄲㅡㄶㅇㅡㄴㅅㅐ_ㄲㅣ_'],
#  ['ㅌㅓㅇㅅㅡ_ㅌㅔㄴㅇㅣ_ㄴㅏ_',
#   'ㄱㅣ_ㅌㅏ_',
#   'ㄱㅘㅇㅁㅜㄹ',
#   'ㅇㅣㅆㄴㅡㄴㄱㅓㄴ',
#   'ㅅㅏ_ㅅㅣㄹㅇㅣㄴㄷㅔ_',
#   'ㅇㅒ_ㄱㅏ_',
#   'ㅁㅏㄹㅎㅏㄴㄱㅓ_ㅊㅓ_ㄹㅓㅁ',
#   'ㅎㅘㄴㄱㅕㅇ',
#   'ㅁㅜㄴㅈㅔ_',
#   'ㄸㅐ_ㅁㅜㄴㅇㅔ_',
#   'ㄱㅐ_ㅂㅏㄹ',
#   'ㅇㅏㄴㅎㅏ_ㄴㅡㄴㄱㅓㄴ',
#   'ㅇㅏ_ㄴㅣ_ㄱㅗ_',
#   'ㅅㅜ_ㅈㅣ_ㅌㅏ_ㅅㅏㄴㅇㅣ_',
#   'ㅇㅏㄴㅁㅏㅈㅇㅏ_ㅅㅓ_',
#   'ㄱㅡ_ㄹㅓㅁ'],
#  ['ㅂㅕㄴㄸㅏㅇㅋㅡ_ㄴㅡㄴ',
#   'ㅁㅝ_ㅎㅏ_ㄴㅑ_',
#   'ㅇㅏ_ㅈㅣㄱㄷㅗ_',
#   'ㅈㅗ_ㅇㅝㄴㅈㅣㄴ',
#   'ㄸㅗㅇㄲㅗ_',
#   'ㅃㅏ_ㄴㅑ_',
#   'ㄷㅐㅅㄱㅡㄹㅇㅔ_',
#   'ㅇㅣ_ㄱㅓ_ㅂㅗ_ㄱㅗ_',
#   'ㅈㅗ_ㅇㅝㄴㅈㅣㄴㅇㅡ_ㄹㅗ_',
#   'ㅈㅓㅇㅎㅐㅅㄷㅏ_',
#   'ㄷㅏㄹㅈㅣ_ㅁㅏ_ㄹㅏ_'],
#  ['ㅈㅓㅇㅁㅏㄹ', 'ㄱㅣㄴㅈㅏㅇㄱㅏㅁㅇㅣㅆㄱㅗ_', 'ㅈㅐ_ㅁㅣㅆㄷㅏ_ㅊㅚ_ㅈㅣ_ㅇㅜ_', 'ㅇㅕㄱㅅㅣ_', 'ㅁㅓㅅㅈㅣ_ㄷㅏ_'],
#  ['ㄱㅡ_ㄹㅓㅎㅈㅣ_',
#   'ㅇㅣ_ㄱㅓㅅㅇㅣ_ㅇㅑ_ㅁㅏㄹㄹㅗ_',
#   'ㅍㅓ_ㄴㅣ_ㄱㅔ_ㅇㅣㅁㅇㅣ_ㅈㅣ_ㅊㅚ_ㄱㅗ_ㅇㅢ_',
#   'ㅅㅏㄹㅇㅣㄴㅁㅏ_ㄷㅡㄹ',
#   'ㄴㅏ_ㄷㅗ_',
#   'ㄲㅣ_ㅇㅝ_ㅈㅝ_'],
#  ['ㅈㅜㄱㄱㅣ_ㅈㅓㄴㅇㅔ_',
#   'ㅂㅘ_ㅇㅑ_ㅎㅏㄹ',
#   'ㅇㅕㅇㅎㅘ_ㄹㅗ_',
#   'ㅇㅓ_ㄷㅣ_ㅅㅓㄴㄱㅏ_',
#   'ㄲㅗㅂㄱㅣㄹㄹㅐ_',
#   'ㅂㅘㅆㄷㅓㄴ',
#   'ㅇㅕㅇㅎㅘ_',
#   'ㅅㅡㄹㄹㅓㅁㄷㅗㄱ',
#   'ㅁㅣㄹㄹㅣ_ㅇㅓ_ㄴㅔ_ㅇㅓ_',
#   'ㅊㅓ_ㄹㅓㅁ',
#   'ㅂㅣㄴㅁㅣㄴㄱㅏ_ㄹㅡㄹ',
#   'ㄱㅡ_ㄹㅕ_ㄴㅐㅆㄷㅏ_',
#   'ㅊㅏ_ㅇㅣ_ㅈㅓㅁㅇㅣ_ㄹㅏ_ㅁㅕㄴ',
#   'ㅅㅡㄹㄹㅓㅁㄷㅗㄱㅇㅡㄴ',
#   'ㄱㅘ_ㅎㅏㄹ',
#   'ㅈㅓㅇㄷㅗ_ㅇㅢ_',
#   'ㄱㅡㅇㅈㅓㅇㅇㅢ_',
#   'ㅇㅕㅇㅎㅘ_ㄹㅏ_ㅁㅕㄴ',
#   'ㅇㅕㅇㅎㅘ_ㄴㅡㄴ',
#   'ㅂㅣㄴㅁㅣㄴㄱㅏ_ㅇㅢ_',
#   'ㅎㅕㄴㅅㅣㄹㅇㅡㄹ',
#   'ㅇㅏ_ㅈㅜ_',
#   'ㅈㅓㄱㅈㅓㄹㅎㅏ_ㄱㅗ_',
#   'ㅅㅏ_ㅅㅣㄹㅈㅓㄱㅇㅣ_ㄱㅔ_',
#   'ㄱㅡ_ㄹㅕ_ㄴㅐㅆㄷㅏ_'],
#  ['ㅅㅏㅇㅅㅏㅇㅇㅡㄹㅊㅗ_ㅇㅝㄹㅎㅏ_ㄴㅡㄴ',
#   'ㄷㅗㄱㅈㅐ_ㅅㅣ_ㅅㅡ_ㅌㅔㅁㅇㅡㄹ',
#   'ㅇㅘㄴㅅㅓㅇㅎㅐ_ㄴㅐㄴ',
#   'ㅁㅜㄴㅈㅜ_ㅈㅜ_ㅇㅢ_ㅈㅓㅇㅂㅜ_',
#   'ㄴㅣ_ㄷㅡㄹㅅㅔ_ㅅㅏㅇㅇㅡㄹ',
#   'ㅅㅣㄹㅋㅓㅅㅈㅡㄹㄱㅣ_ㄱㅣㄹ',
#   'ㅂㅏ_ㄹㅏㄴㄷㅏ_',
#   'ㅎㅏ_ㄴㅡㄹㄴㅗㅍㅇㅣ_',
#   'ㅅㅗㅅㅇㅏ_ㅇㅗ_ㄹㅡㄹㄸㅐ_ㄱㅏ_',
#   'ㅇㅣㅆㅇㅡ_ㅁㅕㄴ',
#   'ㅊㅜ_ㄹㅏㄱㅎㅏ_ㄴㅡㄴ',
#   'ㄸㅐ_ㄱㅏ_',
#   'ㅂㅏㄴㄷㅡ_ㅅㅣ_',
#   'ㅇㅗ_ㄴㅡㄴㅂㅓㅂ',
#   'ㄴㅣ_ㄷㅡㄹㅇㅣ_',
#   'ㅈㅣ_ㄹㅏㄹㅊㅕ_ㄷㅐㄴㄱㅓ_ㅇㅢ_',
#   'ㅁㅕㅊㅂㅐ_ㄹㅗ_',
#   'ㅊㅕ_ㅁㅏㅈㅇㅡㄹㄸㅐ_ㄱㅏ_',
#   'ㄷㅏㄱㅊㅣ_ㄹㅣ_ㄴㅣ_',
#   'ㄱㅡ_ㄸㅐㄴ',
#   'ㅂㅜ_ㅇㅓㅇㅇㅣ_ㅂㅏ_ㅇㅟ_ㅇㅔ_ㅅㅓ_',
#   'ㄸㅟ_ㅇㅓ_ㄴㅐ_ㄹㅣ_ㄴㅡㄴㅈㅓㅇㄷㅗ_ㄹㅗㄴ',
#   'ㅁㅗㅅㅁㅏㄱㅇㅡㄹㄲㅓ_ㄷㅏ_'],
#  ['2ㅇㅣㄹ',
#   'ㅈㅣ_ㄴㅏ_ㅅㅓ_',
#   'ㅁㅗㅅㅈㅜ_ㄴㅔ_',
#   'ㄱㅡㄴㄷㅔ_',
#   'ㅈㅗㅎㅇㅡㄴ',
#   'ㄱㅡㄹㅇㅡㄹ',
#   'ㅂㅏ_ㄹㅗ_',
#   'ㅁㅗㅅㅂㅘㅆㄴㅔ_',
#   'ㅇㅏㅁㅌㅡㄴ',
#   'ㅈㅗㅎㅇㅡㄴ',
#   'ㅈㅓㅇㅂㅗ_',
#   'ㄱㅏㅁㅅㅏ_'],
#  ['ㅎㅏ_ㄱㅗ_',
#   'ㅈㅓㅇㅊㅣ_',
#   'ㅅㅜ_ㄷㅗ_',
#   'ㅇㅣㅆㄴㅡㄴㄷㅔ_',
#   'ㅈㅓ_ㄸㅏ_ㅇㅟ_ㄹㅗ_',
#   'ㅇㅑㄱㅇㅡㄴ',
#   'ㅍㅏㄹㅈㅣ_',
#   'ㅁㅏㄹㅇㅏ_ㅇㅑ_ㅈㅣ_',
#   'ㅁㅣ_ㅅㅔ_ㅁㅓㄴㅈㅣ_',
#   'ㄱㅗㅇㅇㅑㄱㄷㅗ_',
#   'ㄱㅡ_ㄹㅓㅎㄱㅗ_'],
#  ['ㄷㅏㄴㅅㅜㄴㅎㅏㄴ',
#   'ㅇㅛㄱㅁㅏㅇㅇㅣ_',
#   'ㅁㅜㄴㅈㅔ_ㄱㅏ_',
#   'ㅇㅏ_ㄴㅣ_ㄷㅏ_',
#   'ㅇㅣ_ㄴㅡㄴ',
#   'ㅎㅏㄴㄱㅜㄱㅅㅏ_ㄹㅡㄹ',
#   'ㄷㅗㄹㅇㅏ_ㅂㅗㄴ',
#   'ㅇㅣ_ㄷㅔ_ㅇㅗㄹㄹㅗ_ㄱㅣ_ㅇㅔ_',
#   'ㄷㅐ_ㅎㅏㄴ',
#   'ㅁㅗ_ㅅㅜㄴㅇㅡㄹ',
#   'ㅈㅣ_ㅈㅓㄱㅎㅏ_ㄱㅗ_',
#   'ㅇㅣㅆㅇㅡ_ㅁㅕ_',
#   'ㄷㅏ_ㅇㅑㅇㅎㅏㄴ',
#   'ㅇㅗ_ㅂㅡ_ㅈㅔ_ㄹㅡㄹ',
#   'ㅌㅗㅇㅎㅐ_',
#   'ㅇㅏㅁㅅㅣ_ㅎㅏ_ㄱㅗ_',
#   'ㅇㅣㅆㄷㅏ_'],
#  ['ㅅㅣ_ㅂㅏㄹㄹㅕㄴ',
#   'ㅇㅓㄹㅁㅏ_ㅈㅓㄴㅇㅔㄴ',
#   'ㅂㅏㄱㅁㅣ_ㅅㅓㄴㅇㅣ_ㄹㅏㅇ',
#   'kbsㅇㅔ_',
#   'ㄴㅏ_ㅇㅘ_ㅅㅓ_',
#   'ㄱㅏㅁㅅㅓㅇㅍㅏㄹㅇㅣ_ㅎㅏ_ㄷㅓ_ㄴㅣ_',
#   'ㅇㅔㅁㅂㅠㅇㅅㅣㄴㅇㅔ_ㄷㅗ_',
#   'ㄴㅏ_ㅇㅘㅆㄴㅔ_'],
#  ['ㅁㅏㄹㅎㅏㄹ',
#   'ㅍㅣㄹㅇㅛ_ㄱㅏ_',
#   'ㅇㅓㅄㄴㅡㄴ',
#   'ㅁㅕㅇㅈㅏㄱㅇㅣ_ㄷㅏ_',
#   'ㅈㅓㅇㅁㅏㄹ',
#   'ㅈㅐ_ㅁㅣ_ㅇㅣㅆㄱㅔ_',
#   'ㅈㅏㄱㅍㅜㅁ'],
#  ['ㄱㅗㅇㅈㅜㅇㄱㅡㅂㅇㅠ_ㄱㅣ_',
#   'ㅅㅏ_ㅇㅓㅂㅇㅔ_ㅅㅓ_',
#   'ㅁㅣ_ㅈㅔ_',
#   'ㅅㅏ_ㅈㅝㅆㅇㅡ_ㅁㅕㄴ',
#   'ㄷㅏㅇㅇㅕㄴㅎㅏ_ㄱㅔ_',
#   'ㅎㅏㄴㄱㅜㄱㅅㅏㄴ',
#   'ㅎㅜㄴㄹㅕㄴㄱㅣ_ㄹㅡㄹ',
#   'ㅇㅣㅆㅇㅓㅆㅇㅡㄹㅌㅔㄴㄷㅔ_'],
#  ['ㅈㅐ_ㅇㅣㄴㅇㅏ_',
#   'ㅇㅣ_ㄷㅐ_ㄹㅗ_ㅁㅏㄴ',
#   'ㄱㅏ_ㅈㅏ_',
#   'ㅈㅣㄴㅉㅏ_',
#   'ㄱㅐ_ㅈㅗㅈㄱㅏㅌㅇㅡㄴ',
#   'ㅅㅔ_ㅅㅏㅇ',
#   'ㄷㅏ_ㄱㅏㅌㅇㅣ_',
#   'ㅁㅏㅇㅎㅐㅆㅇㅡ_ㅁㅕㄴ',
#   'ㅈㅗㅎㄱㅔㅆㄷㅏ_'],
#  ['ㅎㅗㅇㅇㅓ_ㄴㅏ_',
#   'ㅉㅏㅇㄱㅐ_ㄴㅏ_',
#   'ㅇㅓ_ㄷㅣㄹㄱㅏ_ㄴㅏ_',
#   'ㄷㅗ_ㅇㅜㅁ',
#   'ㅇㅏㄴㄷㅚ_ㄴㅡㄴㄱㅓㄴ',
#   'ㄸㅗㄱㄱㅏㅌㄴㅔ_'],
#  ['ㄷㅗㅇㅁㅜㄹㅇㅣ_ㄴㅏ_ㅅㅏ_ㄹㅏㅁㅇㅡㄹ',
#   'ㅈㅗ_ㄹㅓㅎㄱㅔ_ㅎㅏ_ㄱㅗ_',
#   'ㄱㅡ_ㄱㅓㄹ',
#   'ㄱㅜ_ㄱㅕㅇㅎㅏ_ㄴㅡㄴ',
#   'ㄴㅗㅁㄷㅡㄹㅇㅡㄴ',
#   'ㅅㅣㄱㅋㅏㄹㄹㅗ_',
#   'ㅇㅣㄹㄱㅏ_ㅈㅗㄱㅇㅡㄹ',
#   'ㅆㅓㄹㅇㅓ_',
#   'ㅈㅜㄱㅇㅕ_ㅇㅑ_ㅎㅏㄴㄷㅏ_'],
#  ['ㅊㅗ_ㄷㅡㅇㅎㅏㄱㄱㅛ_',
#   '2ㅎㅏㄱㄴㅕㄴㄸㅐ_',
#   'ㅈㅜ_ㅁㅏㄹㅇㅢ_ㅁㅕㅇㅎㅘ_ㅇㅔ_ㅅㅓ_',
#   'ㅂㅘㅆㅇㅓㅆㄴㅡㄴㄷㅔ_',
#   'ㅎㅏㄴㄷㅏㄹㄷㅗㅇㅇㅏㄴ',
#   'ㅇㅕ_ㅇㅜㄴㅇㅣ_',
#   'ㄴㅏㅁㄷㅓㄴ',
#   'ㅇㅕㅇㅎㅘ_',
#   'ㅋㅣㅇㅇㅘㅇㅉㅏㅇ'],
#  ['ㄴㅐ_ㅇㅛㅇㄷㅗ_ㅈㅐ_ㅁㅣㅆㄱㅗ_',
#   'ㅇㅠㄴㅇㅏ_ㅇㅓㄴㄴㅣ_',
#   'ㅇㅕㄴㄱㅣ_ㄷㅗ_',
#   'ㅊㅚ_ㄱㅗ_',
#   'mㅈㅔ_ㅈㅏㄱ',
#   'ㅇㅠㄴㅇㅏ_ㅂㅏㄹㅇㅕㄴㄱㅣ_ㄹㅏ_ㄴㅡㄴ',
#   'ㅍㅕㄴㄱㅕㄴㅂㅓ_ㄹㅣ_ㄱㅗ_',
#   'ㅂㅘ_ㅈㅜ_ㅅㅔ_ㅇㅛ_',
#   'ㄱㅣ_ㄷㅐ_ㅇㅣ_ㅅㅏㅇㅇㅣㅂㄴㅣ_ㄷㅏ_'],
#  ['tvㄷㅡ_ㄹㅏ_ㅁㅏ_',
#   'ㅈㅐ_ㅁㅣ_ㄹㅡㄹㅇㅟ_ㅎㅐ_',
#   'ㅃㅓㅇㅇㅡㄹㅈㅗㅁㅊㅜ_ㄱㅏ_ㅎㅏㄴㄱㅓㅅㅇㅣ_',
#   'ㄱㅏ_ㅈㅏㅇ',
#   'ㅇㅝㄴㅇㅣㄴ'],
#  ['ㅍㅡ_ㄹㅏㅇㅋㅔㄴㅅㅠ_ㅌㅏ_ㅇㅣㄴㅇㅣ_ㄹㅏㄴ',
#   'ㅇㅣ_ㄹㅡㅁㅇㅢ_',
#   'ㅇㅕㅇㅎㅘ_',
#   'ㄴㅓ_ㅁㅜ_ㅁㅏㄶㄷㅏ_',
#   'ㄴㅐ_ㄱㅏ_ㅂㅗㄴㄱㅓㄴ',
#   'ㅇㅣ_ㄱㅓ_ㅎㅏ_ㄴㅏ_ㅈㅣ_ㅁㅏㄴ',
#   'ㅇㅣ_ㄱㅓ_ㅎㅏ_ㄴㅏ_ㄹㅗ_',
#   'ㅁㅏㄴㅈㅗㄱㅎㅏㄹㄹㅐ_'],
#  ['ㅇㅘㄴㅈㅓㄴ',
#   'ㅈㅐ_ㅁㅣㅆㅇㅓㅆㄷㅏ_',
#   'ㅎㅏ_ㅈㅣ_ㅁㅏㄴ',
#   '9ㅈㅓㅁㅇㅡㄹ',
#   'ㅇㅣ_ㅇㅠ_ㄴㅡㄴ',
#   'ㅇㅏ_ㅋㅏ_ㄴㅔ_',
#   'ㅇㅕㅇㅇㅓ_ㅂㅏㄹㅇㅡㅁㄸㅐ_ㅁㅜㄴ'],
#  ['ㅈㅐ_ㅁㅣ_ㅇㅣㅆㄷㅓㄴㄱㅓㄹㅇㅛ_ㅇㅙ_',
#   'ㄱㅡㄱㅈㅏㅇㅇㅔ_ㅅㅓ_',
#   'ㅇㅏㄴㅎㅏ_ㄴㅡㄴㄱㅓ_ㅈㅛ_',
#   'ㅇㅕㅇㅎㅘ_',
#   'ㄱㅘㅇㅎㅐ_ㄸㅐ_ㅁㅜㄴㅇㅔ_',
#   'ㅃㅏㄹㄹㅣ_',
#   'ㄴㅐ_ㄹㅣㄴㄱㅓㄴㄱㅏ_ㅇㅛ_',
#   'ㄷㅐ_ㄱㅣ_ㅇㅓㅂㅇㅢ_',
#   'ㅎㅚㅇㅍㅗ_ㅇㅣㄴㄱㅏ_ㅇㅛ_',
#   'ㅈㅓ_ㅇㅖ_ㅅㅏㄴ',
#   'ㅇㅕㅇㅎㅘ_ㄹㅡㄹ',
#   'ㅅㅏㄹㄹㅣㅂㅅㅣ_ㄷㅏ_'],
#  ['ㅂㅜ_ㅋㅐ_ㄷㅗㅇㅇㅝㄴ',
#   '10',
#   'ㅆㅣ_ㅂㅏㄹㄴㅕㄴㅇㅏ_',
#   'ㅇㅓ_ㄷㅣ_',
#   'ㅇㅣㄴㄱㅣ_ㄱㅡㄹ',
#   'ㄴㅏㄹㄹㅗ_ㅁㅓㄱㅇㅡㄹㄹㅕ_ㄱㅗ_'],
#  ['ㅈㅓㄻㅇㅡㅁㅇㅣ_ㄹㅏㄴ', 'ㄲㅜㅁㅇㅡㄹ', 'ㅇㅣ_ㄹㅜ_ㄱㅣ_ㅇㅔ_', 'ㅊㅜㅇㅂㅜㄴㅎㅏㄴ', 'ㅅㅣ_ㄱㅏㄴ'],
#  ['ㅊㅓㅇㅇㅘ_ㄷㅐ_', 'ㅅㅜ_ㅈㅜㄴ', 'ㅅㅏㅇㅇㅣ_ㅁㅕㄴ', 'ㅈㅗㅎㅇㅡㄴㅈㅜㄹ', 'ㅇㅏ_ㄴㅏ_'],
#  ['ㄱㅡ_ㄹㅐ_ㄷㅗ_',
#   'ㄱㅜ_ㅈㅣ_ㅅㅓㅇ',
#   'ㅂㅓㅅㅇㅡㄴㅁㅗ_ㅅㅡㅂ',
#   'ㅂㅘ_ㅅㅓ_',
#   'ㄷㅗㄴㅇㅡㄴ',
#   'ㅇㅏㄴㅇㅏ_ㄲㅏ_ㅇㅝㅆㄸㅏ_'],
#  ['ㅁㅣㄴㅈㅜ_ㄷㅏㅇㅈㅓㅇㄱㅝㄴㅇㅡㄴ',
#   'ㅇㅏㄹㄱㅗ_',
#   'ㅈㅓ_ㄹㅓㄴㄱㅓ_ㄷㅏ_',
#   'ㅅㅏ_ㅎㅚ_ㅅㅣ_ㅅㅡ_ㅌㅔㅁ',
#   'ㅈㅓㅇㅈㅣ_ㅅㅣ_ㅋㅣ_ㄱㅗ_',
#   'ㅂㅜㅇㄱㅚ_ㅅㅣ_ㅋㅣ_ㄴㅡㄴㄱㅔ_',
#   'ㅁㅗㄱㅈㅓㄱㅇㅣㄴㄷㅔ_',
#   'ㅁㅏ_ㅅㅡ_ㅋㅡ_ㅇㅓㅂㅊㅔ_ㄱㅏ_',
#   'ㅊㅣ_ㄱㅘ_ㅇㅔ_',
#   'ㅅㅜㅁㅌㅗㅇ',
#   'ㅌㅡ_ㅇㅣ_ㄱㅔ_',
#   'ㅎㅐ_ㅈㅜ_ㄴㅣ_',
#   'ㅇㅏㄱㄷㅓㄱㄱㅣ_ㅇㅓㅂㅇㅡ_ㄹㅗ_',
#   'ㅇㅣ_ㅁㅣ_ㅈㅣ_',
#   'ㅆㅢ_ㅇㅝ_',
#   'ㅈㅗ_ㄹㅣ_ㄷㅗㄹㄹㅣㅁ',
#   'ㅅㅣ_ㅋㅣㄴㄱㅓ_ㅇㅣㅁ'],
#  ['ㅆㅣ_ㅂㅏㄹ',
#   'ㄸㅓㄱㅂㅏㅂ',
#   'ㅌㅓ_ㅈㅣ_ㅁㅕㄴ',
#   'ㄱㅏㄴㄱㅏㄴㅎㅣ_',
#   'ㄱㅏㅂㅅㅜ_ㅈㅘ_',
#   'ㄷㅡ_ㄹㅣㅂ',
#   'ㄴㅏ_ㅇㅗ_ㄴㅡㄴㄷㅔ_',
#   'ㅈㅓ_ㄱㅓ_ㄷㅗ_',
#   'ㅂㅘㅆㅇㅓㅆㄴㅡㄴㄷㅔ_',
#   'ㅆㅣ_ㅂㅏㄹ',
#   'ㅂㅏㅇㅅㅗㅇㅌㅏ_ㄴㅗ_',
#   'ㄱㅐㄴㅈㅓㄱㅇㅡ_ㄹㅗ_',
#   'ㄷㅡ_ㄹㅣㅂ',
#   'ㅈㅐ_ㅁㅣㅆㅇㅡㅁ'],
#  ['ㅇㅛ_ㄹㅣ_ㅍㅡ_ㄹㅗ_ㄱㅏ_',
#   'ㅈㅣ_ㄱㅕㅂㅈㅣ_ㄷㅗ_ㅇㅏㄶㄱㅗ_',
#   'ㅈㅐㅁㅇㅣㅆㅇㅓ_ㅇㅛ_',
#   'ㅈㅏㄹㅂㅗ_ㄱㅗ_ㅇㅣㅆㅅㅡㅂㄴㅣ_ㄷㅏ_',
#   'ㅎㅘ_ㅇㅣ_ㅌㅣㅇ'],
#  ['ㅉㅓ_ㄸㅜㅇㅇㅣ_',
#   'ㅅㅐ_ㄲㅣ_',
#   'ㅇㅓㄹㄱㅜㄹㅇㅔ_',
#   'ㄴㅡㅇㅇㅛㄱㅃㅔㅇㄲㅣ_ㅊㅣㄹㅎㅏ_ㄱㅗ_',
#   'ㅇㅣㄴㅈㅡㅇㅎㅏ_ㅁㅕㄴ',
#   'ㅊㅓㄴㅂㅔ_ㄴㅡㄴ',
#   'ㄱㅏㄹㄷㅡㅅ'],
#  ['ㅍㅡ_ㄹㅏㅇㅅㅡ_ㅅㅣㄱ',
#   'ㅇㅠ_ㅁㅓ_ㄱㅏ_',
#   'ㄴㅏ_ㅎㅏㄴㅌㅔ_',
#   'ㅁㅏㅈㄴㅡㄴㄷㅡㅅ',
#   'ㅈㅓㅇㅁㅏㄹ',
#   'ㅈㅐ_ㅁㅣㅆㄱㅔ_',
#   'ㅂㅘㅆㄷㅏ_',
#   'ㄲㅗ_ㅁㅏ_ㅇㅏ_ㅇㅣ_ㄷㅡㄹㄷㅗ_',
#   'ㅅㅜㄴㅅㅜ_ㅎㅏ_ㄴㅣ_',
#   'ㄱㅟ_ㅇㅕ_ㅇㅝㅆㅇㅡㅁ'],
#  ['ㄱㅏㅁㄷㅗㅇㅈㅓㄱㅇㅣ_ㅇㅖ_ㅇㅛ_ㅊㅐ_ㄴㅓㄹㄷㅗㄹㄹㅣ_ㄷㅏ_',
#   'ㅇㅜ_ㅇㅕㄴㅎㅣ_',
#   'ㅂㅘㅆㄴㅡㄴㄷㅔ_ㄴㅏ_ㄷㅗ_ㅁㅗ_ㄹㅡ_ㄱㅔ_',
#   'ㄴㅜㄴㅁㅜㄹㅇㅣ_',
#   'ㅈㅜ_ㄹㅡ_ㄹㅡㄱ',
#   'ㅈㅐ_ㅁㅣㅆㄱㅗ_',
#   'ㄱㅏㅁㄷㅗㅇㅈㅓㄱㅇㅖ_ㅇㅛ_'],
#  ['ㅅㅏ_ㅈㅣㄴㅇㅓㅄㄱㅗ_',
#   'ㅌㅡㄱㅈㅓㅇㅅㅓㅇㅅㅓㅇㄹㅣㅂㅇㅣ_ㅇㅏㄴㄷㅚ_ㅅㅓ_',
#   'ㅁㅜ_ㅈㅚ_ㅇㅏ_ㄴㅣㅁ',
#   'ㅈㅓ_ㅇㅣ_ㄹㅡㅁㄱㅏ_ㅈㅣㄴㅅㅏ_ㄹㅏㅁㅇㅣ_',
#   'ㅎㅏㄴㄷㅜㄹㅇㅣ_ㅇㅏ_ㄴㅣㄴㄷㅔ_',
#   'ㄸㅏ_ㄹㅡㄴㅅㅏ_ㄹㅏㅁㅇㅣ_ㄹㅏ_ㄱㅗ_ㅎㅏ_ㅁㅕㄴ',
#   'ㅁㅜ_ㅈㅚ_ㄷㅚ_ㄴㅡㄴㄱㅓ_ㅇㅏ_ㄴㅣㅁ'],
#  ['ㅊㅜ_ㅇㅓㄱㅇㅡㄴ',
#   'ㅂㅏㅇㅇㅜㄹㅂㅏㅇㅇㅜㄹ',
#   'ㅊㅜ_ㅇㅓㄱㅇㅡㄹ',
#   'ㅁㅓㄱㄱㅗ_',
#   'ㅅㅏ_ㄴㅡㄴ',
#   'ㄴㅏ_ㅇㅣ_ㄱㅏ_',
#   'ㄷㅚ_ㄴㅣ_',
#   'ㅇㅕㅇㅎㅘ_ㄱㅏ_',
#   'ㄴㅜㄴㅁㅜㄹㄴㅏ_ㄷㅗ_ㄹㅗㄱ',
#   'ㄱㅗ_ㅁㅏㅂㄷㅏ_'],
#  ['ㅇㅕㅇㅎㅘ_ㄹㅏ_ㅅㅓ_',
#   'ㅂㅗ_ㅇㅕㅆㄷㅓㄴ',
#   'ㅇㅕㄴㅊㅜㄹㅇㅣ_',
#   'ㅇㅕㅇㅎㅘ_ㅇㅢ_',
#   'ㄱㅏㅁㅈㅓㅇㅇㅡㄹ',
#   'ㅍㅛ_ㅎㅕㄴㅎㅐㅆㄷㅏ_',
#   'ㄷㅔ_ㅂㅟ_ㅈㅏㄱㅇㅣ_',
#   'ㅅㅓㅁㄸㅡㄱㅎㅏ_ㄷㅏ_'],
#  ['2008ㄴㅕㄴ',
#   'ㅇㅣ_ㅎㅜ_ㅇㅢ_',
#   'ㄱㅓ_ㅇㅢ_',
#   'ㅁㅗ_ㄷㅡㄴ',
#   'ㄱㅗㅇㅍㅗ_ㅇㅕㅇㅎㅘ_ㄹㅡㄹ',
#   'ㅈㅓㅂㄴㅣ_ㄷㅏ_',
#   'ㅇㅣ_ㄱㅓㄴ',
#   'ㅅㅜ_ㅈㅏㄱ'],
#  ['ㅇㅓ_ㄹㅣㄴ', 'ㄴㅏ_ㅇㅣ_ㅇㅔ_', 'ㄷㅏㄺㅁㅗㄱㅈㅏ_ㄹㅡ_ㄴㅡㄴ', 'ㅂㅜ_ㅂㅜㄴㅇㅣ_', 'ㅊㅜㅇㄱㅕㄱㅇㅣ_ㅇㅓㅆㄷㅏ_'],
#  ['ㄹㅠ_ㅈㅜㄴㅇㅕㄹ',
#   'ㅇㅏㄱㅁㅠ_',
#   'ㅇㅣ_ㅊㅏㄴㅎㅕㄱ',
#   'ㄷㅏㄻㅇㅡㄴㄴㅕㄴㄷㅡㄹ',
#   'ㅇㅛ_ㅈㅡㅁ',
#   'ㄱㅣㄹㄱㅓ_ㄹㅣ_ㅇㅔ_',
#   'ㄱㅐ_ㅁㅏㄶㅇㅣ_',
#   'ㄷㅗㄹㅇㅏ_ㄷㅏ_ㄴㅣ_ㄷㅓ_ㄹㅏ_'],
#  ['ㅇㅣ_ㄹㅓㄴ',
#   'ㄷㅏㅁㄷㅏㅁㅎㅏㄴ',
#   'ㅁㅣ_ㄱㅜㄱ',
#   'ㅋㅗ_ㅁㅔ_ㄷㅣ_ㅇㅕㅇㅎㅘ_ㅈㅗㅎㄷㅏ_ㅅㅡ_ㅋㅔ_ㅇㅣㄹㄷㅗ_',
#   'ㄱㅙㄴㅊㅏㄶㄱㅗ_',
#   'ㅇㅕㅇㅎㅘ_ㄱㅏ_',
#   'ㅎㅏㄴㄱㅜㄱㅇㅕㅇㅎㅘ_ㅂㅗ_ㄷㅏ_',
#   'ㅍㅕㅇㅈㅓㅁㅇㅣ_',
#   'ㄴㅏㅈㅇㅡㅁ',
#   'ㅇㅣ_ㅎㅐ_ㅂㅜㄹㄱㅏ_'],
#  ['ㅈㅗㅎㄱㅔㅆㄷㅏ_',
#   'ㅆㅣ_ㅂㅏㄹ',
#   'ㅇㅑ_ㄱㅐㄹㅍㅓㅁㅇㅣ_',
#   '1ㅊㅓㄴㅂㅔ_',
#   'ㅈㅗㅁㅂㅣ_ㅅㅏ_ㅇㅣ_ㅌㅡ_',
#   'ㄷㅏㅂㄴㅔ_'],
#  ['ㅇㅓ_ㄷㅜㅂㄱㅗ_',
#   'ㅈㅏㄴㅎㅗㄱㅎㅏㄴㅇㅣ_ㅇㅑ_ㄱㅣ_',
#   'ㅅㅡ_ㅌㅗ_ㄹㅣ_',
#   'ㅈㅣㄴㅎㅐㅇㅇㅣ_',
#   'ㅃㅏ_ㄹㅡ_ㄱㅗ_',
#   'ㅇㅕㅇㅅㅏㅇㅇㅡㄴ',
#   'ㅎㅗ_ㅋㅙ_ㅎㅏㅁ',
#   'ㅇㅣㄴㄱㅏㄴㅁㅣ_ㅇㅘ_',
#   'ㅊㅓㄹㅎㅏㄱㅇㅣ_',
#   'ㅇㅣㅆㅇㅡㅁ'],
#  ['ㅇㅕㄴㄱㅣ_ㅈㅏ_ㄷㅡㄹㅇㅢ_',
#   'ㅇㅕㄴㄱㅣ_ㄱㅏ_',
#   'ㄸㅟ_ㅇㅓㅆㄴㅏㅆㄱㅗ_ㅅㅡ_ㅌㅗ_ㄹㅣ_ㄱㅏ_',
#   'ㄷㅏㄴㅁㅏㄱㄱㅡㄱㅊㅓ_ㄹㅓㅁㅂㅗ_ㅇㅣ_ㅁㅕㄴㅅㅓ_',
#   'ㅇㅕㄴㄱㅘㄴㅅㅓㅇㅇㅣ_',
#   'ㅇㅣㅆㅇㅓ_',
#   'ㅈㅐ_ㅁㅣ_ㄴㅏㅆㅇㅡㅁ'],
#  ['ㄱㅏㅇㅎㅏㄴ',
#   'ㅈㅜㅇㅅㅗ_ㄱㅣ_ㅇㅓㅂㅇㅡㄴ',
#   'ㄸㅏ_ㄹㅗ_',
#   'ㅁㅏㄴㄷㅡㄹㅁㅕㄴ',
#   'ㄷㅚ_ㅈㅣ_',
#   'ㅅㅏㅁㅅㅓㅇㅇㅡㄹ',
#   'ㅉㅗ_ㄱㅐ_ㅇㅑ_ㄴㅡㄴㄷㅔ_',
#   'ㅈㅜㅇㅅㅗ_ㄱㅣ_ㅇㅓㅂㄷㅡㄹㅇㅣ_',
#   'ㅅㅏㅁㅅㅓㅇㅊㅓ_ㄹㅓㅁ',
#   'ㅇㅐ_ㅍㅡㄹㅇㅣ_ㄹㅏㅇ',
#   'ㄱㅕㅇㅈㅐㅇ',
#   'ㅇㅣㅆㅇㅡㄹㄱㅓ_ㄹㅏ_'],
#  ['ㅁㅜㄴㅈㅐ_ㅇㅏㅇ',
#   'ㅈㅓ_ㅅㅐㄱㄱㅣ_',
#   'ㅊㅜㄹㅅㅐㅇ',
#   'ㅈㅗ_ㅅㅏ_',
#   'ㄷㅏ_ㅅㅣ_ㅎㅐ_ㅂㅘ_ㅇㅑ_ㅎㅏㄴㄷㅏ_',
#   'ㅇㅣ_ㅅㅐㄱㄱㅣ_',
#   'ㄱㅏㄴㅊㅓㅂㅈㅚ_ㄹㅗ_',
#   'ㅊㅔ_ㅍㅗ_ㅎㅏ_ㄱㅗ_ㄴㅏ_ㅁㅕㄴ',
#   'ㅈㅏ_ㅅㅏㄹㅁㅗㅅㅎㅏ_ㄱㅔ_',
#   'ㄲㅗㅇㄲㅗㅇ',
#   'ㅁㅜㄲㅇㅓ_ㄹㅏ_',
#   'ㅎㅕ_ㄷㅗ_',
#   'ㅁㅗㅅㄲㅐ_ㅁㅜㄹㄹㅔ_',
#   'ㅈㅐ_ㄱㅏㄹㅁㅜㄹㄹㅣ_ㄱㅗ_'],
#  ['ㅇㅜ_ㅊㅔ_ㄱㅜㄱㅇㅡㄴ',
#   'ㅌㅐㄱㅂㅐ_ㄱㅣ_ㅅㅏ_ㅈㅗㅁ',
#   'ㄷㅓ_ㅃㅗㅂㄱㅗ_',
#   'ㅈㅣ_ㅇㅝㄴㅈㅗㅁ',
#   'ㄷㅓ_ㅎㅐ_ㅈㅝ_ㄷㅗ_ㄷㅚㅁ',
#   'ㄷㅏ_ㄹㅡㄴㄷㅔ_ㄹㅡㄹ',
#   'ㅈㅜㄹㅇㅣ_ㄱㅗ_'],
#  ['ㄱㅡ_ㅇㅘ_ㅈㅜㅇㅇㅔ_',
#   'ㅇㅕ_ㅈㅏ_ㄹㅗ_',
#   'ㅂㅗ_ㄴㅡㄴㄱㅓ_',
#   'ㄱㅏㅌㅇㅏ_ㄴㅡㄴ',
#   'ㅁㅝ_ㄴㅑ_',
#   'ㅈㅓㅇㅅㅣㄴㅇㅣ_',
#   'ㅇㅣ_ㅅㅏㅇㅎㅏㄴㄷㅡㅅ'],
#  ['ㄴㅐ_ㄱㅏ_',
#   'ㅇㅏㄹㄱㅣ_ㄹㅗ_',
#   'ㄷㅐ_ㅈㅜㅇㅇㅣ_ㄴㅡㄴ',
#   'ㄱㅗ_ㅅㅗㄱㄷㅗ_ㄹㅗ_ㄹㅡㄹ',
#   'ㅂㅏㄴㄷㅐ_ㅎㅏㄴㄱㅔ_',
#   'ㅇㅏ_ㄴㅣ_ㄹㅏ_',
#   'ㄸㅜㅀㄴㅡㄴ',
#   'ㅂㅏㅇㅎㅑㅇㅇㅡㄹ',
#   'ㅂㅏㄴㄷㅐ_ㅎㅏㄴㄱㅓ_',
#   'ㅇㅏ_ㄴㅕ_'],
#  ['ㄷㅏ_ㄷㅡㄹ',
#   'ㅇㅏ_ㅇㅣ_ㄷㅡㄹ',
#   'ㅂㅗ_ㄴㅡ_ㄹㅏ_',
#   'ㄱㅗ_ㅅㅐㅇㅎㅏ_ㅅㅣ_ㄴㅔ_ㅇㅛ_',
#   'ㅇㅏ_ㄱㅣ_ㄷㅡㄹㄷㅗ_',
#   'ㄴㅓ_ㅁㅜ_',
#   'ㄱㅟ_ㅇㅕㅂㄱㅗ_',
#   'ㅂㅗ_ㄱㅗ_',
#   'ㅇㅣㅆㅇㅓ_ㅇㅛ_'],
#  ['ㅇㅣ_ㄹㅓㄴ', 'ㄲㅜㄹㅈㅐㅁㅇㅕㅇㅎㅘ_ㄴㅡㄴ', 'ㅁㅏㄶㅇㅡㄴ', 'ㅅㅏ_ㄹㅏㅁㄷㅡㄹㅇㅣ_', 'ㅂㅘ_ㅇㅑ_ㅎㅏㄴㄷㅏ_'],
#  ['ㅇㅣㄹㅂㅗㄴㅇㅕㅇㅎㅘ_',
#   'ㅅㅜ_ㅇㅣㅂ',
#   'ㄱㅡㅁㅈㅣ_',
#   'ㅅㅣ_ㅈㅓㄹㅇㅔ_ㄷㅗ_',
#   'ㅂㅣ_ㄷㅣ_ㅇㅗ_',
#   'ㅌㅔ_ㅇㅣ_ㅍㅡ_ㄹㅗ_',
#   'ㄷㅗㄹㄹㅕ_ㅂㅘㅆㄷㅓㄴ',
#   'ㅂㅜㄹㅎㅜ_ㅇㅢ_',
#   'ㅁㅕㅇㅈㅏㄱ',
#   'ㄱㅡ_ㄹㅣㅂㄷㅏ_'],
#  ['ㄷㅐ_ㅎㅏㄴㅁㅣㄴㄱㅜㄱ',
#   'ㄱㅜㄱㅁㅣㄴ',
#   'ㄱㅐ_ㄴㅏ_ㅅㅗ_ㄴㅏ_',
#   '70',
#   'ㄷㅐ_ㅎㅏㄱ',
#   'ㅈㅣㄴㅎㅏㄱㅎㅏ_ㄴㅡㄴㄷㅔ_',
#   'ㅈㅒ_ㄴㅡㄴ',
#   'ㄱㅗ_ㄷㅡㅇㅎㅏㄱㄱㅛ_ㄷㅗ_',
#   'ㅁㅗㅅㄴㅏ_ㅇㅗㄴ',
#   'ㅈㅜㅇㅈㅗㄹ',
#   'ㅇㅣ_ㅈㅏㄶㅇㅏ_',
#   'ㅇㅣ_ㅎㅐ_ㅎㅏ_ㅈㅏ_',
#   'ㅈㅜㅇㅈㅗㄹㅇㅣ_ㄴㅣ_ㄲㅏㄴ'],
#  ['ㄴㅐ_ㅇㅛㅇ',
#   'ㄸㅏ_ㄸㅡㅅㅎㅏㄴㅇㅕㅇㅎㅘ_',
#   'ㄴㅏ_ㄴㅜ_ㄱㅗ_',
#   'ㅂㅔ_ㅍㅜ_ㄴㅡㄴㅈㅏㄱㅍㅜㅁㄷㅡㄹㅇㅣ_',
#   'ㅁㅏㄶㅇㅣ_',
#   'ㅁㅏㄴㄷㅡㄹㅇㅓ_ㅈㅣ_ㄱㅣ_ㄹㅡㄹㅎㅢ_ㅁㅏㅇㅎㅏㅂㄴㅣ_ㄷㅏ_'],
#  ['ㅆㅣ_ㅂㅏㄹ',
#   'ㅁㅏㄹㅌㅜ_ㅂㅗ_ㅁㅕㄴ',
#   'ㄱㅡ_ㄴㅑㅇ',
#   'ㅈㅓㄴㅎㅕㅇㅈㅓㄱㅇㅣㄴ',
#   'ㅎㅏㄴㄱㅜㄱㄴㅕㄴㅇㅣ_ㄴㅔ_',
#   'ㅂㅐㄱㅅㅓㄹㄱㅣ_ㅅㅐ_ㄲㅣ_ㄴㅡㄴ',
#   'ㅇㅣㄴㅈㅡㅇㅇㅏㄴㅎㅏ_ㄴㅑ_',
#   'ㄱㅡ_ㄹㅣ_ㄱㅗ_',
#   'ㄷㅗㄱㅇㅣㄹㅅㅏ_ㄹㅏㅁㅇㅣ_ㅁㅕㄴ',
#   'ㄷㅗㄱㅇㅣㄹㅋㅏ_ㅍㅔ_ㅎㅐ_ㅇㅑ_ㅎㅏㄴㄷㅏ_ㄴㅡㄴㄱㅓㄴ',
#   'ㅁㅜ_ㅅㅡㄴ',
#   'ㄴㅗㄴㄹㅣ_ㅇㅣㅁ',
#   'ㅁㅏㅁㅇㅔ_ㅇㅏㄴㄷㅡ_ㄴㅣ_',
#   'ㄱㅙㄴㅎㅣ_',
#   'ㅌㅡ_ㅈㅣㅂㅈㅏㅂㄴㅗ_'],
#  ['ㅈㅣㄱㅈㅏㅇㅇㅓㅄㅇㅣ_',
#   'ㅅㅏ_ㅈㅏㅇㄷㅗ_',
#   'ㅇㅏ_ㄴㅣ_ㄱㅗ_',
#   'ㅂㅐㄱㅅㅜ_ㄱㅏ_',
#   'ㅈㅓ_ㄹㅓ_ㅁㅕㄴ',
#   'ㅇㅏㄴㄷㅚ_ㄴㅣ_ㄲㅏㄴ'],
#  ['ㄱㅗ_ㅌㅗㅇㅂㅏㄷㄴㅡㄴ',
#   'ㄱㅡ_ㄴㅕ_ㅇㅔ_ㄱㅔㄴ',
#   'ㅁㅣ_ㅇㅏㄴㅎㅏㄴ',
#   'ㅇㅒ_ㄱㅣ_ㅈㅣ_ㅁㅏㄴ',
#   'ㅇㅕㅇㅎㅘ_ㄱㅏ_',
#   'ㄲㅡㅌㄴㅏ_ㅈㅣ_',
#   'ㅇㅏㄶㄱㅣㄹ',
#   'ㅂㅏ_ㄹㅐㅆㄷㅏ_'],
#  ['ㅇㅣ_ㅇㅕㅇㅎㅘ_',
#   'ㅂㅐ_ㄱㅕㅇㅇㅣ_',
#   'ㄴㅐ_ㄱㅗ_ㅎㅑㅇ',
#   'ㅁㅗㄱㅍㅗ_ㄱㅗ_',
#   'ㅇㅣ_ㅇㅕㅇㅎㅘ_',
#   'ㄱㅐ_ㅂㅗㅇㅅㅣ_ㅇㅔ_',
#   'ㅈㅜㅇㅇㅏㅇㄱㅜㄱㅁㅣㄴㅎㅏㄱㄱㅛ_',
#   '2ㅎㅏㄱㄴㅕㄴㅇㅣ_ㅇㅓㅆㄴㅐ_ㅇㅛ_',
#   'ㄱㅡ_ㄸㅐ_',
#   'ㅅㅣ_ㅈㅓㄹㅇㅡㄹ',
#   'ㅇㅕㅇㅎㅘ_ㄹㅗ_',
#   'ㄴㅏ_ㅁㅏ_',
#   'ㅂㅗ_ㄴㅣ_',
#   'ㅈㅓ_ㅇㅕㅇㅎㅘ_',
#   'ㅊㅘㄹㅇㅕㅇㄸㅐ_',
#   '2ㅎㅏㄱㄴㅕㄴㅇㅣ_ㅇㅓㅆㄷㅓㄴ',
#   'ㄴㅐ_ㄱㅏ_',
#   'ㄱㅡ_ㄹㅕ_ㅈㅣ_ㄱㅗ_',
#   'ㄱㅡ_ㄸㅐ_',
#   'ㄱㅡ_ㅅㅣ_ㅈㅓㄹ',
#   'ㅈㅏㄱㅇㅏㅆㄷㅓㄴ',
#   'ㅁㅗㄱㅍㅗ_ㅇㅕㄱㄷㅗ_',
#   'ㅂㅗ_ㅇㅣ_ㄱㅗ_',
#   'ㄴㅜㄴㅁㅜㄹㅇㅣ_',
#   'ㄴㅏ_ㄴㅐ_ㅇㅛ_'],
#  ['ㄱㅣ_ㄷㅐ_ㅇㅏㄴㅎㅏ_ㄱㅗ_',
#   'ㅂㅘㅆㄴㅡㄴㄷㅔ_',
#   'ㄱㅣ_ㄷㅐ_ㅇㅣ_ㅅㅏㅇㅇㅣ_ㅇㅓㅆㅇㅓ_ㅇㅛ_',
#   'ㅇㅗ_ㄹㅐㄴㅁㅏㄴㅇㅔ_',
#   'ㅇㅕㅇㅎㅘ_',
#   'ㅁㅗㄹㅇㅣㅂㅎㅐ_ㅅㅓ_',
#   'ㅂㅘㅆㄴㅔ_ㅇㅛ_'],
#  ['ㅈㅜㄹㄱㅓ_ㄹㅣ_ㄱㅏ_',
#   'ㄴㅏ_ㅈㅜㅇㅇㅔ_ㅎㅡ_ㅈㅣ_ㅂㅜ_ㅈㅣ_ㄷㅚ_ㅈㅣ_ㅁㅏㄴ',
#   'ㅇㅣ_ㅈㅜㄴㄱㅣ_ㅇㅕㄴㄱㅣ_ㄹㅕㄱㅇㅡㄴ',
#   'ㅇㅣㄴㅈㅓㅇ',
#   'ㅊㅚ_ㄱㅗ_ㄷㅏ_'],
#  ['ㅈㅗㅎㅇㅏ_ㅅㅓ_',
#   'ㅎㅏ_ㄴㅡㄴ',
#   'ㅂㅐㄴㄷㅡ_ㄱㅏ_',
#   'ㅈㅗㅎㅇㅏ_ㅅㅓ_',
#   'ㅂㅘㅆㄴㅡㄴㄷㅔ_ㅇㅛ_',
#   'ㅈㅗㅎㅇㅏ_ㅅㅓ_',
#   'ㅁㅏㄴㄷㅡㄴ',
#   'ㅇㅕㅇㅎㅘ_ㄷㅗ_',
#   'ㅈㅓㅇㅁㅏㄹ',
#   'ㅈㅗㅎㅇㅏ_ㅇㅛ_'],
#  ['ㄷㅏ_ㅇㅡㅁ',
#   'ㄷㅐ_ㅅㅓㄴ',
#   'ㅇㅣ_ㄴㅏㄱㅇㅕㄴ',
#   'ㄱㅏㅌㅇㅡ_ㄴㅣ_ㄲㅏ_',
#   'ㄲㅏ_ㅈㅣ_',
#   'ㅇㅏ_ㅇㅖ_',
#   'ㅈㅘ_ㅍㅏ_ㄴㅗ_ㅅㅓㄴㅇㅡ_ㄹㅗ_',
#   'ㄱㅏㄹㅇㅏ_ㅌㅏㅆㄴㅏ_ㅂㅗ_ㄴㅔ_',
#   'ㅇㅣ_ㅈㅔ_',
#   'ㅇㅓㅄㄷㅏ_',
#   'ㄴㅠ_ㅅㅡ_'],
#  ['ㄱㅜ_ㅎㅏ_ㄱㅣ_',
#   'ㅇㅣㄹㅅㅏㅇㅇㅣㄴ',
#   'ㅊㅓㅇㅇㅘ_ㄷㅐ_',
#   'ㅍㅔ_ㅇㅣ_ㅈㅣ_',
#   'ㅊㅓㅇㅇㅘ_ㄷㅐ_',
#   'ㄷㅐ_ㅂㅕㄴㅅㅣㄹ'],
#  ['ㅂㅗㄴㅈㅜㄱㄷㅗ_', 'ㅅㅏ_ㅁㅓㄱㅇㅡㄹㅈㅓㅇㄷㅗ_ㄹㅗ_', 'ㄷㅗㄴㅇㅓㅄㄴㅡㄴ', 'ㅅㅏ_ㄹㅏㅁㅇㅣ_', 'ㅇㅣㅆㄴㅑ_'],
#  ['ㅍㅗㄱㄹㅕㄱㅇㅢ_',
#   'ㄱㅓ_ㅈㅏㅇㅇㅣ_',
#   'ㅁㅏㄴㄷㅡㄹㅇㅓ_ㄴㅐㄴ',
#   'ㄱㅓㄹㅈㅏㄱ',
#   'ㅅㅡ_ㄹㅣㄹㄹㅓ_ㅁㅜㄹ',
#   'ㅎㅜ_ㅂㅏㄴㅂㅜ_',
#   '30ㅂㅜㄴㅇㅣ_',
#   'ㅇㅏㅂㄱㅝㄴ'],
#  ['ㄴㅏ_ㄷㅗ_',
#   'ㅇㅕ_ㄹㅡㅁㅎㅕㅇㄱㅣ_ㄸㅐ_',
#   'ㅊㅓ_ㅇㅡㅁㅂㅗ_ㄱㅗ_',
#   'ㅇㅏ_ㅈㅣㄱㄲㅏ_ㅈㅣ_ㄷㅗ_',
#   'ㅇㅣㅈㅎㅕ_ㅈㅣ_ㅈㅣ_ㄱㅏ_ㅇㅏㄶㅇㅡㅁ'],
#  ['ㅈㅐ_ㅇㅏㅇㅇㅣ_',
#   'ㅉㅏ_ㅍㅏ_ㄱㅜ_ㄹㅣ_',
#   'ㅋㅗ_ㄹㅗ_ㄴㅏ_ㅇㅗ_ㄱㅐ_ㅅㅐㅇㄱㅣㅅㄴㅐ_',
#   'ㄷㅙ_ㅈㅣ_ㄴㅕㄴ',
#   'ㅁㅕㄱㄸㅏ_ㄷㅏㄹㄹㅏ_ㄱㅗ_',
#   'ㅁㅗㄱㅅㅏㅁㄱㅕㅂㅊㅕ_ㄷㅡ_ㄴㅡㄴㄱㅓㅅㅈㅗㅁㅂㅗ_ㅅㅗ_'],
#  ['ㅂㅏㄱㅈㅣ_ㅅㅓㅇ', 'ㅈㅓ_ㄹㅓㄴ', 'ㅅㅐ_ㄲㅣ_ㄹㅏㅇ', 'ㅇㅓ_ㅇㅗㄹㄹㅣ_ㄴㅡㄴ', 'ㄲㅗ_ㄹㅏ_ㅈㅣ_'],
#  ['ㅂㅗ_ㄴㅡㄴ',
#   'ㄴㅐ_ㄴㅐ_',
#   'ㄱㅏ_ㅅㅡㅁㅇㅔ_',
#   'ㅇㅡㅇㅇㅓ_ㄹㅣ_ㄱㅏ_',
#   'ㅇㅣㅆㄴㅡㄴㄱㅓㅅ',
#   'ㄱㅏㅌㅇㅏㅆㄱㅗ_',
#   'ㄷㅏㅂㄷㅏㅂㅎㅏ_ㅁㅕㄴㅅㅓ_ㄷㅗ_ㅁㅗ_ㄷㅡㄴㄱㅓㄹ',
#   'ㅇㅣ_ㄹㅜㄹㅅㅜ_',
#   'ㅇㅓㅄㄴㅡㄴ',
#   'ㅇㅜ_ㄹㅣ_',
#   'ㅇㅣㄴㅅㅐㅇㄱㅏㅌㄱㅣ_ㄷㅗ_',
#   'ㅎㅐㅆㅈㅣ_ㅁㅏㄴㅈㅜㄱㅇㅡㅁㄷㅟ_ㅇㅔ_',
#   'ㄷㅏ_ㄹㅡㄴ',
#   'ㅇㅣㄴㅅㅐㅇㅇㅣ_',
#   'ㄱㅣ_ㄷㅏ_ㄹㅣ_ㄱㅗ_',
#   'ㅇㅣㅆㅇㅡㄹㄱㅓㅅㅁㅏㄴ',
#   'ㄱㅏㅌㅇㅏㅆㄷㅏ_'],
#  ['ㅊㅚ_ㄱㅗ_ㅇㅢ_',
#   'ㄷㅡ_ㄹㅏ_ㅁㅏ_ㄹㅡㄹ',
#   'ㅈㅜㄱㅇㅕㅆㄷㅏ_',
#   'ㄷㅐ_ㅅㅏㅇㅇㅡㄹ',
#   'ㅃㅐ_ㅇㅏㅆㄱㅣㄴ',
#   'ㅇㅏㄴㅈㅐ_ㅇㅜㄱㄱㅘ_',
#   'ㅈㅔ_ㅈㅏㄱㅈㅣㄴㅇㅣ_',
#   'ㅂㅜㄹㅆㅏㅇㅎㅏㄹㄸㅏ_ㄹㅡㅁ',
#   'ㄱㅐ_ㅅㅐ_'],
#  ['ㅁㅜ_ㅅㅡㄴ',
#   'ㅆㅣ_ㅂㅏㄹ',
#   'ㅇㅛㅇㄱㅘㅇㄹㅗ_ㄴㅏ_',
#   'ㄱㅡㄱㅈㅣ_ㅂㅏㅇ',
#   'ㅇㅓㄹㅇㅡㅁㅇㅔ_',
#   'ㅃㅏ_ㄸㅡ_ㄹㅣ_ㅁㅕㄴ',
#   'ㅇㅓ_ㅊㅏ_ㅍㅣ_',
#   'ㅁㅗㅅㅊㅏㅈㄴㅡㄴㄱㅓㄹ',
#   'ㅈㅓ_ㅈㅣ_ㄹㅏㄹ',
#   'ㄲㅏ_ㅈㅣ_',
#   'ㅌㅔ_ㅅㅡ_ㅌㅡ_',
#   'ㅎㅐ_ㅇㅑ_ㅎㅏ_ㄴㅑ_'],
#  ['ㅍㅕㅇㅅㅣㄱㅇㅣ_', 'ㅎㅕㅇㅇㅣ_', '6ㅈㅓㅁㅈㅜㄴㄱㅓ_ㅁㅕㄴ', 'ㄴㅏ_ㄹㅡㅁ', 'ㅎㅜ_ㅎㅏ_ㄱㅔ_ㅈㅜㄴㄱㅓ_ㅇㅔ_ㅇㅛ_'],
#  ['ㅅㅔ_ㅇㅝㄹㅎㅗ_ㄸㅐ_', 'ㅃㅏㄹㅇㅏㅆㅈㅏㄶㅇㅏ_', 'ㄴㅣ_ㄴㅔ_', 'ㅇㅣ_ㅈㅔ_', 'ㅇㅕㄱㅍㅜㅇㅅㅣ_ㅈㅡㄴ'],
#  ['ㄱㅏㅁㄷㅗㄱㅇㅡㄴ', 'ㅂㅜㄴㅇㅟ_ㄱㅣ_ㄴㅡㄴ', 'ㅁㅜ_ㄱㅓ_ㅇㅜㄴㄷㅔ_', 'ㅎㅏㅇㅅㅏㅇ', 'ㅎㅐ_ㅍㅣ_ㅇㅔㄴㄷㅣㅇㅇㅣ_ㄴㅔ_'],
#  ['ㅁㅓㅅㅈㅣㄴ', 'ㅂㅐ_ㅇㅜ_', 'ㅈㅗ_ㅈㅣ_', 'ㅋㅡㄹㄹㅜ_ㄴㅣ_ㅇㅢ_', 'ㅅㅣㄱㄱㅕㄴㅇㅔ_', '10ㅈㅓㅁㄷㅡ_ㄹㅣㅁ'],
#  ['ㅇㅣ_ㄱㅓ_',
#   'ㅎㅗㄱㅅㅣ_',
#   'ㅅㅣ_ㄹㅣ_ㅈㅡ_',
#   'ㅇㅏ_ㄴㅣ_ㄴㅑ_',
#   'ㅁㅕㅊㄱㅐ_ㅇㅢ_',
#   'ㅅㅣ_ㄹㅣ_ㅈㅡ_ㄹㅗ_',
#   'ㄷㅚ_ㅇㅓ_',
#   'ㅇㅣㅆㄴㅏ_',
#   'ㄱㅐ_ㄷㅏㅇ',
#   'ㄷㅏㄴㄱㅏ_ㄱㅏ_',
#   '2ㅁㅏㄴㄴㅑㅇㅇㅣ_ㄴㅑ_',
#   'ㅇㅏ_ㄴㅣ_ㅁㅕㄴ',
#   'ㅅㅣ_ㄹㅣ_ㅈㅡ_',
#   'ㅈㅓㄴㅊㅔ_ㄱㅏ_',
#   '2ㅁㅏㄴㅇㅣ_ㄴㅑ_'],
#  ['ㄱㅣㅁㅅㅡㄹㄱㅣ_ㅊㅓㅁㅂㅗ_ㄴㅡㄴ',
#   'ㅂㅐ_ㅇㅜ_ㅇㅣㄴㄷㅔ_',
#   'ㅁㅐ_ㄹㅕㄱㅇㅣㅆㅇㅓ_ㅇㅛ_ㅅㅏㄴㄲㅗㄱㄷㅐ_ㄱㅣ_ㅇㅔ_',
#   'ㅊㅏㅈㅇㅏ_ㅇㅘ_',
#   'ㅅㅗ_ㄹㅣ_ㅈㅣ_ㄹㅡ_ㄴㅡㄴ',
#   'ㅇㅗ_ㅈㅓㅇㅅㅔ_ㄹㅡㄹ',
#   'ㅃㅏㄴㅎㅣ_',
#   'ㅂㅏ_ㄹㅏ_ㅂㅗ_ㅁㅕ_',
#   'ㅁㅣ_ㅅㅗ_ㄸㅣㄴ',
#   'ㅍㅛ_ㅈㅓㅇ'],
#  ['ㅁㅗㄹㅇㅣㅂㄱㅏㅁ',
#   'ㅈㅓㅇㅁㅏㄹ',
#   'ㅊㅚ_ㄱㅗ_ㅇㅔ_ㅇㅛ_',
#   '10ㄴㅕㄴㄷㅜ_',
#   'ㄷㅓ_ㄷㅚㄴㅇㅕㅇㅎㅘ_ㅇㅣㄴㄷㅔ_ㄷㅜ_',
#   'ㅂㅗ_ㄴㅡㄴ',
#   'ㄴㅐ_ㄴㅐ_',
#   'ㅇㅜㄹㅇㅓㅆㅅㅡㅂㄴㅣ_ㄷㅏ_'],
#  ['ㄴㅐ_ㄱㅏ_',
#   'ㅇㅏ_ㄴㅡㄴ',
#   'ㅂㅗ_ㅅㅡ_',
#   'ㅇㅣ_ㅅㅓㄱㄱㅣ_ㅇㅘ_',
#   'ㅈㅜㅇㄱㅏㄴㅂㅗ_ㅅㅡ_',
#   'ㅇㅣㅁㅈㅗㅇㅅㅓㄱㅇㅣ_',
#   'ㄷㅐ_ㅍㅛ_ㅈㅓㄱㅇㅣㄴㄷㅔ_',
#   'ㅈㅏ_ㅅㅣㄴㅇㅡㄴ',
#   'ㅇㅏ_ㄴㅣ_ㄷㅏ_'],
#  ['ㅇㅓ_ㄱㅣ_ㅇㅕㅇ',
#   'ㄴㅓ_ㅁㅜ_ㅎㅐ_ㅇㅖ_ㄱㅗ_ㅍㅕㄴㄷㅗ_',
#   'ㅈㅐ_ㅁㅣ_ㅇㅣㅆㄴㅡㄴ',
#   'ㄷㅏ_ㅇㅡㅁㅇㅣ_ㅇㅑ_ㄱㅣ_',
#   'ㄴㅓ_ㅁㅜ_',
#   'ㄱㅜㅇㄱㅡㅁㅎㅏ_ㄷㅏ_'],
#  ['ㅇㅞㄴㅁㅏㄴㅎㅏ_ㅁㅕㄴ',
#   'ㄷㅓ_ㅂㅣㅇㅂㅗ_ㄷㅏㄴ',
#   'ㅇㅝㄴㅈㅏㄱㅇㅡ_ㄹㅗ_',
#   'ㅂㅗ_ㄴㅡㄴㄷㅔ_',
#   'ㅇㅣ_ㄱㅓㄴ',
#   'ㄷㅓ_ㅂㅣㅇㅇㅡ_ㄹㅗ_ㄷㅗ_',
#   'ㅂㅘ_ㅇㅛ_',
#   'ㅈㅣㄴㅉㅏ_',
#   'ㄷㅣ_ㅈㅡ_ㄴㅣ_',
#   'ㄷㅓ_ㅂㅣㅇㅎㅏ_ㅅㅣㄴㅂㅜㄴㄷㅡㄹㅇㅣ_',
#   'ㅊㅚ_ㄱㅗ_'],
#  ['ㅇㅛ_ㅈㅡㅁ',
#   'ㅅㅏ_ㄱㅡㄱ',
#   'ㅌㅡㄱㅈㅣㅇㅇㅡㄴ',
#   'ㅈㅓㄻㄱㅗ_',
#   'ㅈㅏㄹㅅㅐㅇㄱㅣㄴ',
#   'ㅈㅜ_ㅇㅣㄴㄱㅗㅇㄷㅡㄹㅇㅡㄴ',
#   'ㅅㅜ_ㅇㅕㅁㅇㅣ_',
#   'ㅇㅓㅄㅇㅡㅁ',
#   'ㅅㅏ_ㅅㅣㄹㅅㅏㅇ',
#   'ㅍㅏㄴㅌㅏ_ㅈㅣ_',
#   'ㅅㅏ_ㄱㅡㄱㅇㅣ_ㄹㅏ_',
#   'ㅂㅗ_ㄴㅡㄴㄱㅔ_',
#   'ㅁㅏㅈㄷㅏ_'],
#  ['ㅌㅗ_ㅌㅗ_ㅇㅘ_',
#   'ㅇㅏ_ㅈㅓ_ㅆㅣ_ㅇㅢ_',
#   'ㅇㅏ_ㄹㅡㅁㄷㅏ_ㅇㅜㄴ',
#   'ㅇㅜ_ㅈㅓㅇㅇㅣ_',
#   'ㅇㅏㄴㅌㅏ_ㄲㅏ_ㅇㅜ_ㅁㅕㄴㅅㅓ_ㄷㅗ_',
#   'ㄱㅏㅁㄷㅗㅇㅈㅓㄱㅇㅣ_ㄱㅗ_',
#   'ㅁㅏ_ㅈㅣ_ㅁㅏㄱ',
#   'ㅈㅏㅇㅁㅕㄴㅇㅔ_ㅅㅓ_',
#   'ㅈㅓㅇㅁㅏㄹ',
#   'ㄱㅏ_ㅅㅡㅁㅇㅣ_',
#   'ㄸㅏ_ㄸㅡㅅㅎㅐ_ㅈㅣ_ㄴㅡㄴ',
#   'ㅇㅕㅇㅎㅘ_'],
#  ['5ㄱㅗㅇㅇㅔ_ㅅㅓ_',
#   'ㅂㅐ_ㅇㅕㄱ',
#   'ㅎㅐㅆㄷㅓㄴ',
#   'ㅅㅏ_ㄹㅏㅁㅇㅏ_ㄴㅣ_ㄴㅑ_',
#   'ㅈㅓㅇㅊㅣ_ㅅㅓㅇㅎㅑㅇㅇㅡㄹ',
#   'ㄸㅓ_ㄴㅏ_ㅅㅓ_',
#   'ㅇㅏ_ㅈㅐ_',
#   'ㅇㅕㄴㄱㅣ_ㄴㅡㄴ'],
#  ['ㅂㅗ_ㅌㅗㅇ',
#   'ㄱㅏ_ㄱㅣ_ㅈㅓㄴㅇㅔ_',
#   'ㅂㅣ_ㅅㅓ_ㅅㅣㄹㅇㅔ_ㅅㅓ_',
#   'ㅁㅕㅊㄱㅜㄴㄷㅔ_',
#   'ㅅㅓㅂㅇㅚ_ㅎㅐ_ㅅㅓ_',
#   'ㅁㅏㄹㅁㅏㅈㅊㅝ_ㄴㅗㅎㅈㅣ_',
#   'ㅇㅏㄴㄴㅏ_'],
#  ['ㅅㅏ_ㅎㅚ_ㅇㅔ_ㅅㅓ_ㄷㅗ_',
#   'ㅅㅓㅇㄱㅗㅇㅇㅡㄹ',
#   'ㅎㅏ_ㄹㅕ_ㅁㅕㄴ',
#   'ㅈㅜ_ㄱㅜㄴㅇㅡㄹ',
#   'ㅇㅏㄹㅇㅏ_ㅂㅗ_ㄱㅗ_',
#   'ㅁㅗ_ㅅㅕ_ㅇㅑ_',
#   'ㅎㅏㄴㄷㅏ_',
#   'ㄱㅡ_ㄱㅔ_',
#   'ㅃㅐㄱㅇㅓㅄㄱㅗ_',
#   'ㄷㅗㄴㅇㅓㅄㄴㅡㄴ',
#   'ㄴㅗㅁㄷㅡㄹ',
#   'ㅇㅠ_ㅇㅣㄹㅎㅏㄴ',
#   'ㅎㅢ_ㅁㅏㅇ'],
#  ['ㅇㅣ_ㄱㅓ_',
#   'ㅈㅗㄴㄴㅏ_',
#   'ㅅㅣㅁㄱㅏㄱㅎㅏㄴ',
#   'ㅇㅣㄹㅇㅣㄴㄷㅔ_',
#   'ㅇㅣ_ㄹㅓㄴㄱㅓㄴ',
#   'ㅇㅣ_ㅅㅠ_ㄱㅏ_',
#   'ㅇㅏㄴㄷㅚ_ㄴㅑ_'],
#  ['ㅈㅣㅂㅈㅜㅇㅎㅏ_ㄱㅗ_',
#   'ㅂㅗ_ㄷㅏ_ㅂㅗ_ㅁㅕㄴ',
#   'ㅂㅏㅁㅅㅐㄴㄷㅏ_',
#   'ㅇㅣ_ㄹㅓㄴㄱㅔ_',
#   'ㅈㅣㄴㅉㅏ_',
#   'ㅅㅣ_ㅌㅡ_ㅋㅗㅁ'],
#  ['ㄱㅡ_ㄴㅑㅇ',
#   'ㅍㅕㄴㅇㅢ_ㅈㅓㅁ',
#   'ㅇㅘ_ㅇㅣ_ㅍㅏ_ㅇㅣ_ㄷㅡㄹㅁㅏㄴ',
#   'ㅍㅜㄹㅇㅓ_ㄷㅗ_',
#   'ㄷㅚ_ㄴㅡㄴㄷㅔ_',
#   'ㄷㅗㄴㅇㅡㄹ',
#   'ㅎㅏ_ㄴㅡㄴㄷㅔ_',
#   'ㅈㅓ_ㄹㅐ_ㅆㅡ_ㄴㅑ_',
#   'ㅃㅏㄱㄷㅐ_ㄱㅏ_ㄹㅣㄴㄱㅏ_'],
#  ['ㅇㅕㅇㅎㅘ_ㄹㅡㄹ',
#   'ㅂㅗ_ㅁㅕㄴㅅㅓ_',
#   'ㄴㅏ_ㄷㅗ_',
#   'ㄴㅏㄹㄱㅗ_ㅅㅣㅍㅇㅓㅆㄷㅏ_',
#   'ㅇㅣ_ㅃㅡㄴ',
#   'ㅈㅜ_ㅇㅣㄴㄱㅗㅇㄱㅏㅌㅇㅡㄴ',
#   'ㅇㅕ_ㅇㅣㄴㅇㅣ_ㄹㅏㅇ'],
#  ['ㅇㅣ_ㅇㅑ_ㄱㅣ_',
#   'ㅂㅐ_ㅇㅜ_',
#   'ㅇㅕㄴㅊㅜㄹ',
#   'ㅁㅗ_ㄷㅜ_',
#   'ㄴㅓ_ㅁㅜ_',
#   'ㅈㅗㅎㅇㅏㅆㅇㅓ_ㅇㅛ_ㅇㅣ_ㅈㅔㄴ',
#   'ㅁㅜ_ㅅㅡㄴ',
#   'ㄴㅏㄱㅇㅡ_ㄹㅗ_',
#   'ㅅㅏㄹㅈㅛ_ㅇㅏㅍㅇㅡ_ㄹㅗ_',
#   'ㅈㅗㅎㅇㅡㄴ',
#   'ㅈㅏㄱㅍㅜㅁㅇㅡㄹ',
#   'ㄱㅣ_ㄷㅐ_ㅎㅏ_ㅁㅕ_ㄱㅣㅁㄴㅏㅁㄱㅣㄹㄴㅓ_ㅁㅜ_',
#   'ㅁㅓㅅㅇㅣㅆㅇㅡㅁ'],
#  ['ㅌㅣ_ㅂㅣ_ㄹㅗ_',
#   'ㅇㅓㅁㅁㅏ_ㅇㅏ_ㅃㅏ_ㄹㅏㅇㄱㅏㅌㅇㅣ_',
#   'ㅂㅘㅆㄷㅓㄴ',
#   'ㅈㅓㅇㅁㅏㄹ',
#   'ㅇㅏ_ㅈㅣㄱㄲㅏ_ㅈㅣ_ㄷㅗ_',
#   'ㄱㅣ_ㅇㅓㄱㅇㅔ_ㄴㅏㅁㄴㅡㄴ',
#   'ㅁㅕㅇㅈㅏㄱㅈㅜㅇㅁㅕㅇㅈㅏㄱ',
#   'ㅈㅓㅇㅁㅏㄹ',
#   'ㄱㅏㅁㅈㅓㅇㅇㅣ_ㅇㅣㅂㅎㅏ_ㅁㅕㄴㅅㅓ_',
#   'ㅂㅘㅆㄷㅓㄴㄱㅓ_ㄱㅏㅌㄷㅏ_',
#   'ㅊㅏㅈㄱㅗ_ㅇㅣㅆㅇㅓㅆㄴㅡㄴㄷㅔ_',
#   'ㅇㅣ_ㄱㅓ_ㅇㅕㅆㄱㅜ_ㄴㅏ_ㅇㅔ_ㅇㅣ_',
#   'ㅇㅏ_ㅇㅣ_',
#   'ㄷㅏ_ㅅㅣ_ㅎㅏㄴㅂㅓㄴ',
#   'ㅂㅘ_ㅇㅑ_ㄱㅔㅆㄷㅏ_'],
#  ['ㄱㅜㄱㄱㅏ_ㅇㅏㄴㅂㅗ_ㄹㅡㄹ',
#   'ㄷㅐ_ㅌㅗㅇㄹㅕㅇㅇㅣ_',
#   'ㄱㅘㄴㄹㅣ_ㅎㅏ_ㄴㅑ_',
#   'ㄱㅜㄱㅂㅏㅇㅂㅜ_ㄱㅏ_',
#   'ㄱㅘㄴㄹㅣ_ㅎㅏ_ㄴㅡㄴㄱㅓ_ㅈㅣ_',
#   'ㅈㅣㄴㅉㅏ_',
#   'ㅁㅣ_ㅍㅣㄹㅅㅐ_ㄲㅣ_ㄷㅡㄹ',
#   'ㅈㅗㄴㄴㅏ_',
#   'ㅁㅏㄶㄴㅔ_',
#   'ㅈㅣㄱㅎㅏㅁㅁㅏㄴ',
#   'ㅊㅚ_ㄱㅗ_ㅌㅗㅇㅅㅜ_ㄱㅝㄴㅈㅏ_ㅇㅣㄴㄱㅓ_ㄱㅗ_',
#   'ㅈㅣㄱㅅㅗㄱㅅㅏㅇㄱㅘㄴㅇㅡㄴ',
#   'ㅂㅜ_ㅅㅓ_ㅇㅢ_',
#   'ㅇㅡ_ㄸㅡㅁㅇㅡㄹ',
#   'ㅁㅏㄹㅎㅏ_ㄴㅡㄴㄱㅓ_ㄷㅏ_',
#   'ㅇㅖ_ㄱㅓㅁㅊㅏㄹㄱㅓㅁㅊㅏㄹㅊㅗㅇㅈㅏㅇ',
#   'ㅇㅠㄱㄱㅜㄴㅇㅠㄱㄱㅜㄴㅊㅏㅁㅁㅗ_ㅊㅗㅇㅈㅏㅇ',
#   'ㅇㅣ_ㄹㅓㄴㅅㅣㄱㅇㅡ_ㄹㅗ_',
#   'ㄷㅡㅇㅅㅣㄴㅇㅏ_',
#   'ㄱㅜㄱㅂㅏㅇㅂㅜ_',
#   'ㅊㅚ_ㄱㅗ_',
#   'ㅇㅡ_ㄸㅡㅁㅇㅡㄴ',
#   'ㅈㅏㅇㄱㅘㄴㅇㅣ_ㅇㅑ_'],
#  ['ㅌㅐ_ㅇㅑㅇ', 'ㄱㅗㅇㅈㅓㄴㅇㅣ_ㄱㅔㅆㅈㅣ_', 'ㅌㅐ_ㅇㅑㅇㅇㅣ_', 'ㅇㅜㅁㅈㅣㄱㅇㅕ_ㅅㅓ_', 'ㄸㅡ_ㄴㅡㄴㄱㅓ_ㄴㅣ_ㄲㅏ_'],
#  ['ㅇㅓ_ㄸㅓㄴ', 'ㄱㅏㅁㄷㅗㄱㅇㅡㄴ', '30ㄷㅐ_', 'ㅎㅜ_ㅂㅏㄴㅇㅔ_ㄷㅗ_', 'ㅈㅏㅇㅇㅣㄴㅇㅣ_', 'ㄷㅚㄴㄷㅏ_'],
#  ['ㅊㅏ_ㄹㅏ_ㄹㅣ_', 'ㅎㅏㅂㅅㅓㅇㅇㅡㄹ', 'ㅅㅣ_ㅂㅏㄹ', 'ㅇㅓ_ㅎㅠ_', 'ㅎㅕㄴㅅㅣㄹㅇㅣ_', 'ㅇㅜㅅㄱㅣ_ㄴㅗ_'],
#  ['ㅇㅛㅇㅅㅓ_ㅇㅔ_',
#   'ㄷㅐ_ㅎㅐ_ㅅㅓ_ㅍㅣ_ㅎㅐ_ㅈㅏ_',
#   'ㅇㅣㅂㅈㅏㅇㅇㅔ_ㅅㅓ_',
#   'ㅅㅔ_ㅁㅣㄹㅎㅏ_ㄱㅔ_',
#   'ㅍㅜㄹㅇㅓ_ㄴㅐㄴㅇㅣ_ㅈㅓㅇㅎㅑㅇㄱㅏㅁㄷㅗㄱㄴㅣㅁㅇㅢ_',
#   'ㅅㅣ_ㄱㅏㄱㅇㅔ_ㄴㅗㄹㄹㅏ_ㄱㅗ_ㄸㅗ_',
#   'ㅂㅐ_ㅇㅜ_ㄷㅡㄹㅇㅢ_',
#   'ㅇㅕㄴㄱㅣ_ㅇㅔ_',
#   'ㄴㅗㄹㄹㅏㄴㅁㅏㄶㅇㅡㄴ',
#   'ㄱㅓㅅㅇㅡㄹ',
#   'ㄷㅓㄴㅈㅕ_ㅈㅜㄴ',
#   'ㅇㅕㅇㅎㅘ_ㅇㅕㅆㅅㅡㅂㄴㅣ_ㄷㅏ_'],
#  ['ㅇㅘㄴㅈㅓㄴ', 'ㅈㅐ_ㅁㅣㅆㅇㅡㅁ', '10ㅈㅓㅁㄷㅗ_', 'ㅈㅜ_ㄱㅗ_', 'ㅅㅣㅍㅇㅓ_ㅇㅛ_'],
#  ['ㅎㅏㄴㅂㅓㄴㄷㅗ_',
#   'ㅇㅏㄴㄴㅏ_ㅇㅘㅅㄴㅡㄴㄷㅔ_',
#   'ㄱㅡ_ㅉㅗㄱㅇㅕㅇㅅㅏㅇ',
#   'ㄱㅓㅁㅅㅐㄱㅎㅏ_ㄱㅓ_ㄴㅏ_',
#   'ㅎㅏㄴㄷㅜ_ㅂㅓㄴ',
#   'ㅂㅗㄴㄷㅡㅅ'],
#  ['ㅅㅏ_ㄷㅏㄴㅅㅣㄴㅂㅕㅇㄱㅛ_ㅇㅠㄱㄷㅐ_',
#   'ㅊㅟ_ㅅㅏ_ㅂㅕㅇㅇㅣ_ㅇㅕㅆㄴㅏ_ㅂㅗ_ㄴㅔ_',
#   'ㅎㅜㄴㄹㅕㄴㅂㅕㅇㄷㅡㄹ',
#   'ㅂㅐ_ㅅㅣㄱㅈㅗ_',
#   'ㅇㅜㄴㅇㅕㅇㅎㅐ_ㄷㅗ_',
#   'ㅎㅐㄹㅇㅣ_ㄱㅣㄴ'],
#  ['ㄷㅡㄷㄱㅣ_',
#   'ㅈㅗㅎㅇㅡㄴㅁㅏㄹ',
#   'ㅎㅐ_ㅈㅜㄴㄷㅏ_ㄱㅗ_',
#   'ㅁㅜ_ㅈㅏㄱㅈㅓㅇ',
#   'ㅃㅏ_ㄴㅡㄴ',
#   'ㅈㅏ_ㅅㅔ_ㄴㅡㄴ',
#   'ㅇㅣ_ㅈㅔ_',
#   'ㅂㅓ_ㄹㅕ_ㅇㅑ_',
#   'ㅎㅏㄴㄷㅏ_',
#   'ㅇㅠ_ㅌㅠ_ㅂㅡ_ㅇㅔ_ㅅㅓ_',
#   'ㅅㅠ_ㅍㅓ_ㅊㅔㅅㅇㅣ_ㄴㅏ_',
#   'ㅎㅜ_ㅇㅝㄴㄷㅗ_',
#   'ㅎㅏ_ㅁㅕㄴ',
#   'ㅇㅏㄴㄷㅚㄴㄷㅏ_'],
#  ['ㅇㅓ_ㅂㅔㄴㅈㅕ_ㅅㅡ_ㄸㅏ_ㅇㅟ_ㅇㅘ_',
#   'ㅂㅣ_ㄱㅛ_ㅎㅏㄹ',
#   'ㅇㅓㅄㄴㅡㄴ',
#   'ㅅㅜ_ㅈㅏㄱ',
#   'ㅊㅓㄹㅎㅏㄱㅈㅓㄱ',
#   'ㅎㅣ_ㅇㅓ_ㄹㅗ_ㅁㅜㄹ'],
#  ['ㅂㅏㅇㄱㅡㅁ', 'ㅅㅓ_ㅍㅡ_ㄹㅏ_ㅇㅣ_ㅊㅡ_ㅇㅔ_ㅅㅓ_', 'ㅈㅏㅇㅂㅗ_ㅂㅣ_', 'ㅈㅏㅁㅅㅜ_ㅈㅗㅇㅂㅗ_ㄱㅗ_', 'ㄱㅏㅁㄷㅗㅇ'],
#  ['ㄱㅣㅁㄷㅗㅇㅇㅘㄴ', 'ㄷㅐ_ㅂㅏㄱ', 'ㅇㅕㄴㄱㅣ_ㅈㅓㅇㅁㅏㄹㅈㅏㄹㅎㅏㅁ', 'ㅊㅏ_ㅂㅜㄴㅎㅏ_ㄱㅔ_', 'ㅈㅏㄹㅎㅏㅁ'],
#  ['ㅈㅣㄴㅉㅏ_',
#   'ㅈㅗㅎㅇㅏ_ㅎㅏ_ㄴㅡㄴ',
#   'ㅇㅕㅇㅎㅘ_ㅈㅜㅇ',
#   'ㅎㅏ_ㄴㅏ_',
#   'ㅂㅏㄱㅎㅐ_ㅇㅣㄹ',
#   'ㅈㅣㄴㅉㅏ_',
#   'ㅈㅏㄹㅅㅐㅇㄱㅕㅆㄱㅗ_',
#   'ㅂㅐ_ㄱㅕㅇㄷㅗ_',
#   'ㅇㅣ_ㅃㅡ_ㄱㅗ_',
#   'ㅂㅐ_ㅇㅜ_ㄷㅡㄹ',
#   'ㅇㅕㄴㄱㅣ_ㄷㅗ_',
#   'ㅈㅏㄹㅎㅏ_ㄱㅗ_',
#   'ㅇㅣ_ㄱㅓ_',
#   'ㄱㅡ_ㄴㅑㅇ',
#   'ㅅㅣㅁㅅㅣㅁㅎㅏㄹㄸㅐ_ㅁㅏ_ㄷㅏ_',
#   'ㅂㅗ_ㄱㅗ_ㄴㅏ_ㅁㅕㄴ',
#   'ㅇㅕ_ㅇㅜㄴㄷㅗ_',
#   'ㅇㅣㅆㄱㅗ_'],
#  ['ㅁㅣ_ㄱㅜㄱㄴㅐ_ㅇㅔ_',
#   'ㄱㅏ_ㅈㅏㅇ',
#   'ㅁㅏㄱㄱㅏㅇㅎㅏㄴ',
#   'ㄹㅗ_ㅂㅣ_ㄷㅏㄴㅊㅔ_',
#   'ㄷㅐ_ㅌㅗㅇㄹㅕㅇㅈㅗ_ㅊㅏ_',
#   'ㅋㅓㄴㅌㅡ_ㄹㅗㄹㅎㅏㄹㅅㅜ_ㅇㅓㅄㄴㅡㄴ',
#   'ㅈㅣㅂㄷㅏㄴ',
#   'ㅊㅗㅇㄱㅣ_ㅎㅕㅂㅎㅚ_ㅇㅣ_',
#   'ㅈㅣㅂㄷㅏㄴㅇㅣ_',
#   'ㅅㅏ_ㄹㅏ_ㅈㅣ_ㅈㅣ_ㅇㅏㄶㄴㅡㄴㅎㅏㄴ',
#   'ㅈㅓ_ㄹㅓㄴ',
#   'ㅁㅜ_ㄱㅣ_',
#   'ㅁㅣㄹㄱㅓ_ㄹㅐ_',
#   'ㅁㅣ_ㄱㅜㄱㄴㅐ_',
#   'ㅊㅗㅇㄱㅣ_ㅅㅗ_ㅈㅣ_ㅇㅕ_ㅂㅜ_',
#   'ㄴㅗㄴㄹㅏㄴㅇㅡㄴ',
#   'ㄲㅡㄶㅇㅣ_ㅈㅣ_',
#   'ㅇㅏㄶㅇㅡㄹㄱㅓㅅㅇㅣ_ㄷㅏ_'],
#  ['ㅁㅜㄴㅈㅐ_ㅇㅣㄴㅇㅣ_',
#   'ㅂㅜ_ㄹㅓㅂㄷㅏ_ㅇㅝㄴㄱㅗ_ㅁㅏㄴ',
#   'ㅇㅣㄺㅇㅡ_ㅁㅕㄴ',
#   'ㅇㅏㄹㅇㅏ_ㅅㅓ_',
#   'ㄷㅗㄴㄴㅏ_ㅇㅗ_ㄱㅗ_',
#   'ㅂㅕㅇㅅㅣㄴㄴㅕㄴㄷㅡㄹㅇㅣ_',
#   'ㅃㅏㄹㅇㅏ_ㅈㅜ_ㄱㅗ_',
#   'ㅁㅏㄹㅁㅜㄴ',
#   'ㅁㅏㄱㅎㅣ_ㅁㅕㄴ',
#   'ㅎㅝ_ㅎㅝ_ㅎㅝ_ㅎㅝ_',
#   'ㅁㅕㅊㅂㅓㄴ',
#   'ㄸㅐ_ㅇㅜ_ㅁㅕㄴ',
#   'ㅂㅏㅇㅅㅗㅇㅇㅔ_ㅅㅓ_',
#   'ㅇㅏㄹㅇㅏ_ㅅㅓ_',
#   'ㄷㅐ_ㅂㅕㄴㅇㅣㄴㅇㅣ_',
#   'ㄸㅐ_ㅇㅜ_ㄱㅗ_ㅈㅣ_ㄱㅜ_ㅅㅏㅇㅇㅔ_',
#   'ㅇㅏ_ㄴㅣ_ㅇㅜ_ㅈㅜ_ㅅㅏㅇㅇㅔ_',
#   'ㅈㅓ_ㄹㅓㅎㄱㅔ_',
#   'ㅍㅕㄴㅎㅏㄴㅈㅣㄱㅇㅓㅂ',
#   'ㅇㅓㅄㅇㅡㄹㄷㅡㅅ'],
#  ['ㅂㅣ_ㄹㅗㄱ',
#   'ㅁㅗㅅㅈㅜ_ㅈㅣ_ㅁㅏㄴ',
#   'ㅁㅏ_ㅇㅡㅁㅇㅡ_ㄹㅗ_ㄹㅏ_ㄷㅗ_',
#   'ㅈㅜ_ㄱㅗ_ㄱㅏㅁ',
#   'ㅇㅡㅋㅋㅙ_',
#   'ㅅㅏㅇㅋㅙ_',
#   'ㅌㅗㅇㅋㅙ_'],
#  ['ㅇㅣ_ㅁㅣ_', 'ㅇㅖ_ㅈㅓㄴㅇㅔ_', 'ㅈㅣㄴㄱㅏ_ㄹㅡㄹ', 'ㅇㅣㄴㅈㅓㅇㅂㅏㄷㅇㅏㅆㄷㅓㄴ', 'ㅈㅗㅎㅇㅏ_ㅇㅛ_'],
#  ['ever',
#   'was',
#   'anything',
#   'great',
#   'achieved',
#   'without',
#   'danger',
#   'iccolo',
#   'achiavelli'],
#  ['ㅅㅐㅇㄱㅏㄱㅇㅓㅄㅇㅣ_', 'ㅂㅘㅆㅇㅓㅆㄴㅡㄴㄷㅔ_', 'ㅈㅣㄴㅉㅏ_', 'ㅈㅐㅁㄴㅏㅂㄴㅣ_ㄷㅏ_', 'ㄱㅏㅇㅊㅜ_'],
#  ['ㅇㅓ_ㄸㅓㅎㄱㅔ_',
#   'ㅂㅗ_ㅁㅕㄴ',
#   'ㅈㅣ_ㄹㅜ_ㅎㅏ_ㅈㅣ_ㅁㅏㄴ',
#   'ㅁㅜ_ㅊㅓㄱ',
#   'ㅈㅏㄴㅈㅏㄴㅎㅏ_ㄱㅗ_',
#   'ㅅㅏㄴㄸㅡㅅㅎㅏㄴ',
#   'ㅇㅕㅇㅎㅘ_'],
#  ['ㅅㅗ_ㄹㅡㅁㄷㅗㄷㄴㅡㄴㄷㅏ_',
#   'ㄱㅡ_ㄹㅐ_ㄷㅗ_',
#   'ㅎㅗㅇㅇㅓ_ㅊㅓㄴㅈㅣ_ㄷㅓㄴㄷㅔ_',
#   'ㄴㅏ_ㄴㅡㄴ',
#   'ㄷㅗㅇㅌㅏㄴㅇㅔ_',
#   'ㅅㅏㄹㅈㅣ_ㅁㅏㄴ',
#   'ㅅㅓ_ㅇㅜㄹ',
#   'ㅅㅏ_ㄴㅡㄴ',
#   'ㅇㅣㅂㅈㅏㅇㅇㅣ_ㅁㅕㄴ',
#   'ㅈㅗㄴㄴㅏ_',
#   'ㅈㅗㅈㄱㅏㅌㅇㅡㄹㄱㅓ_ㄱㅏㅌㄷㅏ_'],
#  ['ㄴㅓ_ㅁㅜ_', 'ㄱㅟ_ㅇㅕㅂㄷㅏ_', 'ㅇㅡㅁㅇㅏㄱㄷㅗ_', 'ㅈㅗㅎㄱㅗ_', 'ㅊㅚ_ㄱㅗ_ㅇㅖ_ㅇㅛ_'],
#  ['ㅈㅓ_ㅅㅐ_ㄲㅣ_',
#   'ㄱㅜㄴㄷㅐ_ㄴㅡㄴ',
#   'ㄱㅏㅆㄴㅡㄴㅈㅣ_ㄱㅏ_',
#   'ㄱㅜㅇㄱㅡㅁㅎㅏ_ㄷㅏ_',
#   'ㅇㅙ_ㄴㅑ_ㅁㅕㄴ',
#   '1ㄱㅜㄴㄷㅐ_ㄴㅡㄴ',
#   'ㅁㅜㄴㅅㅣㄴ',
#   'ㅍㅣ_ㅇㅓ_ㅅㅣㅇ',
#   'ㅎㅏ_ㅁㅕㄴ',
#   'ㅇㅏㄴㅂㅏㄷㅇㅏ_ㅈㅜㄴㄷㅏ_ㅇㅣ_ㄱㅓㄴ',
#   'ㅅㅗ_ㅅㅗㅇㅇㅏㄴㅎㅏㅁ',
#   '2ㄱㅗㅇㅁㅜ_ㅇㅝㄴㄷㅗ_',
#   'ㅁㅜㄴㅅㅣㄴ',
#   'ㅍㅣ_ㅇㅓ_ㅅㅣㅇ',
#   'ㅎㅏ_ㅁㅕㄴ',
#   'ㅇㅏㄴㄷㅚㄴㄷㅏ_ㅇㅣ_ㄱㅓㄴ',
#   'ㅅㅗㅇㅅㅗㅇㅎㅏㅁ',
#   'ㄱㅐ_ㅆㅡ_ㄹㅔ_ㄱㅣ_',
#   'ㅅㅐ_ㄲㅣ_ㅇㅣㅁ'],
#  ['ㄱㅕㄹㄱㅜㄱ',
#   'ㅁㅣ_ㄱㅜㄱㅇㅡㄴ',
#   'ㅎㅏㄴㄱㅜㄱㅇㅡㄹ',
#   'ㅅㅗㄴㅈㅓㄹㅎㅏㄹㄲㅓ_ㄹㅏ_',
#   'ㅂㅗㄴㄷㅏ_',
#   'ㅋㅗ_ㄹㅗ_ㄴㅏ_ㄹㅗ_',
#   'ㅈㅜㅇㄱㅜㄱㅍㅕㄴㅇㅣㄴㄱㅔ_',
#   'ㅎㅘㄱㅅㅣㄹㅎㅐ_ㅈㅕㅆㄱㅓ_ㄷㅡㄴ',
#   'ㅇㅓ_ㄸㅓㄴㅂㅏㅇㅅㅣㄱㅇㅡ_ㄹㅗ_',
#   'ㅎㅏㄴㄱㅜㄱㅇㅡㄹ',
#   'ㅅㅗㄴㅈㅓㄹㅎㅏㄹㅈㅣ_',
#   'ㅌㅏ_ㄱㅕㄱㅇㅡㄹㅈㅜㄹㅈㅣ_ㄴㅡㄴ',
#   'ㄴㅏ_ㄷㅗ_',
#   'ㅁㅗ_ㄹㅡ_ㄱㅔㅆㅇㅡㅁ'],
#  ['ㅇㅕㅇㅇㅝㄴㅎㅣ_',
#   'ㅂㅏㄱㅈㅔ_ㄷㅚ_ㅅㅓ_',
#   'ㄱㅗ_ㅌㅗㅇㅂㅏㄷㄴㅡㄴ',
#   'ㅈㅓ_ㅂㅜㄴㄷㅡㄹ',
#   'ㅁㅣㄹㅈㅣㅍㅁㅗ_ㅈㅏ_ㄴㅡㄴ',
#   'ㅁㅐㄴㄴㅏㄹ',
#   'ㄴㅜㄴㅇㅣ_ㄱㅏㄴㄷㅏ_'],
#  ['ㅅㅐㅇㅇㅔ_', 'ㅊㅚ_ㄱㅗ_ㅇㅢ_', 'ㅇㅕㅇㅎㅘ_', 'ㄷㅏ_ㅅㅣ_', 'ㅇㅓㅄㅇㅡㄹ', 'ㅁㅕㅇㅈㅏㄱ'],
#  ['ㄱㅚ_ㅁㅜㄹㅇㅣ_',
#   'ㄱㅏㅌㅇㅣ_',
#   'ㄷㅡㅇㅈㅏㅇㅎㅏㄴㄷㅏ_ㄴㅡㄴㄱㅓㅅㅁㅏㄴㅇㅡ_ㄹㅗ_ㄷㅗ_',
#   'ㅎㅡㅇㅁㅣ_ㄱㅏ_',
#   'ㄱㅏ_ㄴㅡㄴ',
#   'ㅈㅏㄱㅍㅜㅁ',
#   'ㅎㅗ_ㄹㅓ_ㅁㅐ_ㄴㅣ_ㅇㅏ_ㄹㅏ_ㅁㅕㄴ',
#   'ㅊㅜㅇㅂㅜㄴㅎㅣ_',
#   'ㅈㅡㄹㄱㅣㄹㅅㅜ_',
#   'ㅇㅣㅆㄴㅡㄴ',
#   'ㅇㅗ_ㄹㅏㄱㅇㅕㅇㅎㅘ_ㄷㅏ_'],
#  ['ㅈㅜㄹㄹㅣ_ㅇㅏ_',
#   'ㄹㅗ_ㅂㅓ_ㅊㅡ_ㅇㅔ_',
#   'ㄱㅟ_ㅇㅕ_ㅇㅜㄴㅇㅕ_ㅇㅣㄴ',
#   'ㄷㅏ_ㅇㅡㅁㅇㅡ_ㄹㅗ_',
#   'ㅊㅚ_ㄱㅗ_ㅇㅢ_',
#   'ㅇㅕㅇㅎㅘ_ㄱㅏ_',
#   'ㅇㅏ_ㄴㅣㄹㄲㅏ_',
#   'ㅅㅣㅍㄷㅏ_'],
#  ['ㅂㅗ_ㅅㅗ_',
#   'ㅈㅓㅇㅅㅣㄴㅂㅕㅇㅈㅏ_',
#   'ㅎㅗㅇㅇㅓ_ㅅㅐ_ㄲㅣ_',
#   'ㅈㅏ_ㅎㅏㄴㄷㅏㅇ',
#   'ㅍㅐ_ㅎㅏㄴㄱㅓ_',
#   'ㅈㅗㅅㄴㅏ_ㄱㅔ_',
#   'ㄱㅓ_ㄹㅗㄴㅎㅏ_ㄴㅡㄴ',
#   'ㅈㅕㅇㅅㅣㄴㅂㅕㅇㅈㅏ_',
#   'ㅂㅗ_ㅅㅗ_'],
#  ['ㅅㅐ_ㅂㅕㄱㅇㅔ_',
#   'ㅂㅘㅆㄴㅡㄴㄷㅔ_',
#   'ㅎㅏ_ㅈㅣ_ㅇㅝㄴㅂㅗ_ㄴㅡㄴ',
#   'ㅈㅐ_ㅁㅣ_ㅇㅕㅆㅇㅡㅁ',
#   'ㅇㅕㄴㄱㅣ_ㄷㅗ_',
#   'ㅈㅗㅎㅇㅏㅆㄱㅗ_'],
#  ['ㅁㅝ_ㅎㅏ_ㄴㅡㄴㅈㅣ_',
#   'ㄱㅜㅇㄱㅡㅁㅎㅏ_ㅁㅕㄴ',
#   'ㅈㅏㄱㅅㅓㅇㄱㅡㄹㅇㅡㄹ',
#   'ㅂㅗ_ㅁㅕㄴㄷㅚ_ㅈㅣ_ㅇㅏㄶㄴㅑ_',
#   'ㄱㅡ_ㄱㅓ_ㅁㅏ_ㅈㅓ_',
#   'ㅇㅓㅄㅇㅡㄹㅈㅓㅇㄷㅗ_ㄹㅗ_',
#   'ㄴㅚ_ㄱㅏ_',
#   'ㅌㅚ_ㅎㅘ_ㅎㅐㅆㄴㅏ_'],
#  ['ㅇㅕㄴㅊㅜㄹㅇㅣ_ㄴㅏ_',
#   'ㅇㅕㄴㄱㅣ_',
#   'ㄴㅐ_ㅇㅛㅇㅈㅓㄴㄱㅐ_ㄷㅗ_',
#   'ㅇㅓㄱㅈㅣ_ㅅㅡ_ㄹㅓㅂㄱㅗ_',
#   'ㄷㅏㅂㄷㅏㅂㅎㅏㅁ',
#   'ㄱㅡ_ㄹㅓㄴㄷㅔ_',
#   'ㅂㅜㄱㅎㅏㄴㅌㅏㄹㅂㅜㄱ',
#   'ㅇㅕ_ㅅㅓㅇㅇㅣ_',
#   'ㅊㅓ_ㅎㅏㄴ',
#   'ㅇㅓ_ㄹㅕ_ㅇㅜㄴ',
#   'ㅅㅏㅇㅎㅘㅇㅇㅡㄹ',
#   'ㅂㅗ_ㅇㅕ_ㅈㅜㄴㅈㅓㅁㅇㅔ_ㅅㅓㄴ',
#   'ㅇㅘ_ㄷㅏㅎㄴㅡㄴㄱㅔ_',
#   'ㅇㅣㅆㅇㅓ_ㅅㅓ_',
#   'ㄱㅏㅁㄷㅗㄱㅇㅢ_',
#   'ㅈㅏㄱㅍㅜㅁㅇㅢ_ㄷㅗ_ㄴㅡㄴ',
#   'ㅈㅓㄴㄷㅏㄹ',
#   'ㄷㅙㅆㅇㅡㅁ',
#   'ㄱㅡ_ㄹㅓㄴㅇㅢ_ㅁㅣ_ㅇㅔ_ㅅㅓ_',
#   '10ㅈㅓㅁㅈㅜ_ㄱㅗ_',
#   'ㅅㅣㅍㅇㅡㅁ'],
#  ['ㅇㅕㅇㅎㅘ_ㄱㅏ_',
#   'ㅇㅓ_ㄸㅓㅎㄱㅗ_',
#   'ㅈㅓ_ㄸㅓㅎㄱㅗ_',
#   'ㄸㅏ_ㅈㅣ_ㄱㅗ_',
#   'ㅅㅣㅍㅈㅣ_',
#   'ㅇㅏㄶㄷㅏ_',
#   'ㅁㅏ_ㅇㅡㅁㅇㅣ_',
#   'ㅈㅓㅇㅁㅏㄹ',
#   'ㅇㅏ_ㅍㅏㅆㄷㅏ_'],
#  ['ㄷㅏㅇㅅㅣ_',
#   'ㅍㅗㄱㅂㅏㄹㅈㅓㄱ',
#   'ㅇㅣㄴㄱㅣ_ㄹㅗ_',
#   'ㅍㅕㄴㅈㅣㅂㅂㅜ_ㅇㅢ_',
#   'ㅇㅏㅂㅂㅏㄱㅇㅔ_',
#   'ㅇㅓㄱㅈㅣ_ㄹㅗ_',
#   'ㅈㅣㄹㅈㅣㄹ',
#   'ㄴㅡㄹㄹㅕㅆㅈㅣ_ㅁㅏㄴ',
#   'ㄱㅡ_ㄹㅓㅁㅇㅔ_ㄷㅗ_',
#   'ㅈㅓㄴㅅㅓㄹㅇㅣ_',
#   'ㅁㅏㄴㅎㅘ_'],
#  ['ㅇㅏ_ㅇㅣ_ㅅㅡ_ㅋㅠ_ㅂㅡ_ㄴㅡㄴ',
#   'ㅇㅜ_ㄹㅣ_ㄴㅏ_ㄹㅏ_',
#   'ㄱㅓㅂㄴㅏ_ㄷㅣ_ㅅㅡ_ㅎㅏㄴㅎㅡㄱㅇㅣㄴㄹㅐ_ㅍㅓ_ㄹㅗ_ㅅㅓ_',
#   'ㅌㅏ_ㅇㅣ_ㄱㅓ_jkㄱㅏ_',
#   'ㄷㅏ_ㅅㅣ_ㄷㅣ_ㅅㅡ_ㅎㅐ_ㅅㅓ_',
#   'ㅇㅠ_ㅁㅕㅇㅎㅐ_ㅈㅣㄴㄱㅓ_ㄹㅏ_ㄱㅗ_',
#   'ㅁㅏㄹㅎㅏ_ㄱㅗ_ㅅㅣㅍㄷㅏ_',
#   'ㄱㅜ_ㄹㅣ_'],
#  ['ㅇㅖ_ㅈㅓㄴ',
#   'ㅇㅕㅇㅎㅘ_ㄹㅏ_',
#   'ㅈㅣㄴㅂㅜ_ㅎㅏㄹ',
#   'ㅇㅏㄹㅇㅏㅆㄴㅡㄴㄷㅔ_',
#   'ㄱㅣ_ㄷㅐ_ㅇㅣ_ㅅㅏㅇㅇㅡ_ㄹㅗ_',
#   'ㅈㅐ_ㅁㅣ_ㅇㅣㅆㅇㅓㅆㅇㅓ_ㅇㅛ_',
#   'ㅍㅣ_ㅌㅓ_ㄱㅏㅌㅇㅡㄴ',
#   'ㄴㅏㅁㅈㅏ_',
#   'ㅈㅓㅇㅁㅏㄹ',
#   'ㅁㅐ_ㄹㅕㄱㅈㅓㄱㅇㅣㄴㄱㅓ_',
#   'ㄱㅏㅌㅇㅏ_ㅇㅛ_',
#   'ㅈㅏ_ㄱㅣ_ㄱㅏㅁㅈㅓㅇㅇㅔ_',
#   'ㅊㅜㅇㅅㅣㄹㅎㅏ_ㄱㅗ_',
#   'ㅅㅗㄹㅈㅣㄱㅎㅏ_ㄱㅗ_',
#   'ㅅㅏ_ㄹㅏㅇㅇㅔ_',
#   'ㄱㅓ_ㅊㅣㅁㅇㅓㅄㄴㅡㄴ',
#   'ㅁㅓㅅㅇㅣㅆㄴㅔ_ㅇㅛ_'],
#  ['ㅅㅐㅇㄱㅏㄱㄴㅏ_', 'ㅊㅗ_ㄷㅣㅇㄸㅐ_', 'ㅅㅣㄴㄱㅣ_ㅎㅐㅆㅇㅓㅆㄴㅡㄴㄷㅔ_', 'ㅂㅓㄹㅆㅓ_', '6ㄴㅕㄴㅈㅓㄴ'],
#  ['ㅇㅣ_ㄱㅓㅅ', 'ㄴㅓ_ㅁㅜ_', 'ㅃㅏㄹㄹㅣ_', 'ㄲㅡㅌㄴㅏ_ㅅㅓ_', 'ㅇㅏ_ㅅㅟ_ㅇㅜㅁㅇㅣ_'],
#  ['ㅈㅓㄴㅇㅝㄴㅊㅐㄱㅇㅣ_',
#   'ㅁㅏ_ㄹㅡ_ㅋㅡ_ㅅㅡ_ㅇㅘ_',
#   'ㄱㅏㅌㅇㅣ_',
#   'ㅎㅘㄹㄷㅗㅇㅎㅐㅆㄷㅏ_ㄱㅗ_',
#   'ㅎㅐㅆㄴㅡㄴㄷㅔ_ㄷㅗ_',
#   '1850ㄴㅕㄴㄷㅐ_ㄹㅡㄹ',
#   'ㅇㅣ_ㄹㅏ_ㄱㅗ_',
#   'ㅎㅏㄴㄱㅓㅅㄷㅗ_',
#   'ㅇㅓ_ㅊㅓ_ㄱㅜ_ㄴㅣ_ㅇㅓㅄㅈㅣ_ㅁㅏㄴ',
#   'ㅂㅗ_ㅌㅗㅇ',
#   'ㅅㅗ_ㄹㅕㄴㅇㅣ_ㄴㅏ_',
#   'ㄱㅜ_ㅅㅗ_ㄹㅕㄴㅇㅣ_ㄹㅏ_ㄱㅗ_',
#   'ㅎㅏ_ㄴㅡㄴㄱㅓㄹ',
#   'ㄱㅜㄷㅇㅣ_',
#   'ㅇㅣ_ㄹㅏ_ㄱㅗ_',
#   'ㄱㅜㄱㄱㅏ_',
#   'ㅍㅜㄹㄴㅔ_ㅇㅣㅁㅇㅡㄹ',
#   'ㅇㅓㄴㄱㅡㅂㅎㅏㄴㄱㅓ_ㅂㅗ_ㅁㅕㄴ',
#   'ㅇㅓㄹㅁㅏ_ㄴㅏ_',
#   'ㅅㅡㅂㅈㅏ_ㅈㅣ_ㄱㅏㅌㅇㅡㄴ',
#   'ㅈㅣ_ㅅㅣㄱㅇㅡㄹ',
#   'ㅃㅗㅁㄴㅐ_ㄱㅗ_',
#   'ㅅㅣㅍㅇㅓㅆㄴㅡㄴㅈㅣ_',
#   'ㄷㅡ_ㄹㅓ_ㄴㅏㅁ'],
#  ['ㅇㅓㅁㅊㅓㅇ', 'ㅈㅣㅂㅈㅜㅇㅎㅐ_ㅅㅓ_', 'ㅇㅕㅇㅎㅘ_', 'ㅈㅐ_ㅁㅣ_ㅇㅣㅆㄱㅔ_', 'ㅂㅘㅆㄷㅏ_'],
#  ['ㅈㅒ_ㄴㅔ_ㄷㅡㄹㅇㅡㄴ',
#   'ㄷㅏ_ㅇㅡㅁ',
#   'ㅈㅓㅇㄱㅝㄴㄷㅗ_',
#   'ㅈㅣ_ㅅㅗㄱ',
#   'ㅇㅠ_ㅈㅣ_ㅎㅏ_ㄱㅣ_',
#   'ㅇㅟ_ㅎㅐ_',
#   'ㅁㅜ_ㅅㅡㄴ',
#   'ㅈㅣㅅㅇㅣ_ㄹㅏ_ㄷㅗ_',
#   'ㅎㅏㄹㄱㅓ_ㅇㅣㅁ'],
#  ['ㄴㅏ_ㄷㅗ_',
#   'ㄷㅏ_ㅇㅡㅁㅇㅔ_',
#   'ㅇㅣㄹㅂㅗㄴㅇㅕ_ㅎㅐㅇ',
#   'ㄱㅏㄹㄸㅐ_',
#   'ㅇㅑ_ㅅㅡ_ㅋㅜ_ㄴㅣ_',
#   'ㅅㅣㄴㅅㅏ_ㅇㅔ_ㅅㅓ_',
#   'ㅁㅜㄴㅈㅐ_ㅇㅏㅇ',
#   'ㅅㅏ_ㅁㅏㅇ',
#   'ㄱㅣ_ㅇㅝㄴ',
#   'ㅈㅓㄱㄱㅗ_',
#   'ㅇㅘ_ㅇㅑ_ㄱㅔㅆㄷㅏ_'],
#  ['ㄴㅏ_ㄹㅡㅁ',
#   'ㅇㅐㄱㅅㅕㄴㅅㅣㄴ',
#   'ㅈㅗㅎㄱㅗ_',
#   'ㅂㅗㄹㅁㅏㄴㅎㅏㄴ',
#   'ㅇㅕㅇㅎㅘ_ㅇㅣㄴㄷㅔ_',
#   'ㅍㅕㅇㅇㅣ_',
#   'ㅇㅣ_ㅅㅏㅇㅎㅏ_ㄱㅔ_',
#   'ㄴㅏㅈㄴㅔ_ㅇㅛ_ㄱㅐ_ㅇㅣㄴㅈㅓㄱㅇㅡ_ㄹㅗㄴ',
#   'ㅁㅜ_ㅇㅣㄴ',
#   'ㄱㅘㄱㅇㅝㄴㄱㅏㅂㅂㅗ_ㄷㅏㄴ',
#   'ㅈㅐ_ㅁㅣ_ㄴㅏ_ㄱㅔ_',
#   'ㅂㅘㅆㅅㅡㅂㄴㅣ_ㄷㅏ_'],
#  ['ㅆㅣㅂㅅㅐ_ㄲㅑ_',
#   'ㅇㅜ_ㄹㅣ_ㄱㅠ_ㄹㅣ_',
#   'ㅇㅛㄱㅎㅏ_ㅈㅣ_ㅁㅏ_',
#   'ㄱㅠ_ㄹㅣ_ㅇㅑ_',
#   'ㅈㅜ_ㄹㅏ_',
#   'ㄴㅐ_ㄱㅏ_',
#   'ㅇㅣㄹㅂㅔ_ㅇㅔ_ㅅㅓ_',
#   'ㅂㅏㅇㅍㅐ_ㄱㅏ_',
#   'ㄷㅚ_ㅇㅓ_',
#   'ㅈㅜ_ㅁㅏ_',
#   'ㅂㅗ_ㅈㅣ_',
#   'ㅇㅏㅍㅇㅡ_ㄹㅗ_',
#   'ㅁㅓㄱㄱㅗ_',
#   'ㄷㅟ_ㄹㅗ_',
#   'ㄷㅜ_ㅂㅓㄴ',
#   'ㅁㅓㄱㄱㅗ_',
#   'ㄴㅓ_ㄷㅗ_',
#   'ㄴㅐ_ㄲㅓ_',
#   'ㅁㅓㄱㄱㅗ_',
#   'ㅇㅝㄴㄹㅐ_',
#   'ㄱㅗ_ㅎㅑㅇㅇㅔ_ㅅㅓㄴ',
#   'ㅇㅏㄴㄱㅡ_ㄹㅓ_ㄴㅑ_'],
#  ['ㄱㅕㄹㅇㅕ_ㄷㅙㅆㅈㅣ_ㅁㅏㄴ',
#   'ㄱㅡ_ㄴㅑㅇ',
#   'ㅅㅏ_ㄴㅡㄴ',
#   'ㅅㅓㅇㅇㅣㄴㄷㅡㄹㄱㅘ_',
#   'ㄱㅕㄹㅇㅕ_ㄷㅙㅆㅈㅣ_ㅁㅏㄴ',
#   'ㅊㅜㅇㅈㅗㄱㅅㅣ_ㅋㅣ_ㄹㅕ_',
#   'ㄴㅗ_ㄹㅕㄱㅎㅏ_ㄴㅡㄴ',
#   'ㅁㅣ_ㅅㅓㅇㄴㅕㄴㄷㅡㄹㅇㅢ_',
#   'ㅇㅣ_ㅇㅑ_ㄱㅣ_'],
#  ['ㅅㅟㅂㄱㅔ_ㅁㅏㄹㅎㅐ_ㅅㅓ_', 'ㅇㅕㅇㅎㅑㅇㄹㅕㄱ', 'ㅇㅓㅄㄴㅡㄴ', 'ㅉㅓ_ㄹㅣ_ㅇㅐ_ㄷㅡㄹ', 'ㅁㅏㄹㅎㅏ_ㄴㅡㄴㄱㅓ_ㅇㅣㅁ'],
#  ['ㅈㅏㄴㅈㅏㄴㅎㅏ_ㅁㅕㄴㅅㅓ_',
#   'ㅁㅏㄹㅎㅏ_ㄱㅗ_ㅈㅏ_',
#   'ㅎㅏ_ㄴㅡㄴ',
#   'ㅂㅏ_ㄱㅏ_',
#   'ㄸㅜ_ㄹㅕㅆㅎㅏ_ㄱㅔ_',
#   'ㅂㅗ_ㅇㅣ_ㄴㅡㄴ',
#   'ㅈㅗㅎㅇㅡㄴ',
#   'ㅇㅕㅇㅎㅘ_ㄴㅔ_ㅇㅛ_',
#   'ㅊㅓ_ㅇㅡㅁㅇㅔ_',
#   'ㄹㅗ_ㅁㅐㄴㅅㅡ_',
#   'ㅇㅕㅇㅎㅘㄴㅈㅜㄹ',
#   'ㅇㅏㄹㅇㅏㅆㄴㅡㄴㄷㅔ_',
#   'ㄱㅏ_ㅈㅗㄱㅇㅕㅇㅎㅘ_ㅇㅣㅂㄴㅣ_ㄷㅏ_',
#   'ㅂㅗ_ㅅㅔ_ㅇㅛ_'],
#  ['ㅊㅗ_ㅂㅏㄴㅇㅔ_',
#   'ㅅㅡ_ㄹㅣㄹㄱㅏㅁㄷㅗ_',
#   'ㅈㅜㅇㄱㅏㄴㅇㅔ_',
#   'ㄱㅘ_ㄱㅓ_ㅇㅘ_',
#   'ㅎㅕㄴㅈㅐ_ㄱㅏ_',
#   'ㅂㅏ_ㄲㅟ_ㄴㅡㄴㅇㅕㄴㅊㅜㄹㄱㅡ_ㄹㅣ_ㄱㅗ_',
#   'ㅇㅞㄴㅈㅣ_ㅁㅗ_ㄹㅡ_ㄱㅔ_',
#   'ㅁㅏ_ㅈㅣ_ㅁㅏㄱㅆㅣㄴㅇㅡㄴ',
#   'ㄱㅗㅇㅎㅓ_ㅎㅏ_ㅁㅕㄴㅅㅓ_ㄷㅗ_',
#   'ㅇㅏㄴㅌㅏ_ㄲㅏㅂㄱㅗ_',
#   'ㄱㅏㅁㄷㅗㅇㅇㅡㄹ',
#   'ㅈㅜㄴㄷㅏ_'],
#  ['ㄷㅓ_ㅂㅣㅇㅍㅏㄴ', 'ㄷㅏ_ㅅㅣ_', 'ㅂㅗ_ㄱㅗ_', 'ㅅㅣㅍㄴㅔ_ㅇㅛ_', 'ㅊㅜ_ㅇㅓㄱㅇㅢ_', 'ㄷㅡ_ㄹㅏ_ㅁㅏ_'],
#  ['ㅂㅡㄹㅂㅏㄱ',
#   'ㅈㅓㄴㅎㅜ_ㅂㅏㅇ',
#   'ㅅㅓㄹㅊㅣ_ㅎㅐㅆㄴㅡㄴㄷㅔ_',
#   'ㅍㅡㄹㄹㅔ_ㅇㅣ_ㅎㅐ_ㅂㅗ_ㅁㅕㄴ',
#   'ㅈㅓㄴㅂㅏㅇㅂㅏㄲㅇㅔ_',
#   'ㅇㅏㄴㄴㅏ_ㅇㅗ_ㄴㅡㄴㄷㅔ_',
#   'ㅁㅜㄹㅎㅐ_ㅇㅑ_',
#   'ㅈㅓㄴㅎㅜ_ㅂㅏㅇ',
#   'ㄹㅔ_ㅋㅗ_ㄷㅡ_ㄷㅚㄴㄱㅓㅅ',
#   'ㅂㅗㄹㅅㅜ_ㅇㅣㅆㄴㅑ_'],
#  ['ㅎㅏ_ㄷㅡ_ㅇㅢ_',
#   'ㄱㅛ_ㄱㅘ_ㅅㅓ_',
#   'ㅅㅣㅂㅅㅜ_ㄴㅕㄴㅇㅣ_ㄴㅏ_',
#   'ㅎㅜ_ㅇㅔ_',
#   'ㄴㅏ_ㅇㅗㄴ',
#   'ㅍㅡ_ㄹㅗ_ㅁㅔ_ㅌㅔ_ㅇㅜ_ㅅㅡ_ㄱㅏ_',
#   'ㅊㅏ_ㅁㅏ_',
#   'ㅂㅓㅁㅈㅓㅂㅎㅏㄹ',
#   'ㅇㅓㅄㄴㅡㄴ',
#   'ㅇㅘㄴㅅㅓㅇㄷㅗ_'],
#  ['ㅋㅣㄹㄹㅣㅇㅌㅏ_ㅇㅣㅁㅇㅛㅇ',
#   'ㅇㅗ_ㄹㅏㄱㅇㅕㅇㅎㅘ_ㅇㅣㄴㅈㅜㄹ',
#   'ㅇㅏㄹㅇㅏㅆㄴㅡㄴㄷㅔ_',
#   'ㅇㅣ_ㄱㅓㄴ',
#   'ㅈㅓㅇㅁㅏㄹ',
#   'ㅈㅏㄹㅁㅏㄴㄷㅡㄴ',
#   'ㅇㅕㅇㅎㅘ_ㄷㅏ_'],
#  ['ㄹㅗ_ㄱㅡ_ㅇㅣㄴㅎㅐ_ㅅㅓ_',
#   'ㅂㅔ_ㅅㅡ_ㅌㅡ_ㄷㅏㄹㄱㅔ_',
#   'ㅁㅏㄴㄷㅡ_ㄴㅔ_ㅇㅛ_',
#   'ㄱㅣ_ㄷㅐ_ㅇㅓㅄㅇㅣ_ㅂㅘㅆㄴㅡㄴㄷㅔ_',
#   'ㅈㅣㄴㅉㅏ_',
#   'ㅎㅐ_ㄹㅣ_ㅅㅡㄴㅍㅗ_ㄷㅡ_',
#   'ㄴㅓ_ㅁㅜ_',
#   'ㅁㅓㅅㅈㅣ_ㄱㅗ_',
#   'ㅇㅕㄴㄱㅣ_ㅍㅏ_',
#   'ㅂㅐ_ㅇㅜ_ㄷㅡㄹㅇㅔ_',
#   'ㄴㅐ_ㅇㅛㅇㄲㅏ_ㅈㅣ_',
#   'ㅅㅣㄴㅅㅓㄴㅎㅐ_ㅅㅓ_',
#   'ㄱㅏㄴㅁㅏㄴㅇㅔ_',
#   'ㅈㅐ_ㅁㅣ_ㅇㅣㅆㄱㅔ_',
#   'ㅂㅘㅆㅇㅓ_ㅇㅛ_'],
#  ['ㅇㅕ_ㅅㅣㄴㅇㅢ_',
#   'ㄷㅟ_ㄲㅜㅁㅊㅣ_ㅂㅗ_ㄱㅗ_',
#   'ㄲㅏㅁㅉㅏㄱ',
#   'ㄴㅗㄹㄹㅏㅆㄷㅏ_',
#   '3ㄱㅐ_ㄴㅡㄴ',
#   'ㅂㅕㄹㄹㅗ_ㅇㅕㅆㅈㅣ_ㅁㅏㄴ',
#   '2ㄱㅐ_ㅁㅏㄴ',
#   'ㅍㅕㅇㅈㅓㅁㅈㅝ_ㅅㅓ_',
#   '9ㅈㅓㅁ'],
#  ['ㄱㅜㄱㄱㅏ_ㅇㅛ_ㅇㅝㄴㅇㅣㄴㄱㅓ_',
#   'ㅇㅏㄹㄱㅗ_',
#   'ㄷㅗㄹㅇㅏ_ㅇㅗ_ㄴㅡㄴ',
#   'ㄷㅚㄴㅈㅏㅇㄴㅕ_',
#   'ㅈㅓㄴㅂㅜ_ㅇㅣㄴㄱㅘ_',
#   'ㅇㅑㅇㄷㅏ_ㄹㅣ_',
#   'ㅇㅕ_ㅈㅜ_ㅁㅏㄴ',
#   'ㅇㅏ_ㄴㅣ_ㅁㅕㄴ',
#   'ㅈㅓㅇㅁㅏㄹ',
#   'ㅈㅐ_ㅁㅣㅅㄷㅏ_'],
#  ['ㅅㅏㄴㅂㅜㄹㅇㅝㄴㅇㅣㄴㅇㅣ_',
#   'ㅈㅓㄴㄱㅣ_ㅅㅣ_ㅅㅓㄹㅇㅣㄴㄷㅔ_',
#   'ㄱㅡ_ㅇㅔ_ㄷㅐ_ㅎㅏㄴ',
#   'ㅂㅗ_ㄷㅗ_ㄴㅡㄴ',
#   'ㅇㅏㄶㄴㅑ_',
#   'ㅅㅓㅇㅂㅗㄱㅇㅕㄱ',
#   'ㅇㅣㄴㅇㅘㅇㅅㅏㄴ',
#   'ㅈㅓㄴㄱㅣ_ㅊㅗ_',
#   'ㄱㅚ_ㅅㅏㄴ',
#   'ㄱㅗㅇㅈㅏㅇ',
#   'ㅂㅕㄴㅇㅏㅂㄱㅣ_',
#   'ㄱㅗ_ㅅㅓㅇ',
#   'ㅂㅕㄴㅇㅏㅂㄱㅣ_',
#   'ㅎㅏㄴㅈㅓㄴ',
#   'ㅈㅓㄱㅈㅏ_',
#   'ㅅㅣ_ㅅㅓㄹㄱㅛ_ㅊㅔ_',
#   'ㅁㅗㅅㅎㅏㄴㄱㅓ_',
#   'ㄱㅡ_ㄹㅓㄴ',
#   'ㅂㅗ_ㄷㅗ_ㄴㅏ_',
#   'ㅂㅣ_ㅍㅏㄴㅇㅡㄹ',
#   'ㅎㅏ_ㄴㅡㄴ',
#   'ㅇㅓㄴㄹㅗㄴㅅㅏ_',
#   'ㅎㅏ_ㄴㅏ_ㄷㅗ_',
#   'ㅇㅓㅄㄷㅏ_'],
#  ['ㅈㅓ_ㅁㅏ_ㄷㅏ_', 'ㅈㅚ_ㅊㅐㄱㄱㅏㅁㅇㅡㄹ', 'ㅇㅣㅈㅇㅡ_ㄹㅕ_', 'ㅂㅏㄹㅂㅓ_ㄷㅜㅇ', 'ㅊㅓ_ㅂㅗㄴㄷㅏ_'],
#  ['ㄷㅗㅇㅅㅣ_ㄱㅐ_ㅂㅗㅇㄱㅘㄴㅇㅔ_ㅅㅓ_',
#   'ㅁㅓㄴㅈㅓ_',
#   'ㅂㅗ_ㄱㅗ_',
#   'ㄷㅜ_ㅂㅓㄴㅉㅐ_ㅇㅕㅇㅎㅘ_',
#   'ㅂㅗ_ㄱㅗ_',
#   'ㅇㅣ_ㄱㅓ_',
#   'ㄷㅏ_ㅅㅣ_',
#   'ㅂㅗ_ㄱㅗ_',
#   'ㄴㅏ_ㅇㅗㄴ',
#   'ㄱㅣ_ㅇㅓㄱㅇㅣ_',
#   'ㄴㅏ_ㄴㅔ_'],
#  ['ㅈㅓ_ㄹㅓㄴㄱㅔ_', 'ㅈㅣㄴㅉㅏ_', 'ㅈㅓㄱㅍㅖ_ㅈㅣ_', 'ㅈㅣㄴㅉㅏ_', 'ㅈㅓ_ㄱㅓ_', 'ㄱㅜ_ㅅㅗㄱㅅㅣ_ㅋㅕ_ㄹㅏ_'],
#  ['ㅈㅗ_ㅅㅓㄴㅇㅣㄹㅂㅗ_ㄱㅏ_',
#   'ㅌㅏㄴㅎㅐㄱ',
#   'ㅂㅏㅇㅎㅑㅇ',
#   'ㅈㅏㅂㅇㅡ_ㅁㅕㄴ',
#   'ㅁㅜㄴㅈㅐ_ㅇㅣㄴㅇㅣ_',
#   'ㅌㅏㄴㅎㅐㄱ',
#   'ㄷㅚ_ㄴㅑ_',
#   'ㅈㅘ_ㅍㅏ_ㄷㅐ_ㅌㅗㅇㄹㅕㅇㅇㅡㄴ',
#   'ㅈㅘ_ㅍㅏ_',
#   'ㅇㅓㄴㄹㅗㄴㅅㅏ_ㅇㅔ_ㅅㅓ_',
#   'ㅌㅏㄴㅎㅐㄱ',
#   'ㅂㅏㅇㅎㅑㅇ',
#   'ㅈㅏㅂㅇㅏ_ㄴㅑ_',
#   'ㅌㅏㄴㅎㅐㄱ',
#   'ㄷㅚ_ㄴㅡㄴㄱㅓ_ㄷㅏ_',
#   'ㅇㅜ_ㅍㅏ_',
#   'ㄷㅐ_ㅌㅗㅇㄹㅕㅇㅇㅡㄴ',
#   'ㅇㅜ_ㅍㅏ_',
#   'ㅇㅓㄴㄹㅗㄴㅅㅏ_ㅇㅔ_ㅅㅓ_',
#   'ㅌㅏㄴㅎㅐㄱㅅㅣ_ㅋㅣ_ㄴㅡㄴㄱㅓ_ㄱㅗ_',
#   'ㄴㅗ_ㅁㅜ_ㅎㅕㄴㅇㅣ_',
#   'ㄱㅡ_ㄹㅐㅆㄱㅗ_',
#   'ㅂㅏㄱㄱㅡㄴㅎㅖ_ㄱㅏ_',
#   'ㄱㅡ_ㄹㅐㅆㄷㅏ_'],
#  ['ㅇㅓ_ㄹㅣㄹㄸㅐ_',
#   'ㅈㅐ_ㅁㅣㅆㄱㅔ_',
#   'ㅇㅕㅇㅎㅘ_ㅇㅖ_ㅇㅛ_',
#   'ㅈㅔ_ㅁㅗㄱㅇㅣ_',
#   'ㅅㅐㅇㄱㅏㄱㅇㅏㄴㄴㅏ_ㅅㅓ_',
#   'ㅎㅣㅁㄷㅡㄹㄱㅔ_',
#   'ㅊㅏㅈㅇㅏㅆㄷㅏ_'],
#  ['ㄷㅏㅇㅅㅣ_',
#   'ㅈㅔ_ㅁㅗㄱㅇㅣ_',
#   'ㅇㅔ_ㅅㅡ_ㅋㅔ_ㅇㅣ_ㅍㅡ_',
#   'ㄱㅓㄹㅇㅣ_ㄹㅏ_ㄱㅗ_ㄷㅗ_',
#   'ㅎㅐㅆㄷㅓㄴㄱㅓㅅ',
#   'ㄱㅏㅌㄷㅓㄴㄷㅔ_'],
#  ['ㅋㅣ_ㅇㅑ_',
#   'ㅈㅣㄴㅉㅏ_',
#   'ㅁㅓ_ㄹㅣ_ㅈㅗㅎㅇㅡㄴ',
#   'ㅅㅏ_ㄹㅏㅁㅇㅡㄴ',
#   'ㄱㅡㄹㅁㅏㄴ',
#   'ㅇㅣㄺㅇㅓ_ㅂㅘ_ㄷㅗ_',
#   'ㅌㅣ_ㄱㅏ_'],
#  ['ㅈㅗㅈㄴㅏ_',
#   'ㅊㅣ_ㅁㅣㄹㅎㅏㄴ',
#   'ㄱㅖ_ㄹㅑㄱㅇㅣ_ㅇㅓㅆㄷㅓㄴㄱㅔ_',
#   'ㅁㅝ_ㄴㅑ_ㅁㅕㄴ',
#   'ㅂㅏ_ㄹㅗ_',
#   'ㅋㅗㄹㄹㅏ_ㄹㅡㄹ',
#   'ㅍㅔㅂㅅㅣ_ㄹㅗ_',
#   'ㅎㅐㅆㄷㅏ_ㄴㅡㄴ',
#   'ㅈㅓㅁㅇㅣ_ㄷㅏ_',
#   'ㅊㅓ_ㅇㅡㅁㅂㅜ_ㅌㅓ_',
#   'ㅋㅗㄹㄹㅏ_ㄴㅡㄴ',
#   'ㅂㅓ_ㄹㅣㄹ',
#   'ㅋㅗㄹㄹㅏ_ㅇㅕㅆㄷㅏ_',
#   'ㄹㅏ_ㄱㅗ_',
#   'ㅇㅏㅁㅅㅣ_ㅎㅏ_ㄴㅡㄴㄱㅓ_ㅈㅣ_'],
#  ['ㅇㅘㄴㅈㅓㄴ',
#   'ㅈㅐㅁㅇㅣㅅㅇㅓㅅㅇㅓ_ㅇㅛ_',
#   'ㅈㅓㅇㅁㅏㄹㅎㅕㄴㅈㅐ_ㅇㅢ_',
#   'ㄴㅏ_ㄹㅡㄹ',
#   'ㅂㅗ_ㄴㅡㄴ',
#   'ㄷㅡㅅㅎㅏㄴㄴㅡ_ㄲㅣㅁ'],
#  ['ㅇㅖ_ㅈㅓㄴ',
#   'ㅇㅕㅇㅎㅘ_ㄱㅘㄴㅇㅔ_ㅅㅓ_',
#   'ㅂㅗㄴㄱㅣ_ㅇㅓㄱㅇㅣ_',
#   'ㅁㅏ_ㅈㅣ_ㅁㅏㄱ',
#   'ㅂㅏㄴㅈㅓㄴㄱㅏㅌㅇㅡㄴㄱㅓ_',
#   'ㄴㅏ_ㄹㅡㅁ',
#   'ㅈㅐ_ㅁㅣ_ㄴㅏ_ㄱㅔ_',
#   'ㅂㅗㄴㄱㅣ_ㅇㅓㄱ'],
#  ['ㄴㅓ_ㅁㅜ_',
#   'ㄱㅟ_ㅇㅕ_ㅇㅝ_ㅇㅕ_',
#   'ㅊㅗ_ㄹㅗㄱㅅㅣㄴ',
#   'ㄱㅏ_ㅇㅕㅇㅇㅣ_ㄹㅏ_ㄴㅡㄴ',
#   'ㅋㅐ_ㄹㅣㄱㅌㅓ_ㄱㅏ_',
#   'ㅎㅕㄴㄷㅐ_ㅇㅣㄴㄷㅡㄹㅇㅢ_',
#   'ㅁㅗ_ㅅㅡㅂㅇㅡㄹ',
#   'ㅈㅓㅇㅁㅏㄹㅈㅏㄹ',
#   'ㅂㅗ_ㅇㅕ_ㅈㅜ_ㄱㅗ_ㅇㅣㅅㄴㅔ_ㅇㅛ_'],
#  ['ㅇㅖ_ㅃㅡ_ㄱㅗ_',
#   'ㅈㅏㄹㅅㅐㅇㄱㅣㄴ',
#   'ㅇㅐ_ㄷㅡㄹㅇㅣ_',
#   'ㅇㅣㄴㅅㅓㅇㅈㅗㅎㄱㅗ_',
#   'ㄱㅗㅇㅂㅜ_ㅈㅏㄹㅎㅏ_ㄱㅗ_',
#   'ㅊㅏㄱㅎㅏ_ㄷㅏ_'],
#  ['ㄷㅜ_ㅂㅓㄴㅂㅘ_ㄷㅗ_',
#   'ㅅㅔ_ㅂㅓㄴㅂㅘ_ㄷㅗ_',
#   'ㅁㅕㅊㅂㅓㄴㅇㅡㄹㅂㅘ_ㄷㅗ_',
#   'ㄱㅏㅁㄷㅗㅇㅈㅓㄱㅇㅣ_ㄷㅏ_',
#   'ㅅㅐㅇㅇㅔ_',
#   'ㅊㅚ_ㄱㅗ_ㅇㅢ_ㅇㅕㅇㅎㅘ_'],
#  ['ㄱㅐ_ㅂㅗㅇㅎㅏㄴㅈㅣ_',
#   '12ㄴㅕㄴㅁㅏㄴㅇㅔ_',
#   'ㅇㅕㅇㅎㅘ_ㄹㅡㄹ',
#   'ㅊㅏㅈㅇㅏ_',
#   'ㅂㅗ_ㄷㅏ_ㄴㅣ_',
#   'ㅁㅔㄴㄷㅔ_ㅅㅡ_',
#   'ㄱㅗ_ㅁㅏㅂㄴㅔ_',
#   'ㅇㅗ_ㄹㅐㄴㅁㅏㄴㅇㅔ_',
#   'ㅂㅗ_ㄴㅡㄴ',
#   'ㄴㅏㅁㅈㅏ_ㄷㅡㄹ',
#   'ㅇㅕㅇㅎㅘ_',
#   'ㅂㅐ_ㄱㅕㅇㅇㅡㅁㅇㅏㄱㅁㅏ_ㅈㅓ_',
#   'ㄲㅡㅌㄴㅐ_ㅈㅜㅂㄴㅣ_ㄷㅏ_'],
#  ['ㅊㅜ_ㅇㅓㄱㅇㅢ_',
#   'ㅇㅕㅇㅎㅘ_',
#   'ㅇㅣ_ㄱㅓ_',
#   'ㅇㅏㄴㄴㅏ_ㅇㅗ_ㄴㅏ_ㅇㅛ_ㅈㅡㅁ',
#   'ㄱㅣ_ㅅㅜㄹㄹㅕㄱㅇㅡ_ㄹㅗ_',
#   'ㅁㅏㄴㄷㅡㄹㅁㅕㄴ',
#   'ㄷㅐ_ㅂㅏㄱㅇㅣㄹㄷㅡㅅㅎㅏㄴㄷㅔ_'],
#  ['ㅂㅗㄹㅅㅜ_ㄹㅗㄱ',
#   'ㄱㅗㅂㅆㅣㅂㅇㅓ_ㅂㅗㄹㅁㅏㄴㅎㅏㄴ',
#   'ㅇㅕㅇㅎㅘ_',
#   'ㅂㅏㅇㅎㅘㅇㅎㅏ_ㄴㅡㄴ',
#   'ㅇㅕㅇㅎㅗㄴㅇㅣ_',
#   'ㅈㅓㅇㅊㅏㄱㅎㅏㄹ',
#   'ㄱㅗㅅㅇㅡㄴ'],
#  ['ㅅㅗㄹㅈㅣㄱㅎㅣ_',
#   '1ㅈㅓㅁ',
#   'ㅈㅜ_ㄴㅡㄴ',
#   'ㅇㅐ_ㄷㅡㄹㅇㅡㄴ',
#   'ㅇㅕㅇㅎㅘ_ㄹㅡㄹ',
#   'ㅈㅔ_ㄷㅐ_ㄹㅗ_',
#   'ㄱㅏㅌㅈㅣ_',
#   'ㅇㅏㄶㄷㅏ_ㄱㅗ_',
#   'ㅅㅐㅇㄱㅏㄱㅎㅏㄴㄷㅏ_',
#   'ㅅㅐㄱㅇㅏㄴㄱㅕㅇㄲㅣ_ㄱㅗ_',
#   'ㅂㅗㄴㄷㅡㅅ'],
#  ['ㅇㅏㄹㄹㅐㅇㄷㅡㄹㄹㅗㅇ',
#   'ㅎㅏ_ㄴㅏ_ㄹㅗ_ㄷㅗ_',
#   'ㅇㅣ_ㅁㅣ_',
#   'ㅁㅕㅇㅈㅏㄱㅈㅓㅇㅁㅏㄹ',
#   'ㅂㅜ_ㄹㅓ_ㅇㅜㄴㅇㅚ_ㅁㅗ_ㄱㅡ_ㄹㅣ_ㄱㅗ_',
#   'ㅍㅕㅇㅇㅗㄴㅎㅏ_ㄱㅗ_',
#   'ㅇㅏ_ㄹㅡㅁㄷㅏ_ㅇㅜㄴ',
#   'ㅌㅏ_ㄴㅡㄴㄷㅡㅅㅎㅏㄴ',
#   'ㅇㅖㅅㄴㅏㄹ',
#   'ㅇㅣ_ㅌㅏㄹㄹㅣ_ㅇㅏ_ㄹㅡㄹ',
#   'ㅂㅗ_ㄴㅡㄴㅁㅏㅅㅇㅣ_',
#   'ㅁㅓㅅㅈㅣ_ㄴㅔ_ㅇㅛ_'],
#  ['ㅇㅕ_ㄱㅗ_ㄱㅚ_ㄷㅏㅁ',
#   'ㅅㅣ_ㄹㅣ_ㅈㅡ_',
#   'ㅈㅜㅇㅇㅔ_',
#   'ㄱㅏ_ㅈㅏㅇ',
#   'ㅊㅚ_ㄱㅗ_ㅇㅢ_',
#   'ㅈㅏㄱㅍㅜㅁㄱㅣㅁㅇㅗㄱㅂㅣㄴㄸㅐ_ㅁㅜㄴㅇㅔ_',
#   'ㄷㅓ_ㅇㅜㄱ',
#   'ㅂㅣㅊㄴㅏ_ㄴㅡㄴ',
#   'ㅇㅕㅇㅎㅘ_'],
#  ['ㅅㅜㅁㅇㅓ_ㅇㅣㅆㄴㅡㄴ', 'ㅅㅜ_ㅈㅏㄱ', 'ㅇㅕㄴㄱㅡㄱㅇㅢ_', 'ㄱㅏㅁㄷㅗㅇㅇㅣ_', 'ㄱㅡ_ㄷㅐ_ㄹㅗ_'],
#  ['ㄹㅔ_ㄷㅡ_ㅍㅗ_ㄷㅡ_ㅇㅢ_',
#   'ㅍㅏㄹㄸㅜㄱㅇㅢ_',
#   'ㄷㅏ_ㅇㅣ_ㅇㅏ_ㅁㅗㄴㄷㅡ_ㅈㅣㄴㅈㅓㅇㅎㅏㄴ',
#   'ㅅㅏ_ㄹㅏㅇㅇㅣ_ㄹㅏ_ㄱㅗ_',
#   'ㅅㅐㅇㄱㅏㄱㅎㅏㅂㄴㅣ_ㄷㅏ_'],
#  ['ㅇㅣ_ㄹㅓㄴㅇㅕㅇㅎㅘ_',
#   'ㅁㅏㄴㄷㅡㄹㅇㅓ_ㅈㅜ_ㅅㅕ_ㅅㅓ_',
#   'ㄱㅏㅁㅅㅏ_ㅎㅐ_ㅇㅛ_ㄱㅏㅁㄷㅗㄱㄴㅣㅁㅇㅔ_ㄱㅔ_',
#   'ㅈㅣ_ㅈㅣ_',
#   'ㅂㅗ_ㄴㅐㅂㄴㅣ_ㄷㅏ_'],
#  ['ㅂㅘㅆㅇㅡ_ㅁㅕㄴ',
#   'ㅁㅏㄹㅇㅡㄹ',
#   'ㅎㅏ_ㅈㅣ_ㅁㅏ_ㄹㅓ_',
#   'ㄱㅓㅌㅇㅣ_',
#   'ㄱㅜ_ㄹㅕ_ㅂㅗ_ㅇㅣㄴㄷㅏ_ㄱㅗ_',
#   'ㄴㅐ_ㅇㅛㅇㄲㅏ_ㅈㅣ_',
#   'ㄱㅜ_ㄹㅣ_ㄷㅏ_',
#   'ㅅㅐㅇㄱㅏㄱㅊㅣ_ㅁㅏ_ㄹㅏ_'],
#  ['ㅇㅣ_ㄱㅓ_ㄹㅏㅇ',
#   'ㄸㅗㄱㄱㅏㅌㅇㅡㄴ',
#   'ㅂㅏㄹㅇㅓㄴㅇㅡ_ㄹㅗ_',
#   'ㅎㅗㅇㅈㅜㄴㅍㅛ_ㄱㅏ_',
#   'ㅎㅐㅆㅇㅡ_ㅁㅕㄴ',
#   'ㄴㅠ_ㅅㅡ_',
#   'ㄴㅏ_ㅇㅗ_ㄱㅗ_',
#   'ㄴㅏㄴㄹㅣ_',
#   'ㄴㅏㅆㅇㅡㅁ'],
#  ['42ㅅㅔ_',
#   'ㅎㅕㄴㅇㅕㄱ',
#   'ㅈㅜㅇㅎㅏㄱㅅㅐㅇㅇㅣㄴㄷㅔ_',
#   'ㅇㅛ_ㅈㅡㅁ',
#   'ㄷㅗㅇㄱㅣ_ㄷㅡㄹㅇㅣ_ㄹㅏㅇ',
#   'ㅊㅓㅇㄱㅜㄱㅈㅏㅇㅈㅣㅂㄱㅏ_ㄴㅡㄴㄱㅔ_',
#   'ㅇㅠ_ㅎㅐㅇㅇㅣㅁ'],
#  ['ㄱㅓ_ㄷㅐ_',
#   'ㄹㅗ_ㅂㅗㅅㅇㅢ_',
#   'ㅅㅣ_ㅈㅏㄱ',
#   'ㅇㅏ_ㅈㅣㄱㄷㅗ_',
#   'ㄱㅟ_ㅇㅔ_',
#   'ㅅㅐㅇㅅㅐㅇㅎㅏ_ㄷㅏ_',
#   'ㄱㅣ_ㅇㅜㄴㅅㅔㄴ'],
#  ['ㅇㅔ_ㄹㅣㄱㅇㅢ_', 'ㅅㅏㄹㅇㅏ_', 'ㅇㅣㅆㄴㅡㄴ', 'ㅇㅕㄴㄱㅣ_', 'ㅈㅜㄱㅇㅕ_ㅈㅜㅁ'],
#  ['ㅋㅓㄴㅌㅔㄴㅊㅡ_',
#   'ㅎㅓ_ㅈㅓㅂㅎㅏ_ㅁㅕㄴ',
#   'ㅎㅐ_ㅂㅘㅆㅈㅏ_',
#   'ㄱㅜ_ㄷㅗㄱㅈㅏ_ㄷㅗ_',
#   'ㅇㅏㄴㄴㅡㄹㄱㅗ_',
#   'ㅈㅗ_ㅎㅚ_ㅅㅜ_ㄷㅗ_',
#   'ㄴㅡㄹㅇㅓ_ㄴㅏㄴㄷㅏ_',
#   'ㅋㅓㄴㅌㅔㄴㅊㅡ_',
#   'ㅈㅗㅎㅇㅡㄴ',
#   'ㅇㅐ_ㄷㅡㄹㅎㅏㄴㅌㅔ_ㄴㅏ_',
#   'ㅌㅗㅇㅎㅏ_ㄴㅡㄴ',
#   'ㅇㅣ_ㅇㅑ_ㄱㅣ_ㅈㅣ_'],
#  ['ㅅㅣㄴㅅㅓㄴㅎㅏ_ㄱㅗ_',
#   'ㅅㅐ_ㄹㅗㅂㄷㅏ_ㅂㅐ_ㅇㅜ_ㄷㅡㄹㅇㅢ_',
#   'ㅇㅕㄴㄱㅣ_ㄹㅕㄱㅇㅣ_',
#   'ㄴㅓ_ㅁㅜ_',
#   'ㅈㅗㅎㅇㅡㄴ',
#   'ㄱㅏㅌㅇㅏ_ㅇㅛ_'],
#  ['ㅇㅗ_ㄹㅐ_ㅈㅓㄴ',
#   'ㅅㅏ_ㅊㅜㄴㄱㅣ_ㅇㅔ_',
#   'ㅈㅓㅂㅇㅓ_ㄷㅡㄹ',
#   'ㅁㅜ_ㄹㅕㅂ',
#   'ㅂㅗ_ㅇㅏㅆㄷㅓㄴ',
#   'ㅇㅣㅈㅎㅕ_ㅈㅣㄹ',
#   'ㅇㅓㅄㄴㅡㄴ',
#   'ㅇㅕㅇㅎㅘ_'],
#  ['ㄴㅐ_ㅇㅣㄴㅅㅐㅇ',
#   'ㅊㅚ_ㄱㅗ_ㅇㅢ_',
#   'ㄷㅡ_ㄹㅏ_ㅁㅏ_',
#   'ㅈㅣㄴㅉㅏ_',
#   'ㄷㅏㄹㄷㅏㄹㅎㅐ_',
#   'ㅁㅣ_ㅊㅣ_ㄱㅔㅅㄴㅡㄴ',
#   'ㅂㅗ_ㄱㅗ_',
#   'ㅂㅘ_ㄷㅗ_',
#   'ㅈㅓㄹㄷㅐ_',
#   'ㅈㅣㄹㄹㅣ_ㅈㅣ_',
#   'ㅇㅏㄶㄴㅡㄴ',
#   'ㄱㅡ_ㄹㅓㄴㄷㅡ_ㄹㅏ_ㅁㅏ_'],
#  ['ㅈㅜㅇㅌㅐ_ㅇㅣㄴ', 'ㅇㅕ_ㅈㅏ_', 'ㅈㅣ_ㄱㅡㅁㅇㅡㄴ', 'ㅇㅜ_ㅇㅖ_', 'ㄷㅙㅆㄴㅗ_'],
#  ['ㅁㅗ_ㄷㅡㄴ',
#   'ㅋㅐ_ㄹㅣㄱㅌㅓ_ㄱㅏ_',
#   'ㅅㅏㄹㅇㅏ_ㅇㅣㅆㄱㅗ_',
#   'ㄲㅡㅌㅇㅡ_ㄹㅗ_',
#   'ㅎㅑㅇㅎㅐ_ㄱㅏㄹㅅㅜ_ㄹㅗㄱ',
#   'ㅈㅐ_ㅁㅣㅆㅇㅓ_',
#   'ㅈㅣㄴㄷㅏ_',
#   'ㅈㅣㄴㅉㅏ_',
#   'ㅈㅗㅎㅇㅏ_',
#   'ㅇㅕㅇㅎㅘ_'],
#  ['ㅈㅣ_ㄱㅡㅁ',
#   'ㅂㅗ_ㅇㅏ_ㄷㅗ_',
#   'ㅇㅓ_ㅅㅐㄱㅎㅏ_ㅈㅣ_',
#   'ㅇㅏㄶㄴㅡㄴ',
#   'ㄷㅗ_ㅅㅜㄹㅇㅢ_',
#   'ㅁㅏ_ㄹㅕㄱ',
#   'ㅎㅐ_ㄹㅣ_ㅍㅗ_ㅌㅓ_',
#   'ㅇㅣ_ㅅㅏㅇ'],
#  ['ㅎㅏ_ㄴㅏ_ㅇㅢ_',
#   'ㅇㅓㅄㅇㅣ_',
#   'ㅇㅣ_ㄹㅓㄴ',
#   'ㅇㅕㅇㅎㅘ_ㄹㅡㄹ',
#   'ㅁㅏㄴㄷㅡㄹ',
#   'ㅇㅣㅆㄴㅡㄴ',
#   'ㄱㅓㅅㅇㅣㄴㄱㅏ_'],
#  ['ㅅㅗㅇㄱㅛ_ㅅㅜ_ㄴㅣㅁ',
#   'ㅈㅚ_ㅅㅗㅇㅎㅏㅂㄴㅣ_ㄷㅏ_',
#   'ㅁㅏ_ㄹㅣ_',
#   'ㅇㅝㄴㅅㅜㅇㅇㅣ_',
#   'ㅇㅒ_ㄱㅣ_',
#   'ㅇㅣㄴㅅㅏㅇㄱㅣㅍㄱㅔ_',
#   'ㄷㅡㄹㅇㅓㅆㅅㅡㅂㄴㅣ_ㄷㅏ_',
#   'ㅁㅜ_ㅈㅣ_ㅎㅏ_ㄱㅗ_',
#   'ㅇㅑ_ㅁㅏㄴㅈㅓㄱㅇㅣㄴ',
#   'ㄴㅏ_ㄹㅏ_',
#   'ㄷㅐ_ㅎㅏㄴㅁㅣㄴㄱㅜㄱㅇㅣ_',
#   'ㅇㅏ_ㄴㅣ_ㄹㅏ_',
#   'ㅅㅗ_ㅎㅏㄴㄱㅜㄴㄱㅜㄱ'],
#  ['ㅅㅏ_ㅎㅚ_ㅈㅓㄱ',
#   'ㄷㅗ_ㅈㅓㄱㅈㅓㄱㅇㅡ_ㄹㅗㄴ',
#   'ㅇㅣ_ㅁㅣ_',
#   'ㅅㅏ_ㅎㅕㅇㅅㅓㄴㄱㅗ_ㅂㅏㄷㅇㅏㅆㅇㅓ_',
#   'ㅇㅠ_ㅇㅕㅇㅊㅓㄹㄱㅏㅇㅎㅗ_ㅅㅜㄴㅇㅣ_ㅊㅜㄴㅈㅐ_ㅂㅗ_ㄷㅏ_',
#   'ㅇㅜㄴㅈㅓㄴㅈㅏ_ㄱㅏ_ㄷㅓ_ㅈㅗㅈㄱㅏㅌㅇㅡㄴㅅㅐ_ㄲㅣ_ㄹㅗ_ㅉㅣㄱㅎㅕㅆㅇㅡㄹㄲㅓㄹ'],
#  ['ㄲㅗㄹㄹㅣ_ㄴㅡㄴ', 'ㄱㅏㄱㅈㅗㅇ', 'ㅇㅡㅇㄷㅣㅇㅇㅣ_', 'ㅅㅣㄴㄴㅏ_ㄱㅔ_', 'ㅎㅡㄴㄷㅡㄹㄱㅣ_'],
#  ['ㅂㅘㅆㅅㅡㅂㄴㅣ_ㄷㅏ_',
#   'ㅇㅣ_ㄹㅓㅎㄱㅔ_',
#   'ㅁㅜㄷㅎㅕ_ㅈㅣㄴ',
#   'ㅅㅏ_ㅅㅣㄹㄷㅡㄹㅇㅣ_',
#   'ㄷㅓ_ㅇㅜㄱ',
#   'ㄷㅡ_ㄹㅓ_ㄴㅏ_ㅇㅑ_',
#   'ㅎㅏㅂㄴㅣ_ㄷㅏ_'],
#  ['ㅇㅣ_ㄹㅓㄴ',
#   'ㅁㅕㅇㅈㅏㄱㅇㅡㄹ',
#   'ㅇㅣ_ㅈㅔ_ㅂㅘㅆㅇㅡㄹㄲㅏ_',
#   'ㅊㅓ_ㅇㅡㅁㅇㅔㄴ',
#   'ㄱㅡ_ㄴㅑㅇ',
#   'ㅌㅏㅇㅇㅞ_ㅇㅣ_ㄱㅏ_',
#   'ㅇㅣ_ㅃㅓ_ㅅㅓ_',
#   'ㅂㅘㅆㄴㅡㄴㄷㅔ_',
#   'ㅁㅗㄹㅇㅣㅂㄱㅏㅁㅇㅣ_',
#   'ㄷㅐ_ㄷㅏㄴㅎㅏ_ㄴㅔ_ㅇㅛ_'],
#  ['ㅈㅐ_ㅁㅣ_ㅆㅓㅇㅇㅛ_', 'ㅈㅣ_ㄹㅜ_ㅎㅏ_ㅈㅣ_', 'ㅇㅏㄶㄱㅗ_', 'ㄱㅖ_ㅅㅗㄱ', 'ㅇㅜㅅㅇㅓㅆㄴㅔ_ㅇㅛ_'],
#  ['ㅍㅡ_ㅅㅏ_',
#   'ㅌㅡ_ㄹㅓㅁㅍㅡ_ㄱㅏ_',
#   'ㄸㅐ_ㄲㅏ_ㅈㅣ_ㅁㅏㄴㅇㅣ_ㄹㅏ_ㄷㅗ_',
#   'ㅁㅣㄷㅇㅡㅁㅇㅣ_',
#   'ㄱㅏ_ㄴㅡㄴ',
#   'ㄱㅓㅅㅇㅡ_ㄹㅗ_',
#   'ㅂㅏ_ㄲㅝ_ㄹㅏ_ㅍㅡ_ㅅㅏ_',
#   'ㅂㅗ_ㄱㅗ_',
#   'ㄴㅐ_ㅇㅛㅇ',
#   'ㄱㅡ_ㄴㅑㅇ',
#   'ㅅㅐㅇㄲㅏ_ㄱㅔㅆㄷㅏ_'],
#  ['ㄷㅗㄱㅇㅣㄹㅈㅏㅇㄱㅛ_ㅇㅕㅍㅇㅔ_ㅅㅓ_',
#   'ㅍㅣ_ㅇㅏ_ㄴㅗ_',
#   'ㅇㅕㄴㅈㅜ_',
#   'ㅈㅓㄴㅈㅐㅇ',
#   'ㅅㅐㅇㅈㅗㄴㄱㅣ_',
#   'ㅋㅣ_ㅋㅡㄴㄴㅏㅁㅈㅏ_ㄱㅏ_',
#   'ㄱㅏ_ㅈㅏㅇ',
#   'ㄱㅣ_ㅇㅓㄱㅇㅔ_',
#   'ㄴㅏㅁㄴㅡㄴㄷㅏ_',
#   'ㅇㅣㄴㅅㅐㅇㅈㅏㄱㅍㅜㅁ'],
#  ['ㅎㅏㄱㅅㅐㅇ',
#   'ㅇㅟ_ㅎㅏ_ㄴㅡㄴㅊㅓㄱㅇㅡㄴ',
#   'ㅈㅣㄴㅉㅏ_',
#   'ㅎㅏ_ㄴㅡㄴㄷㅔ_',
#   'ㄷㅟ_ㅇㅔ_ㅅㅓ_',
#   'ㄱㅡ_ㄱㅓㄹㄹㅗ_',
#   'ㄷㅗㄴㅂㅓ_ㄴㅡㄴㄱㅓ_',
#   'ㅅㅐㅇㄱㅏㄱㅎㅏ_ㅁㅕㄴ'],
#  ['ㅇㅕㅇㅎㅘ_', 'ㄲㅡㅌㄴㅏㄴ', 'ㅁㅝㄴㄱㅏ_', 'ㄴㅏㅁㄴㅡㄴㄱㅔ_', 'ㅇㅣㅆㄷㅓㄴㄷㅔ_', 'ㅈㅗㅎㅇㅏㅆㅅㅡㅂㄴㅣ_ㄷㅏ_'],
#  ['ㅈㅗㄴㄴㅏ_',
#   'ㅇㅓ_ㅇㅣ_ㅇㅓㅄㄱㅣㄴ',
# ...
#  ['ㄱㅣㅁㄱㅘㄴㅈㅣㄴ',
#   'ㄱㅣㅁㅈㅗㅇㅍㅣㄹ',
#   'ㅇㅣ_ㅎㅚ_ㅊㅏㅇ',
#   'ㅇㅣ_ㅁㅕㅇㅂㅏㄱ',
#   'ㅇㅜ_ㅂㅕㅇㅇㅜ_',
#   'ㅎㅘㅇㄱㅛ_ㅇㅏㄴ',
#   'ㅎㅗㅇㅈㅓㅇㅇㅜㄱ',
#   'ㅈㅏ_ㅎㅏㄴㄷㅏㅇㅇㅔ_',
#   'ㅇㅒ_ㄴㅔ_ㄷㅡㄹ',
#   'ㅇㅕㅇㅇㅣㅂㅎㅏ_ㅁㅕㄴ',
#   'ㅇㅓ_ㄸㅓㄹㄲㅏ_'],
#  ['ㅁㅜ_ㅅㅡㄴ',
#   'ㅇㅒ_ㄱㅣ_ㄹㅡㄹ',
#   'ㅎㅏ_ㄹㅕ_ㄴㅡㄴㄱㅓㄴㅈㅣ_',
#   'ㅈㅗㅇㅈㅏㅂㅇㅡㄹ',
#   'ㅇㅓㅄㅈㅣ_ㅁㅏㄴ',
#   'ㅈㅏ_ㅇㅕㄴㅅㅡ_ㄹㅔ_',
#   'ㅆㅡㅂㅆㅡㄹㅎㅏ_ㄱㅔ_',
#   'ㅇㅜㅅㄱㅔ_',
#   'ㄷㅚ_ㄴㅡㄴ',
#   'ㅇㅕㅇㅎㅘ_'],
#  ['ㅇㅗ_ㄹㅐ_ㅈㅓㄴㅇㅔ_ㅂㅘㅆㄷㅓㄴㄱㅓㄴㄷㅔ_',
#   '3dㅂㅗ_ㄱㅗ_',
#   'ㅅㅐㅇㄱㅏㄱㄴㅏㅁ',
#   'ㄱㅐㄴㅈㅓㄱㅇㅡ_ㄹㅗ_',
#   'ㅅㅣ_ㄹㅣ_ㅈㅡ_ㅈㅜㅇㅇㅔ_ㅅㅓ_',
#   'ㅂㅓ_ㅈㅓㄴㅇㅣ_',
#   'ㅊㅚ_ㄱㅗ_ㄹㅏ_ㄱㅗ_ㅅㅐㅇㄱㅏㄱ',
#   'ㅌㅔㄱㅅㅏ_ㅅㅡ_',
#   'ㅅㅣ_ㄹㅣ_ㅈㅡ_ㄴㅡㄴ',
#   'ㅇㅓㄴㅈㅔ_ㄴㅏ_',
#   'ㄴㅡ_ㄲㅣ_ㅈㅣ_ㅁㅏㄴ',
#   'ㅎㅜㄹㄹㅠㅇㅎㅏㄴ',
#   'ㅅㅡ_ㅌㅗ_ㄹㅣ_ㅇㅔ_',
#   'ㅈㅓㄱㄷㅏㅇㅎㅏㄴ',
#   'ㅈㅏㄴㅇㅣㄴㅎㅏㅁㄱㅘ_',
#   'ㄱㅗㅇㅍㅗ_ㅇㅘ_',
#   'ㄱㅣㄴㅈㅏㅇㄱㅏㅁㅇㅡㄹ',
#   'ㄴㅡ_ㄲㅣㄹㅅㅜ_ㅇㅣㅆㅇㅓ_',
#   'ㅈㅏㄴㅇㅣㄴㅎㅏㄴㅇㅕㅇㅎㅘ_ㅇㅣㄴㄱㅓㄹㄸㅓ_ㄴㅏ_',
#   'ㅂㅗㄹㅁㅏㄴㅎㅏㄴ',
#   'ㅇㅕㅇㅎㅘ_ㅇㅣㄴㄷㅡㅅbb',
#   'ㄱㅕㄹㅁㅏㄹㅇㅣ_',
#   'ㅈㅗㅁㅊㅜㅇㄱㅕㄱ',
#   'butㅅㅡ_ㅌㅗ_ㄹㅣ_ㄱㅜㄷ'],
#  ['ㄷㅓ_ㄹㅓ_ㅇㅝ_', 'ㅈㅜㄱㄱㅔㅆㄴㅔ_', 'ㄴㅜ_ㄹㅓㅇㅇㅏ_', 'ㅂㅏㅂㅁㅓㄱㅈㅏ_ㄷㅗ_', 'ㅇㅏ_ㄴㅣ_ㄱㅗ_'],
#  ['ㅈㅣㄴㅈㅣ_ㅎㅏ_ㄱㅔ_',
#   'ㅇㅏㅁㅅㅏㄹㅎㅏ_ㅁㅕㄴ',
#   'ㅎㅕㄴㅈㅓㅇㄱㅝㄴ',
#   'ㅂㅡㄹㄹㅐㄱㄹㅣ_ㅅㅡ_ㅌㅡ_ㅇㅔ_',
#   'ㅅㅏ_ㅎㅕㅇㅈㅔ_',
#   'ㅂㅜ_ㅎㅘㄹㄷㅚ_ㅅㅓ_',
#   'ㄷㅟ_ㅈㅣㄹㄱㅓ_ㄱㅏㅌㄷㅏ_'],
#  ['ㅅㅜㄴㅅㅜ_ㅎㅏㄴ',
#   'ㅇㅕㄴㄱㅣ_ㄹㅗ_',
#   'ㅅㅡㅇㅂㅜ_ㅎㅏㄴ',
#   'ㄷㅡ_ㄹㅏ_ㅁㅏ_ㄷㅏ_ㄷㅗㅇㄱㅡㄴㅇㅣ_',
#   'ㅎㅘ_ㅇㅣ_ㄹㅣㅇㄱㅜ_ㄹㅏ_ㄹㅏ_ㄱㅗ_ㅁㅝ_ㄱㅏ_'],
#  ['ㅂㅏ_ㄹㅡ_ㄱㅔ_',
#   'ㅅㅏㄹㅈㅏ_ㅇㅘ_',
#   'ㄱㅏㅌㅇㅣ_',
#   'ㅍㅕㅇㅈㅓㅁㅇㅡㄹ',
#   'ㅁㅣㄷㅈㅣ_',
#   'ㅇㅏㄶㄴㅡㄴ',
#   'ㅇㅕㅇㅎㅘ_',
#   'ㅈㅜㅇㅇㅔ_',
#   'ㅎㅏ_ㄴㅏ_ㄷㅏ_',
#   'ㄱㅏㅁㄷㅗㅇㅇㅢ_',
#   'ㅇㅕ_ㅇㅜㄴㅇㅣ_'],
#  ['ㅇㅘ_ㅇㅏ_ㅁㅏㄴㄷㅏ_ㄷㅗ_ㅇㅣ_ㅃㅡ_ㄱㅔ_ㅇㅕㄴㄱㅣ_ㅈㅏㄹㅎㅏ_ㅈㅣ_ㅁㅏㄴ',
#   'ㅅㅡ_ㅌㅗ_ㄹㅣ_ㅈㅏ_ㅊㅔ_ㄷㅗ_ㅊㅏㅁㅈㅗㅎㄴㅔ_ㅇㅛ_',
#   'ㅇㅏ_ㅁㅏㄴㄷㅏ_ㄱㅏ_ㅇㅏ_ㄴㅣ_ㅁㅕㄴ',
#   'ㅅㅏㄹㄹㅣ_ㄱㅣ_ㅎㅣㅁㄷㅜㄴㅋㅐ_ㄹㅣㄱㅌㅓ_',
#   'ㅈㅣㄴㅉㅏ_ㅈㅐㅁㄴㅏ_ㄴㅡㄴㅇㅕㅇㅎㅘ_ㄱㅜㅅㄱㅜㅅ',
#   'ㅂㅔ_ㄹㅣ_ㄱㅜㅅ'],
#  ['ㅈㅜ_ㅈㅔ_ㄱㅗㄱㄷㅗ_', 'ㅈㅗㅎㄱㅗ_', 'ㅂㅐ_ㅇㅜ_ㄷㅡㄹㄷㅗ_', 'ㅈㅗㅎㄱㅗ_', 'ㅈㅗㅎㄷㅏ_'],
#  ['ㄴㅏ_ㄷㅗ_',
#   'ㅈㅓ_ㅆㅣ_ㅂㅏㄹㅇㅡㄴㅎㅐㅇ',
#   'ㅇㅗㄻㄱㅣㄴㄷㅏ_',
#   'ㅇㅣ_ㄹㅓㄹㄸㅐ_',
#   'ㄴㅐ_ㄱㅏ_',
#   'ㅂㅜ_ㅈㅏ_ㄱㅏ_',
#   'ㅇㅏ_ㄴㅣㄴㄱㅔ_',
#   'ㅇㅝㄴㅁㅏㅇㅅㅡ_ㄹㅓㅂㄷㅏ_',
#   'ㅈㅣ_ㅈㅓㅁㅈㅏㅇ',
#   'ㄷㅏㄹㄹㅕ_ㅇㅗ_ㄱㅔ_',
#   'ㅎㅐ_ㅇㅑ_',
#   'ㅁㅓㄱㅎㅣㄹㅌㅔㄴㄷㅔ_',
#   'ㅆㅣ_ㅂㅏㄹ'],
#  ['ㄴㅗ_ㅌㅐ_ㅇㅜ_ㅇㅢ_',
#   'ㅂㅓㅁㅈㅚ_ㅇㅘ_ㅇㅢ_',
#   'ㅈㅓㄴㅈㅐㅇㅇㅡ_ㄹㅗ_',
#   'ㄱㅡ_ㄴㅏ_ㅁㅏ_',
#   'ㄴㅗ_ㄴㅡㄴ',
#   'ㄲㅏㅇㅍㅐ_ㄷㅡㄹㄷㅗ_',
#   'ㅈㅓㄴㅁㅕㄹㅎㅏㅁ'],
#  ['ㅈㅣ_ㅈㅣ_ㅇㅠㄹ', 'ㄸㅓㄹㅇㅓ_ㅈㅣㄹㄲㅏ_', 'ㅁㅜ_ㅅㅓ_ㅇㅝ_ㅅㅓ_', 'ㄱㅗㅇㄱㅐ_', 'ㅎㅏ_ㄴㅗ_'],
#  ['ㅇㅣ_ㄸㅏㄴㄱㅓ_',
#   'ㅈㅐ_ㅇㅓㅂㅇㅣ_ㄸㅏㄴㄱㅓ_',
#   'ㅇㅓㅄㅇㅣ_',
#   'ㅈㅗㄴㄴㅏ_ㅂㅗㄴㄱㅓ_',
#   'ㅇㅣㄹㅂㅔ_ㄱㅏ_ㄴㅡㄴㄱㅓ_ㅂㅗ_ㅁㅕㄴ',
#   'ㅇㅏㅂㄷㅗ_ㅈㅓㄱㅇㅡ_ㄹㅗ_ㄱㅏ_ㄴㅡㄴㄱㅓ_ㅂㅗ_ㅁㅕㄴ',
#   'ㅃㅏㄹㄹㅔㅂㅇㅏ_ㄷㅣ_ㄷㅡㄹㅅㅏ_ㅅㅓ_',
#   'ㅂㅜㄴㅌㅏㅇㅈㅏㄹㅊㅣ_ㅁㅕㄴ',
#   'ㅇㅣㄹㅂㅔ_',
#   'ㅈㅗㄴㄴㅏ_ㅈㅐ_ㅁㅣㅆㄱㅔㅆㄷㅏ_'],
#  ['ㅂㅗ_ㅁㅕㄴ',
#   'ㅂㅗㄹㅅㅜ_ㄹㅗㄱ',
#   'ㄷㅓ_ㅇㅜㄱ',
#   'ㅈㅐ_ㅁㅣ_ㄴㅏ_ㅅㅓ_',
#   'ㅍㅜㄱㅃㅏ_ㅈㅕㅆㅇㅓ_ㅇㅕ_ㄱㅡㅁㅌㅗ_ㅇㅛ_ㅇㅣㄹ',
#   'ㅈㅓ_ㄴㅕㅋㅅㅣ_ㄱㅏㄴㄷㅚ_ㅁㅕㄴ',
#   'ㅇㅞㄴㅈㅣ_',
#   'ㅈㅡㄹㄱㅓㅂㄱㅗ_',
#   'ㅎㅐㅇㅂㅗㄱㅎㅐ_ㅈㅣㅂㅇㅣㅂㄴㅣ_ㄷㅏ_ㅊㅜㄹㅇㅕㄴㅈㅣㄴ',
#   'ㅁㅗ_ㄷㅜ_',
#   'ㅁㅓㅅㅉㅕ_ㅇㅛ_ㅁㅣ_ㅅㅐㅇ',
#   'ㄷㅐ_ㅂㅏㄱㅇㅖ_ㄱㅏㅁ',
#   'ㅎㅘㅅㅌㅣㅇㅇㅣㅂㄴㅣ_ㄷㅏ_'],
#  ['ㅈㅗㅁㅂㅣ_ㅇㅕㅇㅎㅘ_ㅇㅔ_ㅅㅓ_',
#   'ㅇㅣ_ㄱㅓㄹ',
#   'ㅁㅗㅅㅂㅘㅆㄷㅏ_ㅁㅕㄴ',
#   'ㅇㅏ_ㅈㅣㄱ',
#   'ㅁㅐ_ㄴㅣ_ㅇㅏ_ㅇㅔ_',
#   'ㅅㅗㄱㅎㅏ_ㅈㅣ_',
#   'ㅇㅏㄶㅇㅡㅁ'],
#  ['ㅂㅣ_ㅇㅠ_ㄷㅗ_',
#   'ㅈㅗㅈㅂㅕㅇㅅㅣㄴㄱㅏㅌㅇㅣ_ㅎㅐㅆㄴㅔ_',
#   'ㅇㅣㄹㅂㅔ_ㄴㅡㄴ',
#   'ㅂㅓㅁㅈㅚ_ㄱㅏ_',
#   'ㅇㅏ_ㄴㅣ_ㄱㅗ_',
#   'ㅁㅗㄹㅋㅏ_ㄹㅏㅇ',
#   'ㅅㅔㄱㅅㅡ_ㅇㅕㅇㅅㅏㅇ',
#   'ㅇㅠ_ㅍㅗ_ㄴㅡㄴ',
#   'ㅂㅓㅁㅈㅚ_ㅇㅑ_',
#   'ㅅㅐ_ㄷㅐ_ㄱㅏ_ㄹㅣ_ㅅㅐ_ㄲㅣ_ㅇㅑ_',
#   'ㅇㅏㄴㄱㅓㄹㄹㅣ_ㅁㅕㄴ',
#   'ㅈㅏㅇㄸㅐㅇㅇㅣ_ㄱㅣㄴㅎㅏ_ㅈㅣ_',
#   'ㄱㅡㄴㄷㅔ_',
#   'ㄱㅓㄹㄹㅕㅆㄴㅡㄴㄷㅔ_',
#   'ㄱㅐ_ㅎㅓㅅㅅㅗ_ㄹㅣ_ㅆㅏ_ㄱㅗ_ㅇㅣㅆㄴㅗ_'],
#  ['ㅅㅏㅇㄷㅏㅇㅎㅣ_',
#   'ㅈㅐ_ㅁㅣ_ㅇㅣㅆㄱㅔ_',
#   'ㅂㅘㅆㄴㅔ_ㅇㅛ_',
#   'ㅁㅔㄹㄹㅗ_ㅈㅏㅇㄹㅡ_ㄹㅡㄹ',
#   'ㅈㅗㅎㅇㅏ_ㅎㅏ_ㄴㅡㄴㄷㅔ_',
#   'ㅊㅟ_ㅎㅑㅇㅇㅔ_',
#   'ㄷㅡㄹㅇㅓ_ㅁㅏㅈㄴㅡㄴ',
#   'ㅇㅕㅇㅎㅘ_ㅇㅔ_ㅇㅛ_',
#   'ㄱㅡㄴㄷㅔ_',
#   'ㅍㅗ_ㅅㅡ_ㅌㅓ_ㅇㅔ_ㄴㅡㄴ',
#   'ㄴㅏ_ㄴㅡㄴ',
#   'ㅅㅜㄴㅅㅜ_ㅇㅘ_',
#   'ㅈㅏㄱㅂㅕㄹㅎㅏㄴㄷㅏ_ㄱㅗ_',
#   'ㄴㅏ_ㅇㅘ_ㅇㅣㅆㄱㅣㄹㄹㅐ_',
#   'ㅁㅝㄴㄱㅏ_',
#   'ㅍㅏ_ㄱㅕㄱㅈㅓㄱㅇㅣㄴㄱㅔ_',
#   'ㅇㅣㅆㄴㅏ_',
#   'ㅎㅐㅆㄴㅡㄴㄷㅔ_ㅍㅗ_ㅅㅡ_ㅌㅓ_ㄱㅏ_',
#   'ㅈㅏㄹㅁㅗㅅㄷㅚㄴㄱㅓ_',
#   'ㄱㅏㅌㅇㅏ_ㅇㅛ_',
#   'ㄱㅡ_ㄷㅡㄹㅇㅢ_',
#   'ㅅㅏ_ㄹㅏㅇㅇㅡㄴ',
#   'ㅇㅓ_ㄴㅡ_',
#   'ㅅㅏ_ㄹㅏㅇㅂㅗ_ㄷㅏ_',
#   'ㅅㅜㄴㅅㅜ_ㅎㅐㅆㅅㅡㅂㄴㅣ_ㄷㅏ_'],
#  ['ㅇㅑ_ㄷㅏㅇ', 'ㅅㅐ_ㄲㅣ_ㄷㅡㄹ', 'ㅈㅗㅎㅇㅡㄴ', 'ㄸㅓㄱㅂㅏㅂ', 'ㅁㅜ_ㄴㅑ_'],
#  ['ㅎㅏ_ㄱㅣㄴ',
#   'ㅎㅏㄴㅁㅜ_ㄷㅏㅇㅇㅡㄴ',
#   'ㄱㅓㄴㄷㅡㄹㅈㅣ_ㄴㅡㄴ',
#   'ㅁㅗㅅㅎㅏ_ㄱㅗ_',
#   'ㅉㅣㄹㄹㅡ_ㄱㅗ_',
#   'ㅍㅜㄹㅃㅜ_ㄹㅣ_',
#   'ㅁㅓㄱㅇㅕ_',
#   'ㄴㅗㅎㄱㅗ_',
#   'ㄱㅣ_ㄷㅗ_ㄹㅏ_ㄷㅗ_',
#   'ㅎㅐ_ㅈㅜ_ㅈㅣ_',
#   'ㅅㅐ_ㄲㅣ_ㄷㅡㄹㅇㅡㄴ',
#   'ㅇㅣㅆㄴㅡㄴㄱㅓ_',
#   'ㅈㅜㄱㅇㅣ_ㄹㅕ_'],
#  ['ㅈㅏ_ㅎㅘ_ㅈㅏ_ㅊㅏㄴㅇㅔ_',
#   'ㄸㅏㄹㄸㅏㄹㅇㅣ_ㅊㅣ_ㅁㅕ_',
#   'ㅈㅓㅇㅅㅣㄴㅅㅡㅇㄹㅣ_ㅎㅏ_ㄴㅡㄴ',
#   'ㄷㅐ_ㅎㅏㄴㅁㅣㄴㄱㅜㄱ',
#   'ㅇㅓㄴㄹㅗㄴ',
#   'ㅆㅡ_ㄹㅔ_ㄱㅣ_ㄷㅡㄹㅇㅡㄴ',
#   'ㅂㅜㄹㅌㅐ_ㅇㅝ_',
#   'ㅈㅜㄱㅇㅕ_',
#   'ㅂㅓ_ㄹㅕ_ㅇㅑ_',
#   'ㅇㅣㄴㄱㅏㄴㅇㅣ_',
#   'ㅇㅏ_ㄴㅣㅁ',
#   'ㄱㅐ_ㅆㅡ_ㄹㅔ_ㄱㅣ_ㄷㅡㄹㅇㅣㅁ'],
#  ['ㄴㅡ_ㄱㅓㅁㅁㅏ_',
#   'ㄱㅐ_ㄹㅏㅇ',
#   'ㅅㅔㄱㅅㅡ_ㅎㅏ_ㄱㅗ_',
#   'ㄴㅓ_ㄴㅏㅎㅇㅡㄴ',
#   'ㅆㅣ_ㅂㅏㄹㅇㅔ_ㅁㅣ_ㅊㅏㅇㄴㅕㄴㅈㅗㅈㄱㅓㄹㄹㅔ_',
#   'ㄱㅐ_ㅆㅣ_ㅂㅏㄹㄹㅕㄴ',
#   'ㅂㅜㄴㅅㅙ_ㄱㅣ_ㅇㅔ_ㄱㅏㄹㅇㅏ_ㅈㅜㄱㅇㅣㄹ',
#   'ㅈㅗㅈㄱㅏㅌㅇㅡㄴㄴㅕㄴ'],
#  ['ㅌㅗㅂㅅㅡ_ㅌㅏ_ㅇㅓㄹㄱㅜㄹㅂㅗ_ㄷㅏ_',
#   'ㅍㅕㅇㅂㅓㅁㅎㅏㄴㅇㅓㄹㄱㅜㄹㅂㅗ_ㄹㅕ_ㄴㅣ_',
#   'ㅈㅓㄱㅇㅡㅇㅇㅏㄴㄷㅚㅁ',
#   'ㄴㅜㄴㅁㅏㄴ',
#   'ㄱㅏㄹㅅㅜ_ㄹㅗㄱㄴㅗㅍㅇㅏ_ㅈㅕ_',
#   'ㅇㅣㄹㄷㅏㄴ',
#   'ㅅㅣㄹㅈㅔ_ㄹㅗ_',
#   'ㅇㅣㄹㅇㅓ_ㄴㅏㄹㄱㅓㅅㄱㅏㅌㅇㅡㄴ',
#   'ㅇㅣㄹㅇㅣ_ㄹㅏ_ㅅㅓ_',
#   'ㄱㅗㅇㄱㅏㅁㅇㅣ_',
#   'ㄱㅏ_ㄴㅡㄴ',
#   'ㅇㅕㅇㅎㅘ_ㅇㅕㅆㅅㅡㅂㄴㅣ_ㄷㅏ_'],
#  ['outs',
#   'ㄱㅜㄱㅃㅗㅇㅈㅣㅅ',
#   'ㅎㅏ_ㅈㅣ_ㅁㅏ_ㅅㅣ_ㄱㅗ_',
#   'ㄱㅡ_ㄴㅑㅇ',
#   'ㄱㅏ_ㅁㅏㄴㅎㅣ_',
#   'ㅇㅣㅆㅇㅡ_ㅅㅔ_ㅇㅛ_',
#   'ㅇㅕㅇㅎㅘ_ㄹㅡㄹ',
#   'ㅂㅗ_ㄱㅣㄴ',
#   'ㅂㅗㄴㄱㅓㅂㄴㅣ_ㄲㅏ_',
#   'ㅁㅜ_ㅅㅡㄴㅅㅏ_ㄱㅓㄴㅎㅏ_ㄴㅏ_ㅎㅏ_ㄴㅏ_ㄹㅡㄹ',
#   'ㄱㅡ_ㄷㅐ_ㄹㅗ_',
#   'ㅂㅔ_ㄲㅕ_ㅇㅗㄴ',
#   'ㅇㅕㅇㅎㅘ_ㄱㅏ_',
#   'ㄱㅜㄱㄱㅏ_ㄷㅐ_ㅍㅛ_',
#   'ㅁㅏㅈㄱㅜ_ㅁㅏㄴ'],
#  ['ㅇㅕ_ㅎㅐㅇㄱㅏ_ㅅㅓ_',
#   'ㅈㅜㄱㅇㅡㄴㄱㅓ_',
#   'ㅈㅗㄹㄹㅏ_',
#   'ㄲㅗ_ㅅㅣㄴㄱㅓㄴ',
#   'ㄴㅏ_ㅃㅜㄴㅇㅣㄴㄱㅏ_',
#   'ㅈㅣㄴㅉㅏ_',
#   'ㄴㅏ_ㅃㅡㄴㄴㅗㅁㅇㅣㄴㄱㅓ_ㄴㅗ_'],
#  ['ㅇㅣㄹㅂㅔ_ㅇㅔ_ㅅㅓ_',
#   'ㄱㅏ_ㅈㅏㅇ',
#   'ㄱㅜㅇㄱㅡㅁㅎㅐㅆㄷㅓㄴ',
#   'ㄱㅔ_ㅇㅣ_ㅇㅣㄴㄷㅔ_',
#   'ㅈㅏ_ㅈㅜ_',
#   'ㅇㅗㄹㄹㅕ_ㅈㅜ_ㄹㅏ_',
#   'ㅍㅐㄴㅇㅣ_ㄷㅏ_ㅇㅣ_ㄱㅣ_'],
#  ['ㅁㅏ_ㅈㅣ_ㅁㅏㄱㅂㅜ_ㅂㅜㄴㅇㅣ_',
#   'ㅇㅝㄴㅈㅏㄱㄱㅘ_',
#   'ㅇㅣ_ㅇㅓ_ㅈㅣ_ㄱㅣㄴ',
#   'ㅎㅏ_ㅈㅣ_ㅁㅏㄴ',
#   'ㅈㅓㄴㅊㅔ_ㅈㅓㄱㅇㅡ_ㄹㅗ_',
#   'ㅇㅝㄴㅈㅏㄱㄱㅘ_',
#   'ㅅㅏㅇㄷㅏㅇㅎㅣ_',
#   'ㅎㅡㅂㅅㅏ_ㅎㅐ_ㅅㅓ_',
#   'ㄹㅣ_ㅁㅔ_ㅇㅣ_ㅋㅡ_ㅈㅏㄱ',
#   'ㅈㅓㅇㄷㅗ_ㄹㅗ_',
#   'ㅂㅘ_ㄷㅗ_',
#   'ㅁㅜ_ㅂㅏㅇㅎㅏ_ㄷㅏ_',
#   'ㅇㅝㄴㅈㅏㄱㅇㅢ_',
#   'ㄲㅡㅁㅉㅣㄱㅎㅏㄴ',
#   'ㄱㅚ_ㅁㅜㄹㅂㅣ_ㅈㅠ_ㅇㅓㄹㅇㅡㄹ',
#   'ㅊㅓㅁㄷㅏㄴㄹㅗ_',
#   'ㄷㅏ_ㅅㅣ_',
#   'ㅅㅏㄹㄹㅕ_ㄴㅐㅆㄷㅏ_',
#   'ㅍㅡ_ㄹㅣ_ㅋㅝㄹㅈㅏㄱㅇㅡ_ㄹㅗ_',
#   'ㅇㅣ_ㅈㅓㅇㄷㅗ_ㅁㅕㄴ',
#   'ㅎㅏㅂㄱㅕㄱㅈㅓㅁ'],
#  ['ㅇㅠ_ㅈㅡ_ㅇㅓㄹㅅㅓ_ㅅㅡ_ㅍㅔㄱㅌㅡ_ㅇㅘ_',
#   'ㄱㅏㅌㅇㅡㄴ',
#   'ㅂㅏㄴㅈㅓㄴㅇㅣ_',
#   'ㅇㅣㅆㅈㅛ_ㅂㅓㅁㅇㅣㄴㅇㅡㄴ',
#   'ㅂㅓㅁㅇㅣㄴㅇㅡㄴ'],
#  ['ㄱㅡ_ㄹㅓ_',
#   'ㅈㅏ_ㅈㅓㄴㄱㅓ_',
#   'ㄴㅏ_ㅈㅜㅇㅇㅔ_',
#   'ㅂㅐ_ㅇㅜ_ㅁㅕㄴ',
#   'ㄷㅚ_ㅈㅏㄶㅇㅏ_',
#   'ㅎㅏㄹㄸㅐ_',
#   'ㄴㅜㄴㅁㅜㄹ',
#   'ㅈㅣㄴㅉㅏ_',
#   'ㅋㅗ_ㄲㅏ_ㅈㅣ_',
#   'ㅍㅜㄹㅁㅕㄴㅅㅓ_',
#   'ㅇㅜㄹㅇㅓㅆㅅㅡㅂㄴㅣ_ㄷㅏ_'],
#  ['ㄷㅡㄹㄹㅣ_ㄴㅡㄴ',
#   'ㅈㅗㅅㅁㅜㄴㄱㅏ_ㄷㅡㄹㅇㅢ_',
#   'ㅇㅢ_ㄱㅕㄴㅇㅡㄹ',
#   'ㅈㅗㅇㅎㅏㅂㅎㅐ_ㅂㅗ_ㅁㅕㄴ',
#   '30ㅂㅏㄹㅇㅣ_ㅅㅏㅇ',
#   'ㅇㅕㄴㅅㅗㄱ',
#   '74ㅅㅣ_ㅇㅔㄴ',
#   'ㅎㅏ_ㄱㅗ_',
#   'ㅁㅓㄱㄴㅡㄴㄱㅔ_',
#   'ㅍㅕㄴㅎㅏ_ㄷㅏ_ㄱㅗ_',
#   'ㅎㅏ_ㄷㅡ_ㄹㅏ_',
#   'ㄱㅐ_ㅊㅟ_ㄷㅏ_'],
#  ['ㅈㅣㄴㅉㅏ_',
#   'ㅈㅓ_ㄹㅓ_ㄱㅗ_',
#   'ㅇㅓ_ㄷㅣ_',
#   'ㅈㅜ_ㅊㅏ_ㅎㅐ_ㄴㅗㅎㅇㅡ_ㅁㅕㄴ',
#   '100',
#   'ㅌㅔ_ㄹㅓ_',
#   'ㄷㅏㅇㅎㅏㄴㄷㅏ_'],
#  ['ㅈㅓ_ㄹㅓㄴㄴㅗㅁㄷㅡㄹㅇㅣ_',
#   'ㄴㅏ_ㅈㅜㅇㅇㅔ_',
#   'ㅇㅕ_ㅈㅏ_',
#   'ㄱㅏㅇㄱㅏㄴㅎㅏ_ㄱㅗ_',
#   'ㅅㅏㄹㅎㅐ_ㅎㅏ_ㄱㅗ_',
#   'ㄱㅡ_ㄹㅓ_ㄴㅡㄴㄱㅓ_ㅇㅣㅁ',
#   'ㅅㅓㅇㅂㅓㅁㅈㅚ_ㄴㅡㄴ',
#   'ㅁㅜ_ㅈㅗ_ㄱㅓㄴ',
#   'ㅈㅣㅇㅇㅕㄱ',
#   'ㅈㅗㄴㄴㅏ_ㄸㅐ_ㄹㅕ_ㅈㅝ_ㅇㅑ_ㅎㅏㅁ',
#   'ㅅㅓㅇㅎㅢ_ㄹㅗㅇㄷㅗ_',
#   'ㅎㅐ_ㅂㅗ_ㄱㅗ_',
#   'ㅅㅓㅇㅊㅜ_ㅎㅐㅇㄷㅗ_',
#   'ㅎㅐ_ㅂㅗ_ㄱㅗ_',
#   'ㅅㅓㅇㅍㅗㄱㅎㅐㅇ',
#   'ㅎㅐ_ㅂㅗ_ㄱㅗ_',
#   'ㅁㅏㄱㅍㅏㄴㅇㅔ_',
#   'ㅅㅏ_ㄹㅏㅁㅇㅡㄹ',
#   'ㅅㅏㄹㅎㅐ_ㅎㅏ_ㄱㅔ_ㄷㅚ_ㄴㅡㄴㄱㅓ_ㄷㅏ_'],
#  ['ㄱㅣㅁㄷㅐ_ㅈㅜㅇ', 'ㄴㅗ_ㅁㅜ_ㅎㅕㄴ', 'ㄱㅐ_ㅅㅐ_ㄲㅣ_', 'ㅆㅣ_ㅂㅏㄹㄴㅗㅁ', 'ㄱㅘㅇㅈㅜ_ㄴㅡㄴ', 'ㅍㅗㄱㄷㅗㅇ'],
#  ['ㄱㅣ_ㅁㅛ_ㅎㅏㄴ',
#   'ㄱㅗㅇㅍㅗ_ㄱㅏ_',
#   'ㄴㅡ_ㄲㅕ_ㅈㅕㅆㅅㅡㅂㄴㅣ_ㄷㅏ_',
#   'ㅊㅔㄹㄹㅗ_ㄱㅜ_ㅁㅓㅇㅇㅡㄴ',
#   'ㅁㅏ_ㅊㅣ_',
#   'ㄴㅐ_ㅂㅏㅇㅇㅔ_ㅇㅣㅆㄴㅡㄴㄱㅔ_ㅈㅗㅁㅁㅜ_ㅅㅓ_ㅇㅝ_ㅈㅕㅆㅇㅓㅆㅅㅡㅂㄴㅣ_ㄷㅏ_'],
#  ['ㅂㅗ_ㅇㅏㄴㄱㅜ_ㅇㅕㄱㅇㅔ_',
#   'ㅇㅣㅂㅎㅏㅇㅎㅐㅆㄷㅐ_ㅈㅏ_ㄴㅓ_',
#   'ㄱㅜㄱㄱㅏ_ㅇㅔ_ㅅㅓ_',
#   'ㅇㅜㄴㅇㅛㅇㅈㅜㅇㅇㅣㄴ',
#   'ㅅㅓㄴㅂㅏㄱㅇㅣㄴㄷㅡㅅ'],
#  ['ㅁㅔ_ㄹㅡ_ㅅㅡ_',
#   'ㅅㅔ_ㅇㅝㄹㅎㅗ_',
#   'ㄷㅡㅇㄷㅡㅇㅇㅔ_ㅅㅓㄴ',
#   'ㄱㅡ_ㄹㅓㅎㄱㅔ_',
#   'ㅂㅜㄹㅇㅏㄴㄱㅏㅁ',
#   'ㅂㅜ_ㅊㅜ_ㄱㅣ_ㄷㅓ_ㄴㅣ_',
#   'ㄴㅐ_ㄹㅗ_ㄴㅏㅁㅂㅜㄹㄷㅗ_',
#   'ㅈㅓㅇㄷㅗ_ㄲㅓㅅㅎㅐ_ㅇㅑ_ㅈㅣ_'],
#  ['ㄱㅣ_ㄷㅐ_ㅎㅏ_ㅈㅣ_',
#   'ㅇㅏㄶㄱㅗ_',
#   'ㅇㅕㅇㅎㅘ_',
#   'ㅇㅣ_ㄹㅓㄴ',
#   'ㅇㅕㅇㅎㅘ_ㄷㅗ_',
#   'ㅇㅣㅆㄴㅏ_',
#   'ㅅㅣㅍㅇㅓㅆㄴㅡㄴㄷㅔ_',
#   'ㄴㅏ_ㄹㅡㅁ',
#   'ㄱㅙㄴㅊㅏㄶㄷㅓ_ㄹㅏ_',
#   'ㄱㅡㄴㄷㅔ_',
#   'ㅈㅓ_ㅇㅖ_ㅅㅏㄴㅇㅣ_ㄹㅏ_'],
#  ['ㄱㅡ_ㄴㅑㅇ',
#   'ㄱㅏㅂㅈㅏ_ㄱㅣ_',
#   'ㅅㅐㅇㄱㅏㄱㄴㅏ_ㅅㅓ_',
#   'ㅊㅏㅈㅇㅏ_ㅇㅘ_ㅆㅡㅁ',
#   'ㄴㅐ_ㄱㅏ_',
#   'ㅇㅣㄹㅁㅏㄹ',
#   'ㅅㅏㅇㅂㅕㅇ',
#   'ㄲㅏ_ㅈㅣ_',
#   'ㅂㅘㅆㄷㅓㄴㄱㅓㄴㄷㅔ_',
#   'ㄱㅜㄴㄷㅐ_ㅇㅔ_ㅅㅓ_',
#   'ㅈㅣㄴㅉㅏ_',
#   'ㅅㅜㅁㅈㅜㄱㅇㅣ_ㄱㅔ_',
#   'ㅂㅘㅆㄷㅓㄴ',
#   'ㅈㅏㄱㅍㅜㅁ',
#   'ㅇㅐ_ㄷㅡㄹㅇㅣ_ㄹㅏㅇ'],
#  ['ㅅㅗㄹㄲㅏ_ㅁㅏㄹ',
#   'ㄱㅡ_ㄹㅐ_ㅍㅣㄱㅃㅒ_ㄱㅗ_',
#   'ㅇㅛ_ㅈㅡㅁㅇㅡㄴ',
#   'ㅂㅕㄴㅎㅏㄴㄱㅔ_ㅇㅓㅄㅅㅡㅁ',
#   '78ㄴㅕㄴㄷㅗ_',
#   'ㅊㅣ_ㄱㅗ_',
#   'ㅈㅗㄹㄹㅏ_ㅈㅏㄹㅁㅏㄴㄷㅡㄴㄱㅓ_'],
#  ['ㅁㅔㄹㄹㅗ_',
#   'ㅇㅕㅇㅎㅘ_ㅇㅢ_',
#   'ㄹㅔ_ㅈㅓㄴㄷㅡ_ㅇㅏ_ㅇㅣ_ㄱㅏ_ㄴㅐ_4ㅅㅏㄹㄸㅐ_',
#   'ㅎㅐㄴㄱㅣ_ㄴㅔ_',
#   'ㄴㅏㅁㅈㅏ_ㄱㅏ_',
#   'ㅂㅗ_ㄷㅗ_',
#   'ㅈㅟ_ㄱㅣ_ㄴㅔ_',
#   'ㄴㅗ_ㄹㅐ_ㄱㅏ_',
#   'ㅇㅑㅇㄲㅡㅅㅎㅏ_ㄴㅔ_'],
#  ['ㅇㅓ_ㄹㅕㅆㅇㅡㄹ',
#   'ㄴㅜㄴㅁㅜㄹㅋㅗㅅㅁㅜㄹ',
#   'ㅂㅓㅁㅂㅓㄱㄷㅚ_ㅁㅕ_',
#   'ㅂㅘㅆㄷㅓㄴ',
#   'ㅇㅕㅇㅎㅘ_ㅇㅔ_ㅇㅛ_',
#   'ㅈㅓㅇㅁㅏㄹ',
#   'ㅈㅣ_ㄱㅡㅁㄷㅗ_',
#   'ㄱㅏㅁㄷㅗㅇㅇㅡㄴ',
#   'ㅇㅣㅈㅎㅕ_ㅈㅣ_ㅈㅣ_',
#   'ㅇㅏㄶㅇㅏ_ㅇㅛ_'],
#  ['ㅁㅏㄱㅉㅏㄹ', 'ㅂㅏㅇㅎㅑㅇㅇㅔ_', 'ㅇㅣㅆㄴㅡㄴ', 'ㅅㅐ_ㄲㅣ_', 'ㄱㅕㅇㅅㅜ_', 'ㅁㅏㅈㄴㅑ_'],
#  ['ㄱㅡ_ㄹㅓㅎㄱㅔ_',
#   'ㅁㅜ_ㄱㅓ_ㅇㅜㄴ',
#   'ㅅㅗ_ㅈㅐ_ㄹㅡㄹ',
#   'ㄱㅏ_ㅈㅣ_ㄱㅗ_',
#   'ㅇㅣㅆㄴㅡㄴㄱㅓㅅㄷㅗ_',
#   'ㅇㅏ_ㄴㅣ_ㄱㅗ_',
#   'ㅁㅝㄴㄱㅏ_',
#   'ㅁㅗ_ㄹㅡㄹ',
#   'ㄱㅛ_ㅎㅜㄴ',
#   'ㅈㅜ_ㄱㅣ_ㄷㅗ_',
#   'ㅎㅏ_ㄱㅗ_',
#   'ㅎㅏㄴㅍㅕㄴㅇㅢ_',
#   'ㅅㅜㄴㅈㅓㅇㄷㅡ_ㄹㅏ_ㅁㅏ_',
#   'ㅂㅗ_ㄴㅡㄴㄴㅡ_ㄲㅣㅁ',
#   'ㅈㅣㄴㅉㅏ_',
#   'ㅈㅗㅎㅇㅏㅆㄷㅏ_'],
#  ['ㅈㅓ_ㄷㅗ_', 'ㅇㅛ_ㄱㅓ_', 'ㅈㅣㄴㅉㅏ_', 'ㅈㅐ_ㅁㅣㅆㄱㅔ_', 'ㅂㅘㅆㅅㅡㅂㄴㅣ_ㄷㅏ_'],
#  ['ㅈㅣ_ㄱㅡㅁㄲㅏ_ㅈㅣ_', 'ㅇㅕㅇㅎㅘ_ㅈㅜㅇ', 'ㅅㅗㄴㅇㅔ_', 'ㄲㅗㅂㄴㅡㄴ', 'ㅇㅕㅇㅎㅘ_'],
#  ['ㅇㅐㄱㅅㅕㄴㅇㅡㄹ',
#   'ㄱㅣ_ㄷㅐ_ㅎㅐㅆㄴㅡㄴㄷㅔ_',
#   'ㅂㅓㅂㅈㅓㅇㅅㅡ_ㄹㅣㄹㄹㅓ_',
#   'ㄱㅡㄴㄷㅔ_',
#   'ㅁㅏㄱㅈㅏㅇ',
#   'ㅂㅓㅂㅈㅓㅇ'],
#  ['2001ㄴㅕㄴ',
#   'ㅇㅕㅇㅎㅘ_ㄹㅏ_ㄱㅗ_',
#   'ㅂㅗ_ㄱㅣ_ㅇㅔㄴ',
#   'ㅁㅐ_ㅇㅜ_',
#   'ㅎㅕㄱㅅㅣㄴㅈㅓㄱㅇㅣ_ㄱㅗ_',
#   'ㅅㅡ_ㅌㅗ_ㄹㅣ_ㄷㅗ_',
#   'ㅌㅏㄴㅌㅏㄴㅎㅏ_ㄷㅏ_',
#   'ㄱㅣㄴㅈㅏㅇㄱㅏㅁㄷㅗ_',
#   'ㅈㅗㅎㄱㅗ_',
#   'ㅁㅔ_ㅅㅔ_ㅈㅣ_ㄷㅗ_',
#   'ㄴㅏㅁㄴㅡㄴㅍㅕㄴ'],
#  ['ㄴㅗ_ㅈㅗ_',
#   'ㅂㅜㄹㅊㅏㅁㅎㅏ_ㄴㅡㄴ',
#   'ㅎㅐㅇㅇㅟ_ㄹㅏㅇ',
#   'ㅂㅡㄹㄹㅐㄱㄹㅣ_ㅅㅡ_ㅌㅡ_',
#   'ㅁㅏㄴㄷㅡㄹㅇㅓ_ㅅㅓ_',
#   'ㄱㅏㅇㅈㅔ_ㄹㅗ_',
#   'ㄲㅡㄹㅇㅓ_ㄴㅐ_ㄹㅣ_ㄴㅡㄴ',
#   'ㅎㅐㅇㅇㅟ_ㄹㅡㄹ',
#   'ㄷㅗㅇㄱㅡㅂㅇㅡ_ㄹㅗ_',
#   'ㅂㅗ_ㄴㅡㄴ',
#   'ㅈㅘ_ㅈㅗㅁㄷㅡㄹㅇㅢ_',
#   'ㅇㅣㄴㅅㅣㄱㅅㅜ_ㅈㅜㄴ'],
#  ['ㅇㅣ_ㅁㅣ_',
#   'ㅇㅗ_ㄹㅣ_ㅈㅣ_ㄴㅓㄹ',
#   '3ㄱㅝㄴ',
#   'ㄷㅏ_ㄱㅏ_ㅈㅣ_ㄱㅗ_',
#   'ㅇㅣㅅㅇㅡㅁ',
#   'ㄱㅐ_ㅈㅓㅇㅍㅏㄴㅇㅡㄴ',
#   'ㅇㅓ_ㅋㅐ_',
#   'ㅂㅏ_ㄲㅕㅅㄴㅡㄴㅈㅣ_',
#   'ㅁㅗ_ㄹㅡ_ㄱㅔㅅㄴㅡㄴㄷㅔ_',
#   'ㅇㅣㄺㄷㅏ_ㅂㅗ_ㅁㅕㄴ',
#   'ㅈㅣ_ㄱㅡㅁ',
#   'ㅅㅏ_ㅌㅐ_ㄱㅏ_',
#   'ㄱㅡ_ㄴㅑㅇ',
#   'ㅇㅓㄹㅌㅐㅇㄱㅏ_',
#   'ㅇㅓㅄㅇㅡㅁ'],
#  ['ㅇㅣ_ㅅㅔ_ㄴㅏ_',
#   'ㅅㅡㅁㄱㅏ_ㄹㅏㅇ',
#   'ㅇㅓㅁㅌㅐ_ㅇㅜㅇㅇㅣ_',
#   'ㅇㅣ_ㅁㅏ_ㅌㅡ_ㅇㅏㅍㅇㅔ_ㅅㅓ_',
#   'ㅂㅏㄱㅇㅛㅇㅇㅜ_',
#   'ㅈㅝ_ㅍㅐ_ㄴㅡㄴㄱㅔ_',
#   'ㅇㅣㄴㅅㅏㅇㄱㅣㅍㅇㅓㅆㄷㅏ_'],
#  ['ㅅㅣ_ㄱㅏㄴㄴㅏ_ㅌㅏ_ㄴㅐ_ㄴㅡㄴ',
#   'ㄱㅡㄹㅆㅣ_ㅊㅔ_ㅂㅜ_ㅌㅓ_',
#   'ㅁㅝㄴㄱㅏ_',
#   'ㅇㅣ_ㅅㅏㅇㅎㅐㅆㅇㅓ_',
#   'ㅅㅣ_ㅂㅏㄹ',
#   'ㄷㅏ_ㅋㅠ_ㅁㅔㄴㅌㅓ_ㄹㅣ_',
#   'ㅍㅗㄴㅌㅡ_ㄱㅏ_',
#   'ㅇㅏ_ㄴㅣ_ㄷㅏ_',
#   'ㅅㅣㅍㅇㅓㅆㄴㅡㄴㄷㅔ_',
#   'ㅅㅣ_ㅂㅏㄹ'],
#  ['ㅅㅐㄱㅇㅣ_',
#   'ㅎㅕㅇㄱㅘㅇㅎㅕㅇㄱㅘㅇㅇㅣ_ㄹㅏ_ㅅㅓ_',
#   'ㄴㅜㄴㅇㅣ_',
#   'ㅈㅡㄹㄱㅓ_ㅇㅝㅆㄷㅏ_',
#   'ㄷㅗㅇㅇㅑㅇㅈㅓㄱㅇㅣㄴ',
#   'ㅇㅕㄴㅊㅜㄹㅇㅣ_',
#   'ㅇㅏ_ㄹㅡㅁㄷㅏ_ㅇㅜㄴ',
#   'ㅇㅐ_ㄴㅣ_'],
#  ['ㄷㅐ_ㄷㅏㄴㅎㅏ_ㄷㅏ_', 'ㄷㅐ_ㅅㅏ_', 'ㅇㅕㄴㅊㅜㄹ', 'ㅇㅕㄴㄱㅣ_', 'ㅁㅗ_ㄷㅜ_', 'ㄷㅐ_ㄷㅏㄴㅎㅏ_ㄷㅏ_'],
#  ['236', 'ㄷㅏ_ㄹㅝ_ㅈㅜ_ㅁㅕㄴ', 'ㅈㅗㅎㄱㅔㅆㄷㅏ_', 'ㄴㅔ_ㄱㅡㄹㅇㅡㄴ', 'ㅎㅏㅇㅅㅏㅇ', 'ㅈㅐㅁㅇㅣㅆㅇㅓ_'],
#  ['ㄱㅡ_ㄱㅔ_', 'ㅈㅣㄴㅅㅣㅁㅇㅣㄹㄲㅏ_', 'ㄴㅗ_ㄹㅐ_', 'ㅈㅣㄴㅉㅏ_', 'ㅈㅗㅎㄴㅔ_ㅇㅛ_'],
#  ['ㅇㅏ_ㄴㅣ_',
#   'ㄱㅐ_ㅈㅗㅈㅁㅏㄴㅎㅏㄴ',
#   'ㄴㅏ_ㄹㅏ_ㅇㅔ_ㅅㅓ_',
#   'ㄱㅜㄱㅎㅚ_ㅇㅢ_ㅇㅝㄴㅇㅣ_',
#   'ㅁㅜ_ㅅㅡㄴ',
#   '300',
#   'ㅁㅏ_ㄹㅣ_',
#   'ㅆㅣㄱㅇㅣ_ㄴㅏ_',
#   'ㅍㅣㄹㅇㅛ_ㅎㅏ_ㄴㅑ_'],
#  ['ㅈㅏㄹㅁㅏㄴㄷㅡㅁ', 'ㅈㅣㄴㅉㅏ_', 'ㅍㅕㅇㅈㅓㅁ', 'ㄴㅏㅈㄱㅔ_', 'ㅇㅕㅇㅎㅘ_ㄴㅡㄴ', 'ㅇㅏ_ㄴㅣㅁ'],
#  ['ㅌㅡㄹㄸㅏㄱㄴㅣㅁㄷㅡㄹㅇㅏ_',
#   'ㄸㅏㄴㄱㅓ_',
#   'ㄷㅏ_ㅈㅗㅎㅇㅡㄴㄷㅔ_',
#   'ㅂㅐ_ㅋㅏ_',
#   'ㅇㅣ_ㄱㅓㅅㅁㅏㄴㅇㅡㄴ',
#   'ㅎㅏ_ㅈㅣ_ㅁㅏㄹㅇㅏ_ㅈㅜ_ㅅㅣㅂㅅㅣ_ㅇㅗ_',
#   'ㅈㅗㄴㄴㅏ_',
#   'ㅃㅏㄱㅊㅣㅂㄴㅣ_ㄷㅏ_'],
#  ['ㅈㅣㄴㅉㅏ_',
#   'ㅈㅐ_ㅁㅣㅆㄱㅔ_',
#   'ㅂㅘㅆㄴㅔ_ㅇㅛ_',
#   'ㄱㅡㄴㄷㅔ_',
#   'ㅁㅏ_ㅈㅣ_ㅁㅏㄱㅇㅔ_',
#   'ㅈㅗ_ㄱㅡㅁ',
#   'ㄱㅜ_ㅅㅓㅇㅇㅣ_',
#   'ㅇㅏ_ㅅㅟㅂ'],
#  ['ㅌㅗ_ㄴㅣ_ㅌㅏ_ㅋㅣ_ㅌㅏ_ㄴㅣ_ㅇㅘ_',
#   'ㅎㅣ_ㅅㅏ_ㅋㅗ_',
#   'ㅈㅗ_ㄱㅡㅁㅇㅡㄴ',
#   'ㅇㅣ_ㅎㅐ_ㅎㅏㄹ',
#   'ㅇㅣㅆㅇㅡㄹ',
#   'ㄱㅏㅌㄷㅏ_'],
#  ['ㅈㅓㄴㅎㅕㅇㅈㅓㄱㅇㅣㄴ', 'ㅎㅏㄹㄹㅣ_ㅇㅜ_ㄷㅡ_ㅇㅢ_', 'ㅇㅠ_ㅋㅙ_ㅎㅏㄴ', 'ㅇㅐㄱㅅㅕㄴㅇㅕㅇㅎㅘ_', 'ㅈㅐ_ㅁㅣㅆㄴㅔ_'],
#  ['ㅉㅏㅇㅉㅏㅇ',
#   'ㅈㅐ_ㅁㅣㅆㅇㅓ_ㅇㅛ_',
#   'ㅋㅡ_ㄹㅣ_ㅅㅡ_ㅍㅏ_ㅇㅣㄴ',
#   'ㅇㅣ_ㄹㅏㅇ',
#   'ㅌㅗㅁㅎㅏ_ㄷㅣ_',
#   'ㅈㅏㄹㅅㅐㅇㄱㅕㅆㅇㅡㅁ'],
#  ['ㄱㅡ_ㄴㅏ_ㄹㅏ_ㅇㅔ_', 'ㄱㅡ_ㄱㅜㄱㅁㅣㄴㅇㅔ_', 'ㄱㅡ_ㄷㅐ_ㅌㅗㅇㄹㅕㅇ', 'ㅇㅣ_ㅅㅏㅇㅎㅏㄹㄱㅔ_', 'ㅇㅓㅄㄷㅏ_'],
#  ['ㅇㅓ_ㄴㅡ_ㅇㅕㅇㅎㅘ_ㅇㅔ_',
#   'ㄴㅏ_ㅇㅘ_ㄷㅗ_',
#   'ㄱㅏㅌㅇㅡㄴㄱㅐ_ㄱㅡ_',
#   'ㅂㅣ_ㅅㅡㅅㅎㅏㄴㅂㅐ_ㅇㅕㄱㅂㅏㄲㅇㅔ_',
#   'ㅇㅏㄴㅎㅏㅁ'],
#  ['ㅅㅣㄹㅈㅏㅇㅇㅣ_', 'ㅇㅣ_ㄱㅣㄴㄷㅏ_', 'ㅇㅣ_ㄱㅓㄴ', 'ㅍㅕㅇㄷㅡㅇㄱㅝㄴ', 'ㅊㅣㅁㅎㅐ_ㅇㅣㅁ'],
#  ['ㅅㅓㄱㅊㅓㄴㅇㅣ_ㅎㅕㅇ',
#   'ㅅㅣㄱㄷㅏㅇㄷㅡㄹ',
#   'ㅈㅜ_ㅂㅕㄴㅇㅣ_ㄴㅏ_',
#   'ㄷㅏ_ㄹㅡㄴㄱㅗㅅㅇㅔ_',
#   'ㅂㅣ_ㅎㅐ_',
#   'ㅌㅡㄱㅂㅕㄹㅎㅣ_',
#   'ㅁㅏㅅㅇㅣㅆㄴㅡㄴㄱㅓㅅㄷㅗ_',
#   'ㅇㅏ_ㄴㅣㄴㄷㅔ_',
#   'ㅂㅣ_ㅆㅏㅁ'],
#  ['ㄴㅜ_ㄱㅏ_',
#   'ㄱㅜ_ㄱㅡㄹ',
#   'ㅂㅗㄴㅅㅏ_ㅇㅔ_',
#   'ㅇㅕㄴㄹㅏㄱ',
#   'ㅎㅐ_ㄹㅏ_',
#   'ㅈㅓㅇㅊㅣ_ㅁㅗ_ㄹㅣ_ㅂㅐ_',
#   'ㅎㅏㄴㅁㅏ_ㄹㅣ_',
#   'ㄱㅜ_ㄱㅡㄹㅇㅔ_',
#   'ㅇㅣㅆㄷㅏ_ㄱㅗ_'],
#  ['ㅇㅣㄹㅉㅣㄴㅇㅡㄴ',
#   'ㅈㅓㄴㄹㅏ_ㄷㅗ_ㅎㅕㄹㅌㅗㅇㅇㅔ_',
#   'ㅈㅘ_ㅍㅏ_ㄱㅏ_ㅁㅏㄶㅇㅡㄴㄷㅔ_',
#   'ㅈㅓㅁㅁㅏ_ㄷㅡㄹ',
#   'ㅈㅓ_ㄱㅓ_ㅉㅣㄱㄷㅏ_ㄱㅓㄹㄹㅕ_ㅅㅓ_',
#   'ㅈㅗㄴㄴㅏ_ㅁㅏㅈㅇㅏㅆㅇㅡㄹㄷㅡㅅ'],
#  ['ㅇㅏ_ㅇㅣ_ㄷㅗㄹㅁㅏㄹㄱㅗ_',
#   'ㅇㅣ_ㄹㅓㄴ',
#   'ㅇㅏ_ㅈㅐ_ㄱㅏ_',
#   'ㅇㅐㄹㅂㅓㅁㄴㅐ_ㄴㅡㄴㄱㅔ_',
#   'ㅎㅝㄹㅆㅣㄴ',
#   'ㄴㅏ_ㅇㅡㄹㄷㅡㅅ'],
#  ['ㅇㅏㄴㅊㅓㄹㅅㅜ_ㄴㅡㄴ',
#   'ㄱㅣㅁㅁㅜㄴㅅㅜ_',
#   'ㄸㅓㄹㅇㅓ_ㄸㅡ_ㄹㅣ_ㄴㅡㄴ',
#   'ㅋㅏ_ㄷㅡ_ㅇㅕ_ㅅㅓ_ㅂㅏ_ㄹㅡㄴㅁㅣ_ㄹㅐ_ㄷㅏㅇ',
#   'ㅈㅏ_ㅊㅔ_ㄱㅏ_',
#   'ㅈㅏ_ㅎㅏㄴㄷㅏㅇ',
#   'ㅍㅛ_ㅃㅐㅆㄴㅡㄴ',
#   'ㅍㅗ_ㅈㅣ_ㅅㅕ_ㄴㅣㅇㅇㅡㄹ',
#   'ㅊㅟ_ㅎㅏㅁ',
#   'ㅇㅜ_ㅋㅡㄹㄹㅣㄱㅎㅏ_ㄴㅡㄴㄱㅔ_',
#   'ㅂㅏㄴㄱㅏ_ㅇㅜㄴ',
#   'ㅇㅣㄹㅇㅡㄴ',
#   'ㅇㅏ_ㄴㅣㅁ'],
#  ['ㄱㅡ_ㄹㅐ_ㅅㅓ_',
#   'ㅎㅏㄴㄱㅜㄱㅂㅗ_ㅈㅣ_ㄷㅡㄹㅇㅡㄴ',
#   'ㅈㅗㄴㅈㅏㄹㄴㅏㅁㅎㅏㄴㅌㅔ_',
#   'ㅁㅓㄱㅂㅓ_ㄷㅏㅇㅎㅏ_ㄱㅣ_',
#   'ㅅㅟㅂㄷㅏ_ㄴㅡㄴㄱㅓ_ㅇㅑ_',
#   'ㄱㅓㅌㅁㅏㄴㅂㅗ_ㄱㅗ_',
#   'ㅍㅏㄴㄷㅏㄴㅎㅏ_ㄱㅗ_',
#   'ㄱㅓ_ㄱㅣ_ㄷㅏ_',
#   'ㄷㅏㄹㅋㅗㅁㅎㅏㄴㅁㅏㄹ',
#   'ㅁㅕㅊㅁㅏ_ㄷㅣ_ㅁㅕㄴ',
#   'ㅁㅗㅁㄷㅗ_ㅈㅜ_ㄱㅗ_',
#   'ㅁㅏ_ㅇㅡㅁㄷㅗ_ㅈㅜ_ㄱㅗ_',
#   'ㅁㅜㄹㅈㅣㄹㄷㅗ_',
#   'ㅈㅜ_ㄴㅣ_ㄲㅏ_'],
#  ['ㅈㅗㅁㅅㅡ_ㄹㅓ_ㅇㅜ_ㅁㅕㄴㅅㅓ_ㄷㅗ_',
#   'ㅅㅓㅇㅅㅜㄱㅎㅏㄴ',
#   'ㄱㅡ_ㅇㅢ_',
#   'ㅇㅣㄹㅅㅏㅇ',
#   'ㄴㅏ_ㅇㅣ_',
#   'ㅁㅓㄱㄴㅡㄴㄷㅏ_ㄴㅡㄴ',
#   'ㄱㅓㅅㅇㅡㄴ',
#   'ㅇㅣ_ㄹㅓㅎㄷㅏ_'],
#  ['ㅅㅡ_ㅍㅣㄹㅂㅓ_ㄱㅡ_ㅇㅢ_',
#   'ㅈㅛ_ㅅㅡ_',
#   'ㅇㅕㄱㅅㅣ_',
#   'ㅎㅜㄹㄹㅠㅇㅎㅏ_ㅈㅣ_ㅁㅏㄴ',
#   'ㅈㅣ_ㄱㅡㅁ',
#   'ㅅㅜ_ㅈㅜㄴㅇㅡ_ㄹㅗ_',
#   'ㅂㅗ_ㅁㅕㄴ',
#   'ㄷㅣㅂㅂㅡㄹㄹㅜ_ㅆㅣ_ㄱㅏ_',
#   'ㅅㅏㅇㅇㅓ_ㅇㅕㅇㅎㅘ_',
#   'ㅊㅚ_ㄱㅗ_'],
#  ['ㅌㅐㅇㄱㅗ_ㅊㅜㅁㅇㅡㄹ',
#   'ㅊㅜ_ㄴㅡㄴ',
#   'ㅆㅣㄴㅇㅣ_',
#   'ㅇㅣㄴㅅㅏㅇㅈㅓㄱㅇㅣ_ㅇㅓㅆㅇㅓ_ㅇㅛ_ㅊㅗ_ㄷㅣㅇㄸㅐ_',
#   'ㅂㅘㅆㄴㅡㄴㄷㅐ_',
#   'ㅇㅏ_ㅈㅣㄱㄷㅗ_',
#   'ㄱㅣ_ㅇㅓㄱㅎㅏㅁ'],
#  ['ㅇㅏㅍㅂㅜ_ㅂㅜㄴㅇㅣ_',
#   'ㅊㅗㅇㅈㅣㅂㅇㅣ_ㄹㅏ_',
#   '1ㅅㅣ_ㄱㅏㄴ',
#   'ㄴㅏㄹㄹㅕ_ㅁㅓㄱㅇㅡㄴㄴㅡ_ㄲㅣㅁㅇㅣ_',
#   'ㅈㅗ_ㄱㅡㅁㄷㅡㄹㄱㅣㄴㅎㅏ_ㄷㅏ_ㅁㅏㄴ',
#   'ㄴㅏㅁㅇㅡㄴ',
#   '40ㅂㅜㄴㅇㅣ_',
#   'ㅇㅏㄴㅇㅏ_ㄲㅏㅂㄷㅏ_',
#   'ㅈㅓㄴㅌㅜ_ㄱㅏ_',
#   'ㄲㅙ_ㄴㅏ_ㅎㅘ_ㄹㅕ_ㅎㅏㄴㅈㅣ_ㄹㅏ_ㄷㅏ_ㅇㅡㅁㅍㅕㄴㅇㅣ_',
#   'ㄱㅣ_ㄷㅐ_ㄷㅚㅁ'],
#  ['ㄷㅓ_ㅂㅣㅇㅇㅡㄴ', 'ㅂㅘ_ㅅㅓ_', 'ㅁㅗ_ㄹㅡ_ㄱㅔㅆㄱㅗ_', 'ㅅㅡ_ㅌㅗ_ㄹㅣ_', 'ㅈㅗㅎㅇㅡㄴㄷㅔ_'],
#  ['ㅇㅓㄴㅈㅔ_ㅂㅘ_ㄷㅗ_', 'ㅈㅣㄹㄹㅣ_ㅈㅣ_', 'ㅇㅏㄶㄴㅡㄴ', 'ㅊㅚ_ㄱㅗ_ㅇㅢ_', 'ㅇㅕㅇㅎㅘ_'],
#  ['ㅂㅗ_ㅇㅏㅆㄷㅏ_ㅁㅕㄴ',
#   'ㅈㅓㅁㅅㅜ_ㅇㅔ_',
#   'ㄷㅗㅇㅇㅢ_ㅎㅏㄹㅎㅏ_ㄹㅣ_ㄹㅏ_',
#   'ㅇㅏ_ㅈㅣㄱ',
#   'ㅂㅗ_ㅈㅣ_',
#   'ㅁㅗㅅㅎㅐㅆㄷㅏ_ㅁㅕㄴ',
#   'ㅁㅜ_ㅈㅗ_ㄱㅓㄴ',
#   'ㅂㅗ_ㅇㅏ_ㄹㅏ_'],
#  ['ㅁㅗ_ㄷㅡㄴ',
#   'ㄱㅏㄹㄷㅡㅇㅇㅢ_',
#   'ㄱㅣㄴㅈㅏㅇㄱㅘ_',
#   'ㅇㅣ_ㅇㅘㄴㄱㅡ_ㄹㅣ_ㄱㅗ_',
#   'ㅎㅘ_ㅎㅏㅂㅊㅚ_ㄱㅗ_ㅇㅢ_',
#   'ㅊㅜㄱㅈㅔ_ㅊㅚ_ㄱㅗ_ㅇㅢ_',
#   'ㅇㅕㅇㅎㅘ_'],
#  ['ㄴㅔ_ㅇㅣ_ㅂㅓ_',
#   'ㅍㅕㅇㅈㅓㅁ',
#   'ㅅㅣㄴㄹㅚ_',
#   'ㅁㅗㅅㅎㅏ_ㄴㅡㄴ',
#   'ㅅㅏ_ㄹㅏㅁㅇㅣ_ㅈㅣ_ㅁㅏㄴ',
#   'ㅅㅓㄹㄹㅐ_ㅇㅣㅁㅇㅢ_',
#   'ㄱㅏㅁㅈㅓㅇㅇㅡㄹ',
#   'ㅇㅣㅈㄱㅗ_',
#   'ㅇㅣㅆㄷㅏ_ㅁㅕㄴ',
#   'ㅇㅣ_ㅇㅕㅇㅎㅘ_ㄹㅡㄹ'],
#  ['ㅅㅐㅇㄱㅏㄱㅂㅗ_ㄷㅏ_',
#   'ㅁㅓ_ㄹㅣ_ㄱㅏ_',
#   'ㅇㅏㄴㅈㅗㅎㄴㅔ_',
#   'ㅎㅗㄱㅅㅣ_',
#   'ㄱㅏㅌㅇㅣ_ㅌㅏ_ㄱㅗ_',
#   'ㄱㅖ_ㅅㅣ_ㄷㅓㄴ',
#   'ㅁㅜㄴㅈㅐ_ㅇㅣㄴ',
#   'ㄷㅐ_ㅌㅗㅇㄹㅕㅇㄴㅣㅁ',
#   'ㅂㅗ_ㅇㅏㅆㄴㅑ_ㄱㅗ_',
#   'ㅁㅜㅌㄱㅔㅅㄷㅏ_',
#   'ㅇㅏ_ㄴㅣ_ㅇㅛ_',
#   'ㅇㅕㅍㅇㅔ_',
#   'ㅇㅕ_ㅈㅏ_ㅁㅏㄴㅂㅘㅆㄴㅡㄴㄷㅔ_ㅇㅛ_ㅎㅏ_ㅁㅕㄴ',
#   'ㄱㅡ_ㄱㅓㄴ',
#   'ㅇㅕ_ㅈㅏㅇㅎㅏㄴ',
#   'ㄴㅗ_ㅁㅜ_ㅎㅕㄴㅇㅣ_ㄷㅏ_',
#   'ㅎㅏ_ㅁㅕㄴㄷㅐ_ㄱㅗ_',
#   'ㅇㅏ_ㅁㅜ_ㄱㅗ_ㅁㅗㅅㅂㅘㅆㄷㅏ_ㅁㅕㄴ',
#   'ㄴㅓㅁㄹㅓ_ㄱㅏ_ㄱㅗ_'],
#  ['ㅇㅐ_ㄱㅣ_ㄱㅏ_', 'ㅇㅏ_ㅃㅏ_ㄷㅏ_', 'ㅎㅏ_ㄴㅡㄴㄷㅔ_', 'ㄴㅜㄴㅁㅜㄹㄴㅏ_ㄷㅓ_ㄹㅏ_', 'ㅆㅣ_ㅂㅏㄹ'],
#  ['ㅁㅏㅈㅇㅏ_',
#   'ㅇㅓ_ㅊㅏ_ㅍㅣ_',
#   'ㅅㅣ_ㅂㅣ_ㄱㅓ_ㄴㅡㄴ',
#   'ㄱㅓㅅㄷㅡㄹㅇㅡㄴ',
#   'ㅈㅜ_ㄴㅡㄴ',
#   'ㄱㅓㅅㄷㅡㄹㅇㅣㅁ',
#   'ㅅㅣㄴㄱㅕㅇ',
#   'ㅇㅓㅄㄷㅏ_',
#   'ㅇㅗ_ㅎㅣ_ㄹㅕ_',
#   'ㄷㅐ_ㅇㅡㅇ',
#   'ㅎㅏ_ㄴㅡㄴㄱㅔ_',
#   '1ㅍㅛ_ㄹㅏ_ㄷㅗ_',
#   'ㅂㅏㄷㄴㅡㄴㄷㅔ_',
#   'ㅇㅠ_ㄹㅣ_ㅎㅏ_ㄷㅏ_'],
#  ['ㄱㅡ_ㄹㅓㅎㄱㅔ_',
#   'ㅇㅏ_ㅂㅓ_ㅈㅣ_ㄱㅏ_ㄷㅚㄴㄷㅏ_ㄹㅡㄹ',
#   'ㅂㅗㄴㅎㅜ_',
#   'ㅇㅣ_ㄱㅏㅁㄷㅗㄱ',
#   'ㅇㅕㅇㅎㅘ_ㄴㅡㄴ',
#   'ㅁㅗ_ㅈㅗ_ㄹㅣ_ㄷㅏ_',
#   'ㅊㅏㅈㅇㅏ_ㅂㅘ_ㅇㅑ_',
#   'ㄱㅔㅆㄷㅏ_'],
#  ['ㄱㅏㅁㅅㅓㅇ',
#   'ㄷㅗㄷㄱㅔ_',
#   'ㅁㅏㄴㄷㅡ_ㄴㅡㄴ',
#   'ㅎㅜㄹㄹㅠㅇㅎㅏㄴ',
#   'ㅈㅏㄱㅍㅜㅁㅇㅣ_ㅇㅓㅆㅅㅡㅂㄴㅣ_ㄷㅏ_',
#   'ㄱㅣ_ㅈㅜㄴㅇㅔ_ㄴㅡㄴ',
#   'ㅇㅓ_ㄹㅡㄴㅇㅡㄹ',
#   'ㅇㅟ_ㅎㅏㄴ',
#   'ㅇㅐ_ㄴㅣ_ㅁㅔ_ㅇㅣ_ㅅㅕㄴ',
#   'ㅇㅣㅂㄴㅣ_ㄷㅏ_'],
#  ['ㅁㅏ_ㅋㅔ_ㅌㅣㅇ',
#   'ㅅㅣㄹㅍㅐ_ㄹㅗ_',
#   'ㅁㅜㄷㅎㅣㄴ',
#   'ㅂㅣ_ㅇㅜㄴㅇㅢ_',
#   'ㄱㅓㄹㅈㅏㄱㅇㅐ_ㄴㅣ_',
#   'ㅈㅔ_ㅈㅏㄱㅅㅏ_ㄱㅏ_',
#   'ㅇㅝ_ㄴㅓ_ㄱㅏ_',
#   'ㅇㅏ_ㄴㅣ_ㄱㅗ_',
#   'ㄷㅣ_ㅈㅡ_ㄴㅣ_ㅇㅕㅆㄷㅏ_ㅁㅕㄴ',
#   'ㅅㅏㅇㄷㅏㅇㅎㅏㄴ',
#   'ㅎㅡㅇㅎㅐㅇㅇㅡㄹ',
#   'ㅎㅐㅆㅇㅡㄹ',
#   'ㅇㅏ_ㅅㅟ_ㅇㅜㄴ',
#   'ㅈㅏㄱㅍㅜㅁ',
#   'ㅈㅣ_ㄱㅡㅁㅂㅗ_ㅁㅕㄴ',
#   'ㅊㅗㄴㅅㅡ_ㄹㅓㄴ',
#   'ㅂㅜ_ㅂㅜㄴㄷㅗ_',
#   'ㅂㅗ_ㅇㅣ_ㅈㅣ_ㅁㅏㄴ',
#   'ㄷㅏㅇㅅㅣ_ㅇㅔㄴ',
#   'ㅅㅛ_ㅋㅣㅇㅎㅏㄴ',
#   'ㅇㅐ_ㄴㅣ_ㅇㅕㅆㄷㅏ_'],
#  ['ㅊㅐㄱㅇㅔ_ㅅㅓ_ㅇㅢ_',
#   'ㄱㅏㅁㄷㅗㅇ',
#   'ㅇㅕㅇㅎㅘ_ㅇㅔ_ㅅㅓ_',
#   'ㄲㅏ_ㅈㅣ_',
#   'ㄱㅡ_ㄷㅐ_ㄹㅗ_',
#   'ㅇㅗ_ㄴㅣ_',
#   'ㅈㅗㅎㅅㅡㅂㄴㅣ_ㄷㅏ_'],
#  ['ㄱㅏㅁㄷㅗㅇㅈㅓㄱㅇㅣ_ㅈㅣ_ㅁㅏㄴ',
#   'ㅎㅏㄴㅍㅕㄴㅇㅡ_ㄹㅗ_ㄴㅡㄴ',
#   'ㅈㅓㅇㅁㅏㄹ',
#   'ㅅㅡㄹㅍㅡㄴㅇㅕㅇㅎㅘ_',
#   'ㄱㅡ_ㄹㅣ_ㄱㅗ_',
#   'ㅊㅚ_ㄱㅗ_ㅇㅢ_',
#   'ㅇㅕㅇㅎㅘ_'],
#  ['ㄴㅐㅁㅅㅐ_ㄴㅏ_ㄴㅡㄴ', 'ㅈㅓㄴㄹㅏ_ㄷㅗ_', 'ㅎㅗㅇㅇㅓ_ㅅㅐ_ㄲㅣ_ㅇㅑ_', 'ㅈㅔ_ㅂㅏㄹ', 'ㅈㅏ_ㅅㅏㄹ'],
#  ['ㅈㅓㄴㄹㅑㄱㅈㅓㄴㅅㅜㄹㅇㅣ_ㄹㅏ_ㅎㅏ_ㄱㅗ_',
#   'ㄷㅟㅅㅌㅗㅇㅅㅜ_ㅊㅣ_ㄴㅡㄴ',
#   'ㅇㅣ_ㅇㅑ_ㄱㅣ_ㄱㅏ_',
#   'ㅎㅏㄴㄷㅜㄹㅇㅣ_ㄴㅑ_',
#   'ㅎㅏㄴㄱㅜㄱㅇㅕㅇㅎㅘ_ㄴㅡㄴ',
#   'ㄷㅟ_ㅌㅗㅇㅅㅜ_ㅊㅣ_ㄴㅡㄴㅇㅕㅇㅎㅘ_ㅂㅏㄲㅇㅔ_ㅇㅏㄴㄴㅏ_ㅇㅗ_ㄱㅗ_'],
#  ['ㅇㅣ_ㅇㅕㄴㄱㅓㄹㅎㅕㅇㄴㅣㅁㅇㅣ_',
#   'ㄴㅏ_ㅇㅗㄴ',
#   'ㅇㅕㅇㅎㅘ_',
#   'ㅈㅜㅇㅇㅔ_',
#   'top3ㅇㅏㄴㅇㅔ_',
#   'ㄷㅡㄹㅇㅓ_ㄱㅏㄴㄷㅏ_',
#   'ㅊㅚ_ㄱㅗ_'],
#  ['ㅁㅜㄴㅈㅐ_ㅇㅏㅇㅇㅡㄴ', 'ㅎㅏㄴㅂㅓㄴㅇㅔ_', 'ㅁㅏㄶㅇㅡㄴ', 'ㅅㅣ_ㅊㅔ_ㄱㅏ_', 'ㅍㅣㄹㅇㅛ_ㅎㅏㅁ'],
#  ['ㅂㅏㄴㄷㅏㅁㅇㅕㅇㅎㅘ_',
#   'ㅈㅣㄴㅈㅓㅇㅎㅏㄴ',
#   'ㅅㅜ_ㅈㅏㄱ',
#   'ㅂㅏㄴㄷㅏㅁㅇㅢ_',
#   'ㅇㅜ_ㅅㅜ_ㅇㅔ_',
#   'ㅅㅗㄱㄴㅜㄴㅆㅓㅂㅇㅣ_',
#   'ㄴㅓ_ㅁㅜ_ㄴㅏ_',
#   'ㅁㅐ_ㄹㅕㄱㅈㅓㄱㅇㅣ_ㅇㅓㅆㄷㅓㄴ',
#   'ㅇㅕㅇㅎㅘ_'],
#  ['ㅇㅘ_ㅇㅕ_ㅇㅜㄴ',
#   'ㅈㅣㄴㅉㅏ_',
#   'ㅇㅖㅅㄴㅏㄹㅇㅕㅇㅎㅘ_ㄱㅏ_',
#   'ㅁㅜ_ㅅㅡㄴ',
#   'ㅎㅕㄴㄷㅐ_ㅇㅕㅇㅎㅘ_',
#   'ㅁㅗㅅㅈㅣ_ㅇㅏㄶㅇㅡㄴ',
#   'ㅇㅕㄴㅊㅜㄹㄹㅕㄱㅇㅔ_ㄷㅏ_ㅈㅣㄴㅉㅏ_',
#   'ㄴㅓ_ㅁㅜ_',
#   'ㅈㅏ_ㅇㅕㄴㅅㅡ_ㄹㅓㅂㄱㅗ_',
#   'ㄹㅗ_ㅁㅏ_ㅇㅢ_',
#   'ㅎㅠ_ㅇㅣㄹ',
#   'ㅎㅏ_ㄴㅡㄴㅈㅣ_',
#   'ㅇㅏㄹㄱㅔㅆㄷㅏ_'],
#  ['ㅁㅗ_ㄷㅡㄴㄱㅔ_ㅅㅗ_ㅅㅗ_ㅎㅏ_ㄱㅗ_ㅈㅐ_ㅁㅣㅆㄷㅏ_',
#   'ㅁㅔㅁㅂㅓ_ㄱㅛ_ㅊㅔ_ㄴㅡㄴ',
#   'ㅇㅓ_ㅉㅓㄹㅅㅜ_ㅇㅓㅄㄱㅗ_',
#   'ㄱㅡ_ㅈㅓㅇㄷㅗ_ㄹㅡㄹ',
#   'ㅎㅓ_ㅇㅛㅇㅎㅏㄹㅅㅜ_',
#   'ㅇㅓㅄㅇㅡㄹㅁㅏㄴㅋㅡㅁ',
#   'ㅁㅐ_ㄹㅕㄱㅇㅓㅄㄴㅡㄴㄱㅓㅅㄷㅗ_',
#   'ㅇㅏ_ㄴㅣ_ㄷㅏ_',
#   'ㅇㅣ_ㄹㅓㄴ',
#   'ㄹㅣ_ㅇㅓㄹㄹㅣ_ㅌㅣ_',
#   'ㅇㅣㄹㅅㅏㅇ',
#   'ㅍㅡ_ㄹㅗ_ㄱㅡ_ㄹㅐㅁㅇㅣ_',
#   'ㅇㅗ_ㄹㅐ_ㄱㅏㅆㅇㅡ_ㅁㅕㄴ',
#   'ㅎㅏ_ㄴㅡㄴ',
#   'ㅂㅏ_ㄹㅏㅁㅇㅣ_ㄷㅏ_'],
#  ['ㅇㅣ_ㄱㅔ_', '8ㅈㅓㅁㄷㅐ_ㄴㅑ_', 'ㅊㅚ_ㄱㅡㄴ', '3ㄴㅕㄴㄱㅏㄴ', 'ㅇㅕㅇㅎㅘ_', 'ㅊㅚ_ㄱㅗ_ㄷㅏ_'],
#  ['ㅇㅗㅀㅇㅡㄴㅉㅗㄱㅎㅐ_ㅅㅓ_',
#   'ㅇㅗ_ㄹㅡㄴㅉㅗㄱㅇㅣㄴㄷㅔ_',
#   'ㅅㅣ_ㄱㅗㄹㄴㅗ_ㅇㅣㄴㄴㅔ_ㄷㅡㄹ',
#   'ㅂㅏㅇㅇㅓㄴㅇㅡ_ㄹㅗ_ㄴㅡㄴ',
#   'ㅂㅏ_ㄹㅡㄴㅉㅗㄱㅇㅣ_ㄹㅏ_ㄱㅗ_ㄷㅗ_',
#   'ㅎㅏㄴㄷㅏ_'],
#  ['ㅂㅗㄹㅁㅏㄴㅎㅏ_ㄴㅔ_ㅇㅛ_',
#   'ㅁㅜ_ㅇㅓㅅㅂㅗ_ㄷㅏ_',
#   'ㅈㅜㅇㄱㅏㄴㅇㅔ_',
#   'ㄹㅗ_ㅈㅡ_ㄱㅏ_',
#   'ㄴㅓ_ㅁㅜ_',
#   'ㅇㅣ_ㅃㅓ_',
#   'ㅇㅕㅇㅎㅘ_ㄴㅐ_ㄴㅐ_ㅅㅐㅇㄱㅏㄱㄴㅏ_ㄴㅔ_ㅇㅛ_',
#   'ㅍㅕㅇㅈㅓㅁㅇㅡㄴ',
#   '8ㅈㅓㅁㅈㅓㅇㄷㅗ_',
#   'ㄴㅗㅍㅇㅣ_ㄱㅣ_ㅇㅟ_ㅎㅐ_',
#   '10ㅈㅓㅁㅈㅜㅂㄴㅣ_ㄷㅏ_'],
#  ['ㅈㅐ_ㅁㅣ_ㅇㅣㅆㅇㅓㅆㄷㅏ_',
#   'ㅅㅗㄱㅍㅕㄴㅇㅣ_ㄷㅡㄴ',
#   'ㄹㅣ_ㅂㅜ_ㅌㅡ_ㄷㅡㄴ',
#   'ㄷㅏ_ㅅㅣ_',
#   'ㄴㅏ_ㅇㅗ_ㄱㅣㄹ',
#   'ㄱㅣ_ㄷㅐ_ㅎㅏㄴㄷㅏ_',
#   'ㄱㅡ_ㄹㅐ_ㅅㅓ_',
#   'ㅇㅓ_ㅂㅔㄴㅈㅕ_ㅅㅡ_3ㅇㅔ_ㅅㅓ_',
#   'ㅁㅏㄴㄴㅏ_ㄱㅣㄹ'],
#  ['ㄱㅏㅇㄴㅏㅁㅇㅐ_ㄷㅡㄹㅇㅡㄴ',
#   'ㅈㅗㅎㅇㅏ_ㅎㅏㄹㅁㅏㄴㅎㅏ_ㄷㅏ_',
#   'ㅇㅝㄴㅅㅜㅇㅇㅣ_ㄱㅏ_',
#   'ㄱㅏㅇㄴㅏㅁㅁㅏㄴ',
#   'ㅁㅣㄹㅇㅓ_ㅈㅜ_ㄱㅓ_ㄷㅓㅇ',
#   'ㅈㅣ_ㄱㅡㅁ',
#   'ㅈㅣㄴㅎㅐㅇㄷㅚ_ㄱㅗ_',
#   'ㅇㅣㅆㄴㅡㄴ',
#   'ㄱㅏㅇㄴㅏㅁ',
#   'ㄱㅐ_ㅂㅏㄹㅅㅏ_ㅇㅓㅂㅁㅏㄴ',
#   '5ㅈㅗ_',
#   'ㄱㅠ_ㅁㅗ_ㄷㅏ_',
#   'ㄱㅏㅇㅂㅜㄱㅇㅡㄴ',
#   'ㅇㅏ_ㅁㅜ_ㄱㅓㅅㄷㅗ_',
#   'ㅇㅏㄴㅎㅐ_ㅈㅜ_ㄴㅡㄴㄷㅔ_',
#   'ㅁㅣㄴㅈㅜ_ㄷㅏㅇ',
#   'ㅃㅗㅂㄴㅡㄴㄱㅔ_',
#   'ㅇㅜㅅㄱㅣㄴㄱㅓ_ㅈㅣ_'],
#  ['ㅈㅔ_ㄹㅔ_ㅁㅣ_',
#   'ㅅㅓㅁㅌㅓ_',
#   'ㅈㅣㄴㅉㅏ_',
#   'ㅈㅏㄹㅅㅐㅇㄱㅕㅆㅇㅓ_ㅇㅛ_',
#   'ㅍㅐㄴㅍㅐㄴㄱㅘㅇㅍㅐㄴㅇㅣ_ㅇㅔ_ㅇㅛ_',
#   'ㅍㅣ_ㅌㅓ_',
#   'ㅇㅕㅇㅎㅘ_',
#   'ㅈㅓㅇㅁㅏㄹ',
#   'ㅂㅘㅆㅇㅓ_ㅇㅛ_'],
#  ['ㅈㅜㄹㄱㅓ_ㄹㅣ_ㄱㅏ_',
#   'ㄷㅏ_ㅇㅣㄴㅇㅕㅇㅎㅘ_ㄱㅏㅁㄷㅗㅇㅇㅣ_ㄴㅏ_',
#   'ㅇㅜㅅㅇㅡㅁㄷㅗ_',
#   'ㅇㅓㅄㄷㅓ_ㄱㅜㄴㅇㅛ_ㅇㅗㄹㅎㅐ_ㅂㅗㄴㅇㅕㅇㅎㅘ_ㅈㅜㅇ',
#   'ㅈㅔㄹㅈㅐ_ㅁㅣ_ㅇㅓㅄㅇㅓㅆㄷㅓㄴㄱㅓ_ㄱㅏㅌㅇㅏ_ㅇㅛ_'],
#  ['ㅎㅡㅇㅎㅐㅇㅇㅣ_',
#   'ㄱㅓㅅㅇㅣ_',
#   'ㅇㅏ_ㅅㅟㅂㄷㅏ_',
#   'ㅅㅡ_ㅌㅗ_ㄹㅣ_ㄷㅗ_',
#   'ㅈㅗㅎㄱㅗ_',
#   'ㄱㅏㅁㄷㅗㅇㅈㅓㄱㅇㅣ_ㅇㅓㅆㄷㅏ_'],
#  ['ㅎㅕㄴㅅㅣㄹㅇㅡㄹ',
#   'ㄹㅣ_ㅇㅓㄹㅎㅏ_ㄱㅔ_',
#   'ㄷㅏㅁㅇㅏㅆㅈㅣ_ㅁㅏㄴ',
#   'ㄷㅏ_ㄹㅡㄴ',
#   'ㅎㅕㄴㅅㅣㄹㅇㅡㄹ',
#   'ㅇㅙ_ㄱㅗㄱㅎㅏ_ㄴㅡㄴ',
#   'ㅂㅜ_ㅂㅜㄴㄷㅗ_',
#   'ㅁㅏㄶㅇㅡㅁ'],
#  ['ㅇㅣ_ㅇㅕㄴㄱㅓㄹㅇㅢ_',
#   'ㄱㅟ_ㅇㅕ_ㅇㅜㄴ',
#   'ㅁㅗ_ㅅㅡㅂ89ㄴㅕㄴㅈㅏㄱㅇㅣ_ㄹㅏㄴㄱㅓㅅㅇㅡㄹ',
#   'ㄱㅏㅁㅇㅏㄴㅎㅏ_ㄱㅗ_',
#   'ㅂㅗ_ㅅㅣ_ㄱㅣㄹ'],
#  ['ㄷㅏ_ㄹㅡㄴ',
#   'ㅅㅏ_ㄹㅏㅁㄷㅡㄹㅇㅡㄴ',
#   'ㅂㅕㄹㄹㅗ_',
#   'ㅇㅏㄴㅈㅗㅎㅇㅏ_ㅎㅏ_ㄴㅡㄴ',
#   'ㅇㅕㅇㅎㅘ_ㄱㅏㅌㅈㅣ_ㅁㅏㄴ',
#   'ㄴㅐ_ㄱㅏ_ㅂㅗ_ㄱㅣ_ㅇㅔㄴ',
#   'ㅈㅓㅇㅁㅏㄹ',
#   'ㅈㅗㅎㅇㅡㄴㅇㅕㅇㅎㅘ_'],
#  ...]

# %% [markdown]
# ### FastText WordEmbedding

# %%
# fasttext 적용
from gensim.models import FastText
# 임베딩 차원: 50
# window size: 좌우 2단어 비속어는 좌우단어와 별로 연관이 없다고 판단...
# min_count: 최소 3번 등장한 단어들
# workers: -1 전부!!
# sg: skipgram이 더 성능이 좋기 때문
# min_n max_n : n-gram단위인데 한글자가 3글자라 최소 자모3개부터 최대 6개까지 ngram하기로 하였다. 1글자 ~ 2글자
# iter: 반복횟수 10
model = FastText(sentence_list, size=50, window=2, min_count=3, workers=4, sg=1, min_n=3, max_n=6)

# %%
# 총 71983개 단어로 vocab이 만들어졌다.
# len(model.wv)
len(model.wv.vocab)
# Out:
# 39674

# %%
# 연도 같은 경우는 연도와 비슷한 단어들이 나온다.
model.wv.most_similar(jamo_split("2018년"))
# Out:
# [('2016ㄴㅕㄴ', 0.9996845126152039),
#  ('2011ㄴㅕㄴ', 0.9996519684791565),
#  ('2019ㄴㅕㄴ', 0.9996345639228821),
#  ('2017ㄴㅕㄴ', 0.9987547993659973),
#  ('2007ㄴㅕㄴ', 0.9983842372894287),
#  ('2012ㄴㅕㄴ', 0.9982030987739563),
#  ('2001ㄴㅕㄴ', 0.9981569647789001),
#  ('1998ㄴㅕㄴ', 0.997917115688324),
#  ('2015ㄴㅕㄴ', 0.9978830814361572),
#  ('1995ㄴㅕㄴ', 0.9974294304847717)]

# %%
# 욕설 같은 경우는 비슷한 형태의 욕설이 나온다.
model.wv.most_similar(jamo_split("개새끼"))
# Out:
# [('ㅉㅏㅇㄲㅐ_ㅅㅐ_ㄲㅣ_', 0.9976158142089844),
#  ('ㅈㅟ_ㅅㅐ_ㄲㅣ_', 0.9963379502296448),
#  ('ㄱㅐ_ㅆㅣㅂㅅㅐ_ㄲㅣ_', 0.9960469603538513),
#  ('ㄴㅣ_ㅅㅐ_ㄲㅣ_', 0.9959099888801575),
#  ('ㅎㅗㅇㅇㅓ_ㅅㅐ_ㄲㅣ_', 0.9957291483879089),
#  ('ㅇㅐ_ㅅㅐ_ㄲㅣ_', 0.9955008625984192),
#  ('ㅆㅣㅂㅅㅐ_ㄲㅣ_', 0.9950689077377319),
#  ('ㅆㅣ_ㅂㅏㄹㅅㅐ_ㄲㅣ_', 0.9932981133460999),
#  ('ㅌㅡㄹㄸㅏㄱㅅㅐ_ㄲㅣ_', 0.9931620955467224),
#  ('ㅈㅓ_ㅅㅐ_ㄲㅣ_', 0.992912232875824)]

# %%
model.wv.most_similar(jamo_split("시발"))
# Out:
# [('ㅆㅣ_ㅂㅏㄹ', 0.9899727702140808),
#  ('ㅅㅣ_ㅂㅏㄹㄴㅗㅁ', 0.989078938961029),
#  ('ㅅㅣ_ㅂㅏㄹㄴㅕㄴ', 0.9871692657470703),
#  ('ㄱㅐ_ㅅㅣ_ㅂㅏㄹ', 0.9864257574081421),
#  ('ㄱㅐ_ㅆㅣ_ㅂㅏㄹ', 0.9848181009292603),
#  ('ㅆㅣ_ㅂㅏㄹㄴㅕㄴ', 0.9847974181175232),
#  ('ㅆㅣ_ㅂㅏㅇ', 0.9827421307563782),
#  ('ㅈㅓ_ㅆㅣ_ㅂㅏㄹㄴㅕㄴ', 0.9809641242027283),
#  ('ㅆㅣ_ㅂㅏㄹㄴㅗㅁ', 0.9803714752197266),
#  ('ㄱㅐ_ㅂㅏㄹ', 0.9798745512962341)]

# %%
# 시발점을 쳤더니.. 아주 관련없는 단어들이 뜬다. 뭐지?
model.wv.most_similar(jamo_split("시발점"))
# Out:
# [('ㅋㅣ_ㅇㅜ_ㄴㅑ_', 0.973244845867157),
#  ('ㅅㅣㄹㅎㅘ_ㄴㅑ_', 0.9723120927810669),
#  ('ㅍㅕㅇㅊㅏㅇ', 0.9705014228820801),
#  ('ㄱㅐ_ㅉㅓㅁ', 0.967711865901947),
#  ('ㅍㅕㅇㅊㅏㅇㅇㅗㄹㄹㅣㅁㅍㅣㄱ', 0.9660686254501343),
#  ('ㅊㅚ_ㅈㅓ_ㅇㅣㅁㄱㅡㅁ', 0.9642223715782166),
#  ('ㅇㅗㄴㄱㅓ_ㅇㅣㅁ', 0.9639502167701721),
#  ('ㄱㅐ_ㄱㅓ_ㅍㅜㅁ', 0.9633275270462036),
#  ('ㅊㅣ_ㅁㅐ_ㄴㅑ_', 0.9628894329071045),
#  ('ㄴㅣㄱㄴㅔ_ㅇㅣㅁ', 0.9620674848556519)]

# %%
model.wv.most_similar(jamo_split("새끼"))
# Out:
# [('ㅅㅣㅂㅅㅐ_ㄲㅣ_', 0.9882189631462097),
#  ('ㅈㅟ_ㅅㅐ_ㄲㅣ_', 0.987870991230011),
#  ('ㅁㅜㄴㅅㅐ_ㄲㅣ_', 0.9865599274635315),
#  ('ㅆㅣㅂㅅㅐ_ㄲㅣ_', 0.9855552911758423),
#  ('ㄱㅏㄴㅊㅓㅂㅅㅐ_ㄲㅣ_', 0.9846774935722351),
#  ('ㅇㅐ_ㅅㅐ_ㄲㅣ_', 0.9832937717437744),
#  ('ㅁㅜㄴㅈㅐ_ㅇㅏㅇㅅㅐ_ㄲㅣ_', 0.9817355275154114),
#  ('ㅂㅠㅇㅅㅣㄴㅅㅐ_ㄲㅣ_', 0.9787236452102661),
#  ('ㅈㅘ_ㅃㅏㄹㅅㅐ_ㄲㅣ_', 0.9779247045516968),
#  ('ㅉㅏㅇㄲㅐ_ㅅㅐ_ㄲㅣ_', 0.9778134226799011)]

# %%
model.wv.most_similar(jamo_split("존나"))
# Out:
# [('ㅈㅗㅈㄴㅏ_', 0.9585012197494507),
#  ('ㅈㅗ_ㅇㅗㄴㄴㅏ_', 0.9501444101333618),
#  ('ㅈㅗㅅㄴㅏ_', 0.9488620758056641),
#  ('ㅈㅗㄴㄴㅏ_ㅁㅏㄶㄴㅔ_', 0.9374814033508301),
#  ('ㄴㅗ_ㅁㅜ_', 0.9340406060218811),
#  ('ㅈㅗㄴㄴㅏ_ㅁㅏㄶㅇㅡㅁ', 0.9325830340385437),
#  ('ㅈㅗㅇㄴㅏ_', 0.9296299815177917),
#  ('ㅈㅗㄹㄹㅏ_', 0.9283559918403625),
#  ('ㅈㅓㄴㄴㅏ_', 0.923605740070343),
#  ('ㅈㅗㄷㄴㅏ_', 0.9190961122512817)]

# %%
model.wv.most_similar(jamo_split("지랄"))
# Out:
# [('ㅈㅣ_ㄹㅏㄹㅈㅗㅁ', 0.9956641793251038),
#  ('ㅈㅣ_ㄹㅏㄹㅂㅕㅇ', 0.9924980998039246),
#  ('ㅈㅣ_ㄹㅏㄹㅂㅏㄹㄱㅘㅇ', 0.987349271774292),
#  ('ㅈㅓ_ㅈㅣ_ㄹㅏㄹ', 0.9823774099349976),
#  ('ㅈㅣ_ㄹㅏㄹㅇㅣㅁ', 0.9756854176521301),
#  ('ㄱㅐ_ㅈㅣ_ㄹㅏㄹ', 0.9756192564964294),
#  ('ㅈㅣ_ㄹㅏㄹㅁㅏ_', 0.9707022905349731),
#  ('ㄷㅟ_ㅈㅣㄹ', 0.9671946167945862),
#  ('ㅈㅣ_ㄹㅏㄹㅎㅏㅁ', 0.9646296501159668),
#  ('ㄱㅐ_ㅈㅣ_ㄹㅏㄹㅂㅕㅇ', 0.9631133675575256)]

# %%
model.wv.most_similar(jamo_split("벌레"))
# Out:
# [('ㅎㅔ_ㅂㅓㄹㄹㅔ_', 0.9937088489532471),
#  ('ㅂㅏㄹㄹㅔ_', 0.9914841651916504),
#  ('ㅇㅝㄹㅅㅔ_', 0.9911943078041077),
#  ('ㄱㅏㅇㅈㅔ_', 0.9886162281036377),
#  ('ㅊㅜㄱㅈㅔ_', 0.9872520565986633),
#  ('ㅋㅏ_ㅍㅔ_', 0.986951470375061),
#  ('ㅎㅔ_ㅎㅔ_ㅎㅔ_', 0.9867541193962097),
#  ('ㅁㅕㄴㅈㅔ_', 0.9867350459098816),
#  ('ㅈㅠ_ㅅㅔ_ㅍㅔ_', 0.986309289932251),
#  ('ㅇㅜ_ㅂㅔ_', 0.9862683415412903)]

# %%
# # embedding model 저장
# model.save("./gensim_festtext.model")

# %% [markdown]
# ### 자모 분리하려고 했던 코드식들..

# %%
tmp = df.copy()

# %%
# !pip install jamo
# Out:
# Requirement already satisfied: jamo in /anaconda/envs/py38_default/lib/python3.8/site-packages (0.4.1)

# %%
# !pip install jamos-toolkit
# Out:
# Requirement already satisfied: jamos-toolkit in /anaconda/envs/py38_default/lib/python3.8/site-packages (1.7)

# %%
# jamo 패키지 사용해보기 예시

from jamo import h2j, j2hcj
sample_text = "가나다한글"
j2hcj(h2j(sample_text))
# Out:
# 'ㄱㅏㄴㅏㄷㅏㅎㅏㄴㄱㅡㄹ'

# %%
# # 자모 스플릿 하는 코드

# In[54]:


CHOSUNGS = [u'ㄱ',u'ㄲ',u'ㄴ',u'ㄷ',u'ㄸ',u'ㄹ',u'ㅁ',u'ㅂ',u'ㅃ',u'ㅅ',u'ㅆ',u'ㅇ',u'ㅈ',u'ㅉ',u'ㅊ',u'ㅋ',u'ㅌ',u'ㅍ',u'ㅎ']
JOONGSUNGS = [u'ㅏ',u'ㅐ',u'ㅑ',u'ㅒ',u'ㅓ',u'ㅔ',u'ㅕ',u'ㅖ',u'ㅗ',u'ㅘ',u'ㅙ',u'ㅚ',u'ㅛ',u'ㅜ',u'ㅝ',u'ㅞ',u'ㅟ',u'ㅠ',u'ㅡ',u'ㅢ',u'ㅣ']
JONGSUNGS = [u'_',u'ㄱ',u'ㄲ',u'ㄳ',u'ㄴ',u'ㄵ',u'ㄶ',u'ㄷ',u'ㄹ',u'ㄺ',u'ㄻ',u'ㄼ',u'ㄽ',u'ㄾ',u'ㄿ',u'ㅀ',u'ㅁ',u'ㅂ',u'ㅄ',u'ㅅ',u'ㅆ',u'ㅇ',u'ㅈ',u'ㅊ',u'ㅋ',u'ㅌ',u'ㅍ',u'ㅎ']
TOTAL = CHOSUNGS + JOONGSUNGS + JONGSUNGS

# 자모분리
def jamo_split(word, end_char="_"):
    
    result = []
    
    for char in word:
        
        character_code = ord(char)
        
        if 0xD7A3 < character_code or character_code < 0xAC00:
            result.append(char)
            continue

        chosung_index = int((((character_code - 0xAC00) / 28) / 21) % 19)
        joongsung_index = int(((character_code - 0xAC00) / 28) % 21)
        jongsung_index = int((character_code - 0xAC00) % 28)
        
        chosung = CHOSUNGS[chosung_index]
        joongsung = JOONGSUNGS[joongsung_index]
        jongsung = JONGSUNGS[jongsung_index]
        
        # 종성 범위 밖에 있는 것들은 end_char로 메꿔준다.
        if jongsung_index == 0:
            jongsung = end_char
        
        result.append(chosung)
        result.append(joongsung)
        result.append(jongsung)

    return "".join(result)


# 자모결합
def jamo_combine(word):

    result = ""
    index = 0
    
    while index < len(word):
    
        # 3개의 char를 보아 글자가 만들어지면 만들고 아니면 1개의 char만 추가한다.
        try:
            cho = CHOSUNGS.index(word[index]) * 21 * 28
            joong = JOONGSUNGS.index(word[index+1]) * 28
            jong = JONGSUNGS.index(word[index+2])

            result += chr(cho + joong + jong + 0xAC00) 
            index += 3

        except:
            result += word[index]
            index += 1
        
    return result

# %%
tmp.apply(to_be_divided)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 tmp.apply(to_be_divided)
#
# File /anaconda/envs/py38_default/lib/python3.8/site-packages/pandas/core/frame.py:8833, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8822 from pandas.core.apply import frame_apply
#    8824 op = frame_apply(
#    8825     self,
#    8826     func=func,
#    (...)
#    8831     kwargs=kwargs,
#    8832 )
# -> 8833 return op.apply().__finalize__(self, method="apply")
#
# File /anaconda/envs/py38_default/lib/python3.8/site-packages/pandas/core/apply.py:727, in FrameApply.apply(self)
#     724 elif self.raw:
#     725     return self.apply_raw()
# --> 727 return self.apply_standard()
#
# File /anaconda/envs/py38_default/lib/python3.8/site-packages/pandas/core/apply.py:851, in FrameApply.apply_standard(self)
#     850 def apply_standard(self):
# --> 851     results, res_index = self.apply_series_generator()
#     853     # wrap results
#     854     return self.wrap_results(results, res_index)
#
# File /anaconda/envs/py38_default/lib/python3.8/site-packages/pandas/core/apply.py:867, in FrameApply.apply_series_generator(self)
#     864 with option_context("mode.chained_assignment", None):
#     865     for i, v in enumerate(series_gen):
#     866         # ignore SettingWithCopy here in case the user mutates
# --> 867         results[i] = self.f(v)
#     868         if isinstance(results[i], ABCSeries):
#     869             # If we have a view on v, we need to make a copy because
#     870             #  series_generator will swap out the underlying data
#     871             results[i] = results[i].copy(deep=False)
#
# Input In [26], in to_be_divided(korean_word)
#      15 ####################################
#      16 r_lst = []
# ---> 17 for w in list(korean_word.strip()):
#      18     if '가'<=w<='힣':
#      19         ch1 = (ord(w) - ord('가'))//588
#
# File /anaconda/envs/py38_default/lib/python3.8/site-packages/pandas/core/generic.py:5583, in NDFrame.__getattr__(self, name)
#    5576 if (
#    5577     name not in self._internal_names_set
#    5578     and name not in self._metadata
#    5579     and name not in self._accessors
#    5580     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5581 ):
#    5582     return self[name]
# -> 5583 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'strip'

# %%
tmp.dtypes
# Out:
# 문장       object
# 혐오 여부     int64
# 글자수       int64
# dtype: object

# %%
# 한글 음절을 넘파이 배열로 바꾸기
# chr() 함수는 유니코드 번호를 받아서 해당하는 문자를 반환하는 함수 --> '가'에 해당하는 유니코드인 44032를 chr()에 넣으면 '가'가 반환
# ord() 함수는 문자를 받아서 대응하는 유니코드 번호를 반환 --> ord('가')를 치면 44032가 반환



syllables = np.array([chr(code) for code in range(44032, 55204)])
syllables = syllables.reshape(19, 21, 28)

# .... 이 패키지는 말을 직접 언급해줘야 하나보다 ㅜ

# %%
초성의 인덱스 : (문자 - 0xAC00) / 21 / 28
중성의 인덱스 : (문자 - 0xAC00 - (초성 인덱스 * 21 * 28)) / 28 
종성의 인덱스 : (문자 - 0xAC00 - (초성 인덱스 * 21 * 28) - (중성 인덱스 * 28))

# %%
# 한글 초·중·종성 분리 --> 일부러 오타를 내어 비속어를 변형한 경우에도 비속어를 판별 할 수 있도록 한다


def run(x):
    consonant_list = [ord(char) for char in "ㄱㄲㄴㄷㄸㄹㅁㅂㅃㅅㅆㅇㅈㅉㅊㅋㅌㅍㅎ"] #초성 유니코드 리스트
    choseong_list = [char for char in "ㄱㄲㄴㄷㄸㄹㅁㅂㅃㅅㅆㅇㅈㅉㅊㅋㅌㅍㅎ"] #초성리스트
    jungseong_list = [char for char in "ㅏㅐㅑㅒㅓㅔㅕㅖㅗㅘㅙㅚㅛㅜㅝㅞㅟㅠㅡㅢㅣ"] #중성 리스트
    jongseong_list = [char for char in "-ㄱㄲㄳㄴㄵㄶㄷㄹㄺㄻㄼㄽㄾㄿㅀㅁㅂㅄㅅㅆㅇㅈㅊㅋㅌㅍㅎ"] #종성 리스트
    result = []
    
    for char in x:
        if ord(char)==32: #띄어쓰기인 경우
            result.append(char)
            
        elif 48<=ord(char)<=57: #숫자인 경우
            result.append(char)
            
        elif consonant_list.count(char) == 0:
            character_code = ord(char)
            
        if (55203 < character_code or character_code < 44032):
            continue 
            
            code = 44032
            choseong_index = (character_code - code) // 21 // 28
            jungseong_index = (character_code - code - (choseong_index * 21 *  28)) // 28
            jongseong_index = character_code - code - (choseong_index * 21 * 28) - (jungseong_index * 28)
            result.append(choseong_list[choseong_index])
            result.append(jungseong_list[jungseong_index])
            result.append(jongseong_list[jongseong_index])
            
        else:
            choseong_index = consonant_list.index(ord(char))
            result.append(choseong_list[choseong_index])
            result.append("-")
            result.append("-")
        return "".join(result)

# %%
class JamosSeparator():
    def __init__(self, string):
        self.string = string
        self.result = []
        self.choseong_list = [char for char in "ㄱㄲㄴㄷㄸㄹㅁㅂㅃㅅㅆㅇㅈㅉㅊㅋㅌㅍㅎ"]
        self.jungseong_list = [char for char in "ㅏㅐㅑㅒㅓㅔㅕㅖㅗㅘㅙㅚㅛㅜㅝㅞㅟㅠㅡㅢㅣ"]
        self.jongseong_list = [char for char in " ㄱㄲㄳㄴㄵㄶㄷㄹㄺㄻㄼㄽㄾㄿㅀㅁㅂㅄㅅㅆㅇㅈㅊㅋㅌㅍㅎ"]

    def run(self):
        for char in self.string:

            character_code = ord(char)

            # Do not process unless it is in Hangul syllables range.
            if 0xD7A3 < character_code or character_code < 0xAC00:
                continue

            choseong_index = (character_code - 0xAC00) // 21 // 28
            jungseong_index = (character_code - 0xAC00 - (choseong_index * 21 * 28)) // 28
            jongseong_index = character_code - 0xAC00 - (choseong_index * 21 * 28) - (jungseong_index * 28)

            self.result.append(self.choseong_list[choseong_index])
            self.result.append(self.jungseong_list[jungseong_index])
            self.result.append(self.jongseong_list[jongseong_index])
            self.result.append("_")

    def get(self):
        return self.result

# %%
def to_be_divided(korean_word):
    """
    한글 단어를 입력받아서 초성/중성/종성을 구분하여 리턴해줍니다. 
    """
    ####################################
    # 초성 리스트. 00 ~ 18
    CHOSUNG_LIST = ['ㄱ', 'ㄲ', 'ㄴ', 'ㄷ', 'ㄸ', 'ㄹ', 'ㅁ', 'ㅂ', 'ㅃ',
                    'ㅅ', 'ㅆ', 'ㅇ', 'ㅈ', 'ㅉ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ']
    # 중성 리스트. 00 ~ 20
    JUNGSUNG_LIST = ['ㅏ', 'ㅐ', 'ㅑ', 'ㅒ', 'ㅓ', 'ㅔ', 'ㅕ', 'ㅖ', 'ㅗ',
                     'ㅘ', 'ㅙ', 'ㅚ', 'ㅛ', 'ㅜ', 'ㅝ', 'ㅞ', 'ㅟ', 'ㅠ', 'ㅡ', 'ㅢ', 'ㅣ']
    # 종성 리스트. 00 ~ 27 + 1(1개 없음)
    JONGSUNG_LIST = [' ', 'ㄱ', 'ㄲ', 'ㄳ', 'ㄴ', 'ㄵ', 'ㄶ', 'ㄷ', 'ㄹ', 'ㄺ', 'ㄻ', 'ㄼ',
                     'ㄽ', 'ㄾ', 'ㄿ', 'ㅀ', 'ㅁ', 'ㅂ', 'ㅄ', 'ㅅ', 'ㅆ', 'ㅇ', 'ㅈ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ']
    ####################################
    r_lst = []
    for w in list(korean_word.strip()):
        if '가'<=w<='힣':
            ch1 = (ord(w) - ord('가'))//588
            ch2 = ((ord(w) - ord('가')) - (588*ch1)) // 28
            ch3 = (ord(w) - ord('가')) - (588*ch1) - 28*ch2
            r_lst.append([CHOSUNG_LIST[ch1], JUNGSUNG_LIST[ch2], JONGSUNG_LIST[ch3]])
        else:
            r_lst.append([w])
    return r_lst

# %%
class JamoUtils:
    CHOSUNG = ['ㄱ', 'ㄲ', 'ㄴ', 'ㄷ', 'ㄸ', 'ㄹ', 'ㅁ', 'ㅂ', 'ㅃ', 'ㅅ',
                    'ㅆ', 'ㅇ', 'ㅈ', 'ㅉ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ']
    JUNGSUNG = ['ㅏ', 'ㅐ', 'ㅑ', 'ㅒ', 'ㅓ', 'ㅔ', 'ㅕ', 'ㅖ', 'ㅗ', 'ㅘ',
                    'ㅙ', 'ㅚ', 'ㅛ', 'ㅜ', 'ㅝ', 'ㅞ', 'ㅟ', 'ㅠ', 'ㅡ', 'ㅢ', 'ㅣ']
    JONGSUNG = ['', 'ㄱ', 'ㄲ', 'ᆪ', 'ᆫ', 'ᆬ', 'ᆭ', 'ㄷ',
                    'ㄹ', 'ᆰ', 'ᆱ', 'ᆲ', 'ᆳ', 'ᆴ', 'ᆵ', 'ᆶ', 'ㅁ', 'ㅂ', 'ᆹ', 'ᆺ', 'ᆻ', 'ᆼ',
                    'ᆽ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ']

#     def __init__(self):
#         raise NotImplementedError

    @staticmethod
    def split_one(target):
        code_point = ord(target)
        if 0xAC00 <= code_point <= 0xD79D:
            start_value = ord(target[0]) - 0xAC00
            jong = start_value % 28
            jung = int(((start_value - jong) / 28) % 21)
            cho = int((((start_value - jong) / 28) - jung) / 21)

            return JamoUtils.CHOSUNG[cho], JamoUtils.JUNGSUNG[jung], JamoUtils.JONGSUNG[jong]

        return target, '', ''

    @staticmethod
    def split(target):
        result = []
        for c in target:
            result.append(JamoUtils.split_one(c))

        return result

# %%
syllables = np.array([chr(code) for code in range(44032, 55204)])
syllables = syllables.reshape(19, 21, 28)

# %%
# 내가 바꾼 코드

def run(x):
    consonant_list = [ord(char) for char in "ㄱㄲㄴㄷㄸㄹㅁㅂㅃㅅㅆㅇㅈㅉㅊㅋㅌㅍㅎ"] #초성 유니코드 리스트
    choseong_list = [char for char in "ㄱㄲㄴㄷㄸㄹㅁㅂㅃㅅㅆㅇㅈㅉㅊㅋㅌㅍㅎ"] #초성리스트
    jungseong_list = [char for char in "ㅏㅐㅑㅒㅓㅔㅕㅖㅗㅘㅙㅚㅛㅜㅝㅞㅟㅠㅡㅢㅣ"] #중성 리스트
    jongseong_list = [char for char in "-ㄱㄲㄳㄴㄵㄶㄷㄹㄺㄻㄼㄽㄾㄿㅀㅁㅂㅄㅅㅆㅇㅈㅊㅋㅌㅍㅎ"] #종성 리스트
    result = []
    
    for char in x:
        if ord(char)==32: #띄어쓰기인 경우
            result.append(char)
            
        elif 48<=ord(char)<=57: #숫자인 경우
            result.append(char)
            
        elif consonant_list.count(char) == 0:
            character_code = ord(char)
            
        if 0xD7A3 < character_code or character_code < 0xAC00:
            continue
            
            choseong_index = (character_code - 0xAC00) // 21 // 28
            jungseong_index = (character_code - 0xAC00 - (choseong_index * 21 * 28)) // 28
            jongseong_index = character_code - 0xAC00 - (choseong_index * 21 * 28) - (jungseong_index * 28)
            
            result.append(choseong_list[choseong_index])
            result.append(jungseong_list[jungseong_index])
            result.append(jongseong_list[jongseong_index])
            
        else:
            choseong_index = consonant_list.index(ord(char))
            result.append(choseong_list[choseong_index])
            result.append("-")
            result.append("-")
        return "".join(result)

# %%
# 내가 고친것 2

def to_be_divided(korean_word):
    """
    한글 단어를 입력받아서 초성/중성/종성을 구분하여 리턴해줍니다. 
    """
    # 초성 유니코드 리스트
    consonant_list = [ord(char) for char in "ㄱㄲㄴㄷㄸㄹㅁㅂㅃㅅㅆㅇㅈㅉㅊㅋㅌㅍㅎ"] #초성 유니코드 리스트
    
    ####################################
    # 초성 리스트. 00 ~ 18
    choseong_list = ['ㄱ', 'ㄲ', 'ㄴ', 'ㄷ', 'ㄸ', 'ㄹ', 'ㅁ', 'ㅂ', 'ㅃ',
                    'ㅅ', 'ㅆ', 'ㅇ', 'ㅈ', 'ㅉ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ']
    # 중성 리스트. 00 ~ 20
    jungseong_list = ['ㅏ', 'ㅐ', 'ㅑ', 'ㅒ', 'ㅓ', 'ㅔ', 'ㅕ', 'ㅖ', 'ㅗ',
                     'ㅘ', 'ㅙ', 'ㅚ', 'ㅛ', 'ㅜ', 'ㅝ', 'ㅞ', 'ㅟ', 'ㅠ', 'ㅡ', 'ㅢ', 'ㅣ']
    # 종성 리스트. 00 ~ 27 + 1(1개 없음)
    jongseong_list = [' ', 'ㄱ', 'ㄲ', 'ㄳ', 'ㄴ', 'ㄵ', 'ㄶ', 'ㄷ', 'ㄹ', 'ㄺ', 'ㄻ', 'ㄼ',
                     'ㄽ', 'ㄾ', 'ㄿ', 'ㅀ', 'ㅁ', 'ㅂ', 'ㅄ', 'ㅅ', 'ㅆ', 'ㅇ', 'ㅈ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ']
    ####################################
    
    r_lst = []
    for char in list(korean_word.strip()):
        if '가'<=char<='힣':
            ch1 = (ord(char) - ord('가')) // 588
            ch2 = ((ord(char) - ord('가')) - (588 * ch1)) // 28
            ch3 = (ord(char) - ord('가')) - (588 * ch1) - ch2 * 28
            
            r_lst.append(choseong_list[ch1])
            r_lst.append(jungseong_list[ch2])
            r_lst.append(jongseong_list[ch3])
            
        else:
            choseong_index = consonant_list.index(ord(char))
            r_lst.append(choseong_list[choseong_index])
            r_lst.append("-")
            r_lst.append("-")
        return "".join(r_lst)

# %%
tmp7 = df.copy()

# %%
tmp7['문장'] = tmp7['문장'].apply(to_be_divided)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [169], in <cell line: 1>()
# ----> 1 tmp7['문장'] = tmp7['문장'].apply(to_be_divided)
#
# File /anaconda/envs/py38_default/lib/python3.8/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File /anaconda/envs/py38_default/lib/python3.8/site-packages/pandas/core/apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File /anaconda/envs/py38_default/lib/python3.8/site-packages/pandas/core/apply.py:1137, in SeriesApply.apply_standard(self)
#    1131         values = obj.astype(object)._values
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#    1146     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /anaconda/envs/py38_default/lib/python3.8/site-packages/pandas/_libs/lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# Input In [168], in to_be_divided(korean_word)
#      31     r_lst.append(jongseong_list[ch3])
#      33 else:
# ---> 34     choseong_index = consonant_list.index(ord(char))
#      35     r_lst.append(choseong_list[choseong_index])
#      36     r_lst.append("-")
#
# ValueError: 49 is not in list

# %%
ord(ss)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [165], in <cell line: 1>()
# ----> 1 ord(ss)
#
# NameError: name 'ss' is not defined

# %%
ord('정')
# Out:
# 51221

# %%
import re
from konlpy.tag import Okt
from jamo import h2j, j2hcj #초성/중성/종성분리


f = open("./stopwords-ko.txt", 'r', encoding="utf-8")
lines = f.readlines()
stopwords = []
for line in lines:
    line = line.replace('\n', '')
    stopwords.append(line)
f.close()   

class c_token:    
# 불용어 파일 불러오기 ==> 밖에서 지정해저야 오류 안생김                         
         
# 1 + 2 + stopword 그냥 다 합치기!
    def preprocessing(self, input_str):
    # 문자만 필터링
        re_string = re.compile('[^ A-Za-z0-9ㄱ-ㅣ가-힣]+')\
            .sub('', input_str)
    #형태소단위 
        okt = Okt() #선택이유는 논문 참고
        m_token = okt.morphs(re_string, stem=True)                                
    # 초중성분리  ==> 너무 작게 쪼개져서 주석처리!!
        # cm_token = []
        # for i in m_token:
        #     cm_token.append( j2hcj(h2j(i)) )
    # 불용어 처리
        result = [token for token in m_token if token not in stopwords]
        preprocessed_text= ' '.join(result)
        
        return preprocessed_text




# 1.문자만 필터링(이모티콘제외) & stopword(불용어)
    def filter_str(self, input_str):
        re_string = re.compile('[^ A-Za-z0-9ㄱ-ㅣ가-힣]+').sub('', input_str)
        return print(re_string)

# 2. 
# 2-1.텍스트를 형태소 단위로 나눔
# norm(정규화),stem(어간추출) 기본값 False
    def m_tokenize(self, input_str):
        okt = Okt()
        m_token = okt.morphs(self.filter_str(input_str))
        return print(m_token)
#2-2. 초성/중성/종성분리
    def c_tokenize(self, input_str):
        c_token = j2hcj(h2j(self.filter_str(input_str)))
        return list(c_token)

# 형태소단위분리 & 초중종성분리
    def cm_tokenize(self, input_str):
        okt = Okt()
        mm_token = okt.morphs(self.filter_str(input_str))
        cm_token = []
        for i in mm_token:
            cm_token.append(self.c_tokenize(i))
        return cm_token

# 4.텍스트에서 명사만 ==> 워드클라우드 
# join(형태소/품사 설명) 기본값 False
    def noun_tokenize(self, input_str):
        okt = Okt()
        token = okt.nouns(self.filter_str(input_str))
        return token

# 테스트하기
# cl = c_token()
# test = "제품은 좋을수도 있고 나쁠수도 있는데 그걸 고객들을 속이려고 하고 심지어 사과도 안하고 양심도없지"
# result = cl.preprocessing(test)
# print(result)
# # ==> 제품 좋다 있다 나쁘다 있다 그걸 고객 속이다 하다 심지어 사과 하고 양심 없다

# %%
import pandas as pd
ddf = pd.read_csv('./hate_speech_data_womad.csv', index_col=0)
ddf.shape
# Out:
# (2000, 2)

# %%
ddf
# Out:
#                               문장  혐오 여부
# 0                     지금 어디 계세요?      0
# 1                 한국 시간에 시계 맞췄어?      0
# 2               햄버거 두 개랑 콜라 주세요.      0
# 3               우리는 밤새 춤추고 노래했다.      0
# 4     무엇보다도, 스트레스를 줄이는 것이 중요합니다.      0
# ...                          ...    ...
# 1995           개독냄새 나노 ㅋㅋㅋ조팔 개오글      1
# 1996     사실상 페미니즘 영업사원 아니노 ㅋㅋㅋㅋ       1
# 1997                     ㅋㅋㅋㅋㅋㅋㅋ      1
# 1998         아버지는 아침 일찍 서울로 가셨다.      0
# 1999          과천에 있는 국립박물관 가 봤어?      0
#
# [2000 rows x 2 columns]
